# %% [markdown]
# ## Import Cleaned Data

# %% [markdown]
# __DataFrames:__
# df_model - df with all the features (independent festures + Target)
# x - df with all independent features
# y - df with dependent feature
# x_train - df with training data from x
# x_train_out - df with training data from x with outliers treatment applied
# x_test - df with test data from x
# x_test_out - df with test data from x with outliers treatment applied

# %%
import sys
sys.path.insert(1, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions')
sys.path.insert(2, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions\Functions')
sys.path.insert(3, r'..\..\..')


import Classification_CV as class_cv
import importCleanedData as importData
import importSubsets as subsets

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from tensorflow import keras

import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

#set preferences
sns.set_style('whitegrid')

#set color for graphs
#set color for graphs
palette = ["#e41a1c", "#377eb8", "#4daf4a", "#984ea3"]

# dir = r'C:\Users\rafae\Personal\Github\Asset-Allocation\Long-Term-CAPM\SampleData\Sample'
dir = r'..\..\..\SampleData\Sample'
df_model_skew,df_target = importData.importCleanedData(dir=dir,target='CAPM')


#split data
date = '2018-01-01'
#split data without transformation
x_train,x_train_out,x_test, x_test_out,y_train_dict ,y_test_dict, y_train,y_test = importData.splitData(df_model_skew, date) 

#set columns
ratio_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Ratio'))]
shares_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Share'))]
margin_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Margin'))]
turnover_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Turnover'))]
dividend_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('dividend'))]


components_pca, pca_components_test = importData.runPCA(x_train_out= x_train_out,x_test = x_test)


#import subsets
lasso_subset_0, lasso_subset_15, mi_subset_0, mi_subset_15, lgb_subset, corr_subset0, corr_subset15 = subsets.importSubsets()


subset_0, subset_15 = lasso_subset_0, lasso_subset_15
# Out:
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# CAPM
# Import data from: ..\..\..\SampleData\Sample\LongTerm-DataPreparation_Skew.csv
# Original CAPM is being used as Target
# Nr of rows:
# 72538
# The variance explained by each component is: [50.70262543 16.3180414  12.90616231  7.80559243  6.69692605  5.82614766
#   4.47015907  4.07836541  3.82626867  3.40508117  3.17395217  2.97398597
#   2.84255924  2.7491931   2.6284572   2.30920491  2.29580116  2.24676716
#   2.1685526   2.08344875  1.96058327  1.88331954  1.85945512  1.79999003
#   1.75303096  1.72999438  1.67342676  1.57892838  1.52235707  1.48115797
#   1.44613583  1.42029951  1.39091026  1.35520895  1.32448072  1.29342424
#   1.27059382  1.25051426  1.2247642   1.18608517  1.17810508  1.15156743
#   1.14454538  1.12935887  1.10669478  1.0815426   1.07222534  1.05458183
#   1.03848544  1.01988948  1.01877496  0.99533768  0.98807987]
# The total variance explained by the components is: 0.7618344466001962

# %% [markdown]
# # Modelling Stage - Target 15

# %% [markdown]
# # Compare Model Perfomance

# %%
def gen_NNClassification (x, y, hidden_layer_sizes,activation_list, dropout,optimizer,loss = 'BinaryCrossentropy', metrics = ['AUC'],batch_size=180,epochs=10,validation_split = 0.25, class_weight = None, output_bias =None ):
    
    print('Neural Network Parameters:')
    print(f'Optimizer: {optimizer}')
    print(f'Loss: {loss}')
    print(f'Hidden Layer tructure: {hidden_layer_sizes}')
    print(f'Acivation Functions: {activation_list}')
    print(f'Dropout: {dropout}')
    print(f'Class Weight: {class_weight}')
    print(f'Output Bias: {output_bias}')
    
    #import libraries
    from scikeras.wrappers import KerasClassifier, KerasRegressor
    from tensorflow import keras
    reset_random_seeds()
    #get nr features in
    n_features_in_ = x.shape[1]
    n_classes_ = len(y.unique())
    
    if output_bias is not None:
        output_bias =keras.initializers.Constant(output_bias)
    
    #set keras model
    model = keras.models.Sequential()
    
    #define input shape
    # model.add(keras.layers.Input(shape=(n_features_in_,)))
    model.add(keras.layers.Dense(
          4, activation='relu',
          input_shape=(n_features_in_,)))
    
    #define hidden layers
    for hidden_layer_size, activation_ in zip(hidden_layer_sizes,
                                              activation_list):
        
        model.add(keras.layers.Dense(hidden_layer_size,
                                     activation=activation_))
        
        model.add(keras.layers.Dropout(dropout))
    
    #define output layer
    model.add(keras.layers.Dense(1,
                                 activation="sigmoid",
                                 bias_initializer=output_bias))
    
    #compile model 
    model.compile(optimizer=optimizer,
                  loss=loss,
                  metrics=metrics,
                  )
    
    #transform to SKlearn format
    NNmodel = KerasClassifier( model=model,
                            batch_size= batch_size,
                            epochs= epochs,
                            class_weight=class_weight,
                            validation_split=validation_split,
                            loss = loss)

    return NNmodel

metrics = ['AUC','Recall','Precision']


def reset_random_seeds():
    import random
    from numpy.random import seed
    import os
    import numpy as np 
    from tensorflow import random as r
    
    seed_nr = 0
    os.environ['PYTHONHASHSEED']=str(seed_nr)
    r.set_seed(seed_nr)
    np.random.seed(seed_nr)

from numpy.random import seed
from tensorflow import keras 


reset_random_seeds()
optimizer = keras.optimizers.RMSprop(learning_rate=0.001)
loss_ = keras.losses.BinaryCrossentropy()
NNmodel = gen_NNClassification(x_train_out[subset_15], 
                                 y_train_dict['Target_0.15'],
                                 hidden_layer_sizes = (50,),
                                 activation_list = ['relu'],
                                 dropout = 0.3,
                                 optimizer =optimizer ,
                                 loss = loss_, 
                                 metrics = metrics,
                                 batch_size=64,
                                 epochs=15,
                                 validation_split = 0.25,
                                 class_weight = 'balanced',
                                 output_bias =None )



def roc_curve (models,names,X_train,y_train, X_val, y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        list with model names and a list of models 
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays ROC curve of the respective models 
    
    '''''''''''''''
    
    names= names
    from sklearn.metrics import roc_curve
    sns.set_theme(style = 'whitegrid')
    plt.figure(figsize = (10,10))
    for i, names ,in zip(models,names):
        # i.fit(X_train,y_train)
        thresh_dict = {}
        prob_model = i.predict_proba(X_val)
        
        fpr_DT_ent, tpr_DT_ent, thresholds_DT_ent = roc_curve(y_val, prob_model[:,1])
        plt.plot(fpr_DT_ent, tpr_DT_ent, label=f"ROC Curve {names}" , )
        
        plt.xlabel('FPR')
        plt.ylabel('TPR')
        plt.legend()
        
    
    
def precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted inside the function 
    
    '''''''''''''''
    names=names
    model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()
    
    
def fitted_precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted outside the function 
    
    '''''''''''''''
    names=names
    #model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()

def assessTest (x_test, y_test, model):
    
    col = x_test.columns[4]
    index__ = x_test.reset_index()[['symbol','fillingDate',col]].set_index(['symbol','fillingDate'])
    target_copy = df_target.copy()
    target_copy['fillingDate'] = target_copy['fillingDate'].astype(str)
    target_copy = target_copy.drop_duplicates(['symbol','fillingDate']).set_index(['symbol','fillingDate'])
    target_copy = target_copy.loc[target_copy.index.isin(index__.index)]
    
    assess_test_dict = dict()
    pred_test = model.predict(x_test)
    assess_test = pd.DataFrame(index = y_test.index)
    assess_test['Prediction'] = pred_test
    assess_test['Target'] = y_test
#     assess_test['returns'] = df_model.loc[df_model.index.isin(y_test.index),'futReturns']
    assess_test['excReturns'] = target_copy.loc[target_copy.index.isin(index__.index),'futAlpha']

    avg_returns = assess_test.groupby('Prediction').mean()[['excReturns']]


    from sklearn.metrics import roc_auc_score, precision_score, recall_score,accuracy_score
    auc  = roc_auc_score(assess_test['Target'],assess_test['Prediction'] )
    precision = precision_score(assess_test['Target'],assess_test['Prediction'] )
    recall =  recall_score(assess_test['Target'],assess_test['Prediction'] )
    acc =  accuracy_score(assess_test['Target'],assess_test['Prediction'] )
    
    assess_test_dict['accuracy'] = acc
    assess_test_dict['auc'] = auc
    assess_test_dict['precision'] = precision
    assess_test_dict['recall'] = recall
    return(assess_test_dict,assess_test)
# Out:
# Neural Network Parameters:
# Optimizer: <keras.optimizers.optimizer_experimental.rmsprop.RMSprop object at 0x000002E6351D8FA0>
# Loss: <keras.losses.BinaryCrossentropy object at 0x000002E67EEC6790>
# Hidden Layer tructure: (50,)
# Acivation Functions: ['relu']
# Dropout: 0.3
# Class Weight: balanced
# Output Bias: None

# %% [markdown]
# ## Target 0.15

# %% [markdown]
# Perfomance is compared using using standardized data since Neural Networks and Logistic Regressions are highly affected by data scalling.

# %%
def assessModels (x_train,y_train,x_test,y_test,model_list, model_names,):
    new_model_list = []
    full_assess = pd.DataFrame()
    full_assess_test = pd.DataFrame()
    test_assess_list = []
    #iterate over the models and perform CV 
    for model, name in zip(model_list, model_names):
        assess = class_cv.validateModel(x_train,
                                        y_train,
                                        model=model ,
                                        scaler=True ,
                                        over_sampling=False,
                                        predictions=False,
                                        cv_type='stratKfold',
                                        scaler_type='stand',
                                        train_size=10,
                                        test_size=1,
                                        gap=0)
        
        #store scores
        assess_df = assess['scores']
        assess_df['model'] = name
        
        full_assess = pd.concat([full_assess,
                                assess_df],
                                axis=0)
        
        #store model 
        model = assess['model']
        new_model_list.append(model)
        
        if name =='LightGB':
            features = model.feature_name_
    
        elif name =='Keras_NN':
            features = features
        
        else:
            features = model.feature_names_in_
            
        
        scaler = assess['scaler']
        scale_features = scaler.get_feature_names_out()
    
        rest_ft =[]
        for ft in features:
            if ft not in scale_features:
                rest_ft.append(ft)
    
    
    
        # fit scaler on test set 
        X_test = pd.DataFrame(scaler.transform(x_test[scale_features]), 
                            index = x_test.index, 
                            columns = scale_features)
        
        X_test = pd.concat([X_test, x_test[rest_ft]],axis=1)
            
        
        X_test = X_test[features]
        
        assess_test_dict, assess_test_df = assessTest(X_test,
                                                    y_test,
                                                    model)
        assess_test_dict['model'] = name
        assess_test_df['model'] = name
        
        full_assess_test = pd.concat([full_assess_test,
                                assess_test_df],
                                axis=0)
        test_assess_list.append(assess_test_dict)
        
    test_assess_df = pd.DataFrame.from_records(test_assess_list)
    
    return(full_assess,test_assess_df,new_model_list )

# %%
#set models
dt_model = DecisionTreeClassifier(class_weight='balanced',
                                  max_depth=6,
                                  max_features=9,
                                  min_samples_leaf=10,
                                  random_state=0)


lgb_model = lgb.LGBMClassifier(boosting_type='dart',
                               class_weight='balanced',
                               learning_rate=0.2,
                               max_depth=2, 
                               n_estimators=50,
                               random_state=0)

lr_model = LogisticRegression(class_weight='balanced', penalty=None, random_state=0,
                   solver='newton-cholesky')



model_list = [lr_model,dt_model, lgb_model,NNmodel]
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras_NN']

full_assess,test_assess_df,new_model_list  = assessModels(x_train_out[subset_15],y_train_dict['Target_0.15'],
             x_test[subset_15],y_test_dict['Target_0.15'],model_list[-2:], model_names[-2:])
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.622822
# f1_train           0.331861
# recall_train       0.659450
# precision_train    0.221723
# auc_train          0.638104
# accuracy_test      0.617824
# f1_test            0.325915
# recall_test        0.637891
# precision_test     0.223216
# auc_test           0.626200
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# Epoch 1/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.7220 - auc: 0.5535 - recall: 0.7808 - precision: 0.1644WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 6s 10ms/step - loss: 0.7204 - auc: 0.5559 - recall: 0.7804 - precision: 0.1649 - val_loss: 0.6255 - val_auc: 0.6454 - val_recall: 0.7003 - val_precision: 0.1667
# Epoch 2/15
# 542/555 [============================>.] - ETA: 0s - loss: 0.6927 - auc: 0.6074 - recall: 0.7495 - precision: 0.1828WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6923 - auc: 0.6071 - recall: 0.7481 - precision: 0.1824 - val_loss: 0.6156 - val_auc: 0.6591 - val_recall: 0.6606 - val_precision: 0.1796
# Epoch 3/15
# 537/555 [============================>.] - ETA: 0s - loss: 0.6834 - auc: 0.6285 - recall: 0.7390 - precision: 0.1924WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6835 - auc: 0.6291 - recall: 0.7388 - precision: 0.1925 - val_loss: 0.6105 - val_auc: 0.6665 - val_recall: 0.6307 - val_precision: 0.1843
# Epoch 4/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6778 - auc: 0.6428 - recall: 0.7200 - precision: 0.1975WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6778 - auc: 0.6428 - recall: 0.7200 - precision: 0.1975 - val_loss: 0.6096 - val_auc: 0.6695 - val_recall: 0.6516 - val_precision: 0.1827
# Epoch 5/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6753 - auc: 0.6505 - recall: 0.7182 - precision: 0.2008WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6744 - auc: 0.6508 - recall: 0.7187 - precision: 0.2005 - val_loss: 0.6069 - val_auc: 0.6716 - val_recall: 0.5591 - val_precision: 0.2018
# Epoch 6/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6717 - auc: 0.6546 - recall: 0.7099 - precision: 0.2026WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6719 - auc: 0.6551 - recall: 0.7110 - precision: 0.2030 - val_loss: 0.6069 - val_auc: 0.6697 - val_recall: 0.5841 - val_precision: 0.1990
# Epoch 7/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6704 - auc: 0.6557 - recall: 0.7013 - precision: 0.2025WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6697 - auc: 0.6579 - recall: 0.7060 - precision: 0.2033 - val_loss: 0.6056 - val_auc: 0.6719 - val_recall: 0.5556 - val_precision: 0.2009
# Epoch 8/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6685 - auc: 0.6593 - recall: 0.7025 - precision: 0.2059WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6687 - auc: 0.6594 - recall: 0.7017 - precision: 0.2060 - val_loss: 0.6060 - val_auc: 0.6726 - val_recall: 0.6307 - val_precision: 0.1904
# Epoch 9/15
# 527/555 [===========================>..] - ETA: 0s - loss: 0.6650 - auc: 0.6631 - recall: 0.7052 - precision: 0.2079WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6665 - auc: 0.6623 - recall: 0.7062 - precision: 0.2079 - val_loss: 0.6062 - val_auc: 0.6718 - val_recall: 0.6280 - val_precision: 0.1914
# Epoch 10/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6659 - auc: 0.6625 - recall: 0.7030 - precision: 0.2069WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6649 - auc: 0.6635 - recall: 0.7043 - precision: 0.2069 - val_loss: 0.6068 - val_auc: 0.6717 - val_recall: 0.5021 - val_precision: 0.2060
# Epoch 11/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6651 - auc: 0.6651 - recall: 0.7056 - precision: 0.2117WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6649 - auc: 0.6645 - recall: 0.7041 - precision: 0.2113 - val_loss: 0.6071 - val_auc: 0.6739 - val_recall: 0.5459 - val_precision: 0.2036
# Epoch 12/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6649 - auc: 0.6650 - recall: 0.7071 - precision: 0.2093WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6654 - auc: 0.6648 - recall: 0.7060 - precision: 0.2095 - val_loss: 0.6058 - val_auc: 0.6721 - val_recall: 0.5515 - val_precision: 0.2042
# Epoch 13/15
# 536/555 [===========================>..] - ETA: 0s - loss: 0.6639 - auc: 0.6660 - recall: 0.7026 - precision: 0.2088WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6638 - auc: 0.6662 - recall: 0.7026 - precision: 0.2090 - val_loss: 0.6055 - val_auc: 0.6721 - val_recall: 0.5278 - val_precision: 0.2059
# Epoch 14/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6619 - auc: 0.6687 - recall: 0.6979 - precision: 0.2098WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6621 - auc: 0.6687 - recall: 0.6987 - precision: 0.2101 - val_loss: 0.6047 - val_auc: 0.6739 - val_recall: 0.5466 - val_precision: 0.2023
# Epoch 15/15
# 521/555 [===========================>..] - ETA: 0s - loss: 0.6615 - auc: 0.6698 - recall: 0.7039 - precision: 0.2132WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6626 - auc: 0.6682 - recall: 0.7017 - precision: 0.2127 - val_loss: 0.6044 - val_auc: 0.6742 - val_recall: 0.5904 - val_precision: 0.1964
# 740/740 [==============================] - 1s 1ms/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6669 - auc: 0.6600 - recall: 0.7035 - precision: 0.2064WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 6s 10ms/step - loss: 0.6671 - auc: 0.6598 - recall: 0.7038 - precision: 0.2066 - val_loss: 0.6053 - val_auc: 0.6739 - val_recall: 0.5487 - val_precision: 0.2029
# Epoch 2/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6661 - auc: 0.6609 - recall: 0.7045 - precision: 0.2072WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6660 - auc: 0.6607 - recall: 0.7043 - precision: 0.2067 - val_loss: 0.6048 - val_auc: 0.6738 - val_recall: 0.5410 - val_precision: 0.2017
# Epoch 3/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6660 - auc: 0.6617 - recall: 0.6992 - precision: 0.2076WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6653 - auc: 0.6625 - recall: 0.6996 - precision: 0.2079 - val_loss: 0.6057 - val_auc: 0.6740 - val_recall: 0.5334 - val_precision: 0.2026
# Epoch 4/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6655 - auc: 0.6615 - recall: 0.7059 - precision: 0.2073WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6658 - auc: 0.6617 - recall: 0.7066 - precision: 0.2077 - val_loss: 0.6036 - val_auc: 0.6746 - val_recall: 0.5793 - val_precision: 0.1953
# Epoch 5/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6665 - auc: 0.6612 - recall: 0.7077 - precision: 0.2068WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6651 - auc: 0.6620 - recall: 0.7083 - precision: 0.2067 - val_loss: 0.6061 - val_auc: 0.6751 - val_recall: 0.4979 - val_precision: 0.2103
# Epoch 6/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6639 - auc: 0.6648 - recall: 0.7011 - precision: 0.2092WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6636 - auc: 0.6649 - recall: 0.7023 - precision: 0.2088 - val_loss: 0.6048 - val_auc: 0.6725 - val_recall: 0.5174 - val_precision: 0.2061
# Epoch 7/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6654 - auc: 0.6624 - recall: 0.6950 - precision: 0.2066WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6644 - auc: 0.6635 - recall: 0.6979 - precision: 0.2069 - val_loss: 0.6060 - val_auc: 0.6743 - val_recall: 0.5076 - val_precision: 0.2079
# Epoch 8/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6647 - auc: 0.6627 - recall: 0.6997 - precision: 0.2081WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6651 - auc: 0.6633 - recall: 0.6998 - precision: 0.2091 - val_loss: 0.6041 - val_auc: 0.6739 - val_recall: 0.5911 - val_precision: 0.1940
# Epoch 9/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6639 - auc: 0.6643 - recall: 0.7058 - precision: 0.2093WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6639 - auc: 0.6642 - recall: 0.7058 - precision: 0.2093 - val_loss: 0.6043 - val_auc: 0.6734 - val_recall: 0.6001 - val_precision: 0.1902
# Epoch 10/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6644 - auc: 0.6639 - recall: 0.7089 - precision: 0.2074WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6644 - auc: 0.6641 - recall: 0.7093 - precision: 0.2076 - val_loss: 0.6069 - val_auc: 0.6744 - val_recall: 0.5021 - val_precision: 0.2108
# Epoch 11/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6629 - auc: 0.6674 - recall: 0.7014 - precision: 0.2114WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6629 - auc: 0.6667 - recall: 0.7005 - precision: 0.2108 - val_loss: 0.6063 - val_auc: 0.6736 - val_recall: 0.5459 - val_precision: 0.1990
# Epoch 12/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6643 - auc: 0.6637 - recall: 0.7067 - precision: 0.2087WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6640 - auc: 0.6647 - recall: 0.7083 - precision: 0.2095 - val_loss: 0.6062 - val_auc: 0.6728 - val_recall: 0.5236 - val_precision: 0.2021
# Epoch 13/15
# 541/555 [============================>.] - ETA: 0s - loss: 0.6619 - auc: 0.6658 - recall: 0.7024 - precision: 0.2079WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6625 - auc: 0.6662 - recall: 0.7021 - precision: 0.2085 - val_loss: 0.6055 - val_auc: 0.6724 - val_recall: 0.5153 - val_precision: 0.2044
# Epoch 14/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6623 - auc: 0.6660 - recall: 0.7001 - precision: 0.2086WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6630 - auc: 0.6663 - recall: 0.7004 - precision: 0.2094 - val_loss: 0.6044 - val_auc: 0.6746 - val_recall: 0.5271 - val_precision: 0.2031
# Epoch 15/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6631 - auc: 0.6660 - recall: 0.7114 - precision: 0.2108WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6635 - auc: 0.6652 - recall: 0.7110 - precision: 0.2104 - val_loss: 0.6040 - val_auc: 0.6735 - val_recall: 0.5682 - val_precision: 0.1936
# 740/740 [==============================] - 1s 1ms/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6546 - auc: 0.6814 - recall: 0.7140 - precision: 0.2174WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 6s 10ms/step - loss: 0.6555 - auc: 0.6810 - recall: 0.7140 - precision: 0.2180 - val_loss: 0.6077 - val_auc: 0.6736 - val_recall: 0.5299 - val_precision: 0.2027
# Epoch 2/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6540 - auc: 0.6827 - recall: 0.7178 - precision: 0.2200WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6540 - auc: 0.6827 - recall: 0.7178 - precision: 0.2199 - val_loss: 0.6061 - val_auc: 0.6731 - val_recall: 0.5376 - val_precision: 0.1993
# Epoch 3/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6554 - auc: 0.6823 - recall: 0.7135 - precision: 0.2189WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6544 - auc: 0.6835 - recall: 0.7146 - precision: 0.2193 - val_loss: 0.6111 - val_auc: 0.6738 - val_recall: 0.4924 - val_precision: 0.2062
# Epoch 4/15
# 549/555 [============================>.] - ETA: 0s - loss: 0.6544 - auc: 0.6824 - recall: 0.7114 - precision: 0.2191WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6546 - auc: 0.6822 - recall: 0.7115 - precision: 0.2192 - val_loss: 0.6049 - val_auc: 0.6737 - val_recall: 0.5236 - val_precision: 0.1984
# Epoch 5/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6548 - auc: 0.6829 - recall: 0.7117 - precision: 0.2191WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6539 - auc: 0.6831 - recall: 0.7127 - precision: 0.2188 - val_loss: 0.6081 - val_auc: 0.6741 - val_recall: 0.5076 - val_precision: 0.2063
# Epoch 6/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6531 - auc: 0.6835 - recall: 0.7132 - precision: 0.2197WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6535 - auc: 0.6840 - recall: 0.7147 - precision: 0.2203 - val_loss: 0.6066 - val_auc: 0.6729 - val_recall: 0.5132 - val_precision: 0.2011
# Epoch 7/15
# 520/555 [===========================>..] - ETA: 0s - loss: 0.6522 - auc: 0.6850 - recall: 0.7113 - precision: 0.2208WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6522 - auc: 0.6852 - recall: 0.7127 - precision: 0.2209 - val_loss: 0.6065 - val_auc: 0.6743 - val_recall: 0.5216 - val_precision: 0.2023
# Epoch 8/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6518 - auc: 0.6854 - recall: 0.7140 - precision: 0.2211WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6527 - auc: 0.6854 - recall: 0.7155 - precision: 0.2216 - val_loss: 0.6040 - val_auc: 0.6740 - val_recall: 0.5682 - val_precision: 0.1952
# Epoch 9/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6532 - auc: 0.6846 - recall: 0.7137 - precision: 0.2211WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6541 - auc: 0.6844 - recall: 0.7130 - precision: 0.2212 - val_loss: 0.6046 - val_auc: 0.6747 - val_recall: 0.5459 - val_precision: 0.1987
# Epoch 10/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6543 - auc: 0.6830 - recall: 0.7146 - precision: 0.2187WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6525 - auc: 0.6851 - recall: 0.7168 - precision: 0.2195 - val_loss: 0.6174 - val_auc: 0.6751 - val_recall: 0.4520 - val_precision: 0.2167
# Epoch 11/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6541 - auc: 0.6849 - recall: 0.7100 - precision: 0.2216WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6537 - auc: 0.6846 - recall: 0.7093 - precision: 0.2214 - val_loss: 0.6091 - val_auc: 0.6748 - val_recall: 0.5132 - val_precision: 0.2052
# Epoch 12/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6521 - auc: 0.6860 - recall: 0.7163 - precision: 0.2219WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6524 - auc: 0.6857 - recall: 0.7161 - precision: 0.2218 - val_loss: 0.6046 - val_auc: 0.6741 - val_recall: 0.5250 - val_precision: 0.2025
# Epoch 13/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6527 - auc: 0.6848 - recall: 0.7161 - precision: 0.2220WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6527 - auc: 0.6848 - recall: 0.7161 - precision: 0.2220 - val_loss: 0.6085 - val_auc: 0.6755 - val_recall: 0.4903 - val_precision: 0.2102
# Epoch 14/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6530 - auc: 0.6848 - recall: 0.7139 - precision: 0.2215WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6528 - auc: 0.6849 - recall: 0.7140 - precision: 0.2215 - val_loss: 0.6048 - val_auc: 0.6753 - val_recall: 0.5320 - val_precision: 0.2030
# Epoch 15/15
# 542/555 [============================>.] - ETA: 0s - loss: 0.6527 - auc: 0.6862 - recall: 0.7151 - precision: 0.2213WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6525 - auc: 0.6858 - recall: 0.7138 - precision: 0.2207 - val_loss: 0.6084 - val_auc: 0.6760 - val_recall: 0.5125 - val_precision: 0.2042
# 740/740 [==============================] - 1s 1ms/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6544 - auc: 0.6832 - recall: 0.7229 - precision: 0.2210WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 7s 12ms/step - loss: 0.6535 - auc: 0.6848 - recall: 0.7245 - precision: 0.2213 - val_loss: 0.6116 - val_auc: 0.6765 - val_recall: 0.5076 - val_precision: 0.2109
# Epoch 2/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6526 - auc: 0.6855 - recall: 0.7122 - precision: 0.2207WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6523 - auc: 0.6860 - recall: 0.7134 - precision: 0.2209 - val_loss: 0.6069 - val_auc: 0.6761 - val_recall: 0.5473 - val_precision: 0.2003
# Epoch 3/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6523 - auc: 0.6866 - recall: 0.7217 - precision: 0.2218WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6515 - auc: 0.6869 - recall: 0.7215 - precision: 0.2217 - val_loss: 0.6067 - val_auc: 0.6760 - val_recall: 0.5320 - val_precision: 0.2056
# Epoch 4/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6516 - auc: 0.6874 - recall: 0.7189 - precision: 0.2235WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6519 - auc: 0.6872 - recall: 0.7192 - precision: 0.2237 - val_loss: 0.6037 - val_auc: 0.6761 - val_recall: 0.6015 - val_precision: 0.1915
# Epoch 5/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6530 - auc: 0.6868 - recall: 0.7254 - precision: 0.2228WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6519 - auc: 0.6866 - recall: 0.7259 - precision: 0.2220 - val_loss: 0.6087 - val_auc: 0.6758 - val_recall: 0.5209 - val_precision: 0.2053
# Epoch 6/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6524 - auc: 0.6868 - recall: 0.7232 - precision: 0.2218WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6524 - auc: 0.6870 - recall: 0.7245 - precision: 0.2217 - val_loss: 0.6067 - val_auc: 0.6750 - val_recall: 0.5389 - val_precision: 0.2018
# Epoch 7/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6531 - auc: 0.6868 - recall: 0.7285 - precision: 0.2232WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6515 - auc: 0.6871 - recall: 0.7291 - precision: 0.2225 - val_loss: 0.6089 - val_auc: 0.6757 - val_recall: 0.5083 - val_precision: 0.2111
# Epoch 8/15
# 536/555 [===========================>..] - ETA: 0s - loss: 0.6500 - auc: 0.6876 - recall: 0.7206 - precision: 0.2222WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6508 - auc: 0.6880 - recall: 0.7206 - precision: 0.2231 - val_loss: 0.6043 - val_auc: 0.6756 - val_recall: 0.5821 - val_precision: 0.1928
# Epoch 9/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6519 - auc: 0.6868 - recall: 0.7244 - precision: 0.2216WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6524 - auc: 0.6869 - recall: 0.7240 - precision: 0.2221 - val_loss: 0.6088 - val_auc: 0.6748 - val_recall: 0.5556 - val_precision: 0.1976
# Epoch 10/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6520 - auc: 0.6860 - recall: 0.7259 - precision: 0.2216WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6516 - auc: 0.6867 - recall: 0.7270 - precision: 0.2218 - val_loss: 0.6165 - val_auc: 0.6755 - val_recall: 0.5014 - val_precision: 0.2086
# Epoch 11/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6524 - auc: 0.6873 - recall: 0.7216 - precision: 0.2223WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6522 - auc: 0.6869 - recall: 0.7211 - precision: 0.2218 - val_loss: 0.6070 - val_auc: 0.6749 - val_recall: 0.5529 - val_precision: 0.1969
# Epoch 12/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6520 - auc: 0.6875 - recall: 0.7287 - precision: 0.2230WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6520 - auc: 0.6873 - recall: 0.7285 - precision: 0.2227 - val_loss: 0.6047 - val_auc: 0.6749 - val_recall: 0.5369 - val_precision: 0.1990
# Epoch 13/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6514 - auc: 0.6877 - recall: 0.7243 - precision: 0.2215WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6515 - auc: 0.6875 - recall: 0.7240 - precision: 0.2214 - val_loss: 0.6081 - val_auc: 0.6748 - val_recall: 0.5236 - val_precision: 0.2056
# Epoch 14/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6510 - auc: 0.6866 - recall: 0.7254 - precision: 0.2228WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6526 - auc: 0.6860 - recall: 0.7259 - precision: 0.2230 - val_loss: 0.6045 - val_auc: 0.6741 - val_recall: 0.5841 - val_precision: 0.1879
# Epoch 15/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6533 - auc: 0.6865 - recall: 0.7269 - precision: 0.2221WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6528 - auc: 0.6865 - recall: 0.7274 - precision: 0.2217 - val_loss: 0.6077 - val_auc: 0.6749 - val_recall: 0.5508 - val_precision: 0.1978
# 740/740 [==============================] - 1s 1ms/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6646 - auc: 0.6667 - recall: 0.7187 - precision: 0.2100WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 6s 10ms/step - loss: 0.6641 - auc: 0.6671 - recall: 0.7192 - precision: 0.2101 - val_loss: 0.6055 - val_auc: 0.6741 - val_recall: 0.5257 - val_precision: 0.2011
# Epoch 2/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6638 - auc: 0.6664 - recall: 0.7152 - precision: 0.2116WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6645 - auc: 0.6660 - recall: 0.7153 - precision: 0.2116 - val_loss: 0.6044 - val_auc: 0.6731 - val_recall: 0.5855 - val_precision: 0.1876
# Epoch 3/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6642 - auc: 0.6674 - recall: 0.7244 - precision: 0.2124WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6638 - auc: 0.6673 - recall: 0.7226 - precision: 0.2117 - val_loss: 0.6046 - val_auc: 0.6732 - val_recall: 0.5612 - val_precision: 0.1959
# Epoch 4/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6624 - auc: 0.6680 - recall: 0.7125 - precision: 0.2116WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6634 - auc: 0.6676 - recall: 0.7124 - precision: 0.2121 - val_loss: 0.6039 - val_auc: 0.6738 - val_recall: 0.5925 - val_precision: 0.1899
# Epoch 5/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6636 - auc: 0.6671 - recall: 0.7211 - precision: 0.2115WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6638 - auc: 0.6669 - recall: 0.7207 - precision: 0.2115 - val_loss: 0.6040 - val_auc: 0.6733 - val_recall: 0.5535 - val_precision: 0.1964
# Epoch 6/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6618 - auc: 0.6684 - recall: 0.7122 - precision: 0.2114WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6626 - auc: 0.6686 - recall: 0.7124 - precision: 0.2117 - val_loss: 0.6065 - val_auc: 0.6725 - val_recall: 0.5382 - val_precision: 0.2034
# Epoch 7/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6640 - auc: 0.6665 - recall: 0.7116 - precision: 0.2106WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6626 - auc: 0.6675 - recall: 0.7128 - precision: 0.2104 - val_loss: 0.6077 - val_auc: 0.6733 - val_recall: 0.5000 - val_precision: 0.2054
# Epoch 8/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6624 - auc: 0.6673 - recall: 0.7073 - precision: 0.2110WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6633 - auc: 0.6675 - recall: 0.7067 - precision: 0.2117 - val_loss: 0.6046 - val_auc: 0.6724 - val_recall: 0.5841 - val_precision: 0.1931
# Epoch 9/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6611 - auc: 0.6686 - recall: 0.7150 - precision: 0.2120WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6614 - auc: 0.6693 - recall: 0.7149 - precision: 0.2129 - val_loss: 0.6085 - val_auc: 0.6723 - val_recall: 0.5410 - val_precision: 0.2031
# Epoch 10/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6640 - auc: 0.6664 - recall: 0.7143 - precision: 0.2101WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6619 - auc: 0.6685 - recall: 0.7164 - precision: 0.2106 - val_loss: 0.6179 - val_auc: 0.6730 - val_recall: 0.4743 - val_precision: 0.2130
# Epoch 11/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6614 - auc: 0.6698 - recall: 0.7096 - precision: 0.2145WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6614 - auc: 0.6698 - recall: 0.7096 - precision: 0.2145 - val_loss: 0.6067 - val_auc: 0.6726 - val_recall: 0.5376 - val_precision: 0.2015
# Epoch 12/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6633 - auc: 0.6679 - recall: 0.7162 - precision: 0.2116WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6629 - auc: 0.6678 - recall: 0.7151 - precision: 0.2113 - val_loss: 0.6058 - val_auc: 0.6716 - val_recall: 0.5229 - val_precision: 0.2030
# Epoch 13/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6609 - auc: 0.6698 - recall: 0.7080 - precision: 0.2130WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6612 - auc: 0.6702 - recall: 0.7081 - precision: 0.2135 - val_loss: 0.6063 - val_auc: 0.6721 - val_recall: 0.5355 - val_precision: 0.2018
# Epoch 14/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6620 - auc: 0.6683 - recall: 0.7085 - precision: 0.2135WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6628 - auc: 0.6676 - recall: 0.7088 - precision: 0.2132 - val_loss: 0.6053 - val_auc: 0.6722 - val_recall: 0.5821 - val_precision: 0.1924
# Epoch 15/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6628 - auc: 0.6687 - recall: 0.7126 - precision: 0.2119WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6628 - auc: 0.6686 - recall: 0.7124 - precision: 0.2118 - val_loss: 0.6045 - val_auc: 0.6737 - val_recall: 0.5654 - val_precision: 0.1966
# 740/740 [==============================] - 1s 1ms/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6629 - auc: 0.6676 - recall: 0.7026 - precision: 0.2110WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# ...
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6744 - auc: 0.6670 - recall: 0.7281 - precision: 0.2144 - val_loss: 0.5592 - val_auc: 0.6789 - val_recall: 0.5904 - val_precision: 0.1762
# Epoch 7/15
# 522/555 [===========================>..] - ETA: 0s - loss: 0.6746 - auc: 0.6666 - recall: 0.7277 - precision: 0.2144WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6739 - auc: 0.6674 - recall: 0.7255 - precision: 0.2141 - val_loss: 0.5579 - val_auc: 0.6789 - val_recall: 0.5500 - val_precision: 0.1785
# Epoch 8/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6737 - auc: 0.6664 - recall: 0.7239 - precision: 0.2145WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6739 - auc: 0.6666 - recall: 0.7241 - precision: 0.2147 - val_loss: 0.5596 - val_auc: 0.6803 - val_recall: 0.6069 - val_precision: 0.1709
# Epoch 9/15
# 520/555 [===========================>..] - ETA: 0s - loss: 0.6733 - auc: 0.6676 - recall: 0.7272 - precision: 0.2141WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6736 - auc: 0.6679 - recall: 0.7248 - precision: 0.2152 - val_loss: 0.5591 - val_auc: 0.6809 - val_recall: 0.5979 - val_precision: 0.1736
# Epoch 10/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6735 - auc: 0.6667 - recall: 0.7283 - precision: 0.2134WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6735 - auc: 0.6667 - recall: 0.7283 - precision: 0.2134 - val_loss: 0.5600 - val_auc: 0.6787 - val_recall: 0.5417 - val_precision: 0.1818
# Epoch 11/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6735 - auc: 0.6685 - recall: 0.7228 - precision: 0.2164WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6736 - auc: 0.6681 - recall: 0.7225 - precision: 0.2159 - val_loss: 0.5641 - val_auc: 0.6777 - val_recall: 0.6416 - val_precision: 0.1655
# Epoch 12/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6749 - auc: 0.6680 - recall: 0.7317 - precision: 0.2163WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6742 - auc: 0.6681 - recall: 0.7321 - precision: 0.2159 - val_loss: 0.5573 - val_auc: 0.6809 - val_recall: 0.5574 - val_precision: 0.1777
# Epoch 13/15
# 519/555 [===========================>..] - ETA: 0s - loss: 0.6741 - auc: 0.6682 - recall: 0.7226 - precision: 0.2167WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6736 - auc: 0.6675 - recall: 0.7223 - precision: 0.2158 - val_loss: 0.5640 - val_auc: 0.6759 - val_recall: 0.5937 - val_precision: 0.1724
# Epoch 14/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6738 - auc: 0.6669 - recall: 0.7256 - precision: 0.2159WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6735 - auc: 0.6671 - recall: 0.7259 - precision: 0.2155 - val_loss: 0.5637 - val_auc: 0.6781 - val_recall: 0.6284 - val_precision: 0.1642
# Epoch 15/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6733 - auc: 0.6690 - recall: 0.7301 - precision: 0.2151WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6725 - auc: 0.6694 - recall: 0.7301 - precision: 0.2151 - val_loss: 0.5587 - val_auc: 0.6791 - val_recall: 0.5632 - val_precision: 0.1774
# 740/740 [==============================] - 1s 1ms/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 514/555 [==========================>...] - ETA: 0s - loss: 0.6748 - auc: 0.6665 - recall: 0.7213 - precision: 0.2143WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6744 - auc: 0.6665 - recall: 0.7214 - precision: 0.2140 - val_loss: 0.5681 - val_auc: 0.6705 - val_recall: 0.6160 - val_precision: 0.1668
# Epoch 2/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6738 - auc: 0.6680 - recall: 0.7279 - precision: 0.2158WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6734 - auc: 0.6679 - recall: 0.7277 - precision: 0.2155 - val_loss: 0.5676 - val_auc: 0.6722 - val_recall: 0.6358 - val_precision: 0.1641
# Epoch 3/15
# 521/555 [===========================>..] - ETA: 0s - loss: 0.6757 - auc: 0.6669 - recall: 0.7312 - precision: 0.2160WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6741 - auc: 0.6675 - recall: 0.7313 - precision: 0.2153 - val_loss: 0.5675 - val_auc: 0.6688 - val_recall: 0.6086 - val_precision: 0.1690
# Epoch 4/15
# 530/555 [===========================>..] - ETA: 0s - loss: 0.6741 - auc: 0.6695 - recall: 0.7231 - precision: 0.2167WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6740 - auc: 0.6688 - recall: 0.7246 - precision: 0.2165 - val_loss: 0.5675 - val_auc: 0.6718 - val_recall: 0.6292 - val_precision: 0.1608
# Epoch 5/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6732 - auc: 0.6676 - recall: 0.7260 - precision: 0.2156WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6735 - auc: 0.6675 - recall: 0.7259 - precision: 0.2157 - val_loss: 0.5705 - val_auc: 0.6683 - val_recall: 0.6218 - val_precision: 0.1636
# Epoch 6/15
# 537/555 [============================>.] - ETA: 0s - loss: 0.6739 - auc: 0.6693 - recall: 0.7345 - precision: 0.2169WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6733 - auc: 0.6686 - recall: 0.7330 - precision: 0.2156 - val_loss: 0.5678 - val_auc: 0.6683 - val_recall: 0.5896 - val_precision: 0.1708
# Epoch 7/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6744 - auc: 0.6666 - recall: 0.7310 - precision: 0.2147WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6738 - auc: 0.6675 - recall: 0.7306 - precision: 0.2147 - val_loss: 0.5664 - val_auc: 0.6692 - val_recall: 0.5789 - val_precision: 0.1728
# Epoch 8/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6725 - auc: 0.6683 - recall: 0.7257 - precision: 0.2158WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6728 - auc: 0.6686 - recall: 0.7261 - precision: 0.2162 - val_loss: 0.5685 - val_auc: 0.6709 - val_recall: 0.6276 - val_precision: 0.1661
# Epoch 9/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6737 - auc: 0.6667 - recall: 0.7252 - precision: 0.2153WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6742 - auc: 0.6669 - recall: 0.7255 - precision: 0.2158 - val_loss: 0.5673 - val_auc: 0.6703 - val_recall: 0.6102 - val_precision: 0.1688
# Epoch 10/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6735 - auc: 0.6677 - recall: 0.7289 - precision: 0.2146WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6728 - auc: 0.6683 - recall: 0.7295 - precision: 0.2149 - val_loss: 0.5690 - val_auc: 0.6678 - val_recall: 0.5475 - val_precision: 0.1753
# Epoch 11/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6738 - auc: 0.6678 - recall: 0.7192 - precision: 0.2151WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6738 - auc: 0.6678 - recall: 0.7192 - precision: 0.2151 - val_loss: 0.5734 - val_auc: 0.6670 - val_recall: 0.6491 - val_precision: 0.1584
# Epoch 12/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6747 - auc: 0.6681 - recall: 0.7335 - precision: 0.2170WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6729 - auc: 0.6690 - recall: 0.7326 - precision: 0.2167 - val_loss: 0.5642 - val_auc: 0.6722 - val_recall: 0.5656 - val_precision: 0.1743
# Epoch 13/15
# 530/555 [===========================>..] - ETA: 0s - loss: 0.6742 - auc: 0.6681 - recall: 0.7203 - precision: 0.2165WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6735 - auc: 0.6680 - recall: 0.7203 - precision: 0.2159 - val_loss: 0.5739 - val_auc: 0.6657 - val_recall: 0.6061 - val_precision: 0.1667
# Epoch 14/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6732 - auc: 0.6685 - recall: 0.7230 - precision: 0.2162WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6732 - auc: 0.6685 - recall: 0.7230 - precision: 0.2162 - val_loss: 0.5713 - val_auc: 0.6694 - val_recall: 0.6433 - val_precision: 0.1614
# Epoch 15/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6735 - auc: 0.6682 - recall: 0.7302 - precision: 0.2152WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6721 - auc: 0.6693 - recall: 0.7304 - precision: 0.2153 - val_loss: 0.5654 - val_auc: 0.6709 - val_recall: 0.5805 - val_precision: 0.1738
# 740/740 [==============================] - 1s 988us/step
# 83/83 [==============================] - 0s 1ms/step
# accuracy_train     0.602606
# f1_train           0.325349
# recall_train       0.674315
# precision_train    0.214534
# auc_train          0.632524
# accuracy_test      0.592810
# f1_test            0.318902
# recall_test        0.662005
# precision_test     0.213146
# auc_test           0.621684
# dtype: float64
# 312/312 [==============================] - 0s 1ms/step

# %%
test_assess_df
# Out:
#    accuracy       auc  precision    recall               model
# 0  0.723207  0.611920   0.237403  0.458455  LogisticRegression
# 1  0.679487  0.591939   0.207145  0.471210        DecisionTree

# %% [markdown]
# #### Train NN with Random Under Sampling

# %%
import imblearn.under_sampling as underSample
from sklearn.neural_network import MLPClassifier

#set NN model
nn_model = MLPClassifier(activation='logistic', batch_size=512, learning_rate='invscaling',
              learning_rate_init=0.1, max_iter=10, random_state=0,
              solver='sgd')
name = 'MLP'
assess = class_cv.validateModel(x_train_out[subset_15],
                                y_train_dict['Target_0.15'],
                                model=nn_model ,
                                scaler=True ,
                                over_sampling=False,
                                under_sampling=True,
                                predictions=False,
                                cv_type='stratKfold',
                                scaler_type='stand',
                                train_size=10,
                                test_size=1,
                                gap=0)

#store scores
assess_df = assess['scores']
assess_df['model'] = name

#store model 
model = assess['model']
new_model_list.append(model)

scaler = assess['scaler']

full_assess = pd.concat([full_assess,
                            assess_df],
                        axis=0)

#fit scaler on test set 
X_test = pd.DataFrame(scaler.transform(x_test[subset_15]), 
                        index = x_test.index, 
                        columns = subset_15)

assess_test_dict, assess_test_df = assessTest(X_test,
                                                y_test_dict['Target_0.15'],
                                                model)
assess_test_dict['model'] = name
assess_test_df['model'] = name

full_assess_test = pd.concat([full_assess_test,
                            assess_test_df],
                        axis=0)
test_assess_list.append(assess_test_dict)
    
test_assess_df = pd.DataFrame.from_records(test_assess_list)
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# Undersampling will be performed:
# Strategy: Random Undersampling
# accuracy_train     0.607815
# f1_train           0.625074
# recall_train       0.653840
# precision_train    0.598750
# auc_train          0.607815
# accuracy_test      0.577021
# f1_test            0.305846
# recall_test        0.647536
# precision_test     0.202252
# auc_test           0.606447
# dtype: float64

# %% [markdown]
# #### Train NN using SMOTE

# %%
import imblearn.under_sampling as underSample
from sklearn.neural_network import MLPClassifier

#set NN model
nn_model = MLPClassifier(activation='logistic', batch_size=512, learning_rate='invscaling',
              learning_rate_init=0.1, max_iter=10, random_state=0,
              solver='sgd')
name = 'MLP-Oversampling'
assess = class_cv.validateModel(x_train_out[subset_15],
                                y_train_dict['Target_0.15'],
                                model=nn_model ,
                                scaler=True ,
                                over_sampling=True,
                                under_sampling=False,
                                predictions=False,
                                cv_type='stratKfold',
                                scaler_type='stand',
                                train_size=10,
                                test_size=1,
                                gap=0)

#store scores
assess_df = assess['scores']
assess_df['model'] = name

#store model 
model = assess['model']
new_model_list.append(model)

scaler = assess['scaler']

full_assess = pd.concat([full_assess,
                            assess_df],
                        axis=0)

#fit scaler on test set 
X_test = pd.DataFrame(scaler.transform(x_test[subset_15]), 
                        index = x_test.index, 
                        columns = subset_15)

assess_test_dict, assess_test_df = assessTest(X_test,
                                                y_test_dict['Target_0.15'],
                                                model)
assess_test_dict['model'] = name
assess_test_df['model'] = name

full_assess_test = pd.concat([full_assess_test,
                            assess_test_df],
                        axis=0)
test_assess_list.append(assess_test_dict)
    
test_assess_df = pd.DataFrame.from_records(test_assess_list)
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# SMOTE oversampling will be performed
# accuracy_train     0.631797
# f1_train           0.637076
# recall_train       0.646387
# precision_train    0.628051
# auc_train          0.631797
# accuracy_test      0.610881
# f1_test            0.317572
# recall_test        0.627854
# precision_test     0.216730
# auc_test           0.617968
# dtype: float64

# %% [markdown]
# ### Export Metric Report Data

# %%
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\\Validation\full_CV_results_noBeta_Lasso.csv'
full_assess.to_csv(path)

# %% [markdown]
# ### Plot Perfomance

# %% [markdown]
# #### Boxplot Format A

# %%
a = full_assess.copy()

title = 'Target 15 - Model Performance on Validation set - K=10'
plt.figure(figsize=(15, 10))
ax1 = plt.subplot(2, 1, 1)
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'auc_test'].values
df_assess.plot(kind='box', title='boxplot', showmeans=True,ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('AUC', size=15)


ax2 = plt.subplot(2, 1, 2, ) # Share x-axis ticks with ax1
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'precision_test'].values
df_assess.plot(kind='box', showmeans=True,ax=ax2)

ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
plt.tight_layout()

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title} - Lasso.png'
# plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# #### Boxplot Format B

# %%
title = 'Target 15 - Model Performance on Validation set - K=10'
plt.figure(figsize=(15, 10))

# Use sharex parameter to share x-axis ticks between subplots
ax1 = plt.subplot(2, 1, 1)
sns.boxplot(x=a['model'], y=a['auc_test'], hue=a['model'], ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('AUC', size=15)

# Set legend location outside the figure
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2 = plt.subplot(2, 1, 2, sharex=ax1) # Share x-axis ticks with ax1
sns.boxplot(x=a['model'], y=a['precision_test'], hue=a['model'], ax=ax2)
ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
ax2.legend().remove()

plt.tight_layout() # To prevent overlapping of the legend with the second subplot

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title} - Format 2 - Lasso.png'
# plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# #### Display Training and Valdation Results

# %% [markdown]
# Export average scores from the Cross Validation

# %%
train_val_scores = full_assess.groupby('model').mean()
cols_ = train_val_scores.columns[train_val_scores.columns.str.contains('test')]
for col in cols_:
    
    new_col = col.replace('test','val')
    train_val_scores = train_val_scores.rename(columns = {col:new_col})
    
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Validation\modelMetricPerfomance_Target_0.15_valSet_Lasso.csv'
train_val_scores.to_csv(assess_path)
display(train_val_scores)
# Out:
#                     accuracy_train  f1_train  recall_train  precision_train  \
# model
# DecisionTree              0.610040  0.328606      0.671445         0.218234
# Keras_NN                  0.598616  0.324921      0.679836         0.213570
# LightGB                   0.622822  0.331861      0.659450         0.221723
# LogisticRegression        0.620992  0.323455      0.637799         0.216675
# MLP                       0.607815  0.625074      0.653840         0.598750
# MLP-Oversampling          0.631797  0.637076      0.646387         0.628051
#
#                     auc_train  accuracy_val    f1_val  recall_val  \
# model
# DecisionTree         0.635660      0.589975  0.307129    0.632780
# Keras_NN             0.632502      0.591021  0.319313    0.664947
# LightGB              0.638104      0.617824  0.325915    0.637891
# LogisticRegression   0.628004      0.617006  0.320086    0.626378
# MLP                  0.607815      0.577021  0.305846    0.647536
# MLP-Oversampling     0.631797      0.610881  0.317572    0.627854
#
#                     precision_val   auc_val
# model
# DecisionTree             0.204542  0.607835
# Keras_NN                 0.213654  0.621869
# LightGB                  0.223216  0.626200
# LogisticRegression       0.218636  0.620921
# MLP                      0.202252  0.606447
# MLP-Oversampling         0.216730  0.617968

# %% [markdown]
# Export scores on test set

# %%
test_assess_df = test_assess_df.reset_index().set_index('model')
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\modelMetricPerfomance_Target_0.15_testSet_Lasso.csv'
test_assess_df.to_csv(assess_path)
display(test_assess_df)
# Out:
#                     index  accuracy       auc  precision    recall
# model
# LogisticRegression      0  0.723207  0.611920   0.237403  0.458455
# DecisionTree            1  0.679487  0.591939   0.207145  0.471210
# LightGB                 2  0.751502  0.610246   0.253446  0.415452
# Keras_NN                3  0.741386  0.591361   0.232892  0.384475
# MLP                     4  0.674830  0.604711   0.213248  0.508017
# MLP-Oversampling        5  0.746595  0.600507   0.243009  0.399052

# %% [markdown]
# #### ROC Curve Comparison

# %%
import DataScalling as scalling
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras_NN','MLP','MLP-Oversampling']
roc_curve(models = new_model_list,
                       names = model_names, 
                       X_train = X_test[subset_15],
                       y_train  = X_test,
                       X_val = X_test[subset_15],
                       y_val= y_test)

title = 'Model Perfomance Comparison - ROC Curve - Test Set - Target 0.15'
plt.title(title, 
          size = 15)
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title} - Lasso.png'
plt.tight_layout()
plt.savefig(name_plot, dpi=300)
# Out:
# 312/312 [==============================] - 0s 1ms/step
