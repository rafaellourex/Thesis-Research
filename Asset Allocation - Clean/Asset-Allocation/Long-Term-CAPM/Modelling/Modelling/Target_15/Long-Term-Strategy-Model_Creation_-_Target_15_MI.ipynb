# %% [markdown]
# ## Import Cleaned Data

# %% [markdown]
# __DataFrames:__
# df_model - df with all the features (independent festures + Target)
# x - df with all independent features
# y - df with dependent feature
# x_train - df with training data from x
# x_train_out - df with training data from x with outliers treatment applied
# x_test - df with test data from x
# x_test_out - df with test data from x with outliers treatment applied

# %%
import sys
sys.path.insert(1, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions')
sys.path.insert(2, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions\Functions')
sys.path.insert(3, r'..\..\..')


import Classification_CV as class_cv
import importCleanedData as importData
import importSubsets as subsets

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from tensorflow import keras

import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

#set preferences
sns.set_style('whitegrid')

#set color for graphs
#set color for graphs
palette = ["#e41a1c", "#377eb8", "#4daf4a", "#984ea3"]

# dir = r'C:\Users\rafae\Personal\Github\Asset-Allocation\Long-Term-CAPM\SampleData\Sample'
dir = r'..\..\..\SampleData\Sample'
df_model_skew,df_target = importData.importCleanedData(dir=dir,target='CAPM')


#split data
date = '2018-01-01'
#split data without transformation
x_train,x_train_out,x_test, x_test_out,y_train_dict ,y_test_dict, y_train,y_test = importData.splitData(df_model_skew, date) 

#set columns
ratio_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Ratio'))]
shares_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Share'))]
margin_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Margin'))]
turnover_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Turnover'))]
dividend_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('dividend'))]


components_pca, pca_components_test = importData.runPCA(x_train_out= x_train_out,x_test = x_test)


#import subsets
lasso_subset_0, lasso_subset_15, mi_subset_0, mi_subset_15, lgb_subset, corr_subset0, corr_subset15 = subsets.importSubsets()


subset_0, subset_15 = lasso_subset_0, lasso_subset_15
# Out:
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# CAPM
# Import data from: ..\..\..\SampleData\Sample\LongTerm-DataPreparation_Skew.csv
# Original CAPM is being used as Target
# Nr of rows:
# 72538
# The variance explained by each component is: [50.70262543 16.3180414  12.90616231  7.80559243  6.69692605  5.82614766
#   4.47015907  4.07836541  3.82626867  3.40508117  3.17395217  2.97398597
#   2.84255924  2.7491931   2.6284572   2.30920491  2.29580116  2.24676716
#   2.1685526   2.08344875  1.96058327  1.88331954  1.85945512  1.79999003
#   1.75303096  1.72999438  1.67342676  1.57892838  1.52235707  1.48115797
#   1.44613583  1.42029951  1.39091026  1.35520895  1.32448072  1.29342424
#   1.27059382  1.25051426  1.2247642   1.18608517  1.17810508  1.15156743
#   1.14454538  1.12935887  1.10669478  1.0815426   1.07222534  1.05458183
#   1.03848544  1.01988948  1.01877496  0.99533768  0.98807987]
# The total variance explained by the components is: 0.7618344466001962

# %% [markdown]
# # Modelling Stage - Target 15

# %% [markdown]
# # Compare Model Perfomance

# %%
def gen_NNClassification (x, y, hidden_layer_sizes,activation_list, dropout,optimizer,loss = 'BinaryCrossentropy', metrics = ['AUC'],batch_size=180,epochs=10,validation_split = 0.25, class_weight = None, output_bias =None ):
    
    print('Neural Network Parameters:')
    print(f'Optimizer: {optimizer}')
    print(f'Loss: {loss}')
    print(f'Hidden Layer tructure: {hidden_layer_sizes}')
    print(f'Acivation Functions: {activation_list}')
    print(f'Dropout: {dropout}')
    print(f'Class Weight: {class_weight}')
    print(f'Output Bias: {output_bias}')
    
    #import libraries
    from scikeras.wrappers import KerasClassifier, KerasRegressor
    from tensorflow import keras
    reset_random_seeds()
    #get nr features in
    n_features_in_ = x.shape[1]
    n_classes_ = len(y.unique())
    
    if output_bias is not None:
        output_bias =keras.initializers.Constant(output_bias)
    
    #set keras model
    model = keras.models.Sequential()
    
    #define input shape
    # model.add(keras.layers.Input(shape=(n_features_in_,)))
    model.add(keras.layers.Dense(
          4, activation='relu',
          input_shape=(n_features_in_,)))
    
    #define hidden layers
    for hidden_layer_size, activation_ in zip(hidden_layer_sizes,
                                              activation_list):
        
        model.add(keras.layers.Dense(hidden_layer_size,
                                     activation=activation_))
        
        model.add(keras.layers.Dropout(dropout))
    
    #define output layer
    model.add(keras.layers.Dense(1,
                                 activation="sigmoid",
                                 bias_initializer=output_bias))
    
    #compile model 
    model.compile(optimizer=optimizer,
                  loss=loss,
                  metrics=metrics,
                  )
    
    #transform to SKlearn format
    NNmodel = KerasClassifier( model=model,
                            batch_size= batch_size,
                            epochs= epochs,
                            class_weight=class_weight,
                            validation_split=validation_split,
                            loss = loss)

    return NNmodel

metrics = ['AUC','Recall','Precision']


def reset_random_seeds():
    import random
    from numpy.random import seed
    import os
    import numpy as np 
    from tensorflow import random as r
    
    seed_nr = 0
    os.environ['PYTHONHASHSEED']=str(seed_nr)
    r.set_seed(seed_nr)
    np.random.seed(seed_nr)

from numpy.random import seed
from tensorflow import keras 


reset_random_seeds()
optimizer = keras.optimizers.RMSprop(learning_rate=0.001)
loss_ = keras.losses.BinaryCrossentropy()
NNmodel = gen_NNClassification(x_train_out[mi_subset_15], 
                                 y_train_dict['Target_0.15'],
                                 hidden_layer_sizes = (50,),
                                 activation_list = ['relu'],
                                 dropout = 0.3,
                                 optimizer =optimizer ,
                                 loss = loss_, 
                                 metrics = metrics,
                                 batch_size=64,
                                 epochs=15,
                                 validation_split = 0.25,
                                 class_weight = 'balanced',
                                 output_bias =None )



def roc_curve (models,names,X_train,y_train, X_val, y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        list with model names and a list of models 
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays ROC curve of the respective models 
    
    '''''''''''''''
    
    names= names
    from sklearn.metrics import roc_curve
    sns.set_theme(style = 'whitegrid')
    plt.figure(figsize = (10,10))
    for i, names ,in zip(models,names):
        # i.fit(X_train,y_train)
        thresh_dict = {}
        prob_model = i.predict_proba(X_val)
        
        fpr_DT_ent, tpr_DT_ent, thresholds_DT_ent = roc_curve(y_val, prob_model[:,1])
        plt.plot(fpr_DT_ent, tpr_DT_ent, label=f"ROC Curve {names}" , )
        
        plt.xlabel('FPR')
        plt.ylabel('TPR')
        plt.legend()
        
    
    
def precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted inside the function 
    
    '''''''''''''''
    names=names
    model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()
    
    
def fitted_precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted outside the function 
    
    '''''''''''''''
    names=names
    #model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()

def assessTest (x_test, y_test, model):
    
    col = x_test.columns[4]
    index__ = x_test.reset_index()[['symbol','fillingDate',col]].set_index(['symbol','fillingDate'])
    target_copy = df_target.copy()
    target_copy['fillingDate'] = target_copy['fillingDate'].astype(str)
    target_copy = target_copy.drop_duplicates(['symbol','fillingDate']).set_index(['symbol','fillingDate'])
    target_copy = target_copy.loc[target_copy.index.isin(index__.index)]
    
    assess_test_dict = dict()
    pred_test = model.predict(x_test)
    assess_test = pd.DataFrame(index = y_test.index)
    assess_test['Prediction'] = pred_test
    assess_test['Target'] = y_test
#     assess_test['returns'] = df_model.loc[df_model.index.isin(y_test.index),'futReturns']
    assess_test['excReturns'] = target_copy.loc[target_copy.index.isin(index__.index),'futAlpha']

    avg_returns = assess_test.groupby('Prediction').mean()[['excReturns']]


    from sklearn.metrics import roc_auc_score, precision_score, recall_score,accuracy_score
    auc  = roc_auc_score(assess_test['Target'],assess_test['Prediction'] )
    precision = precision_score(assess_test['Target'],assess_test['Prediction'] )
    recall =  recall_score(assess_test['Target'],assess_test['Prediction'] )
    acc =  accuracy_score(assess_test['Target'],assess_test['Prediction'] )
    
    assess_test_dict['accuracy'] = acc
    assess_test_dict['auc'] = auc
    assess_test_dict['precision'] = precision
    assess_test_dict['recall'] = recall
    return(assess_test_dict,assess_test)
# Out:
# Neural Network Parameters:
# Optimizer: <keras.optimizers.optimizer_experimental.rmsprop.RMSprop object at 0x0000018980CAEC10>
# Loss: <keras.losses.BinaryCrossentropy object at 0x00000189B8547790>
# Hidden Layer tructure: (50,)
# Acivation Functions: ['relu']
# Dropout: 0.3
# Class Weight: balanced
# Output Bias: None

# %% [markdown]
# ## Target 0.15

# %% [markdown]
# Perfomance is compared using using standardized data since Neural Networks and Logistic Regressions are highly affected by data scalling.

# %%
def assessModels (x_train,y_train,x_test,y_test,model_list, model_names,):
    new_model_list = []
    full_assess = pd.DataFrame()
    full_assess_test = pd.DataFrame()
    test_assess_list = []
    #iterate over the models and perform CV 
    for model, name in zip(model_list, model_names):
        assess = class_cv.validateModel(x_train,
                                        y_train,
                                        model=model ,
                                        scaler=True ,
                                        over_sampling=False,
                                        predictions=False,
                                        cv_type='stratKfold',
                                        scaler_type='stand',
                                        train_size=10,
                                        test_size=1,
                                        gap=0)
        
        #store scores
        assess_df = assess['scores']
        assess_df['model'] = name
        
        full_assess = pd.concat([full_assess,
                                assess_df],
                                axis=0)
        
        #store model 
        model = assess['model']
        new_model_list.append(model)
        
        if name =='LightGB':
            features = model.feature_name_
    
        elif name =='Keras_NN':
            features = features
        
        else:
            features = model.feature_names_in_
            
        
        scaler = assess['scaler']
        scale_features = scaler.get_feature_names_out()
    
        rest_ft =[]
        for ft in features:
            if ft not in scale_features:
                rest_ft.append(ft)
    
    
    
        # fit scaler on test set 
        X_test = pd.DataFrame(scaler.transform(x_test[scale_features]), 
                            index = x_test.index, 
                            columns = scale_features)
        
        X_test = pd.concat([X_test, x_test[rest_ft]],axis=1)
            
        
        X_test = X_test[features]
        
        assess_test_dict, assess_test_df = assessTest(X_test,
                                                    y_test,
                                                    model)
        assess_test_dict['model'] = name
        assess_test_df['model'] = name
        
        full_assess_test = pd.concat([full_assess_test,
                                assess_test_df],
                                axis=0)
        test_assess_list.append(assess_test_dict)
        
    test_assess_df = pd.DataFrame.from_records(test_assess_list)
    
    return(full_assess,test_assess_df,new_model_list )

# %%
#set models
dt_model = DecisionTreeClassifier(class_weight='balanced',
                                  max_depth=6,
                                  max_features=9,
                                  min_samples_leaf=10,
                                  random_state=0)


lgb_model = lgb.LGBMClassifier(boosting_type='dart',
                               class_weight='balanced',
                               learning_rate=0.2,
                               max_depth=2, 
                               n_estimators=50,
                               random_state=0)

lr_model = LogisticRegression(class_weight='balanced',
                              penalty=None,
                              random_state=0,
                   solver='newton-cholesky')


model_list = [lr_model,dt_model, lgb_model,NNmodel]
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras_NN']

full_assess,test_assess_df,new_model_list  = assessModels(x_train_out[mi_subset_15],y_train_dict['Target_0.15'],
             x_test[mi_subset_15],y_test_dict['Target_0.15'],model_list[-2:], model_names[-2:])
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.591603
# f1_train           0.333280
# recall_train       0.718406
# precision_train    0.216997
# auc_train          0.644508
# accuracy_test      0.588206
# f1_test            0.331821
# recall_test        0.699215
# precision_test     0.222205
# auc_test           0.634524
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# Epoch 1/15
# 526/555 [===========================>..] - ETA: 0s - loss: 0.6485 - auc: 0.6892 - recall: 0.7618 - precision: 0.2190WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 8ms/step - loss: 0.6474 - auc: 0.6896 - recall: 0.7607 - precision: 0.2187 - val_loss: 0.6004 - val_auc: 0.6857 - val_recall: 0.5800 - val_precision: 0.2100
# Epoch 2/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6475 - auc: 0.6899 - recall: 0.7573 - precision: 0.2186WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6487 - auc: 0.6892 - recall: 0.7579 - precision: 0.2187 - val_loss: 0.5997 - val_auc: 0.6851 - val_recall: 0.5848 - val_precision: 0.2107
# Epoch 3/15
# 527/555 [===========================>..] - ETA: 0s - loss: 0.6491 - auc: 0.6877 - recall: 0.7603 - precision: 0.2175WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6490 - auc: 0.6889 - recall: 0.7613 - precision: 0.2185 - val_loss: 0.6008 - val_auc: 0.6849 - val_recall: 0.5821 - val_precision: 0.2094
# Epoch 4/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6471 - auc: 0.6892 - recall: 0.7570 - precision: 0.2176WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6479 - auc: 0.6893 - recall: 0.7573 - precision: 0.2183 - val_loss: 0.5988 - val_auc: 0.6849 - val_recall: 0.6224 - val_precision: 0.2041
# Epoch 5/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6498 - auc: 0.6889 - recall: 0.7676 - precision: 0.2173WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6489 - auc: 0.6888 - recall: 0.7662 - precision: 0.2169 - val_loss: 0.6174 - val_auc: 0.6849 - val_recall: 0.4847 - val_precision: 0.2184
# Epoch 6/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6487 - auc: 0.6890 - recall: 0.7562 - precision: 0.2174WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6488 - auc: 0.6889 - recall: 0.7583 - precision: 0.2178 - val_loss: 0.6002 - val_auc: 0.6857 - val_recall: 0.5904 - val_precision: 0.2077
# Epoch 7/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6480 - auc: 0.6887 - recall: 0.7510 - precision: 0.2164WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6480 - auc: 0.6887 - recall: 0.7534 - precision: 0.2165 - val_loss: 0.6094 - val_auc: 0.6851 - val_recall: 0.5243 - val_precision: 0.2143
# Epoch 8/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6482 - auc: 0.6887 - recall: 0.7581 - precision: 0.2179WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6483 - auc: 0.6889 - recall: 0.7581 - precision: 0.2181 - val_loss: 0.5994 - val_auc: 0.6856 - val_recall: 0.5932 - val_precision: 0.2070
# Epoch 9/15
# 523/555 [===========================>..] - ETA: 0s - loss: 0.6478 - auc: 0.6894 - recall: 0.7550 - precision: 0.2175WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6488 - auc: 0.6895 - recall: 0.7562 - precision: 0.2184 - val_loss: 0.5985 - val_auc: 0.6854 - val_recall: 0.5904 - val_precision: 0.2089
# Epoch 10/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6502 - auc: 0.6872 - recall: 0.7550 - precision: 0.2179WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6485 - auc: 0.6887 - recall: 0.7577 - precision: 0.2183 - val_loss: 0.6221 - val_auc: 0.6854 - val_recall: 0.4659 - val_precision: 0.2205
# Epoch 11/15
# 523/555 [===========================>..] - ETA: 0s - loss: 0.6509 - auc: 0.6869 - recall: 0.7504 - precision: 0.2173WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6491 - auc: 0.6885 - recall: 0.7517 - precision: 0.2175 - val_loss: 0.6109 - val_auc: 0.6860 - val_recall: 0.5181 - val_precision: 0.2154
# Epoch 12/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6490 - auc: 0.6896 - recall: 0.7525 - precision: 0.2185WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6487 - auc: 0.6899 - recall: 0.7528 - precision: 0.2186 - val_loss: 0.6063 - val_auc: 0.6848 - val_recall: 0.5216 - val_precision: 0.2134
# Epoch 13/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6478 - auc: 0.6895 - recall: 0.7570 - precision: 0.2186WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6485 - auc: 0.6892 - recall: 0.7575 - precision: 0.2190 - val_loss: 0.5994 - val_auc: 0.6854 - val_recall: 0.5841 - val_precision: 0.2083
# Epoch 14/15
# 530/555 [===========================>..] - ETA: 0s - loss: 0.6477 - auc: 0.6904 - recall: 0.7529 - precision: 0.2191WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6475 - auc: 0.6902 - recall: 0.7534 - precision: 0.2189 - val_loss: 0.6090 - val_auc: 0.6853 - val_recall: 0.5216 - val_precision: 0.2148
# Epoch 15/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6487 - auc: 0.6884 - recall: 0.7582 - precision: 0.2173WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6489 - auc: 0.6883 - recall: 0.7583 - precision: 0.2173 - val_loss: 0.5980 - val_auc: 0.6851 - val_recall: 0.6106 - val_precision: 0.2039
# 740/740 [==============================] - 1s 914us/step
# 83/83 [==============================] - 0s 915us/step
# Epoch 1/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6508 - auc: 0.6833 - recall: 0.7572 - precision: 0.2142WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6507 - auc: 0.6842 - recall: 0.7573 - precision: 0.2150 - val_loss: 0.5989 - val_auc: 0.6860 - val_recall: 0.5828 - val_precision: 0.2102
# Epoch 2/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6518 - auc: 0.6834 - recall: 0.7561 - precision: 0.2148WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6524 - auc: 0.6831 - recall: 0.7573 - precision: 0.2148 - val_loss: 0.6017 - val_auc: 0.6855 - val_recall: 0.5542 - val_precision: 0.2130
# Epoch 3/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6516 - auc: 0.6842 - recall: 0.7604 - precision: 0.2160WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6520 - auc: 0.6838 - recall: 0.7596 - precision: 0.2160 - val_loss: 0.6009 - val_auc: 0.6853 - val_recall: 0.5654 - val_precision: 0.2109
# Epoch 4/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6508 - auc: 0.6823 - recall: 0.7560 - precision: 0.2143WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6512 - auc: 0.6829 - recall: 0.7560 - precision: 0.2152 - val_loss: 0.5989 - val_auc: 0.6850 - val_recall: 0.5834 - val_precision: 0.2083
# Epoch 5/15
# 527/555 [===========================>..] - ETA: 0s - loss: 0.6526 - auc: 0.6832 - recall: 0.7612 - precision: 0.2154WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6513 - auc: 0.6837 - recall: 0.7596 - precision: 0.2148 - val_loss: 0.6137 - val_auc: 0.6849 - val_recall: 0.4910 - val_precision: 0.2177
# Epoch 6/15
# 537/555 [============================>.] - ETA: 0s - loss: 0.6492 - auc: 0.6860 - recall: 0.7602 - precision: 0.2166WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6494 - auc: 0.6850 - recall: 0.7604 - precision: 0.2156 - val_loss: 0.6005 - val_auc: 0.6855 - val_recall: 0.5751 - val_precision: 0.2124
# Epoch 7/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6512 - auc: 0.6830 - recall: 0.7589 - precision: 0.2156WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6511 - auc: 0.6830 - recall: 0.7596 - precision: 0.2158 - val_loss: 0.6081 - val_auc: 0.6856 - val_recall: 0.5188 - val_precision: 0.2126
# Epoch 8/15
# 515/555 [==========================>...] - ETA: 0s - loss: 0.6488 - auc: 0.6846 - recall: 0.7602 - precision: 0.2141WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6502 - auc: 0.6845 - recall: 0.7588 - precision: 0.2155 - val_loss: 0.5990 - val_auc: 0.6855 - val_recall: 0.5814 - val_precision: 0.2101
# Epoch 9/15
# 524/555 [===========================>..] - ETA: 0s - loss: 0.6513 - auc: 0.6829 - recall: 0.7545 - precision: 0.2145WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6524 - auc: 0.6827 - recall: 0.7553 - precision: 0.2150 - val_loss: 0.5962 - val_auc: 0.6858 - val_recall: 0.6384 - val_precision: 0.2015
# Epoch 10/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6498 - auc: 0.6836 - recall: 0.7588 - precision: 0.2155WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6497 - auc: 0.6838 - recall: 0.7590 - precision: 0.2156 - val_loss: 0.6315 - val_auc: 0.6864 - val_recall: 0.4555 - val_precision: 0.2244
# Epoch 11/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6502 - auc: 0.6836 - recall: 0.7578 - precision: 0.2159WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6504 - auc: 0.6837 - recall: 0.7581 - precision: 0.2161 - val_loss: 0.6065 - val_auc: 0.6865 - val_recall: 0.5501 - val_precision: 0.2119
# Epoch 12/15
# 530/555 [===========================>..] - ETA: 0s - loss: 0.6509 - auc: 0.6833 - recall: 0.7561 - precision: 0.2150WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6506 - auc: 0.6839 - recall: 0.7571 - precision: 0.2151 - val_loss: 0.6099 - val_auc: 0.6856 - val_recall: 0.5083 - val_precision: 0.2134
# Epoch 13/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6508 - auc: 0.6828 - recall: 0.7562 - precision: 0.2142WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6511 - auc: 0.6831 - recall: 0.7570 - precision: 0.2147 - val_loss: 0.5986 - val_auc: 0.6854 - val_recall: 0.6008 - val_precision: 0.2092
# Epoch 14/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6506 - auc: 0.6830 - recall: 0.7558 - precision: 0.2146WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6511 - auc: 0.6833 - recall: 0.7564 - precision: 0.2149 - val_loss: 0.6063 - val_auc: 0.6861 - val_recall: 0.5424 - val_precision: 0.2124
# Epoch 15/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6510 - auc: 0.6840 - recall: 0.7588 - precision: 0.2151WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6512 - auc: 0.6834 - recall: 0.7583 - precision: 0.2146 - val_loss: 0.5970 - val_auc: 0.6851 - val_recall: 0.6433 - val_precision: 0.2020
# 740/740 [==============================] - 1s 851us/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6440 - auc: 0.6979 - recall: 0.7635 - precision: 0.2228WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6441 - auc: 0.6982 - recall: 0.7636 - precision: 0.2230 - val_loss: 0.5988 - val_auc: 0.6855 - val_recall: 0.5841 - val_precision: 0.2086
# Epoch 2/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6439 - auc: 0.6994 - recall: 0.7598 - precision: 0.2263WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6438 - auc: 0.6987 - recall: 0.7606 - precision: 0.2257 - val_loss: 0.5983 - val_auc: 0.6857 - val_recall: 0.5709 - val_precision: 0.2093
# Epoch 3/15
# 526/555 [===========================>..] - ETA: 0s - loss: 0.6453 - auc: 0.6964 - recall: 0.7557 - precision: 0.2226WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6447 - auc: 0.6981 - recall: 0.7562 - precision: 0.2232 - val_loss: 0.6039 - val_auc: 0.6854 - val_recall: 0.5285 - val_precision: 0.2134
# Epoch 4/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6426 - auc: 0.6988 - recall: 0.7564 - precision: 0.2246WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6426 - auc: 0.6994 - recall: 0.7564 - precision: 0.2254 - val_loss: 0.6071 - val_auc: 0.6852 - val_recall: 0.5209 - val_precision: 0.2172
# Epoch 5/15
# 522/555 [===========================>..] - ETA: 0s - loss: 0.6435 - auc: 0.6992 - recall: 0.7540 - precision: 0.2248WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6426 - auc: 0.6995 - recall: 0.7556 - precision: 0.2242 - val_loss: 0.6127 - val_auc: 0.6859 - val_recall: 0.4972 - val_precision: 0.2171
# Epoch 6/15
# 537/555 [============================>.] - ETA: 0s - loss: 0.6417 - auc: 0.7005 - recall: 0.7519 - precision: 0.2250WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6421 - auc: 0.7001 - recall: 0.7526 - precision: 0.2249 - val_loss: 0.6003 - val_auc: 0.6860 - val_recall: 0.5668 - val_precision: 0.2103
# Epoch 7/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6432 - auc: 0.6989 - recall: 0.7539 - precision: 0.2246WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6432 - auc: 0.6989 - recall: 0.7539 - precision: 0.2246 - val_loss: 0.6013 - val_auc: 0.6853 - val_recall: 0.5529 - val_precision: 0.2109
# Epoch 8/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6423 - auc: 0.6977 - recall: 0.7538 - precision: 0.2239WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6424 - auc: 0.6989 - recall: 0.7547 - precision: 0.2252 - val_loss: 0.5984 - val_auc: 0.6855 - val_recall: 0.5779 - val_precision: 0.2068
# Epoch 9/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6417 - auc: 0.6990 - recall: 0.7542 - precision: 0.2229WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6431 - auc: 0.6989 - recall: 0.7534 - precision: 0.2239 - val_loss: 0.5972 - val_auc: 0.6860 - val_recall: 0.6113 - val_precision: 0.2048
# Epoch 10/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6424 - auc: 0.6983 - recall: 0.7579 - precision: 0.2222WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6425 - auc: 0.6986 - recall: 0.7581 - precision: 0.2228 - val_loss: 0.6495 - val_auc: 0.6864 - val_recall: 0.4277 - val_precision: 0.2274
# Epoch 11/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6427 - auc: 0.7006 - recall: 0.7558 - precision: 0.2261WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6420 - auc: 0.7006 - recall: 0.7551 - precision: 0.2257 - val_loss: 0.5991 - val_auc: 0.6864 - val_recall: 0.5848 - val_precision: 0.2088
# Epoch 12/15
# 522/555 [===========================>..] - ETA: 0s - loss: 0.6435 - auc: 0.6992 - recall: 0.7530 - precision: 0.2240WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6436 - auc: 0.6988 - recall: 0.7534 - precision: 0.2238 - val_loss: 0.6007 - val_auc: 0.6856 - val_recall: 0.5640 - val_precision: 0.2106
# Epoch 13/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6433 - auc: 0.6984 - recall: 0.7571 - precision: 0.2237WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6438 - auc: 0.6985 - recall: 0.7570 - precision: 0.2245 - val_loss: 0.5989 - val_auc: 0.6858 - val_recall: 0.5855 - val_precision: 0.2066
# Epoch 14/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6432 - auc: 0.6992 - recall: 0.7533 - precision: 0.2253WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6435 - auc: 0.6987 - recall: 0.7539 - precision: 0.2248 - val_loss: 0.6085 - val_auc: 0.6859 - val_recall: 0.5160 - val_precision: 0.2127
# Epoch 15/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6419 - auc: 0.7001 - recall: 0.7541 - precision: 0.2247WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6420 - auc: 0.7000 - recall: 0.7539 - precision: 0.2245 - val_loss: 0.6033 - val_auc: 0.6859 - val_recall: 0.5501 - val_precision: 0.2114
# 740/740 [==============================] - 1s 966us/step
# 83/83 [==============================] - 0s 983us/step
# Epoch 1/15
# 542/555 [============================>.] - ETA: 0s - loss: 0.6462 - auc: 0.6945 - recall: 0.7532 - precision: 0.2217WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 6s 11ms/step - loss: 0.6459 - auc: 0.6952 - recall: 0.7535 - precision: 0.2221 - val_loss: 0.6110 - val_auc: 0.6865 - val_recall: 0.5125 - val_precision: 0.2156
# Epoch 2/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6449 - auc: 0.6962 - recall: 0.7505 - precision: 0.2246WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6449 - auc: 0.6961 - recall: 0.7503 - precision: 0.2245 - val_loss: 0.6028 - val_auc: 0.6860 - val_recall: 0.5535 - val_precision: 0.2105
# Epoch 3/15
# 541/555 [============================>.] - ETA: 0s - loss: 0.6468 - auc: 0.6948 - recall: 0.7489 - precision: 0.2223WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6458 - auc: 0.6954 - recall: 0.7484 - precision: 0.2220 - val_loss: 0.6022 - val_auc: 0.6843 - val_recall: 0.5529 - val_precision: 0.2085
# Epoch 4/15
# 530/555 [===========================>..] - ETA: 0s - loss: 0.6457 - auc: 0.6954 - recall: 0.7428 - precision: 0.2216WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6462 - auc: 0.6952 - recall: 0.7433 - precision: 0.2222 - val_loss: 0.5998 - val_auc: 0.6854 - val_recall: 0.6175 - val_precision: 0.2038
# Epoch 5/15
# 542/555 [============================>.] - ETA: 0s - loss: 0.6440 - auc: 0.6973 - recall: 0.7500 - precision: 0.2221WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6438 - auc: 0.6971 - recall: 0.7491 - precision: 0.2222 - val_loss: 0.6061 - val_auc: 0.6860 - val_recall: 0.5688 - val_precision: 0.2107
# Epoch 6/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6447 - auc: 0.6961 - recall: 0.7510 - precision: 0.2217WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6453 - auc: 0.6960 - recall: 0.7527 - precision: 0.2223 - val_loss: 0.6067 - val_auc: 0.6864 - val_recall: 0.5542 - val_precision: 0.2097
# Epoch 7/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6454 - auc: 0.6963 - recall: 0.7554 - precision: 0.2216WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6454 - auc: 0.6962 - recall: 0.7554 - precision: 0.2217 - val_loss: 0.6064 - val_auc: 0.6852 - val_recall: 0.5188 - val_precision: 0.2159
# Epoch 8/15
# 527/555 [===========================>..] - ETA: 0s - loss: 0.6451 - auc: 0.6940 - recall: 0.7480 - precision: 0.2208WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6453 - auc: 0.6953 - recall: 0.7484 - precision: 0.2220 - val_loss: 0.5984 - val_auc: 0.6861 - val_recall: 0.6349 - val_precision: 0.2007
# Epoch 9/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6442 - auc: 0.6960 - recall: 0.7517 - precision: 0.2216WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6445 - auc: 0.6964 - recall: 0.7505 - precision: 0.2224 - val_loss: 0.5999 - val_auc: 0.6850 - val_recall: 0.6252 - val_precision: 0.2026
# Epoch 10/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6446 - auc: 0.6962 - recall: 0.7491 - precision: 0.2200WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6447 - auc: 0.6962 - recall: 0.7493 - precision: 0.2202 - val_loss: 0.6324 - val_auc: 0.6864 - val_recall: 0.4729 - val_precision: 0.2209
# Epoch 11/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6448 - auc: 0.6976 - recall: 0.7498 - precision: 0.2240WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6449 - auc: 0.6975 - recall: 0.7495 - precision: 0.2240 - val_loss: 0.6049 - val_auc: 0.6858 - val_recall: 0.5765 - val_precision: 0.2088
# Epoch 12/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6453 - auc: 0.6974 - recall: 0.7507 - precision: 0.2229WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6452 - auc: 0.6968 - recall: 0.7503 - precision: 0.2222 - val_loss: 0.6015 - val_auc: 0.6848 - val_recall: 0.5946 - val_precision: 0.2060
# Epoch 13/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6458 - auc: 0.6963 - recall: 0.7517 - precision: 0.2232WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6450 - auc: 0.6971 - recall: 0.7510 - precision: 0.2239 - val_loss: 0.6019 - val_auc: 0.6855 - val_recall: 0.5967 - val_precision: 0.2051
# Epoch 14/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6447 - auc: 0.6956 - recall: 0.7462 - precision: 0.2223WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6446 - auc: 0.6960 - recall: 0.7482 - precision: 0.2227 - val_loss: 0.6042 - val_auc: 0.6859 - val_recall: 0.5855 - val_precision: 0.2078
# Epoch 15/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6463 - auc: 0.6954 - recall: 0.7510 - precision: 0.2215WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6460 - auc: 0.6959 - recall: 0.7514 - precision: 0.2214 - val_loss: 0.6021 - val_auc: 0.6857 - val_recall: 0.5967 - val_precision: 0.2076
# 740/740 [==============================] - 1s 1ms/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6604 - auc: 0.6678 - recall: 0.7566 - precision: 0.2077WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 5s 8ms/step - loss: 0.6598 - auc: 0.6689 - recall: 0.7571 - precision: 0.2086 - val_loss: 0.6087 - val_auc: 0.6859 - val_recall: 0.5195 - val_precision: 0.2144
# Epoch 2/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6572 - auc: 0.6714 - recall: 0.7542 - precision: 0.2121WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6583 - auc: 0.6712 - recall: 0.7554 - precision: 0.2122 - val_loss: 0.5980 - val_auc: 0.6852 - val_recall: 0.6572 - val_precision: 0.1980
# Epoch 3/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6582 - auc: 0.6707 - recall: 0.7580 - precision: 0.2106WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6579 - auc: 0.6710 - recall: 0.7565 - precision: 0.2107 - val_loss: 0.6006 - val_auc: 0.6845 - val_recall: 0.5668 - val_precision: 0.2077
# Epoch 4/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6570 - auc: 0.6719 - recall: 0.7539 - precision: 0.2112WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6576 - auc: 0.6721 - recall: 0.7552 - precision: 0.2122 - val_loss: 0.5981 - val_auc: 0.6844 - val_recall: 0.6321 - val_precision: 0.2026
# Epoch 5/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6568 - auc: 0.6740 - recall: 0.7588 - precision: 0.2112WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6567 - auc: 0.6737 - recall: 0.7584 - precision: 0.2111 - val_loss: 0.6015 - val_auc: 0.6850 - val_recall: 0.5647 - val_precision: 0.2094
# Epoch 6/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6563 - auc: 0.6736 - recall: 0.7606 - precision: 0.2124WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6566 - auc: 0.6736 - recall: 0.7609 - precision: 0.2125 - val_loss: 0.6076 - val_auc: 0.6847 - val_recall: 0.5508 - val_precision: 0.2087
# Epoch 7/15
# 541/555 [============================>.] - ETA: 0s - loss: 0.6567 - auc: 0.6737 - recall: 0.7674 - precision: 0.2124WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6559 - auc: 0.6736 - recall: 0.7673 - precision: 0.2116 - val_loss: 0.6075 - val_auc: 0.6836 - val_recall: 0.5285 - val_precision: 0.2115
# Epoch 8/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6556 - auc: 0.6745 - recall: 0.7567 - precision: 0.2108WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6560 - auc: 0.6745 - recall: 0.7569 - precision: 0.2110 - val_loss: 0.5986 - val_auc: 0.6835 - val_recall: 0.6572 - val_precision: 0.1947
# Epoch 9/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6567 - auc: 0.6733 - recall: 0.7616 - precision: 0.2113WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6570 - auc: 0.6739 - recall: 0.7620 - precision: 0.2117 - val_loss: 0.6052 - val_auc: 0.6834 - val_recall: 0.5473 - val_precision: 0.2094
# Epoch 10/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6566 - auc: 0.6735 - recall: 0.7572 - precision: 0.2106WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6548 - auc: 0.6745 - recall: 0.7584 - precision: 0.2110 - val_loss: 0.6264 - val_auc: 0.6843 - val_recall: 0.4777 - val_precision: 0.2144
# Epoch 11/15
# 549/555 [============================>.] - ETA: 0s - loss: 0.6569 - auc: 0.6732 - recall: 0.7604 - precision: 0.2110WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6569 - auc: 0.6732 - recall: 0.7599 - precision: 0.2109 - val_loss: 0.5999 - val_auc: 0.6841 - val_recall: 0.6120 - val_precision: 0.2038
# Epoch 12/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6561 - auc: 0.6755 - recall: 0.7638 - precision: 0.2135WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6564 - auc: 0.6743 - recall: 0.7630 - precision: 0.2128 - val_loss: 0.5996 - val_auc: 0.6834 - val_recall: 0.6015 - val_precision: 0.2032
# Epoch 13/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6556 - auc: 0.6743 - recall: 0.7616 - precision: 0.2123WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6561 - auc: 0.6743 - recall: 0.7605 - precision: 0.2126 - val_loss: 0.5980 - val_auc: 0.6842 - val_recall: 0.6467 - val_precision: 0.1987
# Epoch 14/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6561 - auc: 0.6739 - recall: 0.7584 - precision: 0.2112WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6560 - auc: 0.6739 - recall: 0.7586 - precision: 0.2111 - val_loss: 0.6073 - val_auc: 0.6843 - val_recall: 0.5626 - val_precision: 0.2070
# Epoch 15/15
# 545/555 [============================>.] - ETA: 0s - loss: 0.6563 - auc: 0.6738 - recall: 0.7545 - precision: 0.2107WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6564 - auc: 0.6738 - recall: 0.7546 - precision: 0.2106 - val_loss: 0.5993 - val_auc: 0.6841 - val_recall: 0.6161 - val_precision: 0.2047
# 740/740 [==============================] - 1s 1ms/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6523 - auc: 0.6837 - recall: 0.7602 - precision: 0.2171WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# ...
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6669 - auc: 0.6766 - recall: 0.7773 - precision: 0.2163 - val_loss: 0.5472 - val_auc: 0.7055 - val_recall: 0.4897 - val_precision: 0.2023
# Epoch 7/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6664 - auc: 0.6766 - recall: 0.7690 - precision: 0.2167WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6663 - auc: 0.6766 - recall: 0.7686 - precision: 0.2165 - val_loss: 0.5430 - val_auc: 0.7055 - val_recall: 0.5268 - val_precision: 0.1952
# Epoch 8/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6681 - auc: 0.6743 - recall: 0.7671 - precision: 0.2137WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6680 - auc: 0.6751 - recall: 0.7678 - precision: 0.2147 - val_loss: 0.5423 - val_auc: 0.7055 - val_recall: 0.5656 - val_precision: 0.1920
# Epoch 9/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6655 - auc: 0.6776 - recall: 0.7657 - precision: 0.2169WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6657 - auc: 0.6778 - recall: 0.7662 - precision: 0.2170 - val_loss: 0.5448 - val_auc: 0.7056 - val_recall: 0.6457 - val_precision: 0.1872
# Epoch 10/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6669 - auc: 0.6752 - recall: 0.7756 - precision: 0.2148WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6668 - auc: 0.6752 - recall: 0.7756 - precision: 0.2149 - val_loss: 0.5468 - val_auc: 0.7052 - val_recall: 0.5128 - val_precision: 0.1971
# Epoch 11/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6652 - auc: 0.6764 - recall: 0.7782 - precision: 0.2177WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6654 - auc: 0.6761 - recall: 0.7773 - precision: 0.2174 - val_loss: 0.5471 - val_auc: 0.7051 - val_recall: 0.6722 - val_precision: 0.1813
# Epoch 12/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6675 - auc: 0.6760 - recall: 0.7750 - precision: 0.2162WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6666 - auc: 0.6761 - recall: 0.7751 - precision: 0.2157 - val_loss: 0.5514 - val_auc: 0.7054 - val_recall: 0.4822 - val_precision: 0.2020
# Epoch 13/15
# 541/555 [============================>.] - ETA: 0s - loss: 0.6654 - auc: 0.6764 - recall: 0.7721 - precision: 0.2159WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6661 - auc: 0.6762 - recall: 0.7709 - precision: 0.2163 - val_loss: 0.5433 - val_auc: 0.7052 - val_recall: 0.5995 - val_precision: 0.1903
# Epoch 14/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6664 - auc: 0.6763 - recall: 0.7662 - precision: 0.2153WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6669 - auc: 0.6759 - recall: 0.7680 - precision: 0.2150 - val_loss: 0.5440 - val_auc: 0.7047 - val_recall: 0.6235 - val_precision: 0.1880
# Epoch 15/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6667 - auc: 0.6768 - recall: 0.7809 - precision: 0.2163WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6667 - auc: 0.6768 - recall: 0.7809 - precision: 0.2163 - val_loss: 0.5430 - val_auc: 0.7054 - val_recall: 0.5945 - val_precision: 0.1877
# 740/740 [==============================] - 1s 2ms/step
# 83/83 [==============================] - 0s 2ms/step
# Epoch 1/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6649 - auc: 0.6760 - recall: 0.7704 - precision: 0.2163WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 8ms/step - loss: 0.6658 - auc: 0.6765 - recall: 0.7713 - precision: 0.2167 - val_loss: 0.5460 - val_auc: 0.7000 - val_recall: 0.6276 - val_precision: 0.1850
# Epoch 2/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6684 - auc: 0.6760 - recall: 0.7780 - precision: 0.2188WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6668 - auc: 0.6768 - recall: 0.7769 - precision: 0.2182 - val_loss: 0.5460 - val_auc: 0.7000 - val_recall: 0.5871 - val_precision: 0.1907
# Epoch 3/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6679 - auc: 0.6770 - recall: 0.7757 - precision: 0.2169WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6666 - auc: 0.6778 - recall: 0.7753 - precision: 0.2167 - val_loss: 0.5480 - val_auc: 0.6997 - val_recall: 0.5557 - val_precision: 0.1953
# Epoch 4/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6679 - auc: 0.6759 - recall: 0.7712 - precision: 0.2162WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6669 - auc: 0.6761 - recall: 0.7713 - precision: 0.2164 - val_loss: 0.5488 - val_auc: 0.7003 - val_recall: 0.5417 - val_precision: 0.1964
# Epoch 5/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6654 - auc: 0.6772 - recall: 0.7712 - precision: 0.2168WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6662 - auc: 0.6764 - recall: 0.7704 - precision: 0.2165 - val_loss: 0.5503 - val_auc: 0.6992 - val_recall: 0.6804 - val_precision: 0.1790
# Epoch 6/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6679 - auc: 0.6751 - recall: 0.7744 - precision: 0.2155WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6673 - auc: 0.6753 - recall: 0.7736 - precision: 0.2151 - val_loss: 0.5462 - val_auc: 0.6998 - val_recall: 0.5648 - val_precision: 0.1949
# Epoch 7/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6658 - auc: 0.6767 - recall: 0.7737 - precision: 0.2175WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6665 - auc: 0.6765 - recall: 0.7740 - precision: 0.2167 - val_loss: 0.5453 - val_auc: 0.6997 - val_recall: 0.6078 - val_precision: 0.1885
# Epoch 8/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6687 - auc: 0.6735 - recall: 0.7726 - precision: 0.2136WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6681 - auc: 0.6747 - recall: 0.7722 - precision: 0.2144 - val_loss: 0.5463 - val_auc: 0.6995 - val_recall: 0.6309 - val_precision: 0.1835
# Epoch 9/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6665 - auc: 0.6761 - recall: 0.7694 - precision: 0.2152WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6672 - auc: 0.6767 - recall: 0.7711 - precision: 0.2157 - val_loss: 0.5512 - val_auc: 0.6993 - val_recall: 0.6870 - val_precision: 0.1759
# Epoch 10/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6675 - auc: 0.6757 - recall: 0.7785 - precision: 0.2167WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6658 - auc: 0.6755 - recall: 0.7775 - precision: 0.2160 - val_loss: 0.5482 - val_auc: 0.6990 - val_recall: 0.5698 - val_precision: 0.1951
# Epoch 11/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6661 - auc: 0.6759 - recall: 0.7720 - precision: 0.2158WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6662 - auc: 0.6754 - recall: 0.7713 - precision: 0.2150 - val_loss: 0.5581 - val_auc: 0.6994 - val_recall: 0.7242 - val_precision: 0.1659
# Epoch 12/15
# 530/555 [===========================>..] - ETA: 0s - loss: 0.6688 - auc: 0.6762 - recall: 0.7792 - precision: 0.2171WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6673 - auc: 0.6765 - recall: 0.7791 - precision: 0.2168 - val_loss: 0.5476 - val_auc: 0.6996 - val_recall: 0.5508 - val_precision: 0.1966
# Epoch 13/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6665 - auc: 0.6769 - recall: 0.7720 - precision: 0.2170WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6658 - auc: 0.6766 - recall: 0.7706 - precision: 0.2166 - val_loss: 0.5471 - val_auc: 0.6994 - val_recall: 0.6391 - val_precision: 0.1832
# Epoch 14/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6656 - auc: 0.6765 - recall: 0.7647 - precision: 0.2149WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6671 - auc: 0.6757 - recall: 0.7666 - precision: 0.2149 - val_loss: 0.5475 - val_auc: 0.6993 - val_recall: 0.6457 - val_precision: 0.1839
# Epoch 15/15
# 526/555 [===========================>..] - ETA: 0s - loss: 0.6681 - auc: 0.6760 - recall: 0.7778 - precision: 0.2157WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6669 - auc: 0.6768 - recall: 0.7782 - precision: 0.2159 - val_loss: 0.5480 - val_auc: 0.6996 - val_recall: 0.6614 - val_precision: 0.1808
# 740/740 [==============================] - 1s 2ms/step
# 83/83 [==============================] - 0s 1ms/step
# accuracy_train     0.578042
# f1_train           0.331744
# recall_train       0.736857
# precision_train    0.214252
# auc_train          0.644303
# accuracy_test      0.573445
# f1_test            0.331597
# recall_test        0.722935
# precision_test     0.220017
# auc_test           0.635820
# dtype: float64
# 312/312 [==============================] - 1s 2ms/step

# %% [markdown]
# #### Train NN with Random Under Sampling

# %%
# import imblearn.under_sampling as underSample
from sklearn.neural_network import MLPClassifier

#set NN model
nn_model = MLPClassifier(activation='logistic', 
                         batch_size=512, 
                         learning_rate='invscaling',
                        learning_rate_init=0.1, 
                        max_iter=10, 
                        random_state=0,
                        solver='sgd')
name = 'MLP'
assess = class_cv.validateModel(x_train_out[mi_subset_15],
                                y_train_dict['Target_0.15'],
                                model=nn_model ,
                                scaler=True ,
                                over_sampling=False,
                                under_sampling=True,
                                predictions=False,
                                cv_type='stratKfold',
                                scaler_type='stand',
                                train_size=10,
                                test_size=1,
                                gap=0)

#store scores
assess_df = assess['scores']
assess_df['model'] = name

#store model 
model = assess['model']
new_model_list.append(model)

scaler = assess['scaler']

if name =='LightGB':
        features = model.feature_name_
        
else:
    features = model.feature_names_in_
scale_features = scaler.get_feature_names_out()
 
rest_ft =[]
for ft in features:
    if ft not in scale_features:
        rest_ft.append(ft)

full_assess = pd.concat([full_assess,
                            assess_df],
                        axis=0)

#fit scaler on test set 
X_test = pd.DataFrame(scaler.transform(x_test[scale_features]), 
                        index = x_test.index, 
                        columns = scale_features)

X_test = pd.concat([X_test, x_test[rest_ft]],axis=1)
X_test = X_test[features]

assess_test_dict, assess_test_df = assessTest(X_test,
                                                y_test_dict['Target_0.15'],
                                                model)
assess_test_dict['model'] = name
assess_test_df['model'] = name

full_assess_test = pd.concat([full_assess_test,
                            assess_test_df],
                        axis=0)
test_assess_list.append(assess_test_dict)
    
test_assess_df = pd.DataFrame.from_records(test_assess_list)
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# Undersampling will be performed:
# Strategy: Random Undersampling
# accuracy_train     0.627948
# f1_train           0.631862
# recall_train       0.638573
# precision_train    0.625298
# auc_train          0.627948
# accuracy_test      0.622199
# f1_test            0.327299
# recall_test        0.633321
# precision_test     0.223933
# auc_test           0.626841
# dtype: float64

# %% [markdown]
# ### Plot Perfomance

# %%
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Validation\full_CV_results_noBeta_MI.csv'
full_assess.to_csv(path)

# %% [markdown]
# #### Boxplot Format A

# %%
a = full_assess.copy()

title = 'Target 15 - Model Performance on Validation set - K=10'
plt.figure(figsize=(15, 10))
ax1 = plt.subplot(2, 1, 1)
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'auc_test'].values
df_assess.plot(kind='box', title='boxplot', showmeans=True,ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('AUC', size=15)


ax2 = plt.subplot(2, 1, 2, ) # Share x-axis ticks with ax1
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'precision_test'].values
df_assess.plot(kind='box', showmeans=True,ax=ax2)

ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
plt.tight_layout()

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title}-MI.png'
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# #### Boxplot Format B

# %%
title = 'Target 15 - Model Performance on Validation set - K=10'
plt.figure(figsize=(15, 10))

# Use sharex parameter to share x-axis ticks between subplots
ax1 = plt.subplot(2, 1, 1)
sns.boxplot(x=a['model'], y=a['auc_test'], hue=a['model'], ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('AUC', size=15)

# Set legend location outside the figure
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2 = plt.subplot(2, 1, 2, sharex=ax1) # Share x-axis ticks with ax1
sns.boxplot(x=a['model'], y=a['precision_test'], hue=a['model'], ax=ax2)
ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
ax2.legend().remove()

plt.tight_layout() # To prevent overlapping of the legend with the second subplot

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title}- MI - Format 2.png'
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# #### Display Training and Valdation Results

# %% [markdown]
# Export average scores from the Cross Validation

# %%
train_val_scores = full_assess.groupby('model').mean()
cols_ = train_val_scores.columns[train_val_scores.columns.str.contains('test')]
for col in cols_:
    
    new_col = col.replace('test','val')
    train_val_scores = train_val_scores.rename(columns = {col:new_col})
    
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Validation\modelMetricPerfomance_Target_0.15_valSet_MI.csv'
train_val_scores.to_csv(assess_path)
display(train_val_scores)
# Out:
#                     accuracy_train  f1_train  recall_train  precision_train  \
# model
# DecisionTree              0.591404  0.336879      0.729819         0.219233
# Keras_NN                  0.578042  0.331744      0.736857         0.214252
# LightGB                   0.591603  0.333280      0.718406         0.216997
# LogisticRegression        0.631387  0.329061      0.636266         0.221928
# MLP                       0.627948  0.631862      0.638573         0.625298
#
#                     auc_train  accuracy_val    f1_val  recall_val  \
# model
# DecisionTree         0.649154      0.580179  0.319157    0.678174
# Keras_NN             0.644303      0.573445  0.331597    0.722935
# LightGB              0.644508      0.588206  0.331821    0.699215
# LogisticRegression   0.633423      0.626555  0.327712    0.623417
# MLP                  0.627948      0.622199  0.327299    0.633321
#
#                     precision_val   auc_val
# model
# DecisionTree             0.211697  0.621065
# Keras_NN                 0.220017  0.635820
# LightGB                  0.222205  0.634524
# LogisticRegression       0.228353  0.625248
# MLP                      0.223933  0.626841

# %% [markdown]
# Export scores on test set

# %%
test_assess_df = test_assess_df.reset_index().set_index('model')
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Test\modelMetricPerfomance_Target_0.15_testSet_MI.csv'
test_assess_df.to_csv(assess_path)
display(test_assess_df)
# Out:
#                     level_0  index  accuracy       auc  precision    recall
# model
# LogisticRegression        0    0.0  0.689754  0.623779   0.229333  0.532799
# DecisionTree              1    1.0  0.589894  0.629007   0.203851  0.682945
# LightGB                   2    2.0  0.622045  0.632938   0.212705  0.647959
# MLP                       3    3.0  0.685146  0.620036   0.225477  0.530248
# Keras_NN                  1    2.0  0.628355  0.637208   0.216236  0.649417

# %% [markdown]
# #### ROC Curve Comparison

# %%
import DataScalling as scalling
model_names = ['LogisticRegression','DecisionTree','LightGB','MLP']
roc_curve(models = new_model_list,
                       names = model_names, 
                       X_train = X_test[features],
                       y_train  = X_test,
                       X_val = X_test[features],
                       y_val= y_test)

title = 'Model Perfomance Comparison - ROC Curve - Test Set - Target 0.15'
plt.title(title, 
          size = 15)
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title} - MI.png'
plt.tight_layout()
plt.savefig(name_plot, dpi=300)
