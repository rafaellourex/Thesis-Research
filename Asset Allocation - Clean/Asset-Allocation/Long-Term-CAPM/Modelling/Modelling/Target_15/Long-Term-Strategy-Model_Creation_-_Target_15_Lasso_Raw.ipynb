# %% [markdown]
# ## Import Cleaned Data

# %% [markdown]
# __DataFrames:__
# df_model - df with all the features (independent festures + Target)
# x - df with all independent features
# y - df with dependent feature
# x_train - df with training data from x
# x_train_out - df with training data from x with outliers treatment applied
# x_test - df with test data from x
# x_test_out - df with test data from x with outliers treatment applied

# %%
import sys
sys.path.insert(1, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions')
sys.path.insert(2, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions\Functions')
sys.path.insert(3, r'..\..\..')


import Classification_CV as class_cv
import importCleanedData as importData
import importSubsets as subsets

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from tensorflow import keras

import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

#set preferences
sns.set_style('whitegrid')

#set color for graphs
#set color for graphs
palette = ["#e41a1c", "#377eb8", "#4daf4a", "#984ea3"]

# dir = r'C:\Users\rafae\Personal\Github\Asset-Allocation\Long-Term-CAPM\SampleData\Sample'
dir = r'..\..\..\SampleData\Sample'
df_model_skew,df_target = importData.importCleanedData(dir=dir,target='CAPM')


#split data
date = '2018-01-01'
#split data without transformation
x_train,x_train_out,x_test, x_test_out,y_train_dict ,y_test_dict, y_train,y_test = importData.splitData(df_model_skew, date) 

#set columns
ratio_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Ratio'))]
shares_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Share'))]
margin_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Margin'))]
turnover_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Turnover'))]
dividend_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('dividend'))]


components_pca, pca_components_test = importData.runPCA(x_train_out= x_train_out,x_test = x_test)


#import subsets
lasso_subset_0, lasso_subset_15, mi_subset_0, mi_subset_15, lgb_subset, corr_subset0, corr_subset15 = subsets.importSubsets()


subset_0, subset_15 = lasso_subset_0, lasso_subset_15
# Out:
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# CAPM
# Import data from: ..\..\..\SampleData\Sample\LongTerm-DataPreparation_Skew.csv
# Original CAPM is being used as Target
# Nr of rows:
# 72538
# The variance explained by each component is: [50.70262543 16.3180414  12.90616231  7.80559243  6.69692605  5.82614766
#   4.47015907  4.07836541  3.82626867  3.40508117  3.17395217  2.97398597
#   2.84255924  2.7491931   2.6284572   2.30920491  2.29580116  2.24676716
#   2.1685526   2.08344875  1.96058327  1.88331954  1.85945512  1.79999003
#   1.75303096  1.72999438  1.67342676  1.57892838  1.52235707  1.48115797
#   1.44613583  1.42029951  1.39091026  1.35520895  1.32448072  1.29342424
#   1.27059382  1.25051426  1.2247642   1.18608517  1.17810508  1.15156743
#   1.14454538  1.12935887  1.10669478  1.0815426   1.07222534  1.05458183
#   1.03848544  1.01988948  1.01877496  0.99533768  0.98807987]
# The total variance explained by the components is: 0.7618344466001962

# %% [markdown]
# # Modelling Stage - Target 15

# %% [markdown]
# ### Baseline Model

# %%
model = LogisticRegression(random_state=0,
                           class_weight='balanced')

subset_list = [subset_0, subset_15]
baseline_assess = dict()
for key, subset in zip(y_train_dict.keys(), subset_list):
    print(key)
    baseline_assess_df = class_cv.validateModel(x_train_out[[*subset,]],
                      y_train_dict[key],
                      model=model ,
                      scaler=False,
                        over_sampling=False,
                        predictions=False,
                        cv_type='stratKfold',
                        scaler_type='stand',
                        train_size=10,
                        test_size=1,
                        gap=0)
    baseline_assess[key] = baseline_assess_df
    print(' ')
    print('-'*125)
    print(' ')
# Out:
# Target_0
# stratKfold
# Nr of splits: 10
# accuracy_train     0.535119
# f1_train           0.553217
# recall_train       0.555605
# precision_train    0.550900
# auc_train          0.534351
# accuracy_test      0.526441
# f1_test            0.544529
# recall_test        0.548482
# precision_test     0.542866
# auc_test           0.525610
# dtype: float64
#
# -----------------------------------------------------------------------------------------------------------------------------
#
# Target_0.15
# stratKfold
# Nr of splits: 10
# accuracy_train     0.555617
# f1_train           0.304248
# recall_train       0.684017
# precision_train    0.195647
# auc_train          0.609189
# accuracy_test      0.550713
# f1_test            0.300881
# recall_test        0.675514
# precision_test     0.194334
# auc_test           0.602786
# dtype: float64
#
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Compare Model Perfomance

# %%
def gen_NNClassification (x, y, hidden_layer_sizes,activation_list, dropout,optimizer,loss = 'BinaryCrossentropy', metrics = ['AUC'],batch_size=180,epochs=10,validation_split = 0.25, class_weight = None, output_bias =None ):
    
    print('Neural Network Parameters:')
    print(f'Optimizer: {optimizer}')
    print(f'Loss: {loss}')
    print(f'Hidden Layer tructure: {hidden_layer_sizes}')
    print(f'Acivation Functions: {activation_list}')
    print(f'Dropout: {dropout}')
    print(f'Class Weight: {class_weight}')
    print(f'Output Bias: {output_bias}')
    
    #import libraries
    from scikeras.wrappers import KerasClassifier, KerasRegressor
    from tensorflow import keras
    reset_random_seeds()
    #get nr features in
    n_features_in_ = x.shape[1]
    n_classes_ = len(y.unique())
    
    if output_bias is not None:
        output_bias =keras.initializers.Constant(output_bias)
    
    #set keras model
    model = keras.models.Sequential()
    
    #define input shape
    # model.add(keras.layers.Input(shape=(n_features_in_,)))
    model.add(keras.layers.Dense(
          4, activation='relu',
          input_shape=(n_features_in_,)))
    
    #define hidden layers
    for hidden_layer_size, activation_ in zip(hidden_layer_sizes,
                                              activation_list):
        
        model.add(keras.layers.Dense(hidden_layer_size,
                                     activation=activation_))
        
        model.add(keras.layers.Dropout(dropout))
    
    #define output layer
    model.add(keras.layers.Dense(1,
                                 activation="sigmoid",
                                 bias_initializer=output_bias))
    
    #compile model 
    model.compile(optimizer=optimizer,
                  loss=loss,
                  metrics=metrics,
                  )
    
    #transform to SKlearn format
    NNmodel = KerasClassifier( model=model,
                            batch_size= batch_size,
                            epochs= epochs,
                            class_weight=class_weight,
                            validation_split=validation_split,
                            loss = loss)

    return NNmodel

metrics = ['AUC','Recall','Precision']


def reset_random_seeds():
    import random
    from numpy.random import seed
    import os
    import numpy as np 
    from tensorflow import random as r
    
    seed_nr = 0
    os.environ['PYTHONHASHSEED']=str(seed_nr)
    r.set_seed(seed_nr)
    np.random.seed(seed_nr)

from numpy.random import seed
from tensorflow import keras 


reset_random_seeds()
optimizer = keras.optimizers.RMSprop(learning_rate=0.001)
loss_ = keras.losses.BinaryCrossentropy()
NNmodel = gen_NNClassification(x_train_out[subset_15], 
                                 y_train_dict['Target_0.15'],
                                 hidden_layer_sizes = (50,),
                                 activation_list = ['relu'],
                                 dropout = 0.3,
                                 optimizer =optimizer ,
                                 loss = loss_, 
                                 metrics = metrics,
                                 batch_size=64,
                                 epochs=15,
                                 validation_split = 0.25,
                                 class_weight = 'balanced',
                                 output_bias =None )



def roc_curve (models,names,X_train,y_train, X_val, y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        list with model names and a list of models 
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays ROC curve of the respective models 
    
    '''''''''''''''
    
    names= names
    from sklearn.metrics import roc_curve
    sns.set_theme(style = 'whitegrid')
    plt.figure(figsize = (10,10))
    for i, names ,in zip(models,names):
        # i.fit(X_train,y_train)
        thresh_dict = {}
        prob_model = i.predict_proba(X_val)
        
        fpr_DT_ent, tpr_DT_ent, thresholds_DT_ent = roc_curve(y_val, prob_model[:,1])
        plt.plot(fpr_DT_ent, tpr_DT_ent, label=f"ROC Curve {names}" , )
        
        plt.xlabel('FPR')
        plt.ylabel('TPR')
        plt.legend()
        
    
    
def precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted inside the function 
    
    '''''''''''''''
    names=names
    model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()
    
    
def fitted_precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted outside the function 
    
    '''''''''''''''
    names=names
    #model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()

def assessTest (x_test, y_test, model):
    
    col = x_test.columns[4]
    index__ = x_test.reset_index()[['symbol','fillingDate',col]].set_index(['symbol','fillingDate'])
    target_copy = df_target.copy()
    target_copy['fillingDate'] = target_copy['fillingDate'].astype(str)
    target_copy = target_copy.drop_duplicates(['symbol','fillingDate']).set_index(['symbol','fillingDate'])
    target_copy = target_copy.loc[target_copy.index.isin(index__.index)]
    
    assess_test_dict = dict()
    pred_test = model.predict(x_test)
    assess_test = pd.DataFrame(index = y_test.index)
    assess_test['Prediction'] = pred_test
    assess_test['Target'] = y_test
#     assess_test['returns'] = df_model.loc[df_model.index.isin(y_test.index),'futReturns']
    assess_test['excReturns'] = target_copy.loc[target_copy.index.isin(index__.index),'futAlpha']

    avg_returns = assess_test.groupby('Prediction').mean()[['excReturns']]


    from sklearn.metrics import roc_auc_score, precision_score, recall_score,accuracy_score
    auc  = roc_auc_score(assess_test['Target'],assess_test['Prediction'] )
    precision = precision_score(assess_test['Target'],assess_test['Prediction'] )
    recall =  recall_score(assess_test['Target'],assess_test['Prediction'] )
    acc =  accuracy_score(assess_test['Target'],assess_test['Prediction'] )
    
    assess_test_dict['accuracy'] = acc
    assess_test_dict['auc'] = auc
    assess_test_dict['precision'] = precision
    assess_test_dict['recall'] = recall
    return(assess_test_dict,assess_test)
# Out:
# Neural Network Parameters:
# Optimizer: <keras.optimizers.optimizer_experimental.rmsprop.RMSprop object at 0x000001E442BAADF0>
# Loss: <keras.losses.BinaryCrossentropy object at 0x000001E47E646790>
# Hidden Layer tructure: (50,)
# Acivation Functions: ['relu']
# Dropout: 0.3
# Class Weight: balanced
# Output Bias: None

# %% [markdown]
# ## Target 0.15

# %% [markdown]
# Perfomance is compared using using standardized data since Neural Networks and Logistic Regressions are highly affected by data scalling.

# %%
def assessModels (x_train,y_train,x_test,y_test,model_list, model_names,):
    new_model_list = []
    full_assess = pd.DataFrame()
    full_assess_test = pd.DataFrame()
    test_assess_list = []
    #iterate over the models and perform CV 
    for model, name in zip(model_list, model_names):
        assess = class_cv.validateModel(x_train,
                                        y_train,
                                        model=model ,
                                        scaler=True ,
                                        over_sampling=False,
                                        predictions=False,
                                        cv_type='stratKfold',
                                        scaler_type='stand',
                                        train_size=10,
                                        test_size=1,
                                        gap=0)
        
        #store scores
        assess_df = assess['scores']
        assess_df['model'] = name
        
        full_assess = pd.concat([full_assess,
                                assess_df],
                                axis=0)
        
        #store model 
        model = assess['model']
        new_model_list.append(model)
        
        if name =='LightGB':
            features = model.feature_name_
    
        elif name =='Keras_NN':
            features = features
        
        else:
            features = model.feature_names_in_
            
        
        scaler = assess['scaler']
        scale_features = scaler.get_feature_names_out()
    
        rest_ft =[]
        for ft in features:
            if ft not in scale_features:
                rest_ft.append(ft)
    
    
    
        # fit scaler on test set 
        X_test = pd.DataFrame(scaler.transform(x_test[scale_features]), 
                            index = x_test.index, 
                            columns = scale_features)
        
        X_test = pd.concat([X_test, x_test[rest_ft]],axis=1)
            
        
        X_test = X_test[features]
        
        assess_test_dict, assess_test_df = assessTest(X_test,
                                                    y_test,
                                                    model)
        assess_test_dict['model'] = name
        assess_test_df['model'] = name
        
        full_assess_test = pd.concat([full_assess_test,
                                assess_test_df],
                                axis=0)
        test_assess_list.append(assess_test_dict)
        
    test_assess_df = pd.DataFrame.from_records(test_assess_list)
    
    return(full_assess,test_assess_df,new_model_list )

# %%
#set models
dt_model = DecisionTreeClassifier(class_weight='balanced',
                                  max_depth=6,
                                  max_features=9,
                                  min_samples_leaf=10,
                                  random_state=0)


lgb_model = lgb.LGBMClassifier(boosting_type='dart',
                               class_weight='balanced',
                               learning_rate=0.2,
                               max_depth=2, 
                               n_estimators=50,
                               random_state=0)

lr_model = LogisticRegression(class_weight='balanced', penalty=None, random_state=0,
                   solver='newton-cholesky')



model_list = [lr_model,dt_model, lgb_model,NNmodel][:]
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras_NN'][:]

full_assess,test_assess_df,new_model_list  = assessModels(x_train[subset_15],y_train_dict['Target_0.15'],
             x_test[subset_15],y_test_dict['Target_0.15'],model_list[:], model_names[:])
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.611906
# f1_train           0.317859
# recall_train       0.636534
# precision_train    0.211820
# auc_train          0.622181
# accuracy_test      0.609397
# f1_test            0.317026
# recall_test        0.628122
# precision_test     0.215520
# auc_test           0.617215
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.612280
# f1_train           0.326780
# recall_train       0.661444
# precision_train    0.217340
# auc_train          0.632792
# accuracy_test      0.596690
# f1_test            0.306977
# recall_test        0.625842
# precision_test     0.205743
# auc_test           0.608857
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.621852
# f1_train           0.331742
# recall_train       0.660730
# precision_train    0.221477
# auc_train          0.638073
# accuracy_test      0.616264
# f1_test            0.325035
# recall_test        0.639766
# precision_test     0.221981
# auc_test           0.626074
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# Epoch 1/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6957 - auc: 0.6094 - recall: 0.7703 - precision: 0.1759WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 7s 7ms/step - loss: 0.6950 - auc: 0.6113 - recall: 0.7689 - precision: 0.1763 - val_loss: 0.6230 - val_auc: 0.6555 - val_recall: 0.5591 - val_precision: 0.1889
# Epoch 2/15
# 537/555 [============================>.] - ETA: 0s - loss: 0.6790 - auc: 0.6444 - recall: 0.6920 - precision: 0.1971WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6794 - auc: 0.6442 - recall: 0.6901 - precision: 0.1974 - val_loss: 0.6158 - val_auc: 0.6636 - val_recall: 0.5250 - val_precision: 0.1989
# Epoch 3/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6748 - auc: 0.6551 - recall: 0.6669 - precision: 0.2094WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6742 - auc: 0.6560 - recall: 0.6680 - precision: 0.2094 - val_loss: 0.6123 - val_auc: 0.6679 - val_recall: 0.5473 - val_precision: 0.1976
# Epoch 4/15
# 536/555 [===========================>..] - ETA: 0s - loss: 0.6688 - auc: 0.6590 - recall: 0.6653 - precision: 0.2110WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6694 - auc: 0.6595 - recall: 0.6667 - precision: 0.2119 - val_loss: 0.6112 - val_auc: 0.6701 - val_recall: 0.5772 - val_precision: 0.1961
# Epoch 5/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6685 - auc: 0.6624 - recall: 0.6786 - precision: 0.2145WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6673 - auc: 0.6630 - recall: 0.6793 - precision: 0.2144 - val_loss: 0.6105 - val_auc: 0.6713 - val_recall: 0.4861 - val_precision: 0.2087
# Epoch 6/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6652 - auc: 0.6658 - recall: 0.6713 - precision: 0.2178WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6657 - auc: 0.6671 - recall: 0.6740 - precision: 0.2180 - val_loss: 0.6088 - val_auc: 0.6717 - val_recall: 0.5417 - val_precision: 0.2018
# Epoch 7/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6649 - auc: 0.6664 - recall: 0.6643 - precision: 0.2168WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6646 - auc: 0.6681 - recall: 0.6687 - precision: 0.2177 - val_loss: 0.6083 - val_auc: 0.6715 - val_recall: 0.5216 - val_precision: 0.2040
# Epoch 8/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6637 - auc: 0.6689 - recall: 0.6608 - precision: 0.2176WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6637 - auc: 0.6689 - recall: 0.6608 - precision: 0.2176 - val_loss: 0.6079 - val_auc: 0.6721 - val_recall: 0.5814 - val_precision: 0.1946
# Epoch 9/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6622 - auc: 0.6719 - recall: 0.6705 - precision: 0.2163WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6628 - auc: 0.6712 - recall: 0.6703 - precision: 0.2159 - val_loss: 0.6075 - val_auc: 0.6730 - val_recall: 0.5765 - val_precision: 0.1979
# Epoch 10/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6638 - auc: 0.6696 - recall: 0.6760 - precision: 0.2145WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6625 - auc: 0.6710 - recall: 0.6780 - precision: 0.2148 - val_loss: 0.6075 - val_auc: 0.6732 - val_recall: 0.5139 - val_precision: 0.2090
# Epoch 11/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6624 - auc: 0.6714 - recall: 0.6643 - precision: 0.2177WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6616 - auc: 0.6716 - recall: 0.6650 - precision: 0.2175 - val_loss: 0.6106 - val_auc: 0.6721 - val_recall: 0.5334 - val_precision: 0.2012
# Epoch 12/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6617 - auc: 0.6729 - recall: 0.6807 - precision: 0.2182WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6617 - auc: 0.6731 - recall: 0.6801 - precision: 0.2183 - val_loss: 0.6089 - val_auc: 0.6727 - val_recall: 0.5341 - val_precision: 0.2058
# Epoch 13/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6597 - auc: 0.6749 - recall: 0.6817 - precision: 0.2193WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6600 - auc: 0.6747 - recall: 0.6812 - precision: 0.2193 - val_loss: 0.6089 - val_auc: 0.6728 - val_recall: 0.5348 - val_precision: 0.2062
# Epoch 14/15
# 536/555 [===========================>..] - ETA: 0s - loss: 0.6607 - auc: 0.6739 - recall: 0.6753 - precision: 0.2180WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6606 - auc: 0.6740 - recall: 0.6748 - precision: 0.2182 - val_loss: 0.6085 - val_auc: 0.6719 - val_recall: 0.5146 - val_precision: 0.2103
# Epoch 15/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6604 - auc: 0.6750 - recall: 0.6737 - precision: 0.2205WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6608 - auc: 0.6747 - recall: 0.6733 - precision: 0.2205 - val_loss: 0.6077 - val_auc: 0.6718 - val_recall: 0.5529 - val_precision: 0.2010
# 740/740 [==============================] - 1s 915us/step
# 83/83 [==============================] - 0s 899us/step
# Epoch 1/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6662 - auc: 0.6640 - recall: 0.6828 - precision: 0.2123WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 6ms/step - loss: 0.6667 - auc: 0.6642 - recall: 0.6835 - precision: 0.2120 - val_loss: 0.6100 - val_auc: 0.6714 - val_recall: 0.5431 - val_precision: 0.2024
# Epoch 2/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6637 - auc: 0.6675 - recall: 0.6903 - precision: 0.2136WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6644 - auc: 0.6671 - recall: 0.6905 - precision: 0.2141 - val_loss: 0.6077 - val_auc: 0.6724 - val_recall: 0.5320 - val_precision: 0.2055
# Epoch 3/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6661 - auc: 0.6660 - recall: 0.6803 - precision: 0.2139WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6655 - auc: 0.6669 - recall: 0.6811 - precision: 0.2145 - val_loss: 0.6085 - val_auc: 0.6732 - val_recall: 0.5313 - val_precision: 0.2074
# Epoch 4/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6650 - auc: 0.6655 - recall: 0.6844 - precision: 0.2130WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6656 - auc: 0.6661 - recall: 0.6845 - precision: 0.2138 - val_loss: 0.6089 - val_auc: 0.6734 - val_recall: 0.5654 - val_precision: 0.2017
# Epoch 5/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6651 - auc: 0.6671 - recall: 0.6883 - precision: 0.2122WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6638 - auc: 0.6675 - recall: 0.6884 - precision: 0.2118 - val_loss: 0.6091 - val_auc: 0.6741 - val_recall: 0.4910 - val_precision: 0.2114
# Epoch 6/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6626 - auc: 0.6690 - recall: 0.6865 - precision: 0.2147WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6636 - auc: 0.6689 - recall: 0.6875 - precision: 0.2149 - val_loss: 0.6080 - val_auc: 0.6740 - val_recall: 0.5716 - val_precision: 0.2007
# Epoch 7/15
# 523/555 [===========================>..] - ETA: 0s - loss: 0.6646 - auc: 0.6677 - recall: 0.6854 - precision: 0.2144WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6637 - auc: 0.6691 - recall: 0.6901 - precision: 0.2146 - val_loss: 0.6110 - val_auc: 0.6732 - val_recall: 0.5076 - val_precision: 0.2091
# Epoch 8/15
# 524/555 [===========================>..] - ETA: 0s - loss: 0.6652 - auc: 0.6671 - recall: 0.6837 - precision: 0.2146WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6653 - auc: 0.6678 - recall: 0.6846 - precision: 0.2156 - val_loss: 0.6089 - val_auc: 0.6733 - val_recall: 0.5591 - val_precision: 0.2036
# Epoch 9/15
# 523/555 [===========================>..] - ETA: 0s - loss: 0.6618 - auc: 0.6700 - recall: 0.6855 - precision: 0.2130WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6636 - auc: 0.6689 - recall: 0.6873 - precision: 0.2135 - val_loss: 0.6085 - val_auc: 0.6732 - val_recall: 0.5953 - val_precision: 0.1969
# Epoch 10/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6630 - auc: 0.6689 - recall: 0.7037 - precision: 0.2125WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6633 - auc: 0.6694 - recall: 0.7043 - precision: 0.2131 - val_loss: 0.6110 - val_auc: 0.6729 - val_recall: 0.5125 - val_precision: 0.2093
# Epoch 11/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6636 - auc: 0.6701 - recall: 0.6879 - precision: 0.2167WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6636 - auc: 0.6701 - recall: 0.6879 - precision: 0.2168 - val_loss: 0.6112 - val_auc: 0.6727 - val_recall: 0.5348 - val_precision: 0.2045
# Epoch 12/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6631 - auc: 0.6693 - recall: 0.6915 - precision: 0.2133WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6633 - auc: 0.6693 - recall: 0.6920 - precision: 0.2136 - val_loss: 0.6106 - val_auc: 0.6729 - val_recall: 0.5438 - val_precision: 0.2040
# Epoch 13/15
# 527/555 [===========================>..] - ETA: 0s - loss: 0.6635 - auc: 0.6694 - recall: 0.6949 - precision: 0.2124WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6634 - auc: 0.6692 - recall: 0.6968 - precision: 0.2126 - val_loss: 0.6096 - val_auc: 0.6738 - val_recall: 0.5271 - val_precision: 0.2053
# Epoch 14/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6622 - auc: 0.6692 - recall: 0.6948 - precision: 0.2137WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6625 - auc: 0.6695 - recall: 0.6952 - precision: 0.2142 - val_loss: 0.6094 - val_auc: 0.6738 - val_recall: 0.5118 - val_precision: 0.2105
# Epoch 15/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6626 - auc: 0.6701 - recall: 0.6847 - precision: 0.2137WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6631 - auc: 0.6694 - recall: 0.6837 - precision: 0.2134 - val_loss: 0.6077 - val_auc: 0.6743 - val_recall: 0.5424 - val_precision: 0.2038
# 740/740 [==============================] - 1s 809us/step
# 83/83 [==============================] - 0s 864us/step
# Epoch 1/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6546 - auc: 0.6833 - recall: 0.6912 - precision: 0.2213WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6548 - auc: 0.6840 - recall: 0.6926 - precision: 0.2216 - val_loss: 0.6103 - val_auc: 0.6738 - val_recall: 0.5111 - val_precision: 0.2090
# Epoch 2/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6547 - auc: 0.6851 - recall: 0.6997 - precision: 0.2232WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6546 - auc: 0.6851 - recall: 0.6996 - precision: 0.2231 - val_loss: 0.6098 - val_auc: 0.6740 - val_recall: 0.4993 - val_precision: 0.2108
# Epoch 3/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6545 - auc: 0.6847 - recall: 0.6976 - precision: 0.2227WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6549 - auc: 0.6845 - recall: 0.6970 - precision: 0.2228 - val_loss: 0.6134 - val_auc: 0.6738 - val_recall: 0.4798 - val_precision: 0.2128
# Epoch 4/15
# 523/555 [===========================>..] - ETA: 0s - loss: 0.6557 - auc: 0.6849 - recall: 0.6946 - precision: 0.2241WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6561 - auc: 0.6837 - recall: 0.6937 - precision: 0.2235 - val_loss: 0.6090 - val_auc: 0.6737 - val_recall: 0.5292 - val_precision: 0.2073
# Epoch 5/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6540 - auc: 0.6863 - recall: 0.7013 - precision: 0.2242WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6530 - auc: 0.6862 - recall: 0.7009 - precision: 0.2234 - val_loss: 0.6111 - val_auc: 0.6732 - val_recall: 0.5063 - val_precision: 0.2117
# Epoch 6/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6522 - auc: 0.6873 - recall: 0.6968 - precision: 0.2247WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6541 - auc: 0.6867 - recall: 0.6968 - precision: 0.2243 - val_loss: 0.6085 - val_auc: 0.6720 - val_recall: 0.5257 - val_precision: 0.2086
# Epoch 7/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6539 - auc: 0.6874 - recall: 0.6970 - precision: 0.2248WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6544 - auc: 0.6869 - recall: 0.6968 - precision: 0.2249 - val_loss: 0.6115 - val_auc: 0.6723 - val_recall: 0.4951 - val_precision: 0.2092
# Epoch 8/15
# 549/555 [============================>.] - ETA: 0s - loss: 0.6536 - auc: 0.6862 - recall: 0.6900 - precision: 0.2229WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6540 - auc: 0.6862 - recall: 0.6907 - precision: 0.2234 - val_loss: 0.6079 - val_auc: 0.6729 - val_recall: 0.5417 - val_precision: 0.2047
# Epoch 9/15
# 542/555 [============================>.] - ETA: 0s - loss: 0.6534 - auc: 0.6873 - recall: 0.6915 - precision: 0.2234WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6549 - auc: 0.6864 - recall: 0.6901 - precision: 0.2237 - val_loss: 0.6092 - val_auc: 0.6724 - val_recall: 0.5292 - val_precision: 0.2065
# Epoch 10/15
# 524/555 [===========================>..] - ETA: 0s - loss: 0.6564 - auc: 0.6841 - recall: 0.7025 - precision: 0.2210WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6549 - auc: 0.6861 - recall: 0.7047 - precision: 0.2215 - val_loss: 0.6164 - val_auc: 0.6726 - val_recall: 0.4631 - val_precision: 0.2146
# Epoch 11/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6543 - auc: 0.6874 - recall: 0.6893 - precision: 0.2255WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6543 - auc: 0.6869 - recall: 0.6896 - precision: 0.2246 - val_loss: 0.6114 - val_auc: 0.6720 - val_recall: 0.5104 - val_precision: 0.2077
# Epoch 12/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6535 - auc: 0.6884 - recall: 0.7052 - precision: 0.2254WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6536 - auc: 0.6878 - recall: 0.7038 - precision: 0.2244 - val_loss: 0.6091 - val_auc: 0.6717 - val_recall: 0.5181 - val_precision: 0.2092
# Epoch 13/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6540 - auc: 0.6861 - recall: 0.7012 - precision: 0.2222WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6541 - auc: 0.6865 - recall: 0.7009 - precision: 0.2226 - val_loss: 0.6155 - val_auc: 0.6717 - val_recall: 0.4757 - val_precision: 0.2109
# Epoch 14/15
# 549/555 [============================>.] - ETA: 0s - loss: 0.6530 - auc: 0.6875 - recall: 0.6940 - precision: 0.2234WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6533 - auc: 0.6877 - recall: 0.6947 - precision: 0.2235 - val_loss: 0.6103 - val_auc: 0.6713 - val_recall: 0.4993 - val_precision: 0.2086
# Epoch 15/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6551 - auc: 0.6876 - recall: 0.6982 - precision: 0.2240WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6547 - auc: 0.6868 - recall: 0.6949 - precision: 0.2233 - val_loss: 0.6115 - val_auc: 0.6715 - val_recall: 0.4743 - val_precision: 0.2098
# 740/740 [==============================] - 1s 861us/step
# 83/83 [==============================] - 0s 811us/step
# Epoch 1/15
# 527/555 [===========================>..] - ETA: 0s - loss: 0.6566 - auc: 0.6822 - recall: 0.6890 - precision: 0.2224WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6581 - auc: 0.6835 - recall: 0.6914 - precision: 0.2225 - val_loss: 0.6103 - val_auc: 0.6733 - val_recall: 0.5160 - val_precision: 0.2055
# Epoch 2/15
# 527/555 [===========================>..] - ETA: 0s - loss: 0.6556 - auc: 0.6835 - recall: 0.6983 - precision: 0.2224WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6557 - auc: 0.6840 - recall: 0.6980 - precision: 0.2234 - val_loss: 0.6100 - val_auc: 0.6734 - val_recall: 0.4986 - val_precision: 0.2087
# Epoch 3/15
# 527/555 [===========================>..] - ETA: 0s - loss: 0.6567 - auc: 0.6851 - recall: 0.6982 - precision: 0.2250WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6559 - auc: 0.6858 - recall: 0.6978 - precision: 0.2252 - val_loss: 0.6080 - val_auc: 0.6736 - val_recall: 0.4965 - val_precision: 0.2102
# Epoch 4/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6534 - auc: 0.6878 - recall: 0.6880 - precision: 0.2256WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6551 - auc: 0.6863 - recall: 0.6848 - precision: 0.2252 - val_loss: 0.6066 - val_auc: 0.6735 - val_recall: 0.5612 - val_precision: 0.1995
# Epoch 5/15
# 536/555 [===========================>..] - ETA: 0s - loss: 0.6554 - auc: 0.6854 - recall: 0.7050 - precision: 0.2246WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6543 - auc: 0.6855 - recall: 0.7054 - precision: 0.2241 - val_loss: 0.6101 - val_auc: 0.6739 - val_recall: 0.5035 - val_precision: 0.2091
# Epoch 6/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6529 - auc: 0.6860 - recall: 0.6943 - precision: 0.2245WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6553 - auc: 0.6856 - recall: 0.6939 - precision: 0.2241 - val_loss: 0.6075 - val_auc: 0.6745 - val_recall: 0.5243 - val_precision: 0.2100
# Epoch 7/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6569 - auc: 0.6862 - recall: 0.6976 - precision: 0.2260WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6552 - auc: 0.6863 - recall: 0.6982 - precision: 0.2247 - val_loss: 0.6083 - val_auc: 0.6741 - val_recall: 0.4958 - val_precision: 0.2126
# Epoch 8/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6544 - auc: 0.6862 - recall: 0.6925 - precision: 0.2252WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6548 - auc: 0.6868 - recall: 0.6925 - precision: 0.2262 - val_loss: 0.6071 - val_auc: 0.6739 - val_recall: 0.5438 - val_precision: 0.2060
# Epoch 9/15
# 520/555 [===========================>..] - ETA: 0s - loss: 0.6562 - auc: 0.6851 - recall: 0.6930 - precision: 0.2252WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6561 - auc: 0.6854 - recall: 0.6920 - precision: 0.2259 - val_loss: 0.6069 - val_auc: 0.6735 - val_recall: 0.5285 - val_precision: 0.2094
# Epoch 10/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6582 - auc: 0.6828 - recall: 0.6966 - precision: 0.2229WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6564 - auc: 0.6848 - recall: 0.6990 - precision: 0.2229 - val_loss: 0.6134 - val_auc: 0.6742 - val_recall: 0.5014 - val_precision: 0.2138
# Epoch 11/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6562 - auc: 0.6860 - recall: 0.6916 - precision: 0.2252WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6561 - auc: 0.6857 - recall: 0.6924 - precision: 0.2248 - val_loss: 0.6074 - val_auc: 0.6738 - val_recall: 0.5480 - val_precision: 0.2056
# Epoch 12/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6551 - auc: 0.6865 - recall: 0.7054 - precision: 0.2240WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6555 - auc: 0.6857 - recall: 0.7041 - precision: 0.2236 - val_loss: 0.6074 - val_auc: 0.6731 - val_recall: 0.5250 - val_precision: 0.2100
# Epoch 13/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6552 - auc: 0.6872 - recall: 0.6995 - precision: 0.2248WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6553 - auc: 0.6872 - recall: 0.6994 - precision: 0.2248 - val_loss: 0.6145 - val_auc: 0.6739 - val_recall: 0.4937 - val_precision: 0.2137
# Epoch 14/15
# 519/555 [===========================>..] - ETA: 0s - loss: 0.6549 - auc: 0.6865 - recall: 0.6980 - precision: 0.2228WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6567 - auc: 0.6851 - recall: 0.6967 - precision: 0.2229 - val_loss: 0.6074 - val_auc: 0.6730 - val_recall: 0.5598 - val_precision: 0.2020
# Epoch 15/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6542 - auc: 0.6872 - recall: 0.6978 - precision: 0.2247WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6539 - auc: 0.6876 - recall: 0.6978 - precision: 0.2249 - val_loss: 0.6083 - val_auc: 0.6726 - val_recall: 0.5209 - val_precision: 0.2104
# 740/740 [==============================] - 1s 813us/step
# 83/83 [==============================] - 0s 800us/step
# Epoch 1/15
# 520/555 [===========================>..] - ETA: 0s - loss: 0.6660 - auc: 0.6668 - recall: 0.6899 - precision: 0.2147WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6671 - auc: 0.6674 - recall: 0.6905 - precision: 0.2140 - val_loss: 0.6066 - val_auc: 0.6709 - val_recall: 0.5431 - val_precision: 0.2083
# Epoch 2/15
# 549/555 [============================>.] - ETA: 0s - loss: 0.6646 - auc: 0.6682 - recall: 0.6881 - precision: 0.2145WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6649 - auc: 0.6682 - recall: 0.6880 - precision: 0.2146 - val_loss: 0.6075 - val_auc: 0.6701 - val_recall: 0.5556 - val_precision: 0.2024
# Epoch 3/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6673 - auc: 0.6676 - recall: 0.6922 - precision: 0.2162WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6667 - auc: 0.6674 - recall: 0.6916 - precision: 0.2160 - val_loss: 0.6072 - val_auc: 0.6704 - val_recall: 0.5341 - val_precision: 0.2088
# Epoch 4/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6648 - auc: 0.6682 - recall: 0.6804 - precision: 0.2164WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6657 - auc: 0.6678 - recall: 0.6793 - precision: 0.2169 - val_loss: 0.6076 - val_auc: 0.6701 - val_recall: 0.5556 - val_precision: 0.1998
# Epoch 5/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6660 - auc: 0.6680 - recall: 0.6900 - precision: 0.2153WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6662 - auc: 0.6673 - recall: 0.6889 - precision: 0.2150 - val_loss: 0.6075 - val_auc: 0.6694 - val_recall: 0.5243 - val_precision: 0.2083
# Epoch 6/15
# 536/555 [===========================>..] - ETA: 0s - loss: 0.6625 - auc: 0.6693 - recall: 0.6884 - precision: 0.2160WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6664 - auc: 0.6689 - recall: 0.6891 - precision: 0.2158 - val_loss: 0.6078 - val_auc: 0.6696 - val_recall: 0.5369 - val_precision: 0.2056
# Epoch 7/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6660 - auc: 0.6676 - recall: 0.6883 - precision: 0.2157WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6658 - auc: 0.6679 - recall: 0.6889 - precision: 0.2160 - val_loss: 0.6084 - val_auc: 0.6699 - val_recall: 0.4861 - val_precision: 0.2123
# Epoch 8/15
# 523/555 [===========================>..] - ETA: 0s - loss: 0.6657 - auc: 0.6677 - recall: 0.6856 - precision: 0.2151WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6659 - auc: 0.6682 - recall: 0.6842 - precision: 0.2163 - val_loss: 0.6072 - val_auc: 0.6692 - val_recall: 0.5473 - val_precision: 0.2030
# Epoch 9/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6661 - auc: 0.6676 - recall: 0.6804 - precision: 0.2152WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6661 - auc: 0.6685 - recall: 0.6808 - precision: 0.2160 - val_loss: 0.6085 - val_auc: 0.6685 - val_recall: 0.5132 - val_precision: 0.2079
# Epoch 10/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6658 - auc: 0.6674 - recall: 0.6877 - precision: 0.2145WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6645 - auc: 0.6691 - recall: 0.6891 - precision: 0.2149 - val_loss: 0.6135 - val_auc: 0.6700 - val_recall: 0.4604 - val_precision: 0.2149
# Epoch 11/15
# 521/555 [===========================>..] - ETA: 0s - loss: 0.6654 - auc: 0.6697 - recall: 0.6838 - precision: 0.2175WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6653 - auc: 0.6698 - recall: 0.6844 - precision: 0.2177 - val_loss: 0.6076 - val_auc: 0.6700 - val_recall: 0.5299 - val_precision: 0.2085
# Epoch 12/15
# 521/555 [===========================>..] - ETA: 0s - loss: 0.6674 - auc: 0.6696 - recall: 0.6925 - precision: 0.2165WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6664 - auc: 0.6692 - recall: 0.6903 - precision: 0.2157 - val_loss: 0.6087 - val_auc: 0.6690 - val_recall: 0.4979 - val_precision: 0.2124
# Epoch 13/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6675 - auc: 0.6684 - recall: 0.6858 - precision: 0.2159WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6661 - auc: 0.6694 - recall: 0.6871 - precision: 0.2161 - val_loss: 0.6112 - val_auc: 0.6701 - val_recall: 0.4958 - val_precision: 0.2116
# Epoch 14/15
# 518/555 [===========================>..] - ETA: 0s - loss: 0.6643 - auc: 0.6694 - recall: 0.6902 - precision: 0.2157WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6656 - auc: 0.6680 - recall: 0.6899 - precision: 0.2152 - val_loss: 0.6085 - val_auc: 0.6696 - val_recall: 0.5584 - val_precision: 0.2009
# Epoch 15/15
# 542/555 [============================>.] - ETA: 0s - loss: 0.6659 - auc: 0.6698 - recall: 0.6907 - precision: 0.2153WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# ...
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6756 - auc: 0.6667 - recall: 0.7165 - precision: 0.2156 - val_loss: 0.5699 - val_auc: 0.6793 - val_recall: 0.5458 - val_precision: 0.1791
# Epoch 7/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6762 - auc: 0.6653 - recall: 0.7177 - precision: 0.2164WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6751 - auc: 0.6669 - recall: 0.7192 - precision: 0.2170 - val_loss: 0.5684 - val_auc: 0.6800 - val_recall: 0.5128 - val_precision: 0.1873
# Epoch 8/15
# 523/555 [===========================>..] - ETA: 0s - loss: 0.6762 - auc: 0.6655 - recall: 0.7169 - precision: 0.2157WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6759 - auc: 0.6659 - recall: 0.7174 - precision: 0.2159 - val_loss: 0.5703 - val_auc: 0.6795 - val_recall: 0.5582 - val_precision: 0.1733
# Epoch 9/15
# 519/555 [===========================>..] - ETA: 0s - loss: 0.6755 - auc: 0.6657 - recall: 0.7097 - precision: 0.2151WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6755 - auc: 0.6667 - recall: 0.7083 - precision: 0.2160 - val_loss: 0.5701 - val_auc: 0.6801 - val_recall: 0.5483 - val_precision: 0.1771
# Epoch 10/15
# 549/555 [============================>.] - ETA: 0s - loss: 0.6751 - auc: 0.6672 - recall: 0.7196 - precision: 0.2169WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6747 - auc: 0.6674 - recall: 0.7194 - precision: 0.2168 - val_loss: 0.5704 - val_auc: 0.6795 - val_recall: 0.5169 - val_precision: 0.1878
# Epoch 11/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6756 - auc: 0.6675 - recall: 0.7127 - precision: 0.2181WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6761 - auc: 0.6670 - recall: 0.7146 - precision: 0.2171 - val_loss: 0.5752 - val_auc: 0.6793 - val_recall: 0.6152 - val_precision: 0.1625
# Epoch 12/15
# 522/555 [===========================>..] - ETA: 0s - loss: 0.6772 - auc: 0.6672 - recall: 0.7226 - precision: 0.2177WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6750 - auc: 0.6677 - recall: 0.7203 - precision: 0.2169 - val_loss: 0.5701 - val_auc: 0.6801 - val_recall: 0.5227 - val_precision: 0.1853
# Epoch 13/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6758 - auc: 0.6671 - recall: 0.7201 - precision: 0.2179WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6756 - auc: 0.6675 - recall: 0.7205 - precision: 0.2180 - val_loss: 0.5732 - val_auc: 0.6787 - val_recall: 0.5500 - val_precision: 0.1790
# Epoch 14/15
# 536/555 [===========================>..] - ETA: 0s - loss: 0.6739 - auc: 0.6660 - recall: 0.7119 - precision: 0.2167WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6752 - auc: 0.6658 - recall: 0.7127 - precision: 0.2173 - val_loss: 0.5748 - val_auc: 0.6781 - val_recall: 0.5937 - val_precision: 0.1692
# Epoch 15/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6745 - auc: 0.6682 - recall: 0.7220 - precision: 0.2167WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6737 - auc: 0.6686 - recall: 0.7219 - precision: 0.2166 - val_loss: 0.5727 - val_auc: 0.6795 - val_recall: 0.5590 - val_precision: 0.1751
# 740/740 [==============================] - 1s 818us/step
# 83/83 [==============================] - 0s 793us/step
# Epoch 1/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6763 - auc: 0.6656 - recall: 0.7136 - precision: 0.2178WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 6ms/step - loss: 0.6764 - auc: 0.6657 - recall: 0.7134 - precision: 0.2174 - val_loss: 0.5777 - val_auc: 0.6687 - val_recall: 0.5599 - val_precision: 0.1686
# Epoch 2/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6747 - auc: 0.6672 - recall: 0.7141 - precision: 0.2182WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6745 - auc: 0.6669 - recall: 0.7134 - precision: 0.2175 - val_loss: 0.5791 - val_auc: 0.6683 - val_recall: 0.5813 - val_precision: 0.1635
# Epoch 3/15
# 516/555 [==========================>...] - ETA: 0s - loss: 0.6764 - auc: 0.6665 - recall: 0.7178 - precision: 0.2164WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6751 - auc: 0.6666 - recall: 0.7174 - precision: 0.2161 - val_loss: 0.5792 - val_auc: 0.6680 - val_recall: 0.5747 - val_precision: 0.1648
# Epoch 4/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6761 - auc: 0.6673 - recall: 0.7129 - precision: 0.2172WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6763 - auc: 0.6667 - recall: 0.7139 - precision: 0.2168 - val_loss: 0.5797 - val_auc: 0.6681 - val_recall: 0.5879 - val_precision: 0.1645
# Epoch 5/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6748 - auc: 0.6678 - recall: 0.7162 - precision: 0.2171WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6748 - auc: 0.6676 - recall: 0.7161 - precision: 0.2169 - val_loss: 0.5813 - val_auc: 0.6676 - val_recall: 0.5896 - val_precision: 0.1625
# Epoch 6/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6751 - auc: 0.6675 - recall: 0.7220 - precision: 0.2167WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6750 - auc: 0.6678 - recall: 0.7223 - precision: 0.2169 - val_loss: 0.5816 - val_auc: 0.6659 - val_recall: 0.5450 - val_precision: 0.1708
# Epoch 7/15
# 521/555 [===========================>..] - ETA: 0s - loss: 0.6760 - auc: 0.6659 - recall: 0.7184 - precision: 0.2159WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6752 - auc: 0.6666 - recall: 0.7197 - precision: 0.2159 - val_loss: 0.5790 - val_auc: 0.6674 - val_recall: 0.5277 - val_precision: 0.1741
# Epoch 8/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6747 - auc: 0.6664 - recall: 0.7179 - precision: 0.2170WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6753 - auc: 0.6667 - recall: 0.7186 - precision: 0.2176 - val_loss: 0.5815 - val_auc: 0.6671 - val_recall: 0.5723 - val_precision: 0.1654
# Epoch 9/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6747 - auc: 0.6677 - recall: 0.7189 - precision: 0.2176WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6757 - auc: 0.6677 - recall: 0.7181 - precision: 0.2182 - val_loss: 0.5815 - val_auc: 0.6675 - val_recall: 0.5747 - val_precision: 0.1663
# Epoch 10/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6744 - auc: 0.6684 - recall: 0.7199 - precision: 0.2167WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6745 - auc: 0.6684 - recall: 0.7199 - precision: 0.2169 - val_loss: 0.5805 - val_auc: 0.6660 - val_recall: 0.5326 - val_precision: 0.1758
# Epoch 11/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6759 - auc: 0.6661 - recall: 0.7148 - precision: 0.2167WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6760 - auc: 0.6661 - recall: 0.7148 - precision: 0.2167 - val_loss: 0.5847 - val_auc: 0.6670 - val_recall: 0.6292 - val_precision: 0.1560
# Epoch 12/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6766 - auc: 0.6677 - recall: 0.7283 - precision: 0.2185WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6744 - auc: 0.6686 - recall: 0.7281 - precision: 0.2182 - val_loss: 0.5802 - val_auc: 0.6682 - val_recall: 0.5293 - val_precision: 0.1743
# Epoch 13/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6756 - auc: 0.6682 - recall: 0.7174 - precision: 0.2183WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6757 - auc: 0.6682 - recall: 0.7170 - precision: 0.2183 - val_loss: 0.5833 - val_auc: 0.6654 - val_recall: 0.5541 - val_precision: 0.1675
# Epoch 14/15
# 524/555 [===========================>..] - ETA: 0s - loss: 0.6742 - auc: 0.6673 - recall: 0.7142 - precision: 0.2176WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6757 - auc: 0.6663 - recall: 0.7141 - precision: 0.2177 - val_loss: 0.5861 - val_auc: 0.6649 - val_recall: 0.6078 - val_precision: 0.1599
# Epoch 15/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6746 - auc: 0.6680 - recall: 0.7233 - precision: 0.2153WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6750 - auc: 0.6675 - recall: 0.7230 - precision: 0.2152 - val_loss: 0.5834 - val_auc: 0.6671 - val_recall: 0.5863 - val_precision: 0.1633
# 740/740 [==============================] - 1s 790us/step
# 83/83 [==============================] - 0s 870us/step
# accuracy_train     0.611339
# f1_train           0.324858
# recall_train       0.657932
# precision_train    0.215840
# auc_train          0.630779
# accuracy_test      0.603633
# f1_test            0.318061
# recall_test        0.642312
# precision_test     0.214131
# auc_test           0.619775
# dtype: float64
# 312/312 [==============================] - 0s 991us/step

# %% [markdown]
# #### Train NN with Random Under Sampling

# %%
import imblearn.under_sampling as underSample
from sklearn.neural_network import MLPClassifier

#set NN model
nn_model = MLPClassifier(activation='logistic', batch_size=512, learning_rate='invscaling',
              learning_rate_init=0.1, max_iter=10, random_state=0,
              solver='sgd')
name = 'MLP'
assess = class_cv.validateModel(x_train[subset_15],
                                y_train_dict['Target_0.15'],
                                model=nn_model ,
                                scaler=True ,
                                over_sampling=False,
                                under_sampling=True,
                                predictions=False,
                                cv_type='stratKfold',
                                scaler_type='stand',
                                train_size=10,
                                test_size=1,
                                gap=0)

#store scores
assess_df = assess['scores']
assess_df['model'] = name

#store model 
model = assess['model']
new_model_list.append(model)

scaler = assess['scaler']

full_assess = pd.concat([full_assess,
                            assess_df],
                        axis=0)

#fit scaler on test set 
X_test = pd.DataFrame(scaler.transform(x_test[subset_15]), 
                        index = x_test.index, 
                        columns = subset_15)

assess_test_dict, assess_test_df = assessTest(X_test,
                                                y_test_dict['Target_0.15'],
                                                model)

assess_test_MLP = pd.DataFrame.from_records([assess_test_dict])

assess_test_dict['model'] = name
assess_test_df['model'] = name

full_assess_test = pd.concat([test_assess_df,
                            assess_test_MLP],
                        axis=0)
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# Undersampling will be performed:
# Strategy: Random Undersampling
# accuracy_train     0.602540
# f1_train           0.623644
# recall_train       0.658616
# precision_train    0.592211
# auc_train          0.602540
# accuracy_test      0.567301
# f1_test            0.304446
# recall_test        0.656376
# precision_test     0.200518
# auc_test           0.604470
# dtype: float64

# %% [markdown]
# ### Export Metric Report Data

# %%
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\\Validation\full_CV_results_noBeta_Lasso_Raw.csv'
full_assess.to_csv(path)

# %% [markdown]
# ### Plot Perfomance

# %% [markdown]
# #### Boxplot Format A

# %%
a = full_assess.copy()

title = 'Target 15 - Model Performance on Validation set - K=10'
plt.figure(figsize=(15, 10))
ax1 = plt.subplot(2, 1, 1)
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'auc_test'].values
df_assess.plot(kind='box', title='boxplot', showmeans=True,ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('AUC', size=15)


ax2 = plt.subplot(2, 1, 2, ) # Share x-axis ticks with ax1
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'precision_test'].values
df_assess.plot(kind='box', showmeans=True,ax=ax2)

ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
plt.tight_layout()

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title} - Lasso.png'
# plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# #### Boxplot Format B

# %%
title = 'Target 15 - Model Performance on Validation set - K=10'
plt.figure(figsize=(15, 10))

# Use sharex parameter to share x-axis ticks between subplots
ax1 = plt.subplot(2, 1, 1)
sns.boxplot(x=a['model'], y=a['auc_test'], hue=a['model'], ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('AUC', size=15)

# Set legend location outside the figure
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2 = plt.subplot(2, 1, 2, sharex=ax1) # Share x-axis ticks with ax1
sns.boxplot(x=a['model'], y=a['precision_test'], hue=a['model'], ax=ax2)
ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
ax2.legend().remove()

plt.tight_layout() # To prevent overlapping of the legend with the second subplot

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title} - Format 2 - Lasso.png'
# plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# #### Display Training and Valdation Results

# %% [markdown]
# Export average scores from the Cross Validation

# %%
train_val_scores = full_assess.groupby('model').mean()
cols_ = train_val_scores.columns[train_val_scores.columns.str.contains('test')]
for col in cols_:
    
    new_col = col.replace('test','val')
    train_val_scores = train_val_scores.rename(columns = {col:new_col})
    
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Validation\modelMetricPerfomance_Target_0.15_valSet_Lasso_Raw.csv'
train_val_scores.to_csv(assess_path)
display(train_val_scores)
# Out:
#                     accuracy_train  f1_train  recall_train  precision_train  \
# model
# DecisionTree              0.612280  0.326780      0.661444         0.217340
# Keras_NN                  0.611339  0.324858      0.657932         0.215840
# LightGB                   0.621852  0.331742      0.660730         0.221477
# LogisticRegression        0.611906  0.317859      0.636534         0.211820
# MLP                       0.602540  0.623644      0.658616         0.592211
#
#                     auc_train  accuracy_val    f1_val  recall_val  \
# model
# DecisionTree         0.632792      0.596690  0.306977    0.625842
# Keras_NN             0.630779      0.603633  0.318061    0.642312
# LightGB              0.638073      0.616264  0.325035    0.639766
# LogisticRegression   0.622181      0.609397  0.317026    0.628122
# MLP                  0.602540      0.567301  0.304446    0.656376
#
#                     precision_val   auc_val
# model
# DecisionTree             0.205743  0.608857
# Keras_NN                 0.214131  0.619775
# LightGB                  0.221981  0.626074
# LogisticRegression       0.215520  0.617215
# MLP                      0.200518  0.604470

# %% [markdown]
# Export scores on test set

# %%
test_assess_df = test_assess_df.reset_index().set_index('model')
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Test\modelMetricPerfomance_Target_0.15_testSet_Lasso_Raw.csv'
test_assess_df.to_csv(assess_path)
display(test_assess_df)
# Out:
#                     index  accuracy       auc  precision    recall
# model
# LogisticRegression      0  0.735377  0.607485   0.241133  0.431122
# DecisionTree            1  0.733624  0.588546   0.226471  0.388484
# LightGB                 2  0.751052  0.607533   0.251173  0.409621
# Keras_NN                3  0.727013  0.604629   0.234556  0.435860
# MLP                     0  0.711088  0.597236   0.222018  0.440233

# %% [markdown]
# ### Export Models and scalers

# %%
model_names = ['LogisticRegression_Raw.pkl', 'DecisionTree_Raw.pkl', 'LightGB_Raw.pkl', 'Keras_NN_Raw.pkl','MLP_Raw.pkl']


for model, model_name in zip(new_model_list, model_names):
    joblib.dump(model, f'{path}{model_name}', compress=9)
    
    
joblib.dump(scaler, f'{path}scaler.pkl', compress=9)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\rafae\AppData\Local\Temp\tmpw3mbd0i5\assets
# INFO:tensorflow:Assets written to: C:\Users\rafae\AppData\Local\Temp\tmpw3mbd0i5\assets

# %% [markdown]
# ### Import Models

# %%
model_list = []
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Models\Raw\\'
for model, model_name in zip(new_model_list, model_names):
    model_clone = joblib.load(f'{path}{model_name}')
    
    model_list.append(model_clone)
    
    
scaler = joblib.load(f'{path}scaler.pkl')

# %%
test_stand = pd.DataFrame(scaler.transform(x_test[subset_15]), index = x_test.index, columns= subset_15)

model_clone.predict(test_stand).mean()

# %% [markdown]
# #### ROC Curve Comparison

# %%
import DataScalling as scalling
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras_NN','MLP','MLP-Oversampling']
roc_curve(models = new_model_list,
                       names = model_names, 
                       X_train = X_test[subset_15],
                       y_train  = X_test,
                       X_val = X_test[subset_15],
                       y_val= y_test)

title = 'Model Perfomance Comparison - ROC Curve - Test Set - Target 0.15'
plt.title(title, 
          size = 15)
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title} - Lasso.png'
plt.tight_layout()
plt.savefig(name_plot, dpi=300)
# Out:
# 312/312 [==============================] - 0s 1ms/step
