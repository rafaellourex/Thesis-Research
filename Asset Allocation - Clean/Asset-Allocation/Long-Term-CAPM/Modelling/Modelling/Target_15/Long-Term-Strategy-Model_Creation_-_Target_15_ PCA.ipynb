# %% [markdown]
# ## Import Cleaned Data

# %% [markdown]
# __DataFrames:__
# df_model - df with all the features (independent festures + Target)
# x - df with all independent features
# y - df with dependent feature
# x_train - df with training data from x
# x_train_out - df with training data from x with outliers treatment applied
# x_test - df with test data from x
# x_test_out - df with test data from x with outliers treatment applied

# %%
import sys
sys.path.insert(1, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions')
sys.path.insert(2, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions\Functions')
sys.path.insert(3, r'..\..\..')


import Classification_CV as class_cv
import importCleanedData as importData
import importSubsets as subsets

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from tensorflow import keras

import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

#set preferences
sns.set_style('whitegrid')

#set color for graphs
#set color for graphs
palette = ["#e41a1c", "#377eb8", "#4daf4a", "#984ea3"]

# dir = r'C:\Users\rafae\Personal\Github\Asset-Allocation\Long-Term-CAPM\SampleData\Sample'
dir = r'..\..\..\SampleData\Sample'
df_model_skew,df_target = importData.importCleanedData(dir=dir,target='CAPM')


#split data
date = '2018-01-01'
#split data without transformation
x_train,x_train_out,x_test, x_test_out,y_train_dict ,y_test_dict, y_train,y_test = importData.splitData(df_model_skew, date) 

#set columns
ratio_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Ratio'))]
shares_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Share'))]
margin_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Margin'))]
turnover_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Turnover'))]
dividend_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('dividend'))]


components_pca, pca_components_test = importData.runPCA(x_train_out= x_train_out,x_test = x_test)


#import subsets
lasso_subset_0, lasso_subset_15, mi_subset_0, mi_subset_15, lgb_subset, corr_subset0, corr_subset15 = subsets.importSubsets()


subset_0, subset_15 = lasso_subset_0, lasso_subset_15
# Out:
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# CAPM
# Import data from: ..\..\..\SampleData\Sample\LongTerm-DataPreparation_Skew.csv
# Original CAPM is being used as Target
# Nr of rows:
# 72538
# The variance explained by each component is: [50.70262543 16.3180414  12.90616231  7.80559243  6.69692605  5.82614766
#   4.47015907  4.07836541  3.82626867  3.40508117  3.17395217  2.97398597
#   2.84255924  2.7491931   2.6284572   2.30920491  2.29580116  2.24676716
#   2.1685526   2.08344875  1.96058327  1.88331954  1.85945512  1.79999003
#   1.75303096  1.72999438  1.67342676  1.57892838  1.52235707  1.48115797
#   1.44613583  1.42029951  1.39091026  1.35520895  1.32448072  1.29342424
#   1.27059382  1.25051426  1.2247642   1.18608517  1.17810508  1.15156743
#   1.14454538  1.12935887  1.10669478  1.0815426   1.07222534  1.05458183
#   1.03848544  1.01988948  1.01877496  0.99533768  0.98807987]
# The total variance explained by the components is: 0.7618344466001962

# %% [markdown]
# # Modelling Stage - Target 15

# %% [markdown]
# # Compare Model Perfomance

# %%
def gen_NNClassification (x, y, hidden_layer_sizes,activation_list, dropout,optimizer,loss = 'BinaryCrossentropy', metrics = ['AUC'],batch_size=180,epochs=10,validation_split = 0.25, class_weight = None, output_bias =None ):
    
    print('Neural Network Parameters:')
    print(f'Optimizer: {optimizer}')
    print(f'Loss: {loss}')
    print(f'Hidden Layer tructure: {hidden_layer_sizes}')
    print(f'Acivation Functions: {activation_list}')
    print(f'Dropout: {dropout}')
    print(f'Class Weight: {class_weight}')
    print(f'Output Bias: {output_bias}')
    
    #import libraries
    from scikeras.wrappers import KerasClassifier, KerasRegressor
    from tensorflow import keras
    reset_random_seeds()
    #get nr features in
    n_features_in_ = x.shape[1]
    n_classes_ = len(y.unique())
    
    if output_bias is not None:
        output_bias =keras.initializers.Constant(output_bias)
    
    #set keras model
    model = keras.models.Sequential()
    
    #define input shape
    # model.add(keras.layers.Input(shape=(n_features_in_,)))
    model.add(keras.layers.Dense(
          4, activation='relu',
          input_shape=(n_features_in_,)))
    
    #define hidden layers
    for hidden_layer_size, activation_ in zip(hidden_layer_sizes,
                                              activation_list):
        
        model.add(keras.layers.Dense(hidden_layer_size,
                                     activation=activation_))
        
        model.add(keras.layers.Dropout(dropout))
    
    #define output layer
    model.add(keras.layers.Dense(1,
                                 activation="sigmoid",
                                 bias_initializer=output_bias))
    
    #compile model 
    model.compile(optimizer=optimizer,
                  loss=loss,
                  metrics=metrics,
                  )
    
    #transform to SKlearn format
    NNmodel = KerasClassifier( model=model,
                            batch_size= batch_size,
                            epochs= epochs,
                            class_weight=class_weight,
                            validation_split=validation_split,
                            loss = loss)

    return NNmodel

metrics = ['AUC','Recall','Precision']


def reset_random_seeds():
    import random
    from numpy.random import seed
    import os
    import numpy as np 
    from tensorflow import random as r
    
    seed_nr = 0
    os.environ['PYTHONHASHSEED']=str(seed_nr)
    r.set_seed(seed_nr)
    np.random.seed(seed_nr)

from numpy.random import seed
from tensorflow import keras 


reset_random_seeds()
optimizer = keras.optimizers.RMSprop(learning_rate=0.001)
loss_ = keras.losses.BinaryCrossentropy()
NNmodel = gen_NNClassification(components_pca, 
                                 y_train_dict['Target_0.15'],
                                 hidden_layer_sizes = (50,),
                                 activation_list = ['relu'],
                                 dropout = 0.3,
                                 optimizer =optimizer ,
                                 loss = loss_, 
                                 metrics = metrics,
                                 batch_size=64,
                                 epochs=15,
                                 validation_split = 0.25,
                                 class_weight = 'balanced',
                                 output_bias =None )

def roc_curve (models,names,X_train,y_train, X_val, y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        list with model names and a list of models 
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays ROC curve of the respective models 
    
    '''''''''''''''
    
    names= names
    from sklearn.metrics import roc_curve
    sns.set_theme(style = 'whitegrid')
    plt.figure(figsize = (10,10))
    for i, names ,in zip(models,names):
        # i.fit(X_train,y_train)
        thresh_dict = {}
        prob_model = i.predict_proba(X_val)
        
        fpr_DT_ent, tpr_DT_ent, thresholds_DT_ent = roc_curve(y_val, prob_model[:,1])
        plt.plot(fpr_DT_ent, tpr_DT_ent, label=f"ROC Curve {names}" , )
        
        plt.xlabel('FPR')
        plt.ylabel('TPR')
        plt.legend()
           
def precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted inside the function 
    
    '''''''''''''''
    names=names
    model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()
    
    
def fitted_precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted outside the function 
    
    '''''''''''''''
    names=names
    #model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()

def assessTest (x_test, y_test, model):
    
    col = x_test.columns[4]
    index__ = x_test.reset_index()[['symbol','fillingDate',col]].set_index(['symbol','fillingDate'])
    target_copy = df_target.copy()
    target_copy['fillingDate'] = target_copy['fillingDate'].astype(str)
    target_copy = target_copy.drop_duplicates(['symbol','fillingDate']).set_index(['symbol','fillingDate'])
    target_copy = target_copy.loc[target_copy.index.isin(index__.index)]
    
    assess_test_dict = dict()
    pred_test = model.predict(x_test)
    assess_test = pd.DataFrame(index = y_test.index)
    assess_test['Prediction'] = pred_test
    assess_test['Target'] = y_test
#     assess_test['returns'] = df_model.loc[df_model.index.isin(y_test.index),'futReturns']
    assess_test['excReturns'] = target_copy.loc[target_copy.index.isin(index__.index),'futAlpha']

    avg_returns = assess_test.groupby('Prediction').mean()[['excReturns']]


    from sklearn.metrics import roc_auc_score, precision_score, recall_score,accuracy_score
    auc  = roc_auc_score(assess_test['Target'],assess_test['Prediction'] )
    precision = precision_score(assess_test['Target'],assess_test['Prediction'] )
    recall =  recall_score(assess_test['Target'],assess_test['Prediction'] )
    acc =  accuracy_score(assess_test['Target'],assess_test['Prediction'] )
    
    assess_test_dict['accuracy'] = acc
    assess_test_dict['auc'] = auc
    assess_test_dict['precision'] = precision
    assess_test_dict['recall'] = recall
    return(assess_test_dict,assess_test)
# Out:
# Neural Network Parameters:
# Optimizer: <keras.optimizers.optimizer_experimental.rmsprop.RMSprop object at 0x00000198D9C908B0>
# Loss: <keras.losses.BinaryCrossentropy object at 0x00000198B3A07790>
# Hidden Layer tructure: (50,)
# Acivation Functions: ['relu']
# Dropout: 0.3
# Class Weight: balanced
# Output Bias: None

# %% [markdown]
# ## Target 15

# %% [markdown]
# Perfomance is compared using using standardized data since Neural Networks and Logistic Regressions are highly affected by data scalling.

# %%
#set models
dt_model = DecisionTreeClassifier(class_weight='balanced',
                                  max_depth=6,
                                  max_features=9,
                                  min_samples_leaf=10,
                                  random_state=0)


lgb_model = lgb.LGBMClassifier(boosting_type='dart',
                               class_weight='balanced',
                               learning_rate=0.2,
                               max_depth=2, 
                               n_estimators=50,
                               random_state=0)

lr_model = LogisticRegression(class_weight='balanced', penalty=None, random_state=0,
                   solver='newton-cholesky')


model_list = [lr_model,dt_model, lgb_model,NNmodel][:]
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras_NN'][:]

new_model_list = []
full_assess = pd.DataFrame()
full_assess_test = pd.DataFrame()
test_assess_list = []
#iterate over the models and perform CV 
for model, name in zip(model_list, model_names):
    assess = class_cv.validateModel(components_pca,
                                    y_train_dict['Target_0.15'],
                                    model=model ,
                                    scaler=False ,
                                    over_sampling=False,
                                    predictions=False,
                                    cv_type='stratKfold',
                                    scaler_type='stand',
                                    train_size=10,
                                    test_size=1,
                                    gap=0)
    
    #store scores
    assess_df = assess['scores']
    assess_df['model'] = name
    
    #store model 
    model = assess['model']
    new_model_list.append(model)
    
    # scaler = assess['scaler']
    
    full_assess = pd.concat([full_assess,
                             assess_df],
                            axis=0)
    
    
    X_test = pca_components_test
    
    assess_test_dict, assess_test_df = assessTest(X_test,
                                                  y_test_dict['Target_0.15'],
                                                  model)
    assess_test_dict['model'] = name
    assess_test_df['model'] = name
    
    full_assess_test = pd.concat([full_assess_test,
                             assess_test_df],
                            axis=0)
    test_assess_list.append(assess_test_dict)
    
test_assess_df = pd.DataFrame.from_records(test_assess_list)
# Out:
# stratKfold
# Nr of splits: 10
# accuracy_train     0.638998
# f1_train           0.337689
# recall_train       0.647843
# precision_train    0.228370
# auc_train          0.642688
# accuracy_test      0.631615
# f1_test            0.333395
# recall_test        0.627572
# precision_test     0.234048
# auc_test           0.629931
# dtype: float64
# stratKfold
# Nr of splits: 10
# accuracy_train     0.593524
# f1_train           0.315433
# recall_train       0.658824
# precision_train    0.207485
# auc_train          0.620769
# accuracy_test      0.576260
# f1_test            0.287567
# recall_test        0.596767
# precision_test     0.190716
# auc_test           0.584818
# dtype: float64
# stratKfold
# Nr of splits: 10
# accuracy_train     0.613899
# f1_train           0.329541
# recall_train       0.667931
# precision_train    0.218740
# auc_train          0.636442
# accuracy_test      0.607438
# f1_test            0.320275
# recall_test        0.640151
# precision_test     0.215641
# auc_test           0.621088
# dtype: float64
# stratKfold
# Nr of splits: 10
# Epoch 1/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6954 - auc: 0.5947 - recall: 0.6364 - precision: 0.1838WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 5s 8ms/step - loss: 0.6955 - auc: 0.5956 - recall: 0.6375 - precision: 0.1842 - val_loss: 0.6208 - val_auc: 0.6466 - val_recall: 0.6266 - val_precision: 0.1799
# Epoch 2/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6693 - auc: 0.6548 - recall: 0.7426 - precision: 0.2023WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6695 - auc: 0.6547 - recall: 0.7424 - precision: 0.2024 - val_loss: 0.6100 - val_auc: 0.6688 - val_recall: 0.6537 - val_precision: 0.1922
# Epoch 3/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6563 - auc: 0.6744 - recall: 0.7614 - precision: 0.2105WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6571 - auc: 0.6740 - recall: 0.7606 - precision: 0.2107 - val_loss: 0.6069 - val_auc: 0.6790 - val_recall: 0.6078 - val_precision: 0.2003
# Epoch 4/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6501 - auc: 0.6825 - recall: 0.7619 - precision: 0.2135WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6509 - auc: 0.6830 - recall: 0.7611 - precision: 0.2141 - val_loss: 0.6024 - val_auc: 0.6844 - val_recall: 0.6273 - val_precision: 0.2016
# Epoch 5/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6468 - auc: 0.6886 - recall: 0.7676 - precision: 0.2153WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6468 - auc: 0.6886 - recall: 0.7676 - precision: 0.2153 - val_loss: 0.6046 - val_auc: 0.6873 - val_recall: 0.5772 - val_precision: 0.2089
# Epoch 6/15
# 521/555 [===========================>..] - ETA: 0s - loss: 0.6445 - auc: 0.6933 - recall: 0.7690 - precision: 0.2163WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6443 - auc: 0.6938 - recall: 0.7702 - precision: 0.2165 - val_loss: 0.5994 - val_auc: 0.6888 - val_recall: 0.6015 - val_precision: 0.2096
# Epoch 7/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6431 - auc: 0.6953 - recall: 0.7617 - precision: 0.2170WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6429 - auc: 0.6952 - recall: 0.7619 - precision: 0.2170 - val_loss: 0.6036 - val_auc: 0.6885 - val_recall: 0.5709 - val_precision: 0.2117
# Epoch 8/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6420 - auc: 0.6961 - recall: 0.7640 - precision: 0.2184WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6420 - auc: 0.6963 - recall: 0.7641 - precision: 0.2187 - val_loss: 0.5990 - val_auc: 0.6907 - val_recall: 0.5967 - val_precision: 0.2112
# Epoch 9/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6396 - auc: 0.6986 - recall: 0.7624 - precision: 0.2180WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6407 - auc: 0.6984 - recall: 0.7632 - precision: 0.2188 - val_loss: 0.5969 - val_auc: 0.6925 - val_recall: 0.6001 - val_precision: 0.2138
# Epoch 10/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6406 - auc: 0.6980 - recall: 0.7632 - precision: 0.2186WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6396 - auc: 0.6987 - recall: 0.7645 - precision: 0.2183 - val_loss: 0.6001 - val_auc: 0.6927 - val_recall: 0.5814 - val_precision: 0.2160
# Epoch 11/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6382 - auc: 0.7013 - recall: 0.7527 - precision: 0.2229WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6386 - auc: 0.7012 - recall: 0.7528 - precision: 0.2232 - val_loss: 0.6052 - val_auc: 0.6937 - val_recall: 0.5494 - val_precision: 0.2228
# Epoch 12/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6414 - auc: 0.6990 - recall: 0.7561 - precision: 0.2215WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6407 - auc: 0.6994 - recall: 0.7585 - precision: 0.2212 - val_loss: 0.6015 - val_auc: 0.6937 - val_recall: 0.5431 - val_precision: 0.2235
# Epoch 13/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6379 - auc: 0.7022 - recall: 0.7581 - precision: 0.2244WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6382 - auc: 0.7020 - recall: 0.7579 - precision: 0.2242 - val_loss: 0.5978 - val_auc: 0.6947 - val_recall: 0.5654 - val_precision: 0.2216
# Epoch 14/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6374 - auc: 0.7031 - recall: 0.7507 - precision: 0.2244WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6373 - auc: 0.7026 - recall: 0.7500 - precision: 0.2242 - val_loss: 0.6013 - val_auc: 0.6946 - val_recall: 0.5501 - val_precision: 0.2238
# Epoch 15/15
# 521/555 [===========================>..] - ETA: 0s - loss: 0.6368 - auc: 0.7034 - recall: 0.7469 - precision: 0.2258WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6381 - auc: 0.7020 - recall: 0.7443 - precision: 0.2254 - val_loss: 0.5990 - val_auc: 0.6935 - val_recall: 0.5570 - val_precision: 0.2207
# 740/740 [==============================] - 1s 929us/step
# 83/83 [==============================] - 0s 946us/step
# Epoch 1/15
# 527/555 [===========================>..] - ETA: 0s - loss: 0.6404 - auc: 0.6993 - recall: 0.7426 - precision: 0.2238WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6406 - auc: 0.6995 - recall: 0.7422 - precision: 0.2238 - val_loss: 0.5993 - val_auc: 0.6957 - val_recall: 0.5480 - val_precision: 0.2269
# Epoch 2/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6399 - auc: 0.7006 - recall: 0.7376 - precision: 0.2260WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6399 - auc: 0.7006 - recall: 0.7376 - precision: 0.2260 - val_loss: 0.6021 - val_auc: 0.6955 - val_recall: 0.5341 - val_precision: 0.2277
# Epoch 3/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6387 - auc: 0.7009 - recall: 0.7368 - precision: 0.2271WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6392 - auc: 0.7010 - recall: 0.7373 - precision: 0.2276 - val_loss: 0.6062 - val_auc: 0.6951 - val_recall: 0.5410 - val_precision: 0.2252
# Epoch 4/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6384 - auc: 0.7015 - recall: 0.7383 - precision: 0.2257WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6395 - auc: 0.7011 - recall: 0.7376 - precision: 0.2261 - val_loss: 0.6008 - val_auc: 0.6944 - val_recall: 0.5480 - val_precision: 0.2220
# Epoch 5/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6398 - auc: 0.7029 - recall: 0.7385 - precision: 0.2274WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6387 - auc: 0.7027 - recall: 0.7382 - precision: 0.2262 - val_loss: 0.6085 - val_auc: 0.6942 - val_recall: 0.5153 - val_precision: 0.2250
# Epoch 6/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6384 - auc: 0.7030 - recall: 0.7379 - precision: 0.2283WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6385 - auc: 0.7029 - recall: 0.7390 - precision: 0.2280 - val_loss: 0.5953 - val_auc: 0.6941 - val_recall: 0.5369 - val_precision: 0.2210
# Epoch 7/15
# 524/555 [===========================>..] - ETA: 0s - loss: 0.6388 - auc: 0.7020 - recall: 0.7285 - precision: 0.2286WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6381 - auc: 0.7031 - recall: 0.7312 - precision: 0.2289 - val_loss: 0.6039 - val_auc: 0.6940 - val_recall: 0.5195 - val_precision: 0.2245
# Epoch 8/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6375 - auc: 0.7023 - recall: 0.7319 - precision: 0.2269WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6382 - auc: 0.7021 - recall: 0.7314 - precision: 0.2274 - val_loss: 0.6001 - val_auc: 0.6947 - val_recall: 0.5410 - val_precision: 0.2220
# Epoch 9/15
# 537/555 [============================>.] - ETA: 0s - loss: 0.6371 - auc: 0.7038 - recall: 0.7266 - precision: 0.2286WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6379 - auc: 0.7037 - recall: 0.7276 - precision: 0.2296 - val_loss: 0.5990 - val_auc: 0.6953 - val_recall: 0.5369 - val_precision: 0.2209
# Epoch 10/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6386 - auc: 0.7023 - recall: 0.7331 - precision: 0.2270WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6380 - auc: 0.7033 - recall: 0.7341 - precision: 0.2273 - val_loss: 0.6040 - val_auc: 0.6946 - val_recall: 0.5250 - val_precision: 0.2247
# Epoch 11/15
# 542/555 [============================>.] - ETA: 0s - loss: 0.6375 - auc: 0.7044 - recall: 0.7275 - precision: 0.2297WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6374 - auc: 0.7044 - recall: 0.7276 - precision: 0.2295 - val_loss: 0.6079 - val_auc: 0.6951 - val_recall: 0.5223 - val_precision: 0.2237
# Epoch 12/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6364 - auc: 0.7050 - recall: 0.7372 - precision: 0.2279WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6362 - auc: 0.7053 - recall: 0.7378 - precision: 0.2281 - val_loss: 0.6068 - val_auc: 0.6940 - val_recall: 0.5167 - val_precision: 0.2260
# Epoch 13/15
# 536/555 [===========================>..] - ETA: 0s - loss: 0.6365 - auc: 0.7053 - recall: 0.7278 - precision: 0.2293WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6370 - auc: 0.7054 - recall: 0.7291 - precision: 0.2295 - val_loss: 0.6006 - val_auc: 0.6951 - val_recall: 0.5306 - val_precision: 0.2236
# Epoch 14/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6367 - auc: 0.7046 - recall: 0.7322 - precision: 0.2296WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6367 - auc: 0.7054 - recall: 0.7335 - precision: 0.2304 - val_loss: 0.6035 - val_auc: 0.6949 - val_recall: 0.5278 - val_precision: 0.2262
# Epoch 15/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6356 - auc: 0.7062 - recall: 0.7324 - precision: 0.2296WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6357 - auc: 0.7060 - recall: 0.7323 - precision: 0.2295 - val_loss: 0.6005 - val_auc: 0.6943 - val_recall: 0.5223 - val_precision: 0.2272
# 740/740 [==============================] - 1s 950us/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 545/555 [============================>.] - ETA: 0s - loss: 0.6284 - auc: 0.7175 - recall: 0.7368 - precision: 0.2381WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6290 - auc: 0.7173 - recall: 0.7367 - precision: 0.2382 - val_loss: 0.6032 - val_auc: 0.6940 - val_recall: 0.5250 - val_precision: 0.2258
# Epoch 2/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6268 - auc: 0.7199 - recall: 0.7314 - precision: 0.2404WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6275 - auc: 0.7187 - recall: 0.7289 - precision: 0.2395 - val_loss: 0.6043 - val_auc: 0.6941 - val_recall: 0.5167 - val_precision: 0.2289
# Epoch 3/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6293 - auc: 0.7174 - recall: 0.7375 - precision: 0.2390WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6282 - auc: 0.7185 - recall: 0.7384 - precision: 0.2392 - val_loss: 0.6128 - val_auc: 0.6934 - val_recall: 0.5021 - val_precision: 0.2287
# Epoch 4/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6278 - auc: 0.7182 - recall: 0.7276 - precision: 0.2404WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6281 - auc: 0.7184 - recall: 0.7267 - precision: 0.2403 - val_loss: 0.6043 - val_auc: 0.6932 - val_recall: 0.5299 - val_precision: 0.2262
# Epoch 5/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6273 - auc: 0.7200 - recall: 0.7280 - precision: 0.2407WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6268 - auc: 0.7198 - recall: 0.7276 - precision: 0.2399 - val_loss: 0.6097 - val_auc: 0.6938 - val_recall: 0.5139 - val_precision: 0.2275
# Epoch 6/15
# 536/555 [===========================>..] - ETA: 0s - loss: 0.6257 - auc: 0.7202 - recall: 0.7402 - precision: 0.2390WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6263 - auc: 0.7200 - recall: 0.7401 - precision: 0.2390 - val_loss: 0.6056 - val_auc: 0.6936 - val_recall: 0.5118 - val_precision: 0.2257
# Epoch 7/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6261 - auc: 0.7208 - recall: 0.7299 - precision: 0.2407WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6261 - auc: 0.7208 - recall: 0.7295 - precision: 0.2406 - val_loss: 0.6053 - val_auc: 0.6934 - val_recall: 0.5035 - val_precision: 0.2282
# Epoch 8/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6265 - auc: 0.7197 - recall: 0.7296 - precision: 0.2406WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6265 - auc: 0.7198 - recall: 0.7297 - precision: 0.2407 - val_loss: 0.6023 - val_auc: 0.6943 - val_recall: 0.5306 - val_precision: 0.2250
# Epoch 9/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6265 - auc: 0.7197 - recall: 0.7341 - precision: 0.2402WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6264 - auc: 0.7200 - recall: 0.7339 - precision: 0.2403 - val_loss: 0.6043 - val_auc: 0.6943 - val_recall: 0.5376 - val_precision: 0.2269
# Epoch 10/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6267 - auc: 0.7195 - recall: 0.7370 - precision: 0.2382WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6250 - auc: 0.7208 - recall: 0.7386 - precision: 0.2385 - val_loss: 0.6139 - val_auc: 0.6941 - val_recall: 0.4944 - val_precision: 0.2283
# Epoch 11/15
# 537/555 [============================>.] - ETA: 0s - loss: 0.6265 - auc: 0.7207 - recall: 0.7313 - precision: 0.2414WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6259 - auc: 0.7204 - recall: 0.7318 - precision: 0.2405 - val_loss: 0.6086 - val_auc: 0.6941 - val_recall: 0.5223 - val_precision: 0.2260
# Epoch 12/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6264 - auc: 0.7204 - recall: 0.7466 - precision: 0.2381WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6267 - auc: 0.7203 - recall: 0.7462 - precision: 0.2381 - val_loss: 0.6027 - val_auc: 0.6935 - val_recall: 0.5118 - val_precision: 0.2235
# Epoch 13/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6266 - auc: 0.7199 - recall: 0.7404 - precision: 0.2383WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6262 - auc: 0.7205 - recall: 0.7409 - precision: 0.2388 - val_loss: 0.6089 - val_auc: 0.6938 - val_recall: 0.4944 - val_precision: 0.2275
# Epoch 14/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6251 - auc: 0.7210 - recall: 0.7265 - precision: 0.2430WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6248 - auc: 0.7215 - recall: 0.7278 - precision: 0.2434 - val_loss: 0.6059 - val_auc: 0.6943 - val_recall: 0.5118 - val_precision: 0.2234
# Epoch 15/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6255 - auc: 0.7213 - recall: 0.7424 - precision: 0.2386WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6255 - auc: 0.7215 - recall: 0.7431 - precision: 0.2389 - val_loss: 0.6053 - val_auc: 0.6934 - val_recall: 0.5028 - val_precision: 0.2250
# 740/740 [==============================] - 1s 962us/step
# 83/83 [==============================] - 0s 971us/step
# Epoch 1/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6333 - auc: 0.7108 - recall: 0.7224 - precision: 0.2364WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6333 - auc: 0.7108 - recall: 0.7226 - precision: 0.2365 - val_loss: 0.6035 - val_auc: 0.6936 - val_recall: 0.5334 - val_precision: 0.2243
# Epoch 2/15
# 530/555 [===========================>..] - ETA: 0s - loss: 0.6318 - auc: 0.7118 - recall: 0.7162 - precision: 0.2372WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6318 - auc: 0.7122 - recall: 0.7158 - precision: 0.2376 - val_loss: 0.6091 - val_auc: 0.6925 - val_recall: 0.5104 - val_precision: 0.2256
# Epoch 3/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6321 - auc: 0.7131 - recall: 0.7202 - precision: 0.2375WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6315 - auc: 0.7131 - recall: 0.7202 - precision: 0.2368 - val_loss: 0.6089 - val_auc: 0.6922 - val_recall: 0.5403 - val_precision: 0.2224
# Epoch 4/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6281 - auc: 0.7153 - recall: 0.7093 - precision: 0.2384WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6294 - auc: 0.7147 - recall: 0.7092 - precision: 0.2386 - val_loss: 0.6092 - val_auc: 0.6909 - val_recall: 0.5647 - val_precision: 0.2152
# Epoch 5/15
# 545/555 [============================>.] - ETA: 0s - loss: 0.6291 - auc: 0.7157 - recall: 0.7203 - precision: 0.2375WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6291 - auc: 0.7154 - recall: 0.7200 - precision: 0.2371 - val_loss: 0.6117 - val_auc: 0.6920 - val_recall: 0.5459 - val_precision: 0.2190
# Epoch 6/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6290 - auc: 0.7151 - recall: 0.7193 - precision: 0.2376WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6290 - auc: 0.7151 - recall: 0.7196 - precision: 0.2377 - val_loss: 0.6036 - val_auc: 0.6924 - val_recall: 0.5647 - val_precision: 0.2187
# Epoch 7/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6303 - auc: 0.7155 - recall: 0.7256 - precision: 0.2374WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6294 - auc: 0.7150 - recall: 0.7245 - precision: 0.2357 - val_loss: 0.6063 - val_auc: 0.6903 - val_recall: 0.5445 - val_precision: 0.2183
# Epoch 8/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6283 - auc: 0.7160 - recall: 0.7182 - precision: 0.2375WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 4ms/step - loss: 0.6283 - auc: 0.7160 - recall: 0.7181 - precision: 0.2376 - val_loss: 0.6051 - val_auc: 0.6910 - val_recall: 0.5765 - val_precision: 0.2137
# Epoch 9/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6294 - auc: 0.7157 - recall: 0.7244 - precision: 0.2359WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 4ms/step - loss: 0.6294 - auc: 0.7156 - recall: 0.7240 - precision: 0.2358 - val_loss: 0.6109 - val_auc: 0.6913 - val_recall: 0.5640 - val_precision: 0.2172
# Epoch 10/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6291 - auc: 0.7145 - recall: 0.7294 - precision: 0.2355WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6282 - auc: 0.7159 - recall: 0.7314 - precision: 0.2361 - val_loss: 0.6174 - val_auc: 0.6911 - val_recall: 0.5473 - val_precision: 0.2191
# Epoch 11/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6294 - auc: 0.7149 - recall: 0.7255 - precision: 0.2353WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6294 - auc: 0.7149 - recall: 0.7255 - precision: 0.2353 - val_loss: 0.6099 - val_auc: 0.6913 - val_recall: 0.5688 - val_precision: 0.2123
# Epoch 12/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6285 - auc: 0.7167 - recall: 0.7401 - precision: 0.2348WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6282 - auc: 0.7166 - recall: 0.7402 - precision: 0.2345 - val_loss: 0.6073 - val_auc: 0.6901 - val_recall: 0.5556 - val_precision: 0.2168
# Epoch 13/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6270 - auc: 0.7170 - recall: 0.7263 - precision: 0.2355WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6280 - auc: 0.7166 - recall: 0.7251 - precision: 0.2360 - val_loss: 0.6140 - val_auc: 0.6892 - val_recall: 0.5598 - val_precision: 0.2127
# Epoch 14/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6288 - auc: 0.7154 - recall: 0.7268 - precision: 0.2345WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6284 - auc: 0.7158 - recall: 0.7272 - precision: 0.2346 - val_loss: 0.6154 - val_auc: 0.6901 - val_recall: 0.5695 - val_precision: 0.2147
# Epoch 15/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6288 - auc: 0.7167 - recall: 0.7323 - precision: 0.2363WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6287 - auc: 0.7165 - recall: 0.7323 - precision: 0.2360 - val_loss: 0.6106 - val_auc: 0.6882 - val_recall: 0.5640 - val_precision: 0.2117
# 740/740 [==============================] - 1s 2ms/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6442 - auc: 0.6909 - recall: 0.7447 - precision: 0.2173WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 8ms/step - loss: 0.6443 - auc: 0.6920 - recall: 0.7463 - precision: 0.2177 - val_loss: 0.6064 - val_auc: 0.6912 - val_recall: 0.5709 - val_precision: 0.2147
# Epoch 2/15
# 549/555 [============================>.] - ETA: 0s - loss: 0.6423 - auc: 0.6946 - recall: 0.7459 - precision: 0.2208WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6428 - auc: 0.6941 - recall: 0.7452 - precision: 0.2209 - val_loss: 0.6054 - val_auc: 0.6918 - val_recall: 0.5661 - val_precision: 0.2161
# Epoch 3/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6416 - auc: 0.6958 - recall: 0.7442 - precision: 0.2226WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6416 - auc: 0.6958 - recall: 0.7442 - precision: 0.2226 - val_loss: 0.6092 - val_auc: 0.6933 - val_recall: 0.5480 - val_precision: 0.2172
# Epoch 4/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6392 - auc: 0.6978 - recall: 0.7341 - precision: 0.2228WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6396 - auc: 0.6975 - recall: 0.7342 - precision: 0.2229 - val_loss: 0.6075 - val_auc: 0.6918 - val_recall: 0.5535 - val_precision: 0.2160
# Epoch 5/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6411 - auc: 0.6980 - recall: 0.7453 - precision: 0.2234WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6413 - auc: 0.6978 - recall: 0.7452 - precision: 0.2233 - val_loss: 0.6095 - val_auc: 0.6925 - val_recall: 0.5431 - val_precision: 0.2189
# Epoch 6/15
# 537/555 [============================>.] - ETA: 0s - loss: 0.6391 - auc: 0.6994 - recall: 0.7460 - precision: 0.2241WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6394 - auc: 0.6990 - recall: 0.7457 - precision: 0.2237 - val_loss: 0.6052 - val_auc: 0.6932 - val_recall: 0.5369 - val_precision: 0.2186
# Epoch 7/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6409 - auc: 0.6979 - recall: 0.7475 - precision: 0.2239WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6407 - auc: 0.6975 - recall: 0.7465 - precision: 0.2231 - val_loss: 0.6051 - val_auc: 0.6909 - val_recall: 0.5341 - val_precision: 0.2179
# Epoch 8/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6407 - auc: 0.6981 - recall: 0.7410 - precision: 0.2251WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6407 - auc: 0.6980 - recall: 0.7408 - precision: 0.2250 - val_loss: 0.6017 - val_auc: 0.6924 - val_recall: 0.5598 - val_precision: 0.2160
# Epoch 9/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6402 - auc: 0.6986 - recall: 0.7484 - precision: 0.2236WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6397 - auc: 0.6993 - recall: 0.7491 - precision: 0.2241 - val_loss: 0.6103 - val_auc: 0.6920 - val_recall: 0.5327 - val_precision: 0.2192
# Epoch 10/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6399 - auc: 0.6986 - recall: 0.7374 - precision: 0.2236WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6386 - auc: 0.6999 - recall: 0.7395 - precision: 0.2240 - val_loss: 0.6172 - val_auc: 0.6935 - val_recall: 0.5139 - val_precision: 0.2236
# Epoch 11/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6380 - auc: 0.7011 - recall: 0.7330 - precision: 0.2278WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6383 - auc: 0.7004 - recall: 0.7315 - precision: 0.2268 - val_loss: 0.6059 - val_auc: 0.6942 - val_recall: 0.5522 - val_precision: 0.2208
# Epoch 12/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6386 - auc: 0.7011 - recall: 0.7509 - precision: 0.2245WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6385 - auc: 0.7006 - recall: 0.7484 - precision: 0.2238 - val_loss: 0.6053 - val_auc: 0.6932 - val_recall: 0.5292 - val_precision: 0.2247
# Epoch 13/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6384 - auc: 0.7000 - recall: 0.7370 - precision: 0.2247WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6386 - auc: 0.6999 - recall: 0.7370 - precision: 0.2248 - val_loss: 0.6058 - val_auc: 0.6934 - val_recall: 0.5473 - val_precision: 0.2202
# Epoch 14/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6401 - auc: 0.6995 - recall: 0.7414 - precision: 0.2238WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6403 - auc: 0.6991 - recall: 0.7420 - precision: 0.2237 - val_loss: 0.6115 - val_auc: 0.6941 - val_recall: 0.5542 - val_precision: 0.2195
# Epoch 15/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6392 - auc: 0.7004 - recall: 0.7467 - precision: 0.2244WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 2s 3ms/step - loss: 0.6392 - auc: 0.7004 - recall: 0.7467 - precision: 0.2244 - val_loss: 0.6081 - val_auc: 0.6942 - val_recall: 0.5431 - val_precision: 0.2226
# 740/740 [==============================] - 1s 1ms/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# ...
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6483 - auc: 0.7002 - recall: 0.7727 - precision: 0.2252 - val_loss: 0.5489 - val_auc: 0.7095 - val_recall: 0.5260 - val_precision: 0.2038
# Epoch 7/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6500 - auc: 0.6998 - recall: 0.7679 - precision: 0.2264WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6490 - auc: 0.7006 - recall: 0.7678 - precision: 0.2258 - val_loss: 0.5471 - val_auc: 0.7097 - val_recall: 0.5351 - val_precision: 0.2030
# Epoch 8/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6494 - auc: 0.7000 - recall: 0.7714 - precision: 0.2255WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6495 - auc: 0.7005 - recall: 0.7720 - precision: 0.2261 - val_loss: 0.5484 - val_auc: 0.7108 - val_recall: 0.5384 - val_precision: 0.2020
# Epoch 9/15
# 522/555 [===========================>..] - ETA: 0s - loss: 0.6496 - auc: 0.6991 - recall: 0.7765 - precision: 0.2234WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6495 - auc: 0.6999 - recall: 0.7755 - precision: 0.2245 - val_loss: 0.5478 - val_auc: 0.7098 - val_recall: 0.5318 - val_precision: 0.2019
# Epoch 10/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6472 - auc: 0.7014 - recall: 0.7680 - precision: 0.2275WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6473 - auc: 0.7015 - recall: 0.7684 - precision: 0.2277 - val_loss: 0.5491 - val_auc: 0.7090 - val_recall: 0.5334 - val_precision: 0.2014
# Epoch 11/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6484 - auc: 0.7009 - recall: 0.7617 - precision: 0.2280WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 3ms/step - loss: 0.6482 - auc: 0.7010 - recall: 0.7622 - precision: 0.2276 - val_loss: 0.5462 - val_auc: 0.7090 - val_recall: 0.5384 - val_precision: 0.2004
# Epoch 12/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6495 - auc: 0.7000 - recall: 0.7763 - precision: 0.2248WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6487 - auc: 0.7000 - recall: 0.7758 - precision: 0.2243 - val_loss: 0.5529 - val_auc: 0.7080 - val_recall: 0.5062 - val_precision: 0.2089
# Epoch 13/15
# 523/555 [===========================>..] - ETA: 0s - loss: 0.6493 - auc: 0.7000 - recall: 0.7710 - precision: 0.2279WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6490 - auc: 0.6997 - recall: 0.7693 - precision: 0.2269 - val_loss: 0.5495 - val_auc: 0.7088 - val_recall: 0.5326 - val_precision: 0.2021
# Epoch 14/15
# 542/555 [============================>.] - ETA: 0s - loss: 0.6483 - auc: 0.6996 - recall: 0.7676 - precision: 0.2247WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6489 - auc: 0.6997 - recall: 0.7677 - precision: 0.2253 - val_loss: 0.5505 - val_auc: 0.7081 - val_recall: 0.5376 - val_precision: 0.2013
# Epoch 15/15
# 527/555 [===========================>..] - ETA: 0s - loss: 0.6495 - auc: 0.7004 - recall: 0.7747 - precision: 0.2266WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6486 - auc: 0.7003 - recall: 0.7740 - precision: 0.2265 - val_loss: 0.5506 - val_auc: 0.7083 - val_recall: 0.5219 - val_precision: 0.2049
# 740/740 [==============================] - 1s 933us/step
# 83/83 [==============================] - 0s 1ms/step
# Epoch 1/15
# 524/555 [===========================>..] - ETA: 0s - loss: 0.6476 - auc: 0.7005 - recall: 0.7721 - precision: 0.2268WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6483 - auc: 0.7003 - recall: 0.7729 - precision: 0.2266 - val_loss: 0.5514 - val_auc: 0.7043 - val_recall: 0.5937 - val_precision: 0.1920
# Epoch 2/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6491 - auc: 0.7001 - recall: 0.7672 - precision: 0.2263WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6479 - auc: 0.7007 - recall: 0.7686 - precision: 0.2261 - val_loss: 0.5595 - val_auc: 0.7033 - val_recall: 0.5615 - val_precision: 0.1973
# Epoch 3/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6485 - auc: 0.7011 - recall: 0.7721 - precision: 0.2267WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6474 - auc: 0.7008 - recall: 0.7706 - precision: 0.2258 - val_loss: 0.5559 - val_auc: 0.7039 - val_recall: 0.5648 - val_precision: 0.1981
# Epoch 4/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6488 - auc: 0.6995 - recall: 0.7653 - precision: 0.2269WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6476 - auc: 0.7009 - recall: 0.7660 - precision: 0.2274 - val_loss: 0.5585 - val_auc: 0.7041 - val_recall: 0.5574 - val_precision: 0.1995
# Epoch 5/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6479 - auc: 0.7012 - recall: 0.7705 - precision: 0.2279WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6485 - auc: 0.7004 - recall: 0.7693 - precision: 0.2276 - val_loss: 0.5564 - val_auc: 0.7028 - val_recall: 0.5805 - val_precision: 0.1937
# Epoch 6/15
# 545/555 [============================>.] - ETA: 0s - loss: 0.6490 - auc: 0.7003 - recall: 0.7701 - precision: 0.2257WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6481 - auc: 0.7008 - recall: 0.7706 - precision: 0.2253 - val_loss: 0.5539 - val_auc: 0.7042 - val_recall: 0.5756 - val_precision: 0.1959
# Epoch 7/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6478 - auc: 0.7008 - recall: 0.7707 - precision: 0.2265WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6474 - auc: 0.7013 - recall: 0.7709 - precision: 0.2266 - val_loss: 0.5528 - val_auc: 0.7051 - val_recall: 0.5813 - val_precision: 0.1952
# Epoch 8/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6475 - auc: 0.7006 - recall: 0.7663 - precision: 0.2252WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6481 - auc: 0.7011 - recall: 0.7667 - precision: 0.2261 - val_loss: 0.5576 - val_auc: 0.7036 - val_recall: 0.5830 - val_precision: 0.1938
# Epoch 9/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6469 - auc: 0.7007 - recall: 0.7760 - precision: 0.2251WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6474 - auc: 0.7009 - recall: 0.7751 - precision: 0.2258 - val_loss: 0.5594 - val_auc: 0.7034 - val_recall: 0.5789 - val_precision: 0.1948
# Epoch 10/15
# 515/555 [==========================>...] - ETA: 0s - loss: 0.6488 - auc: 0.7019 - recall: 0.7697 - precision: 0.2270WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6476 - auc: 0.7013 - recall: 0.7713 - precision: 0.2251 - val_loss: 0.5591 - val_auc: 0.7022 - val_recall: 0.5921 - val_precision: 0.1919
# Epoch 11/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6464 - auc: 0.7020 - recall: 0.7692 - precision: 0.2250WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6471 - auc: 0.7016 - recall: 0.7698 - precision: 0.2248 - val_loss: 0.5562 - val_auc: 0.7033 - val_recall: 0.5937 - val_precision: 0.1911
# Epoch 12/15
# 523/555 [===========================>..] - ETA: 0s - loss: 0.6505 - auc: 0.7003 - recall: 0.7812 - precision: 0.2259WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6484 - auc: 0.7008 - recall: 0.7814 - precision: 0.2249 - val_loss: 0.5602 - val_auc: 0.7025 - val_recall: 0.5599 - val_precision: 0.1980
# Epoch 13/15
# 524/555 [===========================>..] - ETA: 0s - loss: 0.6486 - auc: 0.7007 - recall: 0.7779 - precision: 0.2268WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6481 - auc: 0.7006 - recall: 0.7758 - precision: 0.2258 - val_loss: 0.5585 - val_auc: 0.7030 - val_recall: 0.5855 - val_precision: 0.1928
# Epoch 14/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6474 - auc: 0.7004 - recall: 0.7760 - precision: 0.2245WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6485 - auc: 0.7003 - recall: 0.7758 - precision: 0.2252 - val_loss: 0.5596 - val_auc: 0.7030 - val_recall: 0.5896 - val_precision: 0.1932
# Epoch 15/15
# 542/555 [============================>.] - ETA: 0s - loss: 0.6477 - auc: 0.7020 - recall: 0.7718 - precision: 0.2259WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6480 - auc: 0.7012 - recall: 0.7707 - precision: 0.2255 - val_loss: 0.5559 - val_auc: 0.7047 - val_recall: 0.5739 - val_precision: 0.1944
# 740/740 [==============================] - 1s 996us/step
# 83/83 [==============================] - 0s 1ms/step
# accuracy_train     0.627234
# f1_train           0.346137
# recall_train       0.694359
# precision_train    0.230618
# auc_train          0.655240
# accuracy_test      0.617881
# f1_test            0.336150
# recall_test        0.658648
# precision_test     0.232262
# auc_test           0.634894
# dtype: float64
# 312/312 [==============================] - 0s 1ms/step

# %% [markdown]
# #### Train NN with Random Under Sampling

# %%
import imblearn.under_sampling as underSample
from sklearn.neural_network import MLPClassifier

#set NN model
nn_model = MLPClassifier(activation='logistic', batch_size=512, learning_rate='invscaling',
              learning_rate_init=0.1, max_iter=10, random_state=0,
              solver='sgd')
name = 'MLP'
assess = class_cv.validateModel(components_pca,
                                y_train_dict['Target_0.15'],
                                model=nn_model ,
                                scaler=True ,
                                over_sampling=False,
                                under_sampling=True,
                                predictions=False,
                                cv_type='stratKfold',
                                scaler_type='stand',
                                train_size=10,
                                test_size=1,
                                gap=0)

#store scores
assess_df = assess['scores']
assess_df['model'] = name

#store model 
model = assess['model']
new_model_list.append(model)

scaler = assess['scaler']

full_assess = pd.concat([full_assess,
                            assess_df],
                        axis=0)


X_test = pca_components_test
assess_test_dict, assess_test_df = assessTest(X_test,
                                                y_test_dict['Target_0.15'],
                                                model)
assess_test_dict['model'] = name
assess_test_df['model'] = name

full_assess_test = pd.concat([full_assess_test,
                            assess_test_df],
                        axis=0)
test_assess_list.append(assess_test_dict)
    
test_assess_df = pd.DataFrame.from_records(test_assess_list)
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# Undersampling will be performed:
# Strategy: Random Undersampling
# accuracy_train     0.638342
# f1_train           0.636900
# recall_train       0.634376
# precision_train    0.639458
# auc_train          0.638342
# accuracy_test      0.631748
# f1_test            0.325515
# recall_test        0.607889
# precision_test     0.228099
# auc_test           0.621797
# dtype: float64

# %%
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Validation\full_CV_results_PCA.csv'
full_assess.to_csv(path)

# %% [markdown]
# ### Boxplot Format A

# %%
a = full_assess.copy()
title = 'Target 0 - Model Performance on Validation set - K=10, PCA'
plt.figure(figsize=(15, 10))
ax1 = plt.subplot(2, 1, 1)
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'auc_test'].values
df_assess.plot(kind='box', title='boxplot', showmeans=True,ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('AUC', size=15)


ax2 = plt.subplot(2, 1, 2, ) # Share x-axis ticks with ax1
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'precision_test'].values
df_assess.plot(kind='box', showmeans=True,ax=ax2)

ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
plt.tight_layout()

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title}-PCA.png'
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# ### Boxplot Format B

# %%
title = 'Target 0 - Model Performance on Validation set - K=10, PCA'
plt.figure(figsize=(15, 10))

# Use sharex parameter to share x-axis ticks between subplots
ax1 = plt.subplot(2, 1, 1)
sns.boxplot(x=a['model'], y=a['auc_test'], hue=a['model'], ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('AUC', size=15)

# Set legend location outside the figure
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2 = plt.subplot(2, 1, 2, sharex=ax1) # Share x-axis ticks with ax1
sns.boxplot(x=a['model'], y=a['precision_test'], hue=a['model'], ax=ax2)
ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
ax2.legend().remove()

plt.tight_layout() # To prevent overlapping of the legend with the second subplot

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title}- PCA - Format 2.png'
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# #### Display Training and Valdation Results

# %% [markdown]
# Export average scores from the Cross Validation

# %% [markdown]
# ##### With Standartization inside CV

# %%
train_val_scores = full_assess.groupby('model').mean()
cols_ = train_val_scores.columns[train_val_scores.columns.str.contains('test')]
for col in cols_:
    
    new_col = col.replace('test','val')
    train_val_scores = train_val_scores.rename(columns = {col:new_col})
    
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Validation\modelMetricPerfomance_Target_15_valSet_PCA.csv'
train_val_scores.to_csv(assess_path)
display(train_val_scores)
# Out:
#                     accuracy_train  f1_train  recall_train  precision_train  \
# model
# DecisionTree              0.593524  0.315433      0.658824         0.207485
# Keras_NN                  0.627234  0.346137      0.694359         0.230618
# LightGB                   0.613899  0.329541      0.667931         0.218740
# LogisticRegression        0.638998  0.337689      0.647843         0.228370
# MLP                       0.638342  0.636900      0.634376         0.639458
#
#                     auc_train  accuracy_val    f1_val  recall_val  \
# model
# DecisionTree         0.620769      0.576260  0.287567    0.596767
# Keras_NN             0.655240      0.617881  0.336150    0.658648
# LightGB              0.636442      0.607438  0.320275    0.640151
# LogisticRegression   0.642688      0.631615  0.333395    0.627572
# MLP                  0.638342      0.631748  0.325515    0.607889
#
#                     precision_val   auc_val
# model
# DecisionTree             0.190716  0.584818
# Keras_NN                 0.232262  0.634894
# LightGB                  0.215641  0.621088
# LogisticRegression       0.234048  0.629931
# MLP                      0.228099  0.621797

# %% [markdown]
# #### Display test Results

# %% [markdown]
# Export scores on test set

# %%
test_assess_df = test_assess_df.reset_index().set_index('model')
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Test\modelMetricPerfomance_Target_15_testSet_PCA.csv'
test_assess_df.to_csv(assess_path)

# %% [markdown]
# #### ROC Curve Comparison

# %%
import DataScalling as scalling
model_names = ['LogisticRegression','DecisionTree','LightGB','MLP']
roc_curve(models = new_model_list,
                       names = model_names, 
                       X_train = x_train[mi_subset_0],
                       y_train  = y_train_dict['Target_0'],
                       X_val = X_test,
                       y_val= y_test_dict['Target_0.15'])


title = 'Model Perfomance Comparison - ROC Curve - Test Set - Target 15, PCA'
plt.title(title, 
          size = 15)
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables'
name_plot = f'{path}\\{title}.png'
plt.tight_layout()
plt.savefig(name_plot, dpi=300)
