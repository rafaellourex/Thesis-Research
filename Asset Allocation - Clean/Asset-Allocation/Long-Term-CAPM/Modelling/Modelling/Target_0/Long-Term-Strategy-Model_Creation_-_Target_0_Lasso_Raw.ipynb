# %% [markdown]
# ## Import Cleaned Data

# %% [markdown]
# __DataFrames:__
# df_model - df with all the features (independent festures + Target)
# x - df with all independent features
# y - df with dependent feature
# x_train - df with training data from x
# x_train_out - df with training data from x with outliers treatment applied
# x_test - df with test data from x
# x_test_out - df with test data from x with outliers treatment applied

# %%
import sys
sys.path.insert(1, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions')
sys.path.insert(2, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions\Functions')
# sys.path.insert(3, r'C:\Users\rafae\Personal\Github\Asset-Allocation\Long-Term-CAPM')
sys.path.insert(3, r'..\..\..')


import Classification_CV as class_cv
import importCleanedData as importData
import importSubsets as subsets

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from tensorflow import keras

import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeClassifier

import warnings
warnings.filterwarnings('ignore')

#set preferences
sns.set_style('whitegrid')

#set color for graphs
#set color for graphs
palette = ["#e41a1c", "#377eb8", "#4daf4a", "#984ea3"]

# dir = r'C:\Users\rafae\Personal\Github\Asset-Allocation\Long-Term-CAPM\SampleData\Sample'
dir = r'..\..\..\SampleData\Sample'
df_model_skew,df_target = importData.importCleanedData(dir=dir,target='CAPM')


#split data
date = '2018-01-01'
#split data without transformation
x_train,x_train_out,x_test, x_test_out,y_train_dict ,y_test_dict, y_train,y_test = importData.splitData(df_model_skew, date) 

#set columns
ratio_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Ratio'))]
shares_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Share'))]
margin_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Margin'))]
turnover_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Turnover'))]
dividend_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('dividend'))]


components_pca, pca_components_test = importData.runPCA(x_train_out= x_train_out,x_test = x_test)


#import subsets
lasso_subset_0, lasso_subset_15, mi_subset_0, mi_subset_15, lgb_subset, corr_subset0, corr_subset15 = subsets.importSubsets()


subset_0, subset_15 = lasso_subset_0, lasso_subset_15
# Out:
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# CAPM
# Import data from: ..\..\..\SampleData\Sample\LongTerm-DataPreparation_Skew.csv
# Original CAPM is being used as Target
# Nr of rows:
# 72538
# The variance explained by each component is: [50.70262543 16.3180414  12.90616231  7.80559243  6.69692605  5.82614766
#   4.47015907  4.07836541  3.82626867  3.40508117  3.17395217  2.97398597
#   2.84255924  2.7491931   2.6284572   2.30920491  2.29580116  2.24676716
#   2.1685526   2.08344875  1.96058327  1.88331954  1.85945512  1.79999003
#   1.75303096  1.72999438  1.67342676  1.57892838  1.52235707  1.48115797
#   1.44613583  1.42029951  1.39091026  1.35520895  1.32448072  1.29342424
#   1.27059382  1.25051426  1.2247642   1.18608517  1.17810508  1.15156743
#   1.14454538  1.12935887  1.10669478  1.0815426   1.07222534  1.05458183
#   1.03848544  1.01988948  1.01877496  0.99533768  0.98807987]
# The total variance explained by the components is: 0.7618344466001962

# %% [markdown]
# # Modelling Stage - Target 0

# %% [markdown]
# # Compare Model Perfomance

# %%
def reset_random_seeds():
    import random
    from numpy.random import seed
    import os
    from tensorflow import random as r
    
    seed_nr = 0
    os.environ['PYTHONHASHSEED']=str(seed_nr)
    r.set_seed(seed_nr)
    np.random.seed(seed_nr)
    
    
def gen_NNClassification (x, y, hidden_layer_sizes,activation_list, dropout,optimizer,loss = 'BinaryCrossentropy', metrics = ['AUC'],batch_size=180,epochs=10,validation_split = 0.25, class_weight = None, output_bias =None ):
    
    print('Neural Network Parameters:')
    print(f'Optimizer: {optimizer}')
    print(f'Loss: {loss}')
    print(f'Hidden Layer tructure: {hidden_layer_sizes}')
    print(f'Acivation Functions: {activation_list}')
    print(f'Dropout: {dropout}')
    print(f'Class Weight: {class_weight}')
    print(f'Output Bias: {output_bias}')
    
    #import libraries
    from scikeras.wrappers import KerasClassifier, KerasRegressor
    from tensorflow import keras
    
    reset_random_seeds()
    #get nr features in
    n_features_in_ = x.shape[1]
    n_classes_ = len(y.unique())
    
    if output_bias is not None:
        output_bias =keras.initializers.Constant(output_bias)
    
    #set keras model
    model = keras.models.Sequential()
    
    #define input shape
    # model.add(keras.layers.Input(shape=(n_features_in_,)))
    model.add(keras.layers.Dense(
          4, activation='relu',
          input_shape=(n_features_in_,)))
    
    #define hidden layers
    for hidden_layer_size, activation_ in zip(hidden_layer_sizes,
                                              activation_list):
        
        model.add(keras.layers.Dense(hidden_layer_size,
                                     activation=activation_))
        
        model.add(keras.layers.Dropout(dropout))
    
    #define output layer
    model.add(keras.layers.Dense(1,
                                 activation="sigmoid",
                                 bias_initializer=output_bias))
    
    #compile model 
    model.compile(optimizer=optimizer,
                  loss=loss,
                  metrics=metrics,
                  )
    
    #transform to SKlearn format
    NNmodel = KerasClassifier( model=model,
                            batch_size= batch_size,
                            epochs= epochs,
                            class_weight=class_weight,
                            validation_split=validation_split,
                            loss = loss)

    return NNmodel





metrics = ['AUC','Recall','Precision']
pos = len(y_train.loc[y_train.values==1])
neg = len(y_train.loc[y_train.values==0])
output_bias = np.log(pos/neg)



from numpy.random import seed
from tensorflow import keras 


reset_random_seeds()
optimizer = keras.optimizers.Adam(learning_rate=0.001)
loss_ = keras.losses.BinaryCrossentropy()
NNmodel = gen_NNClassification(x_train_out[subset_0], 
                                 y_train_dict['Target_0'],
                                 hidden_layer_sizes = (150,),
                                 activation_list = ['relu'],
                                 dropout = 0.2,
                                 optimizer =optimizer ,
                                 loss = loss_, 
                                 metrics = ['accuracy', 'Precision'],
                                 batch_size=180,
                                 epochs=30,
                                 validation_split = 0.3,
                                 class_weight = None,
                                 output_bias =None )
    
    
def fitted_precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted outside the function 
    
    '''''''''''''''
    names=names
    #model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()

def assessTest (x_test, y_test, model):
    index__ = x_test.reset_index()[['symbol','fillingDate','close']].set_index(['symbol','fillingDate'])
    target_copy = df_target.copy()
    target_copy['fillingDate'] = target_copy['fillingDate'].astype(str)
    target_copy = target_copy.drop_duplicates(['symbol','fillingDate']).set_index(['symbol','fillingDate'])
    target_copy = target_copy.loc[target_copy.index.isin(index__.index)]
    
    assess_test_dict = dict()
    pred_test = model.predict(x_test)
    assess_test = pd.DataFrame(index = y_test.index)
    assess_test['Prediction'] = pred_test
    assess_test['Target'] = y_test
#     assess_test['returns'] = df_model.loc[df_model.index.isin(y_test.index),'futReturns']
    assess_test['excReturns'] = target_copy.loc[target_copy.index.isin(index__.index),'futAlpha']

    avg_returns = assess_test.groupby('Prediction').mean()[['excReturns']]


    from sklearn.metrics import roc_auc_score, precision_score, recall_score,accuracy_score
    auc  = roc_auc_score(assess_test['Target'],assess_test['Prediction'] )
    precision = precision_score(assess_test['Target'],assess_test['Prediction'] )
    recall =  recall_score(assess_test['Target'],assess_test['Prediction'] )
    acc =  accuracy_score(assess_test['Target'],assess_test['Prediction'] )
    
    assess_test_dict['accuracy'] = acc
    assess_test_dict['auc'] = auc
    assess_test_dict['precision'] = precision
    assess_test_dict['recall'] = recall
    return(assess_test_dict,assess_test)
# Out:
# Neural Network Parameters:
# Optimizer: <keras.optimizers.optimizer_experimental.adam.Adam object at 0x0000022F4C8716A0>
# Loss: <keras.losses.BinaryCrossentropy object at 0x0000022F63826820>
# Hidden Layer tructure: (150,)
# Acivation Functions: ['relu']
# Dropout: 0.2
# Class Weight: None
# Output Bias: None

# %% [markdown]
# ## Target 0

# %% [markdown]
# Perfomance is compared using using standardized data since Neural Networks and Logistic Regressions are highly affected by data scalling.

# %%
dt_model = DecisionTreeClassifier(max_depth=6,
                                  max_features=4,
                                  min_samples_leaf=100,
                                   random_state=0)


lgb_model = lgb.LGBMClassifier(learning_rate=0.2,
                               max_depth=2,
                               n_estimators=50,
                               random_state=0)

lr_model = LogisticRegression(random_state=0,
                           solver='liblinear' )





model_list = [lr_model,dt_model, lgb_model,NNmodel][:2]
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras_NN'][:2]

new_model_list = []
full_assess = pd.DataFrame()
full_assess_test = pd.DataFrame()
test_assess_list = []
predictions_df = pd.DataFrame()
#iterate over the models and perform CV 
for model, name in zip(model_list, model_names):
    assess = class_cv.validateModel(x_train[subset_0],
                                    y_train_dict['Target_0'],
                                    model=model ,
                                    scaler=True ,
                                    over_sampling=False,
                                    predictions=True,
                                    cv_type='stratKfold',
                                    scaler_type='stand',
                                    train_size=10,
                                    test_size=1,
                                    gap=0)
    
    #store scores
    assess_df = assess['scores']
    assess_df['model'] = name
    
    predictions = assess['predictions']
    predictions['model'] = name 
    predictions_df = pd.concat([predictions_df,predictions],axis=0)
    
    #store model 
    model = assess['model']
    new_model_list.append(model)
    
    scaler = assess['scaler']
    
    full_assess = pd.concat([full_assess,
                             assess_df],
                            axis=0)
    
    #fit scaler on test set 
    X_test = pd.DataFrame(scaler.transform(x_test[subset_0]), 
                          index = x_test.index, 
                          columns = subset_0)
    
    assess_test_dict, assess_test_df = assessTest(X_test,
                                                  y_test_dict['Target_0'],
                                                  model)
    assess_test_dict['model'] = name
    assess_test_df['model'] = name
    
    full_assess_test = pd.concat([full_assess_test,
                             assess_test_df],
                            axis=0)
    test_assess_list.append(assess_test_dict)
    
test_assess_df = pd.DataFrame.from_records(test_assess_list)
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.541927
# f1_train           0.624377
# recall_train       0.734884
# precision_train    0.542779
# auc_train          0.534692
# accuracy_test      0.535286
# f1_test            0.617210
# recall_test        0.727048
# precision_test     0.537887
# auc_test           0.528101
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.547112
# f1_train           0.621544
# recall_train       0.722558
# precision_train    0.548481
# auc_train          0.540532
# accuracy_test      0.525185
# f1_test            0.601120
# recall_test        0.702344
# precision_test     0.531332
# auc_test           0.518555
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.566717
# f1_train           0.629601
# recall_train       0.710842
# precision_train    0.565073
# auc_train          0.561313
# accuracy_test      0.543789
# f1_test            0.610632
# recall_test        0.693488
# precision_test     0.546757
# auc_test           0.538180
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.7062 - accuracy: 0.5071 - precision: 0.5131 - val_loss: 0.6941 - val_accuracy: 0.5282 - val_precision: 0.5294
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.5176 - precision: 0.5219 - val_loss: 0.6929 - val_accuracy: 0.5264 - val_precision: 0.5310
# Epoch 3/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.5247 - precision: 0.5272 - val_loss: 0.6936 - val_accuracy: 0.5230 - val_precision: 0.5321
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5335 - precision: 0.5338 - val_loss: 0.6951 - val_accuracy: 0.5027 - val_precision: 0.5253
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6903 - accuracy: 0.5339 - precision: 0.5347 - val_loss: 0.6944 - val_accuracy: 0.5163 - val_precision: 0.5333
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6894 - accuracy: 0.5382 - precision: 0.5377 - val_loss: 0.6949 - val_accuracy: 0.5118 - val_precision: 0.5342
# Epoch 7/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6885 - accuracy: 0.5435 - precision: 0.5426 - val_loss: 0.6982 - val_accuracy: 0.5081 - val_precision: 0.5350
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6887 - accuracy: 0.5413 - precision: 0.5406 - val_loss: 0.6957 - val_accuracy: 0.5094 - val_precision: 0.5358
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6878 - accuracy: 0.5440 - precision: 0.5441 - val_loss: 0.6949 - val_accuracy: 0.5165 - val_precision: 0.5382
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6878 - accuracy: 0.5456 - precision: 0.5446 - val_loss: 0.6950 - val_accuracy: 0.5202 - val_precision: 0.5413
# Epoch 11/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6869 - accuracy: 0.5470 - precision: 0.5461 - val_loss: 0.6955 - val_accuracy: 0.5173 - val_precision: 0.5425
# Epoch 12/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6866 - accuracy: 0.5483 - precision: 0.5478 - val_loss: 0.6978 - val_accuracy: 0.5073 - val_precision: 0.5406
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5509 - precision: 0.5521 - val_loss: 0.6958 - val_accuracy: 0.5201 - val_precision: 0.5432
# Epoch 14/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6860 - accuracy: 0.5509 - precision: 0.5510 - val_loss: 0.6955 - val_accuracy: 0.5175 - val_precision: 0.5434
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5509 - precision: 0.5521 - val_loss: 0.6965 - val_accuracy: 0.5156 - val_precision: 0.5445
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5507 - precision: 0.5517 - val_loss: 0.6950 - val_accuracy: 0.5223 - val_precision: 0.5472
# Epoch 17/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6851 - accuracy: 0.5535 - precision: 0.5550 - val_loss: 0.6981 - val_accuracy: 0.5169 - val_precision: 0.5473
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.5525 - precision: 0.5542 - val_loss: 0.6959 - val_accuracy: 0.5212 - val_precision: 0.5471
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5556 - precision: 0.5569 - val_loss: 0.6950 - val_accuracy: 0.5229 - val_precision: 0.5462
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5535 - precision: 0.5547 - val_loss: 0.6946 - val_accuracy: 0.5204 - val_precision: 0.5428
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5537 - precision: 0.5551 - val_loss: 0.6978 - val_accuracy: 0.5185 - val_precision: 0.5507
# Epoch 22/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6847 - accuracy: 0.5550 - precision: 0.5566 - val_loss: 0.6952 - val_accuracy: 0.5216 - val_precision: 0.5474
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.5535 - precision: 0.5552 - val_loss: 0.6950 - val_accuracy: 0.5217 - val_precision: 0.5451
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6844 - accuracy: 0.5534 - precision: 0.5549 - val_loss: 0.7016 - val_accuracy: 0.5125 - val_precision: 0.5493
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.5551 - precision: 0.5573 - val_loss: 0.6995 - val_accuracy: 0.5136 - val_precision: 0.5465
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6841 - accuracy: 0.5577 - precision: 0.5599 - val_loss: 0.6959 - val_accuracy: 0.5221 - val_precision: 0.5482
# Epoch 27/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6836 - accuracy: 0.5572 - precision: 0.5584 - val_loss: 0.6976 - val_accuracy: 0.5166 - val_precision: 0.5483
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.5545 - precision: 0.5581 - val_loss: 0.6964 - val_accuracy: 0.5203 - val_precision: 0.5487
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5565 - precision: 0.5591 - val_loss: 0.6956 - val_accuracy: 0.5229 - val_precision: 0.5471
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5575 - precision: 0.5600 - val_loss: 0.6950 - val_accuracy: 0.5227 - val_precision: 0.5460
# 263/263 [==============================] - 0s 801us/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 850us/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6857 - accuracy: 0.5475 - precision: 0.5497 - val_loss: 0.6935 - val_accuracy: 0.5261 - val_precision: 0.5454
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.5536 - precision: 0.5555 - val_loss: 0.6933 - val_accuracy: 0.5257 - val_precision: 0.5480
# Epoch 3/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6851 - accuracy: 0.5517 - precision: 0.5534 - val_loss: 0.6943 - val_accuracy: 0.5242 - val_precision: 0.5508
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5522 - precision: 0.5547 - val_loss: 0.6945 - val_accuracy: 0.5245 - val_precision: 0.5518
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5503 - precision: 0.5528 - val_loss: 0.6964 - val_accuracy: 0.5185 - val_precision: 0.5537
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6844 - accuracy: 0.5536 - precision: 0.5564 - val_loss: 0.6960 - val_accuracy: 0.5174 - val_precision: 0.5499
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6843 - accuracy: 0.5507 - precision: 0.5539 - val_loss: 0.6972 - val_accuracy: 0.5193 - val_precision: 0.5525
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5537 - precision: 0.5558 - val_loss: 0.6964 - val_accuracy: 0.5213 - val_precision: 0.5537
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6845 - accuracy: 0.5533 - precision: 0.5568 - val_loss: 0.6953 - val_accuracy: 0.5232 - val_precision: 0.5508
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6843 - accuracy: 0.5545 - precision: 0.5566 - val_loss: 0.6955 - val_accuracy: 0.5235 - val_precision: 0.5516
# Epoch 11/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6842 - accuracy: 0.5550 - precision: 0.5566 - val_loss: 0.6965 - val_accuracy: 0.5227 - val_precision: 0.5556
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.5513 - precision: 0.5547 - val_loss: 0.6980 - val_accuracy: 0.5126 - val_precision: 0.5495
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5557 - precision: 0.5604 - val_loss: 0.6960 - val_accuracy: 0.5222 - val_precision: 0.5494
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5549 - precision: 0.5581 - val_loss: 0.6947 - val_accuracy: 0.5284 - val_precision: 0.5498
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5544 - precision: 0.5577 - val_loss: 0.6951 - val_accuracy: 0.5248 - val_precision: 0.5503
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6840 - accuracy: 0.5556 - precision: 0.5574 - val_loss: 0.6956 - val_accuracy: 0.5227 - val_precision: 0.5522
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5533 - precision: 0.5571 - val_loss: 0.6970 - val_accuracy: 0.5227 - val_precision: 0.5566
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5545 - precision: 0.5579 - val_loss: 0.6960 - val_accuracy: 0.5253 - val_precision: 0.5542
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.5539 - precision: 0.5575 - val_loss: 0.6954 - val_accuracy: 0.5282 - val_precision: 0.5529
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5556 - precision: 0.5591 - val_loss: 0.6951 - val_accuracy: 0.5295 - val_precision: 0.5499
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5535 - precision: 0.5564 - val_loss: 0.6966 - val_accuracy: 0.5229 - val_precision: 0.5556
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6840 - accuracy: 0.5516 - precision: 0.5554 - val_loss: 0.6953 - val_accuracy: 0.5242 - val_precision: 0.5522
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5531 - precision: 0.5575 - val_loss: 0.6952 - val_accuracy: 0.5285 - val_precision: 0.5514
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5525 - precision: 0.5560 - val_loss: 0.7008 - val_accuracy: 0.5104 - val_precision: 0.5536
# Epoch 25/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6837 - accuracy: 0.5518 - precision: 0.5558 - val_loss: 0.6982 - val_accuracy: 0.5159 - val_precision: 0.5506
# Epoch 26/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6833 - accuracy: 0.5558 - precision: 0.5593 - val_loss: 0.6961 - val_accuracy: 0.5229 - val_precision: 0.5534
# Epoch 27/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6830 - accuracy: 0.5553 - precision: 0.5587 - val_loss: 0.6966 - val_accuracy: 0.5247 - val_precision: 0.5528
# Epoch 28/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.5553 - precision: 0.5593 - val_loss: 0.6969 - val_accuracy: 0.5218 - val_precision: 0.5534
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6834 - accuracy: 0.5535 - precision: 0.5573 - val_loss: 0.6965 - val_accuracy: 0.5221 - val_precision: 0.5526
# Epoch 30/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6835 - accuracy: 0.5523 - precision: 0.5569 - val_loss: 0.6949 - val_accuracy: 0.5270 - val_precision: 0.5532
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 879us/step
# 30/30 [==============================] - 0s 929us/step
# Epoch 1/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6819 - accuracy: 0.5608 - precision: 0.5640 - val_loss: 0.6971 - val_accuracy: 0.5216 - val_precision: 0.5508
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6815 - accuracy: 0.5622 - precision: 0.5663 - val_loss: 0.6965 - val_accuracy: 0.5221 - val_precision: 0.5492
# Epoch 3/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6817 - accuracy: 0.5637 - precision: 0.5665 - val_loss: 0.6985 - val_accuracy: 0.5206 - val_precision: 0.5548
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6811 - accuracy: 0.5647 - precision: 0.5687 - val_loss: 0.6972 - val_accuracy: 0.5229 - val_precision: 0.5507
# Epoch 5/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6814 - accuracy: 0.5631 - precision: 0.5664 - val_loss: 0.6976 - val_accuracy: 0.5219 - val_precision: 0.5524
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6811 - accuracy: 0.5640 - precision: 0.5673 - val_loss: 0.6979 - val_accuracy: 0.5204 - val_precision: 0.5512
# Epoch 7/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6807 - accuracy: 0.5632 - precision: 0.5667 - val_loss: 0.7001 - val_accuracy: 0.5190 - val_precision: 0.5518
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6814 - accuracy: 0.5630 - precision: 0.5660 - val_loss: 0.6989 - val_accuracy: 0.5202 - val_precision: 0.5525
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6807 - accuracy: 0.5641 - precision: 0.5682 - val_loss: 0.6983 - val_accuracy: 0.5221 - val_precision: 0.5512
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6806 - accuracy: 0.5651 - precision: 0.5678 - val_loss: 0.6977 - val_accuracy: 0.5237 - val_precision: 0.5516
# Epoch 11/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6807 - accuracy: 0.5646 - precision: 0.5678 - val_loss: 0.6984 - val_accuracy: 0.5207 - val_precision: 0.5509
# Epoch 12/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6807 - accuracy: 0.5646 - precision: 0.5679 - val_loss: 0.6984 - val_accuracy: 0.5206 - val_precision: 0.5499
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6801 - accuracy: 0.5668 - precision: 0.5708 - val_loss: 0.6983 - val_accuracy: 0.5209 - val_precision: 0.5481
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5648 - precision: 0.5683 - val_loss: 0.6974 - val_accuracy: 0.5226 - val_precision: 0.5488
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5656 - precision: 0.5700 - val_loss: 0.6978 - val_accuracy: 0.5221 - val_precision: 0.5471
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.5637 - precision: 0.5661 - val_loss: 0.6981 - val_accuracy: 0.5227 - val_precision: 0.5522
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6808 - accuracy: 0.5648 - precision: 0.5683 - val_loss: 0.7001 - val_accuracy: 0.5204 - val_precision: 0.5538
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6805 - accuracy: 0.5646 - precision: 0.5687 - val_loss: 0.6977 - val_accuracy: 0.5259 - val_precision: 0.5520
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5648 - precision: 0.5682 - val_loss: 0.6990 - val_accuracy: 0.5203 - val_precision: 0.5506
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6804 - accuracy: 0.5651 - precision: 0.5695 - val_loss: 0.6978 - val_accuracy: 0.5262 - val_precision: 0.5514
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6804 - accuracy: 0.5624 - precision: 0.5654 - val_loss: 0.6997 - val_accuracy: 0.5214 - val_precision: 0.5537
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6808 - accuracy: 0.5645 - precision: 0.5684 - val_loss: 0.6983 - val_accuracy: 0.5214 - val_precision: 0.5503
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.5650 - precision: 0.5697 - val_loss: 0.6984 - val_accuracy: 0.5271 - val_precision: 0.5525
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5656 - precision: 0.5682 - val_loss: 0.7048 - val_accuracy: 0.5161 - val_precision: 0.5562
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5634 - precision: 0.5674 - val_loss: 0.7005 - val_accuracy: 0.5211 - val_precision: 0.5531
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5661 - precision: 0.5693 - val_loss: 0.6989 - val_accuracy: 0.5244 - val_precision: 0.5539
# Epoch 27/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6803 - accuracy: 0.5672 - precision: 0.5702 - val_loss: 0.6989 - val_accuracy: 0.5233 - val_precision: 0.5524
# Epoch 28/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6802 - accuracy: 0.5639 - precision: 0.5681 - val_loss: 0.6990 - val_accuracy: 0.5209 - val_precision: 0.5511
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6799 - accuracy: 0.5658 - precision: 0.5691 - val_loss: 0.6998 - val_accuracy: 0.5206 - val_precision: 0.5522
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.5657 - precision: 0.5703 - val_loss: 0.6982 - val_accuracy: 0.5239 - val_precision: 0.5538
# 263/263 [==============================] - 0s 873us/step
# 30/30 [==============================] - 0s 936us/step
# 30/30 [==============================] - 0s 850us/step
# 30/30 [==============================] - 0s 873us/step
# Epoch 1/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6828 - accuracy: 0.5567 - precision: 0.5616 - val_loss: 0.6970 - val_accuracy: 0.5228 - val_precision: 0.5477
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6825 - accuracy: 0.5571 - precision: 0.5626 - val_loss: 0.6964 - val_accuracy: 0.5306 - val_precision: 0.5510
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6824 - accuracy: 0.5571 - precision: 0.5620 - val_loss: 0.6988 - val_accuracy: 0.5211 - val_precision: 0.5564
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6823 - accuracy: 0.5593 - precision: 0.5660 - val_loss: 0.6971 - val_accuracy: 0.5275 - val_precision: 0.5506
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6824 - accuracy: 0.5570 - precision: 0.5628 - val_loss: 0.6980 - val_accuracy: 0.5237 - val_precision: 0.5561
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6825 - accuracy: 0.5579 - precision: 0.5643 - val_loss: 0.6977 - val_accuracy: 0.5210 - val_precision: 0.5517
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6821 - accuracy: 0.5579 - precision: 0.5647 - val_loss: 0.6998 - val_accuracy: 0.5196 - val_precision: 0.5554
# Epoch 8/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6821 - accuracy: 0.5582 - precision: 0.5650 - val_loss: 0.6981 - val_accuracy: 0.5263 - val_precision: 0.5557
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6824 - accuracy: 0.5577 - precision: 0.5649 - val_loss: 0.6996 - val_accuracy: 0.5189 - val_precision: 0.5529
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6818 - accuracy: 0.5584 - precision: 0.5660 - val_loss: 0.6979 - val_accuracy: 0.5229 - val_precision: 0.5512
# Epoch 11/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6819 - accuracy: 0.5575 - precision: 0.5647 - val_loss: 0.6991 - val_accuracy: 0.5235 - val_precision: 0.5581
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6817 - accuracy: 0.5589 - precision: 0.5657 - val_loss: 0.6995 - val_accuracy: 0.5235 - val_precision: 0.5597
# Epoch 13/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6821 - accuracy: 0.5565 - precision: 0.5649 - val_loss: 0.6979 - val_accuracy: 0.5252 - val_precision: 0.5542
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6818 - accuracy: 0.5585 - precision: 0.5662 - val_loss: 0.6972 - val_accuracy: 0.5259 - val_precision: 0.5514
# Epoch 15/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6818 - accuracy: 0.5589 - precision: 0.5672 - val_loss: 0.6978 - val_accuracy: 0.5226 - val_precision: 0.5509
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6820 - accuracy: 0.5582 - precision: 0.5646 - val_loss: 0.6985 - val_accuracy: 0.5256 - val_precision: 0.5574
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6821 - accuracy: 0.5583 - precision: 0.5670 - val_loss: 0.6985 - val_accuracy: 0.5241 - val_precision: 0.5582
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6823 - accuracy: 0.5559 - precision: 0.5636 - val_loss: 0.6974 - val_accuracy: 0.5271 - val_precision: 0.5539
# Epoch 19/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6818 - accuracy: 0.5595 - precision: 0.5661 - val_loss: 0.7003 - val_accuracy: 0.5242 - val_precision: 0.5549
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6820 - accuracy: 0.5582 - precision: 0.5665 - val_loss: 0.6989 - val_accuracy: 0.5262 - val_precision: 0.5523
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6816 - accuracy: 0.5573 - precision: 0.5642 - val_loss: 0.7001 - val_accuracy: 0.5216 - val_precision: 0.5571
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6821 - accuracy: 0.5589 - precision: 0.5676 - val_loss: 0.6994 - val_accuracy: 0.5240 - val_precision: 0.5551
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6812 - accuracy: 0.5605 - precision: 0.5690 - val_loss: 0.6998 - val_accuracy: 0.5233 - val_precision: 0.5519
# Epoch 24/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6818 - accuracy: 0.5589 - precision: 0.5654 - val_loss: 0.7043 - val_accuracy: 0.5103 - val_precision: 0.5552
# Epoch 25/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6818 - accuracy: 0.5596 - precision: 0.5681 - val_loss: 0.7001 - val_accuracy: 0.5197 - val_precision: 0.5574
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6814 - accuracy: 0.5616 - precision: 0.5700 - val_loss: 0.6990 - val_accuracy: 0.5259 - val_precision: 0.5546
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6815 - accuracy: 0.5591 - precision: 0.5667 - val_loss: 0.7001 - val_accuracy: 0.5239 - val_precision: 0.5553
# Epoch 28/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6812 - accuracy: 0.5591 - precision: 0.5668 - val_loss: 0.7001 - val_accuracy: 0.5232 - val_precision: 0.5590
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6817 - accuracy: 0.5583 - precision: 0.5666 - val_loss: 0.6994 - val_accuracy: 0.5226 - val_precision: 0.5556
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6817 - accuracy: 0.5594 - precision: 0.5674 - val_loss: 0.6999 - val_accuracy: 0.5228 - val_precision: 0.5578
# 263/263 [==============================] - 0s 934us/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 954us/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6839 - accuracy: 0.5596 - precision: 0.5654 - val_loss: 0.6964 - val_accuracy: 0.5256 - val_precision: 0.5517
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6813 - accuracy: 0.5617 - precision: 0.5679 - val_loss: 0.6970 - val_accuracy: 0.5253 - val_precision: 0.5511
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6814 - accuracy: 0.5597 - precision: 0.5653 - val_loss: 0.6978 - val_accuracy: 0.5249 - val_precision: 0.5577
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6814 - accuracy: 0.5619 - precision: 0.5685 - val_loss: 0.6973 - val_accuracy: 0.5220 - val_precision: 0.5518
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6811 - accuracy: 0.5605 - precision: 0.5663 - val_loss: 0.6980 - val_accuracy: 0.5209 - val_precision: 0.5535
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6813 - accuracy: 0.5612 - precision: 0.5688 - val_loss: 0.6987 - val_accuracy: 0.5193 - val_precision: 0.5509
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6813 - accuracy: 0.5610 - precision: 0.5665 - val_loss: 0.7000 - val_accuracy: 0.5178 - val_precision: 0.5541
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.5606 - precision: 0.5676 - val_loss: 0.6978 - val_accuracy: 0.5246 - val_precision: 0.5556
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6812 - accuracy: 0.5651 - precision: 0.5716 - val_loss: 0.6999 - val_accuracy: 0.5173 - val_precision: 0.5524
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6812 - accuracy: 0.5611 - precision: 0.5678 - val_loss: 0.6981 - val_accuracy: 0.5205 - val_precision: 0.5524
# Epoch 11/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6813 - accuracy: 0.5646 - precision: 0.5704 - val_loss: 0.6997 - val_accuracy: 0.5173 - val_precision: 0.5532
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6812 - accuracy: 0.5599 - precision: 0.5670 - val_loss: 0.6982 - val_accuracy: 0.5223 - val_precision: 0.5550
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6812 - accuracy: 0.5611 - precision: 0.5681 - val_loss: 0.6986 - val_accuracy: 0.5233 - val_precision: 0.5568
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6814 - accuracy: 0.5613 - precision: 0.5674 - val_loss: 0.6977 - val_accuracy: 0.5221 - val_precision: 0.5535
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6810 - accuracy: 0.5618 - precision: 0.5685 - val_loss: 0.6977 - val_accuracy: 0.5168 - val_precision: 0.5493
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6811 - accuracy: 0.5629 - precision: 0.5688 - val_loss: 0.6979 - val_accuracy: 0.5218 - val_precision: 0.5542
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6818 - accuracy: 0.5588 - precision: 0.5662 - val_loss: 0.6970 - val_accuracy: 0.5235 - val_precision: 0.5544
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6812 - accuracy: 0.5607 - precision: 0.5675 - val_loss: 0.6983 - val_accuracy: 0.5196 - val_precision: 0.5527
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6805 - accuracy: 0.5616 - precision: 0.5682 - val_loss: 0.6972 - val_accuracy: 0.5242 - val_precision: 0.5511
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6813 - accuracy: 0.5615 - precision: 0.5682 - val_loss: 0.6972 - val_accuracy: 0.5244 - val_precision: 0.5553
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6808 - accuracy: 0.5634 - precision: 0.5696 - val_loss: 0.6991 - val_accuracy: 0.5197 - val_precision: 0.5542
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.5613 - precision: 0.5686 - val_loss: 0.6975 - val_accuracy: 0.5216 - val_precision: 0.5533
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.5628 - precision: 0.5696 - val_loss: 0.6980 - val_accuracy: 0.5228 - val_precision: 0.5550
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6806 - accuracy: 0.5638 - precision: 0.5688 - val_loss: 0.7022 - val_accuracy: 0.5108 - val_precision: 0.5515
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6808 - accuracy: 0.5624 - precision: 0.5694 - val_loss: 0.7004 - val_accuracy: 0.5159 - val_precision: 0.5531
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6810 - accuracy: 0.5630 - precision: 0.5693 - val_loss: 0.6974 - val_accuracy: 0.5209 - val_precision: 0.5537
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6810 - accuracy: 0.5630 - precision: 0.5703 - val_loss: 0.6973 - val_accuracy: 0.5212 - val_precision: 0.5535
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.5598 - precision: 0.5656 - val_loss: 0.6989 - val_accuracy: 0.5166 - val_precision: 0.5530
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6805 - accuracy: 0.5633 - precision: 0.5703 - val_loss: 0.6997 - val_accuracy: 0.5184 - val_precision: 0.5544
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.5611 - precision: 0.5687 - val_loss: 0.6972 - val_accuracy: 0.5213 - val_precision: 0.5540
# 263/263 [==============================] - 0s 773us/step
# 30/30 [==============================] - 0s 885us/step
# 30/30 [==============================] - 0s 912us/step
# 30/30 [==============================] - 0s 889us/step
# Epoch 1/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6804 - accuracy: 0.5632 - precision: 0.5699 - val_loss: 0.6968 - val_accuracy: 0.5252 - val_precision: 0.5534
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5635 - precision: 0.5694 - val_loss: 0.6970 - val_accuracy: 0.5259 - val_precision: 0.5508
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6804 - accuracy: 0.5622 - precision: 0.5688 - val_loss: 0.6977 - val_accuracy: 0.5237 - val_precision: 0.5540
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5616 - precision: 0.5674 - val_loss: 0.6987 - val_accuracy: 0.5218 - val_precision: 0.5527
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5624 - precision: 0.5685 - val_loss: 0.6970 - val_accuracy: 0.5230 - val_precision: 0.5524
# Epoch 6/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5642 - precision: 0.5698 - val_loss: 0.6989 - val_accuracy: 0.5198 - val_precision: 0.5492
# Epoch 7/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6800 - accuracy: 0.5614 - precision: 0.5665 - val_loss: 0.6994 - val_accuracy: 0.5221 - val_precision: 0.5546
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6806 - accuracy: 0.5633 - precision: 0.5694 - val_loss: 0.6989 - val_accuracy: 0.5238 - val_precision: 0.5524
# Epoch 9/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.5615 - precision: 0.5679 - val_loss: 0.7022 - val_accuracy: 0.5187 - val_precision: 0.5513
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6796 - accuracy: 0.5643 - precision: 0.5692 - val_loss: 0.7005 - val_accuracy: 0.5187 - val_precision: 0.5512
# Epoch 11/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5626 - precision: 0.5676 - val_loss: 0.6997 - val_accuracy: 0.5232 - val_precision: 0.5549
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5622 - precision: 0.5685 - val_loss: 0.7007 - val_accuracy: 0.5198 - val_precision: 0.5530
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5615 - precision: 0.5679 - val_loss: 0.6999 - val_accuracy: 0.5230 - val_precision: 0.5553
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5627 - precision: 0.5682 - val_loss: 0.7007 - val_accuracy: 0.5201 - val_precision: 0.5523
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5638 - precision: 0.5691 - val_loss: 0.6992 - val_accuracy: 0.5172 - val_precision: 0.5473
# Epoch 16/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.5648 - precision: 0.5698 - val_loss: 0.7015 - val_accuracy: 0.5185 - val_precision: 0.5508
# Epoch 17/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6795 - accuracy: 0.5632 - precision: 0.5697 - val_loss: 0.6998 - val_accuracy: 0.5213 - val_precision: 0.5520
# Epoch 18/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6802 - accuracy: 0.5596 - precision: 0.5659 - val_loss: 0.7009 - val_accuracy: 0.5192 - val_precision: 0.5510
# Epoch 19/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5631 - precision: 0.5689 - val_loss: 0.6998 - val_accuracy: 0.5221 - val_precision: 0.5487
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5610 - precision: 0.5671 - val_loss: 0.6989 - val_accuracy: 0.5208 - val_precision: 0.5492
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.5634 - precision: 0.5689 - val_loss: 0.6992 - val_accuracy: 0.5207 - val_precision: 0.5494
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.5625 - precision: 0.5683 - val_loss: 0.6994 - val_accuracy: 0.5206 - val_precision: 0.5483
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6796 - accuracy: 0.5643 - precision: 0.5695 - val_loss: 0.7004 - val_accuracy: 0.5196 - val_precision: 0.5505
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6797 - accuracy: 0.5652 - precision: 0.5693 - val_loss: 0.7026 - val_accuracy: 0.5152 - val_precision: 0.5520
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.5629 - precision: 0.5688 - val_loss: 0.7020 - val_accuracy: 0.5166 - val_precision: 0.5501
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5645 - precision: 0.5710 - val_loss: 0.6990 - val_accuracy: 0.5216 - val_precision: 0.5509
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6797 - accuracy: 0.5617 - precision: 0.5678 - val_loss: 0.6993 - val_accuracy: 0.5229 - val_precision: 0.5514
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5638 - precision: 0.5686 - val_loss: 0.7012 - val_accuracy: 0.5170 - val_precision: 0.5523
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.5612 - precision: 0.5675 - val_loss: 0.7014 - val_accuracy: 0.5175 - val_precision: 0.5530
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6801 - accuracy: 0.5632 - precision: 0.5695 - val_loss: 0.6996 - val_accuracy: 0.5206 - val_precision: 0.5526
# 263/263 [==============================] - 0s 788us/step
# 30/30 [==============================] - 0s 737us/step
# 30/30 [==============================] - 0s 828us/step
# 30/30 [==============================] - 0s 828us/step
# Epoch 1/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.5597 - precision: 0.5653 - val_loss: 0.6980 - val_accuracy: 0.5222 - val_precision: 0.5507
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6805 - accuracy: 0.5608 - precision: 0.5648 - val_loss: 0.6983 - val_accuracy: 0.5223 - val_precision: 0.5534
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6806 - accuracy: 0.5600 - precision: 0.5649 - val_loss: 0.6988 - val_accuracy: 0.5228 - val_precision: 0.5566
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5621 - precision: 0.5681 - val_loss: 0.6978 - val_accuracy: 0.5231 - val_precision: 0.5524
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6801 - accuracy: 0.5602 - precision: 0.5655 - val_loss: 0.6966 - val_accuracy: 0.5252 - val_precision: 0.5544
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5638 - precision: 0.5686 - val_loss: 0.6984 - val_accuracy: 0.5225 - val_precision: 0.5538
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6804 - accuracy: 0.5617 - precision: 0.5668 - val_loss: 0.6983 - val_accuracy: 0.5231 - val_precision: 0.5553
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6801 - accuracy: 0.5629 - precision: 0.5690 - val_loss: 0.6976 - val_accuracy: 0.5237 - val_precision: 0.5527
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6806 - accuracy: 0.5607 - precision: 0.5654 - val_loss: 0.7004 - val_accuracy: 0.5218 - val_precision: 0.5564
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5616 - precision: 0.5672 - val_loss: 0.6992 - val_accuracy: 0.5221 - val_precision: 0.5547
# Epoch 11/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6801 - accuracy: 0.5631 - precision: 0.5686 - val_loss: 0.6982 - val_accuracy: 0.5248 - val_precision: 0.5558
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5644 - precision: 0.5685 - val_loss: 0.6996 - val_accuracy: 0.5217 - val_precision: 0.5564
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5623 - precision: 0.5669 - val_loss: 0.6975 - val_accuracy: 0.5240 - val_precision: 0.5553
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5622 - precision: 0.5679 - val_loss: 0.6993 - val_accuracy: 0.5199 - val_precision: 0.5548
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5617 - precision: 0.5668 - val_loss: 0.6976 - val_accuracy: 0.5236 - val_precision: 0.5538
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5631 - precision: 0.5675 - val_loss: 0.6988 - val_accuracy: 0.5220 - val_precision: 0.5544
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5634 - precision: 0.5703 - val_loss: 0.6971 - val_accuracy: 0.5235 - val_precision: 0.5523
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6804 - accuracy: 0.5622 - precision: 0.5673 - val_loss: 0.6992 - val_accuracy: 0.5222 - val_precision: 0.5538
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.5635 - precision: 0.5688 - val_loss: 0.6993 - val_accuracy: 0.5227 - val_precision: 0.5505
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.5625 - precision: 0.5673 - val_loss: 0.6984 - val_accuracy: 0.5236 - val_precision: 0.5520
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6801 - accuracy: 0.5638 - precision: 0.5684 - val_loss: 0.6978 - val_accuracy: 0.5240 - val_precision: 0.5510
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5649 - precision: 0.5694 - val_loss: 0.6988 - val_accuracy: 0.5245 - val_precision: 0.5523
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6796 - accuracy: 0.5631 - precision: 0.5685 - val_loss: 0.7004 - val_accuracy: 0.5210 - val_precision: 0.5564
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5647 - precision: 0.5688 - val_loss: 0.7003 - val_accuracy: 0.5183 - val_precision: 0.5529
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.5624 - precision: 0.5676 - val_loss: 0.6985 - val_accuracy: 0.5232 - val_precision: 0.5537
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.5641 - precision: 0.5693 - val_loss: 0.6982 - val_accuracy: 0.5223 - val_precision: 0.5520
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6805 - accuracy: 0.5631 - precision: 0.5681 - val_loss: 0.6985 - val_accuracy: 0.5235 - val_precision: 0.5523
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6796 - accuracy: 0.5645 - precision: 0.5683 - val_loss: 0.6998 - val_accuracy: 0.5190 - val_precision: 0.5531
# Epoch 29/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6795 - accuracy: 0.5647 - precision: 0.5696 - val_loss: 0.7020 - val_accuracy: 0.5155 - val_precision: 0.5542
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6799 - accuracy: 0.5641 - precision: 0.5696 - val_loss: 0.7002 - val_accuracy: 0.5194 - val_precision: 0.5549
# 263/263 [==============================] - 0s 925us/step
# 30/30 [==============================] - 0s 897us/step
# 30/30 [==============================] - 0s 931us/step
# 30/30 [==============================] - 0s 916us/step
# Epoch 1/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.5633 - precision: 0.5705 - val_loss: 0.6938 - val_accuracy: 0.5339 - val_precision: 0.5482
# Epoch 2/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6794 - accuracy: 0.5632 - precision: 0.5675 - val_loss: 0.6943 - val_accuracy: 0.5332 - val_precision: 0.5536
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.5644 - precision: 0.5697 - val_loss: 0.6954 - val_accuracy: 0.5292 - val_precision: 0.5533
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.5640 - precision: 0.5703 - val_loss: 0.6943 - val_accuracy: 0.5333 - val_precision: 0.5484
# Epoch 5/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6798 - accuracy: 0.5641 - precision: 0.5691 - val_loss: 0.6938 - val_accuracy: 0.5330 - val_precision: 0.5511
# Epoch 6/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6795 - accuracy: 0.5638 - precision: 0.5692 - val_loss: 0.6944 - val_accuracy: 0.5309 - val_precision: 0.5497
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5650 - precision: 0.5708 - val_loss: 0.6949 - val_accuracy: 0.5307 - val_precision: 0.5503
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6794 - accuracy: 0.5619 - precision: 0.5673 - val_loss: 0.6938 - val_accuracy: 0.5318 - val_precision: 0.5479
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5640 - precision: 0.5687 - val_loss: 0.6959 - val_accuracy: 0.5316 - val_precision: 0.5557
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5642 - precision: 0.5701 - val_loss: 0.6952 - val_accuracy: 0.5296 - val_precision: 0.5490
# Epoch 11/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6795 - accuracy: 0.5641 - precision: 0.5696 - val_loss: 0.6951 - val_accuracy: 0.5309 - val_precision: 0.5508
# Epoch 12/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6793 - accuracy: 0.5652 - precision: 0.5698 - val_loss: 0.6951 - val_accuracy: 0.5280 - val_precision: 0.5471
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6797 - accuracy: 0.5630 - precision: 0.5680 - val_loss: 0.6942 - val_accuracy: 0.5323 - val_precision: 0.5510
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6796 - accuracy: 0.5629 - precision: 0.5687 - val_loss: 0.6950 - val_accuracy: 0.5313 - val_precision: 0.5523
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6794 - accuracy: 0.5635 - precision: 0.5684 - val_loss: 0.6942 - val_accuracy: 0.5302 - val_precision: 0.5460
# Epoch 16/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6792 - accuracy: 0.5655 - precision: 0.5705 - val_loss: 0.6944 - val_accuracy: 0.5318 - val_precision: 0.5503
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.5638 - precision: 0.5709 - val_loss: 0.6938 - val_accuracy: 0.5316 - val_precision: 0.5469
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.5650 - precision: 0.5702 - val_loss: 0.6945 - val_accuracy: 0.5294 - val_precision: 0.5482
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.5627 - precision: 0.5680 - val_loss: 0.6946 - val_accuracy: 0.5294 - val_precision: 0.5454
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6791 - accuracy: 0.5636 - precision: 0.5688 - val_loss: 0.6944 - val_accuracy: 0.5302 - val_precision: 0.5475
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6799 - accuracy: 0.5622 - precision: 0.5682 - val_loss: 0.6940 - val_accuracy: 0.5292 - val_precision: 0.5462
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6799 - accuracy: 0.5644 - precision: 0.5698 - val_loss: 0.6954 - val_accuracy: 0.5293 - val_precision: 0.5434
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.5641 - precision: 0.5695 - val_loss: 0.6951 - val_accuracy: 0.5309 - val_precision: 0.5512
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.5665 - precision: 0.5709 - val_loss: 0.6952 - val_accuracy: 0.5302 - val_precision: 0.5471
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6789 - accuracy: 0.5652 - precision: 0.5694 - val_loss: 0.6951 - val_accuracy: 0.5320 - val_precision: 0.5480
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5619 - precision: 0.5675 - val_loss: 0.6938 - val_accuracy: 0.5309 - val_precision: 0.5486
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5646 - precision: 0.5696 - val_loss: 0.6947 - val_accuracy: 0.5294 - val_precision: 0.5466
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.5647 - precision: 0.5697 - val_loss: 0.6951 - val_accuracy: 0.5294 - val_precision: 0.5518
# Epoch 29/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6790 - accuracy: 0.5656 - precision: 0.5708 - val_loss: 0.6950 - val_accuracy: 0.5306 - val_precision: 0.5528
# Epoch 30/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6791 - accuracy: 0.5642 - precision: 0.5698 - val_loss: 0.6954 - val_accuracy: 0.5280 - val_precision: 0.5507
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 946us/step
# 30/30 [==============================] - 0s 898us/step
# 30/30 [==============================] - 0s 897us/step
# Epoch 1/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6789 - accuracy: 0.5632 - precision: 0.5693 - val_loss: 0.6941 - val_accuracy: 0.5320 - val_precision: 0.5475
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5613 - precision: 0.5661 - val_loss: 0.6946 - val_accuracy: 0.5338 - val_precision: 0.5529
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5642 - precision: 0.5698 - val_loss: 0.6957 - val_accuracy: 0.5341 - val_precision: 0.5573
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.5633 - precision: 0.5697 - val_loss: 0.6947 - val_accuracy: 0.5318 - val_precision: 0.5482
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5660 - precision: 0.5710 - val_loss: 0.6942 - val_accuracy: 0.5320 - val_precision: 0.5485
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6791 - accuracy: 0.5629 - precision: 0.5689 - val_loss: 0.6953 - val_accuracy: 0.5328 - val_precision: 0.5522
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.5654 - precision: 0.5707 - val_loss: 0.6949 - val_accuracy: 0.5339 - val_precision: 0.5527
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.5645 - precision: 0.5705 - val_loss: 0.6944 - val_accuracy: 0.5345 - val_precision: 0.5502
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6786 - accuracy: 0.5651 - precision: 0.5705 - val_loss: 0.6961 - val_accuracy: 0.5326 - val_precision: 0.5565
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.5646 - precision: 0.5710 - val_loss: 0.6955 - val_accuracy: 0.5306 - val_precision: 0.5501
# Epoch 11/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5641 - precision: 0.5694 - val_loss: 0.6943 - val_accuracy: 0.5340 - val_precision: 0.5524
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.5637 - precision: 0.5696 - val_loss: 0.6955 - val_accuracy: 0.5301 - val_precision: 0.5499
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.5648 - precision: 0.5699 - val_loss: 0.6944 - val_accuracy: 0.5330 - val_precision: 0.5509
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.5647 - precision: 0.5712 - val_loss: 0.6952 - val_accuracy: 0.5342 - val_precision: 0.5555
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6791 - accuracy: 0.5656 - precision: 0.5709 - val_loss: 0.6941 - val_accuracy: 0.5325 - val_precision: 0.5493
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6788 - accuracy: 0.5630 - precision: 0.5692 - val_loss: 0.6945 - val_accuracy: 0.5319 - val_precision: 0.5505
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6791 - accuracy: 0.5652 - precision: 0.5733 - val_loss: 0.6946 - val_accuracy: 0.5324 - val_precision: 0.5476
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6789 - accuracy: 0.5641 - precision: 0.5704 - val_loss: 0.6954 - val_accuracy: 0.5325 - val_precision: 0.5522
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.5618 - precision: 0.5680 - val_loss: 0.6948 - val_accuracy: 0.5325 - val_precision: 0.5484
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6791 - accuracy: 0.5638 - precision: 0.5687 - val_loss: 0.6946 - val_accuracy: 0.5306 - val_precision: 0.5470
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6791 - accuracy: 0.5645 - precision: 0.5709 - val_loss: 0.6942 - val_accuracy: 0.5323 - val_precision: 0.5501
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6786 - accuracy: 0.5645 - precision: 0.5711 - val_loss: 0.6951 - val_accuracy: 0.5326 - val_precision: 0.5461
# Epoch 23/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6789 - accuracy: 0.5647 - precision: 0.5710 - val_loss: 0.6951 - val_accuracy: 0.5341 - val_precision: 0.5542
# Epoch 24/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6789 - accuracy: 0.5641 - precision: 0.5697 - val_loss: 0.6948 - val_accuracy: 0.5334 - val_precision: 0.5511
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6787 - accuracy: 0.5642 - precision: 0.5693 - val_loss: 0.6948 - val_accuracy: 0.5328 - val_precision: 0.5491
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6794 - accuracy: 0.5637 - precision: 0.5704 - val_loss: 0.6938 - val_accuracy: 0.5345 - val_precision: 0.5516
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6788 - accuracy: 0.5644 - precision: 0.5706 - val_loss: 0.6948 - val_accuracy: 0.5329 - val_precision: 0.5505
# Epoch 28/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6794 - accuracy: 0.5630 - precision: 0.5682 - val_loss: 0.6948 - val_accuracy: 0.5345 - val_precision: 0.5565
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6787 - accuracy: 0.5635 - precision: 0.5695 - val_loss: 0.6950 - val_accuracy: 0.5331 - val_precision: 0.5545
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6788 - accuracy: 0.5659 - precision: 0.5719 - val_loss: 0.6955 - val_accuracy: 0.5339 - val_precision: 0.5576
# 263/263 [==============================] - 0s 899us/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 897us/step
# 30/30 [==============================] - 0s 993us/step
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6827 - accuracy: 0.5626 - precision: 0.5688 - val_loss: 0.6946 - val_accuracy: 0.5316 - val_precision: 0.5464
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.5604 - precision: 0.5648 - val_loss: 0.6945 - val_accuracy: 0.5333 - val_precision: 0.5504
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5641 - precision: 0.5680 - val_loss: 0.6947 - val_accuracy: 0.5320 - val_precision: 0.5511
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5653 - precision: 0.5714 - val_loss: 0.6941 - val_accuracy: 0.5329 - val_precision: 0.5468
# Epoch 5/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6797 - accuracy: 0.5656 - precision: 0.5704 - val_loss: 0.6939 - val_accuracy: 0.5327 - val_precision: 0.5479
# Epoch 6/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5663 - precision: 0.5720 - val_loss: 0.6946 - val_accuracy: 0.5300 - val_precision: 0.5456
# Epoch 7/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.5648 - precision: 0.5701 - val_loss: 0.6948 - val_accuracy: 0.5323 - val_precision: 0.5479
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5643 - precision: 0.5691 - val_loss: 0.6940 - val_accuracy: 0.5337 - val_precision: 0.5473
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.5643 - precision: 0.5690 - val_loss: 0.6969 - val_accuracy: 0.5338 - val_precision: 0.5530
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6801 - accuracy: 0.5658 - precision: 0.5713 - val_loss: 0.6957 - val_accuracy: 0.5349 - val_precision: 0.5505
# Epoch 11/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6794 - accuracy: 0.5655 - precision: 0.5705 - val_loss: 0.6946 - val_accuracy: 0.5362 - val_precision: 0.5510
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5650 - precision: 0.5698 - val_loss: 0.6952 - val_accuracy: 0.5316 - val_precision: 0.5479
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5638 - precision: 0.5686 - val_loss: 0.6947 - val_accuracy: 0.5320 - val_precision: 0.5479
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.5654 - precision: 0.5716 - val_loss: 0.6952 - val_accuracy: 0.5321 - val_precision: 0.5497
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.5663 - precision: 0.5704 - val_loss: 0.6947 - val_accuracy: 0.5325 - val_precision: 0.5468
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5633 - precision: 0.5682 - val_loss: 0.6950 - val_accuracy: 0.5302 - val_precision: 0.5450
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.5647 - precision: 0.5709 - val_loss: 0.6942 - val_accuracy: 0.5297 - val_precision: 0.5434
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.5620 - precision: 0.5661 - val_loss: 0.6954 - val_accuracy: 0.5323 - val_precision: 0.5484
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6787 - accuracy: 0.5635 - precision: 0.5690 - val_loss: 0.6957 - val_accuracy: 0.5287 - val_precision: 0.5433
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5646 - precision: 0.5690 - val_loss: 0.6940 - val_accuracy: 0.5340 - val_precision: 0.5472
# Epoch 21/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6792 - accuracy: 0.5665 - precision: 0.5723 - val_loss: 0.6954 - val_accuracy: 0.5314 - val_precision: 0.5462
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5637 - precision: 0.5687 - val_loss: 0.6957 - val_accuracy: 0.5266 - val_precision: 0.5402
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6788 - accuracy: 0.5647 - precision: 0.5688 - val_loss: 0.6962 - val_accuracy: 0.5298 - val_precision: 0.5465
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6791 - accuracy: 0.5641 - precision: 0.5686 - val_loss: 0.6958 - val_accuracy: 0.5299 - val_precision: 0.5437
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6788 - accuracy: 0.5651 - precision: 0.5695 - val_loss: 0.6957 - val_accuracy: 0.5294 - val_precision: 0.5436
# Epoch 26/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6791 - accuracy: 0.5663 - precision: 0.5709 - val_loss: 0.6945 - val_accuracy: 0.5368 - val_precision: 0.5504
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6794 - accuracy: 0.5652 - precision: 0.5694 - val_loss: 0.6959 - val_accuracy: 0.5335 - val_precision: 0.5467
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.5655 - precision: 0.5689 - val_loss: 0.6959 - val_accuracy: 0.5334 - val_precision: 0.5501
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6786 - accuracy: 0.5649 - precision: 0.5697 - val_loss: 0.6965 - val_accuracy: 0.5309 - val_precision: 0.5502
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.5655 - precision: 0.5708 - val_loss: 0.6958 - val_accuracy: 0.5351 - val_precision: 0.5548
# 263/263 [==============================] - 0s 899us/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 994us/step
# 30/30 [==============================] - 0s 943us/step
# accuracy_train     0.553106
# f1_train           0.576039
# recall_train       0.587136
# precision_train    0.566650
# auc_train          0.551829
# accuracy_test      0.544113
# f1_test            0.564811
# recall_test        0.579082
# precision_test     0.557749
# auc_test           0.542811
# dtype: float64
# 111/111 [==============================] - 0s 842us/step

# %% [markdown]
# #### Train NN

# %%
from sklearn.neural_network import MLPClassifier

#set NN model
nn_model = MLPClassifier(activation='tanh', batch_size=64, learning_rate_init=0.01,
              max_iter=10, random_state=0, solver='sgd')
name = 'MLP'
assess = class_cv.validateModel(x_train[subset_0],
                                y_train_dict['Target_0'],
                                model=nn_model ,
                                scaler=True ,
                                over_sampling=False,
                                under_sampling=False,
                                predictions=True,
                                cv_type='stratKfold',
                                scaler_type='stand',
                                train_size=10,
                                test_size=1,
                                gap=0)

#store scores
assess_df = assess['scores']
assess_df['model'] = name

#store cross-validation predictions
predictions = assess['predictions']
predictions['model'] = name 
predictions_df = pd.concat([predictions_df,predictions],axis=0)

#store model 
model = assess['model']
new_model_list.append(model)

scaler = assess['scaler']

full_assess = pd.concat([full_assess,
                            assess_df],
                        axis=0)

#fit scaler on test set 
X_test = pd.DataFrame(scaler.transform(x_test[subset_0]), 
                        index = x_test.index, 
                        columns = subset_0)

assess_test_dict, assess_test_df = assessTest(X_test,
                                                y_test_dict['Target_0'],
                                                model)




assess_test_dict['model'] = name
assess_test_df['model'] = name
assess_test_MLP = pd.DataFrame.from_records([assess_test_dict])
full_assess_test = pd.concat([test_assess_df,
                            assess_test_MLP],
                        axis=0)
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.552772
# f1_train           0.613386
# recall_train       0.685038
# precision_train    0.555519
# auc_train          0.547812
# accuracy_test      0.535933
# f1_test            0.596811
# recall_test        0.666682
# precision_test     0.542250
# auc_test           0.531033
# dtype: float64

# %%
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Validation\Full_Validation\full_CV_results_Lasso_Raw.csv'
full_assess.to_csv(path)

# %% [markdown]
# ## Plot Perfomance

# %% [markdown]
# ### Boxplot Format A

# %%
a = full_assess.copy()
title = 'Target 0 - Model Performance on Validation set - K=10'
plt.figure(figsize=(15, 10))
ax1 = plt.subplot(2, 1, 1)
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'accuracy_test'].values
df_assess.plot(kind='box', title='boxplot', showmeans=True,ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('Accuracy', size=15)


ax2 = plt.subplot(2, 1, 2, ) # Share x-axis ticks with ax1
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'precision_test'].values
df_assess.plot(kind='box', showmeans=True,ax=ax2)

ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
plt.tight_layout()

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0'
name_plot = f'{path}\\{title} - Lasso .png'
# plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# ### Boxplot Format B

# %%
title = 'Target 0 - Model Performance on Validation set - K=10'
plt.figure(figsize=(15, 10))

# Use sharex parameter to share x-axis ticks between subplots
ax1 = plt.subplot(2, 1, 1)
sns.boxplot(x=a['model'], y=a['accuracy_test'], hue=a['model'], ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('Accuracy', size=15)

# Set legend location outside the figure
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2 = plt.subplot(2, 1, 2, sharex=ax1) # Share x-axis ticks with ax1
sns.boxplot(x=a['model'], y=a['precision_test'], hue=a['model'], ax=ax2)
ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
ax2.legend().remove()

plt.tight_layout() # To prevent overlapping of the legend with the second subplot

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0'
name_plot = f'{path}\\{title} - Format 2 - Lasso.png'
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# ## Display Training and Valdation Results

# %% [markdown]
# Export average scores from the Cross Validation

# %% [markdown]
# ##### With Standartization inside CV

# %%
train_val_scores = full_assess.groupby('model').mean()
cols_ = train_val_scores.columns[train_val_scores.columns.str.contains('test')]
for col in cols_:
    
    new_col = col.replace('test','val')
    train_val_scores = train_val_scores.rename(columns = {col:new_col})
    
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Validation\modelMetricPerfomance_Target_0_valSet_Lasso_Raw.csv'
train_val_scores.to_csv(assess_path)
display(train_val_scores)
# Out:
#                     accuracy_train  f1_train  recall_train  precision_train  \
# model
# DecisionTree              0.547112  0.621544      0.722558         0.548481
# Keras_NN                  0.553106  0.576039      0.587136         0.566650
# LightGB                   0.566717  0.629601      0.710842         0.565073
# LogisticRegression        0.541927  0.624377      0.734884         0.542779
# MLP                       0.552777  0.613004      0.684152         0.555598
#
#                     auc_train  accuracy_val    f1_val  recall_val  \
# model
# DecisionTree         0.540532      0.525185  0.601120    0.702344
# Keras_NN             0.551829      0.544113  0.564811    0.579082
# LightGB              0.561313      0.543789  0.610632    0.693488
# LogisticRegression   0.534692      0.535286  0.617210    0.727048
# MLP                  0.547806      0.536218  0.596802    0.666149
#
#                     precision_val   auc_val
# model
# DecisionTree             0.531332  0.518555
# Keras_NN                 0.557749  0.542811
# LightGB                  0.546757  0.538180
# LogisticRegression       0.537887  0.528101
# MLP                      0.542709  0.531444

# %% [markdown]
# #### Display test Results

# %% [markdown]
# Export scores on test set

# %%
# test_assess_df = test_assess_df.reset_index().set_index('model')
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Test\modelMetricPerfomance_Target_0_testSet_Lasso_Raw.csv'
test_assess_df.to_csv(assess_path)

# %% [markdown]
# ## Export Models and scalers

# %%
import joblib

model_names = ['LogisticRegression_Raw.pkl', 'DecisionTree_Raw.pkl', 'LightGB_Raw.pkl', 'Keras_NN_Raw.pkl','MLP_Raw.pkl']

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Models\Raw\Lasso\\'
for model, model_name in zip(new_model_list, model_names):
    joblib.dump(model, f'{path}{model_name}', compress=9)
    
    
joblib.dump(scaler, f'{path}scaler.pkl', compress=9)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\rafae\AppData\Local\Temp\tmpy40b5v78\assets
# INFO:tensorflow:Assets written to: C:\Users\rafae\AppData\Local\Temp\tmpy40b5v78\assets
# ['D:\\Utilitários\\Facul\\Mestrado\\2o Ano\\Research\\Thesis\\Tables\\Target_0\\Models\\Raw\\Lasso\\\\scaler.pkl']

# %% [markdown]
# ### Import Models

# %%
model_list = []
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Models\Raw\Lasso\\'
for model, model_name in zip(new_model_list, model_names):
    model_clone = joblib.load(f'{path}{model_name}')
    
    model_list.append(model_clone)
    
    
scaler = joblib.load(f'{path}scaler.pkl')

# %%
test_stand = pd.DataFrame(scaler.transform(x_test[subset_0]), index = x_test.index, columns= subset_0)

model_list[3].score(test_stand,y_test_dict['Target_0'])
# Out:
# 111/111 [==============================] - 0s 1ms/step
# 0.5279947916666666

# %% [markdown]
# #### ROC Curve Comparison

# %%
import DataScalling as scalling
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras NN','MLP']
roc_curve(models = new_model_list,
                       names = model_names, 
                       X_train = x_train_stand[subset_0],
                       y_train  = y_train_dict['Target_0'],
                       X_val = X_test,
                       y_val= y_test_dict['Target_0'])


title = 'Model Perfomance Comparison - ROC Curve - Test Set - Target 0'
plt.title(title, 
          size = 15)
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0'
name_plot = f'{path}\\{title} - Lasso.png'
plt.tight_layout()
plt.savefig(name_plot, dpi=300)
# Out:
# 111/111 [==============================] - 0s 1ms/step
