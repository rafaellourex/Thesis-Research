# %% [markdown]
# ## Import Cleaned Data

# %% [markdown]
# __DataFrames:__
# df_model - df with all the features (independent festures + Target)
# x - df with all independent features
# y - df with dependent feature
# x_train - df with training data from x
# x_train_out - df with training data from x with outliers treatment applied
# x_test - df with test data from x
# x_test_out - df with test data from x with outliers treatment applied

# %%
import sys
sys.path.insert(1, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions')
sys.path.insert(2, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions\Functions')
# sys.path.insert(3, r'C:\Users\rafae\Personal\Github\Asset-Allocation\Long-Term-CAPM')
sys.path.insert(3, r'..\..\..')


import Classification_CV as class_cv
import importCleanedData as importData
import importSubsets as subsets

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from tensorflow import keras

import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

#set preferences
sns.set_style('whitegrid')

#set color for graphs
#set color for graphs
palette = ["#e41a1c", "#377eb8", "#4daf4a", "#984ea3"]

# dir = r'C:\Users\rafae\Personal\Github\Asset-Allocation\Long-Term-CAPM\SampleData\Sample'
dir = r'..\..\..\SampleData\Sample'
df_model_skew,df_target = importData.importCleanedData(dir=dir,target='CAPM')


#split data
date = '2018-01-01'
#split data without transformation
x_train,x_train_out,x_test, x_test_out,y_train_dict ,y_test_dict, y_train,y_test = importData.splitData(df_model_skew, date) 

#set columns
ratio_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Ratio'))]
shares_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Share'))]
margin_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Margin'))]
turnover_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Turnover'))]
dividend_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('dividend'))]


components_pca, pca_components_test = importData.runPCA(x_train_out= x_train_out,x_test = x_test)


#import subsets
lasso_subset_0, lasso_subset_15, mi_subset_0, mi_subset_15, lgb_subset, corr_subset0, corr_subset15 = subsets.importSubsets()


subset_0, subset_15 = lasso_subset_0, lasso_subset_15
# Out:
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# CAPM
# Import data from: ..\..\..\SampleData\Sample\LongTerm-DataPreparation_Skew.csv
# Original CAPM is being used as Target
# Nr of rows:
# 72538
# The variance explained by each component is: [50.70262543 16.3180414  12.90616231  7.80559243  6.69692605  5.82614766
#   4.47015907  4.07836541  3.82626867  3.40508117  3.17395217  2.97398597
#   2.84255924  2.7491931   2.6284572   2.30920491  2.29580116  2.24676716
#   2.1685526   2.08344875  1.96058327  1.88331954  1.85945512  1.79999003
#   1.75303096  1.72999438  1.67342676  1.57892838  1.52235707  1.48115797
#   1.44613583  1.42029951  1.39091026  1.35520895  1.32448072  1.29342424
#   1.27059382  1.25051426  1.2247642   1.18608517  1.17810508  1.15156743
#   1.14454538  1.12935887  1.10669478  1.0815426   1.07222534  1.05458183
#   1.03848544  1.01988948  1.01877496  0.99533768  0.98807987]
# The total variance explained by the components is: 0.7618344466001962

# %% [markdown]
# # Modelling Stage - Target 0

# %% [markdown]
# # Compare Model Perfomance

# %%
def reset_random_seeds():
    import random
    from numpy.random import seed
    import os
    from tensorflow import random as r
    
    seed_nr = 0
    os.environ['PYTHONHASHSEED']=str(seed_nr)
    r.set_seed(seed_nr)
    np.random.seed(seed_nr)
    
    
def gen_NNClassification (x, y, hidden_layer_sizes,activation_list, dropout,optimizer,loss = 'BinaryCrossentropy', metrics = ['AUC'],batch_size=180,epochs=10,validation_split = 0.25, class_weight = None, output_bias =None ):
    
    print('Neural Network Parameters:')
    print(f'Optimizer: {optimizer}')
    print(f'Loss: {loss}')
    print(f'Hidden Layer tructure: {hidden_layer_sizes}')
    print(f'Acivation Functions: {activation_list}')
    print(f'Dropout: {dropout}')
    print(f'Class Weight: {class_weight}')
    print(f'Output Bias: {output_bias}')
    
    #import libraries
    from scikeras.wrappers import KerasClassifier, KerasRegressor
    from tensorflow import keras
    
    reset_random_seeds()
    #get nr features in
    n_features_in_ = x.shape[1]
    n_classes_ = len(y.unique())
    
    if output_bias is not None:
        output_bias =keras.initializers.Constant(output_bias)
    
    #set keras model
    model = keras.models.Sequential()
    
    #define input shape
    # model.add(keras.layers.Input(shape=(n_features_in_,)))
    model.add(keras.layers.Dense(
          4, activation='relu',
          input_shape=(n_features_in_,)))
    
    #define hidden layers
    for hidden_layer_size, activation_ in zip(hidden_layer_sizes,
                                              activation_list):
        
        model.add(keras.layers.Dense(hidden_layer_size,
                                     activation=activation_))
        
        model.add(keras.layers.Dropout(dropout))
    
    #define output layer
    model.add(keras.layers.Dense(1,
                                 activation="sigmoid",
                                 bias_initializer=output_bias))
    
    #compile model 
    model.compile(optimizer=optimizer,
                  loss=loss,
                  metrics=metrics,
                  )
    
    #transform to SKlearn format
    NNmodel = KerasClassifier( model=model,
                            batch_size= batch_size,
                            epochs= epochs,
                            class_weight=class_weight,
                            validation_split=validation_split,
                            loss = loss)

    return NNmodel





metrics = ['AUC','Recall','Precision']
pos = len(y_train.loc[y_train.values==1])
neg = len(y_train.loc[y_train.values==0])
output_bias = np.log(pos/neg)



from numpy.random import seed
from tensorflow import keras 


reset_random_seeds()
optimizer = keras.optimizers.Adam(learning_rate=0.001)
loss_ = keras.losses.BinaryCrossentropy()
NNmodel = gen_NNClassification(components_pca, 
                                 y_train_dict['Target_0'],
                                 hidden_layer_sizes = (150,),
                                 activation_list = ['relu'],
                                 dropout = 0.2,
                                 optimizer =optimizer ,
                                 loss = loss_, 
                                 metrics = ['accuracy', 'Precision'],
                                 batch_size=180,
                                 epochs=30,
                                 validation_split = 0.3,
                                 class_weight = None,
                                 output_bias =None )

def roc_curve (models,names,X_train,y_train, X_val, y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        list with model names and a list of models 
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays ROC curve of the respective models 
    
    '''''''''''''''
    
    names= names
    from sklearn.metrics import roc_curve
    sns.set_theme(style = 'whitegrid')
    plt.figure(figsize = (10,10))
    for i, names ,in zip(models,names):
        # i.fit(X_train,y_train)
        thresh_dict = {}
        prob_model = i.predict_proba(X_val)
        
        fpr_DT_ent, tpr_DT_ent, thresholds_DT_ent = roc_curve(y_val, prob_model[:,1])
        plt.plot(fpr_DT_ent, tpr_DT_ent, label=f"ROC Curve {names}" , )
        
        plt.xlabel('FPR')
        plt.ylabel('TPR')
        plt.legend()
    
def fitted_precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted outside the function 
    
    '''''''''''''''
    names=names
    #model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()

def assessTest (x_test, y_test, model):
    index__ = x_test.reset_index()[['symbol','fillingDate','PC_0']].set_index(['symbol','fillingDate'])
    target_copy = df_target.copy()
    target_copy['fillingDate'] = target_copy['fillingDate'].astype(str)
    target_copy = target_copy.drop_duplicates(['symbol','fillingDate']).set_index(['symbol','fillingDate'])
    target_copy = target_copy.loc[target_copy.index.isin(index__.index)]
    
    assess_test_dict = dict()
    pred_test = model.predict(x_test)
    assess_test = pd.DataFrame(index = y_test.index)
    assess_test['Prediction'] = pred_test
    assess_test['Target'] = y_test
#     assess_test['returns'] = df_model.loc[df_model.index.isin(y_test.index),'futReturns']
    assess_test['excReturns'] = target_copy.loc[target_copy.index.isin(index__.index),'futAlpha']

    avg_returns = assess_test.groupby('Prediction').mean()[['excReturns']]


    from sklearn.metrics import roc_auc_score, precision_score, recall_score,accuracy_score
    auc  = roc_auc_score(assess_test['Target'],assess_test['Prediction'] )
    precision = precision_score(assess_test['Target'],assess_test['Prediction'] )
    recall =  recall_score(assess_test['Target'],assess_test['Prediction'] )
    acc =  accuracy_score(assess_test['Target'],assess_test['Prediction'] )
    
    assess_test_dict['accuracy'] = acc
    assess_test_dict['auc'] = auc
    assess_test_dict['precision'] = precision
    assess_test_dict['recall'] = recall
    return(assess_test_dict,assess_test)
# Out:
# Neural Network Parameters:
# Optimizer: <keras.optimizers.optimizer_experimental.adam.Adam object at 0x000001E0C79A0F10>
# Loss: <keras.losses.BinaryCrossentropy object at 0x000001E0C7BE7820>
# Hidden Layer tructure: (150,)
# Acivation Functions: ['relu']
# Dropout: 0.2
# Class Weight: None
# Output Bias: None

# %% [markdown]
# ## Target 0

# %% [markdown]
# Perfomance is compared using using standardized data since Neural Networks and Logistic Regressions are highly affected by data scalling.

# %%
import joblib

dt_model = DecisionTreeClassifier(max_depth=6,
                                  max_features=4,
                                  min_samples_leaf=100,
                                   random_state=0)


lgb_model = lgb.LGBMClassifier(learning_rate=0.2,
                               max_depth=2,
                               n_estimators=50,
                               random_state=0)

lr_model = LogisticRegression(random_state=0,
                              solver='liblinear')


model_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Models\PCA\\'

#create a list of model and model names 
model_list = [lr_model,dt_model, lgb_model,NNmodel]
model_names = ['LogisticRegression','DecisionTree','LightGB','NeuralNetwork']
new_model_list = []
test_assess_list = []

full_assess = pd.DataFrame()
full_assess_test = pd.DataFrame()
predictions_df = pd.DataFrame()

#iterate over the models and perform CV 
for model, name in zip(model_list, model_names):
    assess = class_cv.validateModel(components_pca,
                                    y_train_dict['Target_0'],
                                    model=model ,
                                    scaler=False ,
                                    over_sampling=False,
                                    predictions=True,
                                    cv_type='stratKfold',
                                    scaler_type='stand',
                                    train_size=10,
                                    test_size=1,
                                    gap=0)
    
    #store scores
    assess_df = assess['scores']
    assess_df['model'] = name
    
    #store model 
    model = assess['model']
    new_model_list.append(model)
    
    predictions = assess['predictions']
    predictions['model'] = name
    predictions_df = pd.concat([predictions_df,predictions],
                               axis=0)
    
    new_model_name = name + '_PCA.pkl'
    # joblib.dump(model, f'{model_path}{new_model_name}', compress=9)
    
    full_assess = pd.concat([full_assess,
                             assess_df],
                            axis=0)
    
    
    
    X_test = pca_components_test
    
    assess_test_dict, assess_test_df = assessTest(X_test,
                                                  y_test_dict['Target_0'],
                                                  model)
    assess_test_dict['model'] = name
    assess_test_df['model'] = name
    
    full_assess_test = pd.concat([full_assess_test,
                             assess_test_df],
                            axis=0)
    test_assess_list.append(assess_test_dict)
    
test_assess_df = pd.DataFrame.from_records(test_assess_list)
# Out:
# stratKfold
# Nr of splits: 10
# accuracy_train     0.548555
# f1_train           0.618256
# recall_train       0.705673
# precision_train    0.550151
# auc_train          0.542664
# accuracy_test      0.536066
# f1_test            0.600897
# recall_test        0.684193
# precision_test     0.542350
# auc_test           0.530511
# dtype: float64
# stratKfold
# Nr of splits: 10
# accuracy_train     0.544844
# f1_train           0.602487
# recall_train       0.672910
# precision_train    0.550656
# auc_train          0.540043
# accuracy_test      0.514799
# f1_test            0.576056
# recall_test        0.646550
# precision_test     0.526109
# auc_test           0.509850
# dtype: float64
# stratKfold
# Nr of splits: 10
# accuracy_train     0.568863
# f1_train           0.636858
# recall_train       0.729739
# precision_train    0.564964
# auc_train          0.562830
# accuracy_test      0.537835
# f1_test            0.609251
# recall_test        0.699172
# precision_test     0.542015
# auc_test           0.531783
# dtype: float64
# stratKfold
# Nr of splits: 10
# Epoch 1/30
# 184/184 [==============================] - 2s 4ms/step - loss: 0.7325 - accuracy: 0.5150 - precision: 0.5188 - val_loss: 0.6990 - val_accuracy: 0.5093 - val_precision: 0.5301
# Epoch 2/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6978 - accuracy: 0.5161 - precision: 0.5216 - val_loss: 0.6931 - val_accuracy: 0.5182 - val_precision: 0.5290
# Epoch 3/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6944 - accuracy: 0.5235 - precision: 0.5273 - val_loss: 0.6926 - val_accuracy: 0.5246 - val_precision: 0.5313
# Epoch 4/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6934 - accuracy: 0.5253 - precision: 0.5287 - val_loss: 0.6943 - val_accuracy: 0.5133 - val_precision: 0.5329
# Epoch 5/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6909 - accuracy: 0.5338 - precision: 0.5362 - val_loss: 0.6939 - val_accuracy: 0.5173 - val_precision: 0.5316
# Epoch 6/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6904 - accuracy: 0.5376 - precision: 0.5389 - val_loss: 0.6942 - val_accuracy: 0.5180 - val_precision: 0.5393
# Epoch 7/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6871 - accuracy: 0.5429 - precision: 0.5445 - val_loss: 0.6971 - val_accuracy: 0.5137 - val_precision: 0.5418
# Epoch 8/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6877 - accuracy: 0.5476 - precision: 0.5477 - val_loss: 0.6958 - val_accuracy: 0.5164 - val_precision: 0.5418
# Epoch 9/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6864 - accuracy: 0.5489 - precision: 0.5497 - val_loss: 0.6938 - val_accuracy: 0.5263 - val_precision: 0.5471
# Epoch 10/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6856 - accuracy: 0.5512 - precision: 0.5510 - val_loss: 0.6932 - val_accuracy: 0.5343 - val_precision: 0.5487
# Epoch 11/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6846 - accuracy: 0.5538 - precision: 0.5533 - val_loss: 0.6936 - val_accuracy: 0.5320 - val_precision: 0.5509
# Epoch 12/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6844 - accuracy: 0.5548 - precision: 0.5545 - val_loss: 0.6963 - val_accuracy: 0.5180 - val_precision: 0.5514
# Epoch 13/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6838 - accuracy: 0.5549 - precision: 0.5557 - val_loss: 0.6936 - val_accuracy: 0.5321 - val_precision: 0.5513
# Epoch 14/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6834 - accuracy: 0.5565 - precision: 0.5566 - val_loss: 0.6944 - val_accuracy: 0.5303 - val_precision: 0.5524
# Epoch 15/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6834 - accuracy: 0.5549 - precision: 0.5555 - val_loss: 0.6966 - val_accuracy: 0.5246 - val_precision: 0.5520
# Epoch 16/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6829 - accuracy: 0.5577 - precision: 0.5577 - val_loss: 0.6939 - val_accuracy: 0.5345 - val_precision: 0.5569
# Epoch 17/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6829 - accuracy: 0.5579 - precision: 0.5581 - val_loss: 0.6956 - val_accuracy: 0.5255 - val_precision: 0.5521
# Epoch 18/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6832 - accuracy: 0.5567 - precision: 0.5567 - val_loss: 0.6954 - val_accuracy: 0.5297 - val_precision: 0.5540
# Epoch 19/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6827 - accuracy: 0.5592 - precision: 0.5594 - val_loss: 0.6936 - val_accuracy: 0.5363 - val_precision: 0.5515
# Epoch 20/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6829 - accuracy: 0.5579 - precision: 0.5581 - val_loss: 0.6943 - val_accuracy: 0.5314 - val_precision: 0.5484
# Epoch 21/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6830 - accuracy: 0.5584 - precision: 0.5582 - val_loss: 0.6984 - val_accuracy: 0.5183 - val_precision: 0.5536
# Epoch 22/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6825 - accuracy: 0.5598 - precision: 0.5595 - val_loss: 0.6961 - val_accuracy: 0.5294 - val_precision: 0.5605
# Epoch 23/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6822 - accuracy: 0.5595 - precision: 0.5598 - val_loss: 0.6931 - val_accuracy: 0.5332 - val_precision: 0.5505
# Epoch 24/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6825 - accuracy: 0.5575 - precision: 0.5578 - val_loss: 0.7009 - val_accuracy: 0.5156 - val_precision: 0.5543
# Epoch 25/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6815 - accuracy: 0.5603 - precision: 0.5605 - val_loss: 0.6980 - val_accuracy: 0.5202 - val_precision: 0.5532
# Epoch 26/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6818 - accuracy: 0.5590 - precision: 0.5600 - val_loss: 0.6943 - val_accuracy: 0.5302 - val_precision: 0.5532
# Epoch 27/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6814 - accuracy: 0.5606 - precision: 0.5608 - val_loss: 0.6996 - val_accuracy: 0.5134 - val_precision: 0.5488
# Epoch 28/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6814 - accuracy: 0.5610 - precision: 0.5620 - val_loss: 0.6943 - val_accuracy: 0.5316 - val_precision: 0.5539
# Epoch 29/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6817 - accuracy: 0.5593 - precision: 0.5603 - val_loss: 0.6937 - val_accuracy: 0.5331 - val_precision: 0.5516
# Epoch 30/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6810 - accuracy: 0.5612 - precision: 0.5618 - val_loss: 0.6950 - val_accuracy: 0.5288 - val_precision: 0.5519
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6828 - accuracy: 0.5587 - precision: 0.5588 - val_loss: 0.6938 - val_accuracy: 0.5308 - val_precision: 0.5589
# Epoch 2/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6824 - accuracy: 0.5620 - precision: 0.5625 - val_loss: 0.6935 - val_accuracy: 0.5291 - val_precision: 0.5543
# Epoch 3/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6825 - accuracy: 0.5609 - precision: 0.5606 - val_loss: 0.6948 - val_accuracy: 0.5287 - val_precision: 0.5572
# Epoch 4/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6819 - accuracy: 0.5615 - precision: 0.5613 - val_loss: 0.6943 - val_accuracy: 0.5294 - val_precision: 0.5553
# Epoch 5/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6816 - accuracy: 0.5620 - precision: 0.5624 - val_loss: 0.6947 - val_accuracy: 0.5266 - val_precision: 0.5543
# Epoch 6/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6821 - accuracy: 0.5609 - precision: 0.5605 - val_loss: 0.6946 - val_accuracy: 0.5226 - val_precision: 0.5555
# Epoch 7/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6816 - accuracy: 0.5628 - precision: 0.5633 - val_loss: 0.6971 - val_accuracy: 0.5224 - val_precision: 0.5564
# Epoch 8/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6814 - accuracy: 0.5630 - precision: 0.5632 - val_loss: 0.6954 - val_accuracy: 0.5268 - val_precision: 0.5560
# Epoch 9/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6814 - accuracy: 0.5646 - precision: 0.5646 - val_loss: 0.6957 - val_accuracy: 0.5276 - val_precision: 0.5608
# Epoch 10/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6811 - accuracy: 0.5632 - precision: 0.5626 - val_loss: 0.6947 - val_accuracy: 0.5287 - val_precision: 0.5559
# Epoch 11/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6809 - accuracy: 0.5654 - precision: 0.5649 - val_loss: 0.6942 - val_accuracy: 0.5314 - val_precision: 0.5570
# Epoch 12/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6810 - accuracy: 0.5633 - precision: 0.5631 - val_loss: 0.6959 - val_accuracy: 0.5195 - val_precision: 0.5550
# Epoch 13/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6813 - accuracy: 0.5638 - precision: 0.5647 - val_loss: 0.6942 - val_accuracy: 0.5311 - val_precision: 0.5575
# Epoch 14/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6811 - accuracy: 0.5650 - precision: 0.5648 - val_loss: 0.6929 - val_accuracy: 0.5333 - val_precision: 0.5533
# Epoch 15/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6808 - accuracy: 0.5652 - precision: 0.5651 - val_loss: 0.6946 - val_accuracy: 0.5284 - val_precision: 0.5518
# Epoch 16/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6811 - accuracy: 0.5618 - precision: 0.5614 - val_loss: 0.6943 - val_accuracy: 0.5297 - val_precision: 0.5576
# Epoch 17/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6808 - accuracy: 0.5659 - precision: 0.5659 - val_loss: 0.6956 - val_accuracy: 0.5259 - val_precision: 0.5563
# Epoch 18/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6813 - accuracy: 0.5629 - precision: 0.5629 - val_loss: 0.6955 - val_accuracy: 0.5277 - val_precision: 0.5559
# Epoch 19/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6812 - accuracy: 0.5624 - precision: 0.5626 - val_loss: 0.6935 - val_accuracy: 0.5354 - val_precision: 0.5519
# Epoch 20/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6811 - accuracy: 0.5646 - precision: 0.5641 - val_loss: 0.6939 - val_accuracy: 0.5348 - val_precision: 0.5502
# Epoch 21/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6811 - accuracy: 0.5618 - precision: 0.5616 - val_loss: 0.6963 - val_accuracy: 0.5256 - val_precision: 0.5606
# Epoch 22/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6808 - accuracy: 0.5636 - precision: 0.5641 - val_loss: 0.6952 - val_accuracy: 0.5295 - val_precision: 0.5606
# Epoch 23/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6806 - accuracy: 0.5656 - precision: 0.5658 - val_loss: 0.6925 - val_accuracy: 0.5394 - val_precision: 0.5534
# Epoch 24/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6805 - accuracy: 0.5668 - precision: 0.5660 - val_loss: 0.7002 - val_accuracy: 0.5173 - val_precision: 0.5579
# Epoch 25/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.5657 - precision: 0.5655 - val_loss: 0.6977 - val_accuracy: 0.5201 - val_precision: 0.5539
# Epoch 26/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6804 - accuracy: 0.5652 - precision: 0.5655 - val_loss: 0.6947 - val_accuracy: 0.5287 - val_precision: 0.5534
# Epoch 27/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6804 - accuracy: 0.5645 - precision: 0.5645 - val_loss: 0.6993 - val_accuracy: 0.5219 - val_precision: 0.5577
# Epoch 28/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6800 - accuracy: 0.5674 - precision: 0.5679 - val_loss: 0.6944 - val_accuracy: 0.5335 - val_precision: 0.5553
# Epoch 29/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6807 - accuracy: 0.5644 - precision: 0.5645 - val_loss: 0.6942 - val_accuracy: 0.5318 - val_precision: 0.5551
# Epoch 30/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6807 - accuracy: 0.5666 - precision: 0.5664 - val_loss: 0.6951 - val_accuracy: 0.5307 - val_precision: 0.5550
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6785 - accuracy: 0.5689 - precision: 0.5686 - val_loss: 0.6981 - val_accuracy: 0.5230 - val_precision: 0.5581
# Epoch 2/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6786 - accuracy: 0.5671 - precision: 0.5680 - val_loss: 0.6952 - val_accuracy: 0.5325 - val_precision: 0.5548
# Epoch 3/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6782 - accuracy: 0.5706 - precision: 0.5700 - val_loss: 0.6977 - val_accuracy: 0.5248 - val_precision: 0.5574
# Epoch 4/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6780 - accuracy: 0.5699 - precision: 0.5696 - val_loss: 0.6965 - val_accuracy: 0.5263 - val_precision: 0.5504
# Epoch 5/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6784 - accuracy: 0.5679 - precision: 0.5685 - val_loss: 0.6954 - val_accuracy: 0.5318 - val_precision: 0.5572
# Epoch 6/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6781 - accuracy: 0.5710 - precision: 0.5694 - val_loss: 0.6961 - val_accuracy: 0.5285 - val_precision: 0.5536
# Epoch 7/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6777 - accuracy: 0.5688 - precision: 0.5686 - val_loss: 0.6998 - val_accuracy: 0.5228 - val_precision: 0.5582
# Epoch 8/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6773 - accuracy: 0.5695 - precision: 0.5691 - val_loss: 0.6999 - val_accuracy: 0.5226 - val_precision: 0.5549
# Epoch 9/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6775 - accuracy: 0.5690 - precision: 0.5692 - val_loss: 0.7001 - val_accuracy: 0.5233 - val_precision: 0.5596
# Epoch 10/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6769 - accuracy: 0.5698 - precision: 0.5690 - val_loss: 0.6966 - val_accuracy: 0.5321 - val_precision: 0.5538
# Epoch 11/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6777 - accuracy: 0.5696 - precision: 0.5687 - val_loss: 0.6973 - val_accuracy: 0.5261 - val_precision: 0.5536
# Epoch 12/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6771 - accuracy: 0.5711 - precision: 0.5704 - val_loss: 0.6969 - val_accuracy: 0.5280 - val_precision: 0.5553
# Epoch 13/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5708 - precision: 0.5706 - val_loss: 0.6967 - val_accuracy: 0.5309 - val_precision: 0.5537
# Epoch 14/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5702 - precision: 0.5696 - val_loss: 0.6971 - val_accuracy: 0.5301 - val_precision: 0.5522
# Epoch 15/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6765 - accuracy: 0.5721 - precision: 0.5720 - val_loss: 0.6982 - val_accuracy: 0.5273 - val_precision: 0.5473
# Epoch 16/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6768 - accuracy: 0.5718 - precision: 0.5700 - val_loss: 0.6974 - val_accuracy: 0.5327 - val_precision: 0.5601
# Epoch 17/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6771 - accuracy: 0.5683 - precision: 0.5674 - val_loss: 0.7021 - val_accuracy: 0.5222 - val_precision: 0.5580
# Epoch 18/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6766 - accuracy: 0.5720 - precision: 0.5714 - val_loss: 0.6991 - val_accuracy: 0.5285 - val_precision: 0.5522
# Epoch 19/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6771 - accuracy: 0.5737 - precision: 0.5721 - val_loss: 0.6975 - val_accuracy: 0.5301 - val_precision: 0.5549
# Epoch 20/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6763 - accuracy: 0.5718 - precision: 0.5711 - val_loss: 0.6979 - val_accuracy: 0.5293 - val_precision: 0.5475
# Epoch 21/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5718 - precision: 0.5693 - val_loss: 0.6998 - val_accuracy: 0.5225 - val_precision: 0.5547
# Epoch 22/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6773 - accuracy: 0.5702 - precision: 0.5698 - val_loss: 0.6973 - val_accuracy: 0.5305 - val_precision: 0.5575
# Epoch 23/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6768 - accuracy: 0.5737 - precision: 0.5726 - val_loss: 0.6955 - val_accuracy: 0.5335 - val_precision: 0.5520
# Epoch 24/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6761 - accuracy: 0.5737 - precision: 0.5715 - val_loss: 0.7059 - val_accuracy: 0.5170 - val_precision: 0.5614
# Epoch 25/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6767 - accuracy: 0.5739 - precision: 0.5728 - val_loss: 0.6999 - val_accuracy: 0.5251 - val_precision: 0.5521
# Epoch 26/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6768 - accuracy: 0.5712 - precision: 0.5702 - val_loss: 0.6986 - val_accuracy: 0.5286 - val_precision: 0.5545
# Epoch 27/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6765 - accuracy: 0.5727 - precision: 0.5712 - val_loss: 0.7034 - val_accuracy: 0.5203 - val_precision: 0.5548
# Epoch 28/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6765 - accuracy: 0.5726 - precision: 0.5723 - val_loss: 0.6989 - val_accuracy: 0.5301 - val_precision: 0.5551
# Epoch 29/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6761 - accuracy: 0.5760 - precision: 0.5742 - val_loss: 0.6992 - val_accuracy: 0.5275 - val_precision: 0.5561
# Epoch 30/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6761 - accuracy: 0.5748 - precision: 0.5736 - val_loss: 0.6997 - val_accuracy: 0.5273 - val_precision: 0.5609
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6810 - accuracy: 0.5652 - precision: 0.5643 - val_loss: 0.6965 - val_accuracy: 0.5312 - val_precision: 0.5614
# Epoch 2/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6803 - accuracy: 0.5663 - precision: 0.5659 - val_loss: 0.6956 - val_accuracy: 0.5319 - val_precision: 0.5542
# Epoch 3/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.5687 - precision: 0.5672 - val_loss: 0.6989 - val_accuracy: 0.5272 - val_precision: 0.5576
# Epoch 4/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.5683 - precision: 0.5674 - val_loss: 0.6955 - val_accuracy: 0.5274 - val_precision: 0.5492
# Epoch 5/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6797 - accuracy: 0.5685 - precision: 0.5684 - val_loss: 0.6957 - val_accuracy: 0.5300 - val_precision: 0.5558
# Epoch 6/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6799 - accuracy: 0.5663 - precision: 0.5654 - val_loss: 0.6965 - val_accuracy: 0.5284 - val_precision: 0.5539
# Epoch 7/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6793 - accuracy: 0.5677 - precision: 0.5674 - val_loss: 0.7004 - val_accuracy: 0.5190 - val_precision: 0.5584
# Epoch 8/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6797 - accuracy: 0.5664 - precision: 0.5663 - val_loss: 0.6968 - val_accuracy: 0.5297 - val_precision: 0.5550
# Epoch 9/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6792 - accuracy: 0.5680 - precision: 0.5678 - val_loss: 0.7016 - val_accuracy: 0.5211 - val_precision: 0.5619
# Epoch 10/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6789 - accuracy: 0.5689 - precision: 0.5688 - val_loss: 0.6972 - val_accuracy: 0.5281 - val_precision: 0.5507
# Epoch 11/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6793 - accuracy: 0.5673 - precision: 0.5668 - val_loss: 0.6970 - val_accuracy: 0.5245 - val_precision: 0.5506
# Epoch 12/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6789 - accuracy: 0.5698 - precision: 0.5692 - val_loss: 0.6981 - val_accuracy: 0.5237 - val_precision: 0.5561
# Epoch 13/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.5691 - precision: 0.5693 - val_loss: 0.6979 - val_accuracy: 0.5266 - val_precision: 0.5538
# Epoch 14/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6789 - accuracy: 0.5710 - precision: 0.5711 - val_loss: 0.6956 - val_accuracy: 0.5291 - val_precision: 0.5516
# Epoch 15/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6789 - accuracy: 0.5682 - precision: 0.5688 - val_loss: 0.6969 - val_accuracy: 0.5254 - val_precision: 0.5483
# Epoch 16/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6792 - accuracy: 0.5685 - precision: 0.5681 - val_loss: 0.6979 - val_accuracy: 0.5270 - val_precision: 0.5547
# Epoch 17/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6790 - accuracy: 0.5686 - precision: 0.5685 - val_loss: 0.6973 - val_accuracy: 0.5265 - val_precision: 0.5526
# Epoch 18/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6788 - accuracy: 0.5684 - precision: 0.5687 - val_loss: 0.7001 - val_accuracy: 0.5239 - val_precision: 0.5548
# Epoch 19/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6788 - accuracy: 0.5696 - precision: 0.5691 - val_loss: 0.6975 - val_accuracy: 0.5287 - val_precision: 0.5516
# Epoch 20/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6785 - accuracy: 0.5691 - precision: 0.5699 - val_loss: 0.6963 - val_accuracy: 0.5289 - val_precision: 0.5476
# Epoch 21/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6790 - accuracy: 0.5676 - precision: 0.5674 - val_loss: 0.6993 - val_accuracy: 0.5190 - val_precision: 0.5542
# Epoch 22/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6791 - accuracy: 0.5665 - precision: 0.5680 - val_loss: 0.6972 - val_accuracy: 0.5290 - val_precision: 0.5532
# Epoch 23/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6787 - accuracy: 0.5671 - precision: 0.5672 - val_loss: 0.6965 - val_accuracy: 0.5275 - val_precision: 0.5506
# Epoch 24/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6781 - accuracy: 0.5716 - precision: 0.5712 - val_loss: 0.7051 - val_accuracy: 0.5104 - val_precision: 0.5551
# Epoch 25/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6792 - accuracy: 0.5664 - precision: 0.5667 - val_loss: 0.7000 - val_accuracy: 0.5211 - val_precision: 0.5501
# Epoch 26/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6782 - accuracy: 0.5685 - precision: 0.5685 - val_loss: 0.6968 - val_accuracy: 0.5262 - val_precision: 0.5517
# Epoch 27/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6789 - accuracy: 0.5695 - precision: 0.5693 - val_loss: 0.7012 - val_accuracy: 0.5213 - val_precision: 0.5535
# Epoch 28/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6787 - accuracy: 0.5679 - precision: 0.5683 - val_loss: 0.6995 - val_accuracy: 0.5243 - val_precision: 0.5543
# Epoch 29/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6783 - accuracy: 0.5704 - precision: 0.5699 - val_loss: 0.6988 - val_accuracy: 0.5248 - val_precision: 0.5509
# Epoch 30/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6782 - accuracy: 0.5708 - precision: 0.5712 - val_loss: 0.7013 - val_accuracy: 0.5223 - val_precision: 0.5556
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6797 - accuracy: 0.5654 - precision: 0.5660 - val_loss: 0.6964 - val_accuracy: 0.5261 - val_precision: 0.5513
# Epoch 2/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6785 - accuracy: 0.5660 - precision: 0.5675 - val_loss: 0.6972 - val_accuracy: 0.5249 - val_precision: 0.5480
# Epoch 3/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6790 - accuracy: 0.5671 - precision: 0.5674 - val_loss: 0.6993 - val_accuracy: 0.5203 - val_precision: 0.5489
# Epoch 4/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6783 - accuracy: 0.5701 - precision: 0.5715 - val_loss: 0.6964 - val_accuracy: 0.5252 - val_precision: 0.5505
# Epoch 5/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6781 - accuracy: 0.5684 - precision: 0.5688 - val_loss: 0.6964 - val_accuracy: 0.5262 - val_precision: 0.5535
# Epoch 6/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6784 - accuracy: 0.5667 - precision: 0.5676 - val_loss: 0.6972 - val_accuracy: 0.5249 - val_precision: 0.5504
# Epoch 7/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6784 - accuracy: 0.5698 - precision: 0.5705 - val_loss: 0.7006 - val_accuracy: 0.5145 - val_precision: 0.5534
# Epoch 8/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6786 - accuracy: 0.5670 - precision: 0.5683 - val_loss: 0.6981 - val_accuracy: 0.5232 - val_precision: 0.5502
# Epoch 9/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6784 - accuracy: 0.5693 - precision: 0.5699 - val_loss: 0.7016 - val_accuracy: 0.5122 - val_precision: 0.5494
# Epoch 10/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6786 - accuracy: 0.5663 - precision: 0.5675 - val_loss: 0.6973 - val_accuracy: 0.5265 - val_precision: 0.5501
# Epoch 11/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6784 - accuracy: 0.5686 - precision: 0.5690 - val_loss: 0.6989 - val_accuracy: 0.5192 - val_precision: 0.5496
# Epoch 12/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6778 - accuracy: 0.5702 - precision: 0.5708 - val_loss: 0.6989 - val_accuracy: 0.5180 - val_precision: 0.5486
# Epoch 13/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6789 - accuracy: 0.5678 - precision: 0.5691 - val_loss: 0.7000 - val_accuracy: 0.5161 - val_precision: 0.5507
# Epoch 14/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6786 - accuracy: 0.5675 - precision: 0.5692 - val_loss: 0.6976 - val_accuracy: 0.5279 - val_precision: 0.5518
# Epoch 15/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6782 - accuracy: 0.5701 - precision: 0.5700 - val_loss: 0.6984 - val_accuracy: 0.5212 - val_precision: 0.5494
# Epoch 16/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6781 - accuracy: 0.5678 - precision: 0.5685 - val_loss: 0.6973 - val_accuracy: 0.5256 - val_precision: 0.5508
# Epoch 17/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6788 - accuracy: 0.5694 - precision: 0.5703 - val_loss: 0.6984 - val_accuracy: 0.5204 - val_precision: 0.5478
# Epoch 18/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6776 - accuracy: 0.5705 - precision: 0.5715 - val_loss: 0.7003 - val_accuracy: 0.5221 - val_precision: 0.5490
# Epoch 19/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6779 - accuracy: 0.5705 - precision: 0.5700 - val_loss: 0.6979 - val_accuracy: 0.5291 - val_precision: 0.5514
# Epoch 20/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6775 - accuracy: 0.5710 - precision: 0.5719 - val_loss: 0.6994 - val_accuracy: 0.5218 - val_precision: 0.5477
# Epoch 21/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6780 - accuracy: 0.5731 - precision: 0.5730 - val_loss: 0.6999 - val_accuracy: 0.5209 - val_precision: 0.5504
# Epoch 22/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6773 - accuracy: 0.5708 - precision: 0.5720 - val_loss: 0.6974 - val_accuracy: 0.5251 - val_precision: 0.5481
# Epoch 23/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6773 - accuracy: 0.5710 - precision: 0.5709 - val_loss: 0.6995 - val_accuracy: 0.5205 - val_precision: 0.5470
# Epoch 24/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5728 - precision: 0.5721 - val_loss: 0.7055 - val_accuracy: 0.5092 - val_precision: 0.5527
# Epoch 25/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6774 - accuracy: 0.5694 - precision: 0.5701 - val_loss: 0.7028 - val_accuracy: 0.5178 - val_precision: 0.5491
# Epoch 26/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6776 - accuracy: 0.5704 - precision: 0.5710 - val_loss: 0.6987 - val_accuracy: 0.5232 - val_precision: 0.5498
# Epoch 27/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6774 - accuracy: 0.5706 - precision: 0.5711 - val_loss: 0.7018 - val_accuracy: 0.5172 - val_precision: 0.5457
# Epoch 28/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6776 - accuracy: 0.5685 - precision: 0.5696 - val_loss: 0.7038 - val_accuracy: 0.5132 - val_precision: 0.5526
# Epoch 29/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6771 - accuracy: 0.5704 - precision: 0.5710 - val_loss: 0.7014 - val_accuracy: 0.5143 - val_precision: 0.5463
# Epoch 30/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6780 - accuracy: 0.5678 - precision: 0.5695 - val_loss: 0.7000 - val_accuracy: 0.5199 - val_precision: 0.5503
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6776 - accuracy: 0.5739 - precision: 0.5730 - val_loss: 0.6994 - val_accuracy: 0.5192 - val_precision: 0.5448
# Epoch 2/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6779 - accuracy: 0.5692 - precision: 0.5697 - val_loss: 0.6986 - val_accuracy: 0.5252 - val_precision: 0.5460
# Epoch 3/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6777 - accuracy: 0.5720 - precision: 0.5714 - val_loss: 0.6997 - val_accuracy: 0.5185 - val_precision: 0.5449
# Epoch 4/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6777 - accuracy: 0.5696 - precision: 0.5692 - val_loss: 0.7021 - val_accuracy: 0.5169 - val_precision: 0.5477
# Epoch 5/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6776 - accuracy: 0.5701 - precision: 0.5709 - val_loss: 0.6984 - val_accuracy: 0.5218 - val_precision: 0.5479
# Epoch 6/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6774 - accuracy: 0.5725 - precision: 0.5713 - val_loss: 0.7004 - val_accuracy: 0.5199 - val_precision: 0.5467
# Epoch 7/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5723 - precision: 0.5717 - val_loss: 0.7016 - val_accuracy: 0.5185 - val_precision: 0.5528
# Epoch 8/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6768 - accuracy: 0.5699 - precision: 0.5703 - val_loss: 0.7026 - val_accuracy: 0.5170 - val_precision: 0.5460
# Epoch 9/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6774 - accuracy: 0.5724 - precision: 0.5723 - val_loss: 0.7059 - val_accuracy: 0.5108 - val_precision: 0.5467
# Epoch 10/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6767 - accuracy: 0.5740 - precision: 0.5737 - val_loss: 0.7005 - val_accuracy: 0.5198 - val_precision: 0.5475
# Epoch 11/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6769 - accuracy: 0.5720 - precision: 0.5719 - val_loss: 0.7025 - val_accuracy: 0.5136 - val_precision: 0.5464
# Epoch 12/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6772 - accuracy: 0.5716 - precision: 0.5717 - val_loss: 0.7012 - val_accuracy: 0.5171 - val_precision: 0.5484
# Epoch 13/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5735 - precision: 0.5731 - val_loss: 0.7034 - val_accuracy: 0.5153 - val_precision: 0.5509
# Epoch 14/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6773 - accuracy: 0.5714 - precision: 0.5725 - val_loss: 0.7004 - val_accuracy: 0.5182 - val_precision: 0.5448
# Epoch 15/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6775 - accuracy: 0.5715 - precision: 0.5710 - val_loss: 0.6996 - val_accuracy: 0.5175 - val_precision: 0.5450
# Epoch 16/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6764 - accuracy: 0.5748 - precision: 0.5740 - val_loss: 0.7009 - val_accuracy: 0.5182 - val_precision: 0.5500
# Epoch 17/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6773 - accuracy: 0.5704 - precision: 0.5720 - val_loss: 0.7007 - val_accuracy: 0.5206 - val_precision: 0.5510
# Epoch 18/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6770 - accuracy: 0.5717 - precision: 0.5728 - val_loss: 0.7031 - val_accuracy: 0.5180 - val_precision: 0.5480
# Epoch 19/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6773 - accuracy: 0.5737 - precision: 0.5731 - val_loss: 0.6985 - val_accuracy: 0.5194 - val_precision: 0.5429
# Epoch 20/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5708 - precision: 0.5712 - val_loss: 0.6994 - val_accuracy: 0.5206 - val_precision: 0.5480
# Epoch 21/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6767 - accuracy: 0.5722 - precision: 0.5731 - val_loss: 0.6990 - val_accuracy: 0.5204 - val_precision: 0.5457
# Epoch 22/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5721 - precision: 0.5728 - val_loss: 0.6988 - val_accuracy: 0.5214 - val_precision: 0.5452
# Epoch 23/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6768 - accuracy: 0.5716 - precision: 0.5719 - val_loss: 0.7008 - val_accuracy: 0.5149 - val_precision: 0.5448
# Epoch 24/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6768 - accuracy: 0.5709 - precision: 0.5709 - val_loss: 0.7040 - val_accuracy: 0.5136 - val_precision: 0.5519
# Epoch 25/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5742 - precision: 0.5741 - val_loss: 0.7042 - val_accuracy: 0.5169 - val_precision: 0.5489
# Epoch 26/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6768 - accuracy: 0.5740 - precision: 0.5746 - val_loss: 0.6983 - val_accuracy: 0.5213 - val_precision: 0.5466
# Epoch 27/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5717 - precision: 0.5712 - val_loss: 0.7020 - val_accuracy: 0.5165 - val_precision: 0.5436
# Epoch 28/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6769 - accuracy: 0.5725 - precision: 0.5727 - val_loss: 0.7036 - val_accuracy: 0.5150 - val_precision: 0.5534
# Epoch 29/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6766 - accuracy: 0.5731 - precision: 0.5733 - val_loss: 0.7019 - val_accuracy: 0.5179 - val_precision: 0.5478
# Epoch 30/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6767 - accuracy: 0.5721 - precision: 0.5726 - val_loss: 0.7000 - val_accuracy: 0.5187 - val_precision: 0.5484
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6788 - accuracy: 0.5697 - precision: 0.5693 - val_loss: 0.6970 - val_accuracy: 0.5222 - val_precision: 0.5465
# Epoch 2/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6780 - accuracy: 0.5681 - precision: 0.5680 - val_loss: 0.6986 - val_accuracy: 0.5234 - val_precision: 0.5495
# Epoch 3/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6775 - accuracy: 0.5720 - precision: 0.5716 - val_loss: 0.7012 - val_accuracy: 0.5163 - val_precision: 0.5506
# Epoch 4/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6779 - accuracy: 0.5691 - precision: 0.5702 - val_loss: 0.6990 - val_accuracy: 0.5201 - val_precision: 0.5462
# Epoch 5/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6771 - accuracy: 0.5684 - precision: 0.5691 - val_loss: 0.6973 - val_accuracy: 0.5240 - val_precision: 0.5523
# Epoch 6/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6765 - accuracy: 0.5718 - precision: 0.5725 - val_loss: 0.7012 - val_accuracy: 0.5174 - val_precision: 0.5484
# Epoch 7/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6777 - accuracy: 0.5705 - precision: 0.5709 - val_loss: 0.6983 - val_accuracy: 0.5206 - val_precision: 0.5508
# Epoch 8/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6774 - accuracy: 0.5694 - precision: 0.5703 - val_loss: 0.7008 - val_accuracy: 0.5186 - val_precision: 0.5496
# Epoch 9/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6773 - accuracy: 0.5706 - precision: 0.5708 - val_loss: 0.7049 - val_accuracy: 0.5160 - val_precision: 0.5558
# Epoch 10/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6772 - accuracy: 0.5732 - precision: 0.5740 - val_loss: 0.6994 - val_accuracy: 0.5224 - val_precision: 0.5512
# Epoch 11/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6771 - accuracy: 0.5716 - precision: 0.5721 - val_loss: 0.6994 - val_accuracy: 0.5201 - val_precision: 0.5514
# Epoch 12/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6771 - accuracy: 0.5721 - precision: 0.5723 - val_loss: 0.7003 - val_accuracy: 0.5203 - val_precision: 0.5526
# Epoch 13/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5738 - precision: 0.5742 - val_loss: 0.7035 - val_accuracy: 0.5172 - val_precision: 0.5545
# Epoch 14/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6766 - accuracy: 0.5725 - precision: 0.5737 - val_loss: 0.7004 - val_accuracy: 0.5194 - val_precision: 0.5477
# Epoch 15/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5709 - precision: 0.5715 - val_loss: 0.6977 - val_accuracy: 0.5211 - val_precision: 0.5481
# Epoch 16/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6768 - accuracy: 0.5716 - precision: 0.5716 - val_loss: 0.6995 - val_accuracy: 0.5221 - val_precision: 0.5533
# Epoch 17/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6772 - accuracy: 0.5718 - precision: 0.5737 - val_loss: 0.6980 - val_accuracy: 0.5233 - val_precision: 0.5505
# Epoch 18/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6768 - accuracy: 0.5719 - precision: 0.5729 - val_loss: 0.7007 - val_accuracy: 0.5208 - val_precision: 0.5492
# Epoch 19/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6771 - accuracy: 0.5734 - precision: 0.5731 - val_loss: 0.6979 - val_accuracy: 0.5213 - val_precision: 0.5469
# Epoch 20/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6772 - accuracy: 0.5730 - precision: 0.5734 - val_loss: 0.6984 - val_accuracy: 0.5244 - val_precision: 0.5516
# Epoch 21/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6768 - accuracy: 0.5720 - precision: 0.5733 - val_loss: 0.6972 - val_accuracy: 0.5229 - val_precision: 0.5462
# Epoch 22/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5734 - precision: 0.5743 - val_loss: 0.6980 - val_accuracy: 0.5218 - val_precision: 0.5472
# Epoch 23/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6767 - accuracy: 0.5717 - precision: 0.5736 - val_loss: 0.7013 - val_accuracy: 0.5170 - val_precision: 0.5504
# Epoch 24/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6761 - accuracy: 0.5728 - precision: 0.5731 - val_loss: 0.6995 - val_accuracy: 0.5194 - val_precision: 0.5519
# Epoch 25/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5717 - precision: 0.5729 - val_loss: 0.7002 - val_accuracy: 0.5190 - val_precision: 0.5474
# Epoch 26/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6767 - accuracy: 0.5697 - precision: 0.5721 - val_loss: 0.6979 - val_accuracy: 0.5235 - val_precision: 0.5500
# Epoch 27/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6766 - accuracy: 0.5731 - precision: 0.5741 - val_loss: 0.6997 - val_accuracy: 0.5207 - val_precision: 0.5475
# Epoch 28/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5710 - precision: 0.5722 - val_loss: 0.7031 - val_accuracy: 0.5161 - val_precision: 0.5531
# Epoch 29/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6771 - accuracy: 0.5734 - precision: 0.5741 - val_loss: 0.7012 - val_accuracy: 0.5199 - val_precision: 0.5513
# Epoch 30/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6762 - accuracy: 0.5742 - precision: 0.5756 - val_loss: 0.7004 - val_accuracy: 0.5163 - val_precision: 0.5523
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5713 - precision: 0.5738 - val_loss: 0.6916 - val_accuracy: 0.5406 - val_precision: 0.5516
# Epoch 2/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6773 - accuracy: 0.5717 - precision: 0.5731 - val_loss: 0.6934 - val_accuracy: 0.5376 - val_precision: 0.5531
# Epoch 3/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6772 - accuracy: 0.5705 - precision: 0.5718 - val_loss: 0.6948 - val_accuracy: 0.5333 - val_precision: 0.5543
# Epoch 4/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6771 - accuracy: 0.5725 - precision: 0.5752 - val_loss: 0.6931 - val_accuracy: 0.5378 - val_precision: 0.5502
# Epoch 5/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6771 - accuracy: 0.5705 - precision: 0.5719 - val_loss: 0.6927 - val_accuracy: 0.5366 - val_precision: 0.5504
# Epoch 6/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6773 - accuracy: 0.5729 - precision: 0.5741 - val_loss: 0.6934 - val_accuracy: 0.5379 - val_precision: 0.5538
# Epoch 7/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6771 - accuracy: 0.5724 - precision: 0.5742 - val_loss: 0.6923 - val_accuracy: 0.5397 - val_precision: 0.5565
# Epoch 8/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6771 - accuracy: 0.5720 - precision: 0.5745 - val_loss: 0.6931 - val_accuracy: 0.5377 - val_precision: 0.5532
# Epoch 9/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6771 - accuracy: 0.5699 - precision: 0.5720 - val_loss: 0.6962 - val_accuracy: 0.5316 - val_precision: 0.5589
# Epoch 10/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5710 - precision: 0.5736 - val_loss: 0.6936 - val_accuracy: 0.5368 - val_precision: 0.5535
# Epoch 11/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6772 - accuracy: 0.5728 - precision: 0.5746 - val_loss: 0.6940 - val_accuracy: 0.5359 - val_precision: 0.5540
# Epoch 12/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5732 - precision: 0.5747 - val_loss: 0.6936 - val_accuracy: 0.5379 - val_precision: 0.5555
# Epoch 13/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5716 - precision: 0.5739 - val_loss: 0.6936 - val_accuracy: 0.5385 - val_precision: 0.5565
# Epoch 14/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6768 - accuracy: 0.5736 - precision: 0.5756 - val_loss: 0.6940 - val_accuracy: 0.5356 - val_precision: 0.5506
# Epoch 15/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6773 - accuracy: 0.5728 - precision: 0.5742 - val_loss: 0.6919 - val_accuracy: 0.5376 - val_precision: 0.5506
# Epoch 16/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5728 - precision: 0.5736 - val_loss: 0.6930 - val_accuracy: 0.5388 - val_precision: 0.5555
# Epoch 17/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5721 - precision: 0.5756 - val_loss: 0.6922 - val_accuracy: 0.5376 - val_precision: 0.5525
# Epoch 18/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6764 - accuracy: 0.5736 - precision: 0.5754 - val_loss: 0.6940 - val_accuracy: 0.5363 - val_precision: 0.5519
# Epoch 19/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6771 - accuracy: 0.5726 - precision: 0.5735 - val_loss: 0.6922 - val_accuracy: 0.5370 - val_precision: 0.5508
# Epoch 20/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5716 - precision: 0.5735 - val_loss: 0.6922 - val_accuracy: 0.5383 - val_precision: 0.5521
# Epoch 21/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6768 - accuracy: 0.5719 - precision: 0.5741 - val_loss: 0.6920 - val_accuracy: 0.5395 - val_precision: 0.5511
# Epoch 22/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6771 - accuracy: 0.5713 - precision: 0.5733 - val_loss: 0.6925 - val_accuracy: 0.5375 - val_precision: 0.5523
# Epoch 23/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6764 - accuracy: 0.5755 - precision: 0.5776 - val_loss: 0.6944 - val_accuracy: 0.5322 - val_precision: 0.5530
# Epoch 24/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6768 - accuracy: 0.5698 - precision: 0.5720 - val_loss: 0.6926 - val_accuracy: 0.5350 - val_precision: 0.5512
# Epoch 25/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6763 - accuracy: 0.5729 - precision: 0.5747 - val_loss: 0.6935 - val_accuracy: 0.5373 - val_precision: 0.5508
# Epoch 26/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6767 - accuracy: 0.5730 - precision: 0.5756 - val_loss: 0.6924 - val_accuracy: 0.5391 - val_precision: 0.5519
# Epoch 27/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6768 - accuracy: 0.5752 - precision: 0.5764 - val_loss: 0.6932 - val_accuracy: 0.5385 - val_precision: 0.5541
# Epoch 28/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6770 - accuracy: 0.5726 - precision: 0.5743 - val_loss: 0.6945 - val_accuracy: 0.5340 - val_precision: 0.5573
# Epoch 29/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6769 - accuracy: 0.5722 - precision: 0.5738 - val_loss: 0.6929 - val_accuracy: 0.5371 - val_precision: 0.5539
# Epoch 30/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5729 - precision: 0.5752 - val_loss: 0.6927 - val_accuracy: 0.5362 - val_precision: 0.5583
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6770 - accuracy: 0.5728 - precision: 0.5744 - val_loss: 0.6904 - val_accuracy: 0.5443 - val_precision: 0.5551
# Epoch 2/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6766 - accuracy: 0.5718 - precision: 0.5733 - val_loss: 0.6916 - val_accuracy: 0.5433 - val_precision: 0.5577
# Epoch 3/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6768 - accuracy: 0.5731 - precision: 0.5746 - val_loss: 0.6926 - val_accuracy: 0.5407 - val_precision: 0.5618
# Epoch 4/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6765 - accuracy: 0.5715 - precision: 0.5745 - val_loss: 0.6914 - val_accuracy: 0.5418 - val_precision: 0.5549
# Epoch 5/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6762 - accuracy: 0.5700 - precision: 0.5718 - val_loss: 0.6912 - val_accuracy: 0.5422 - val_precision: 0.5542
# Epoch 6/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6767 - accuracy: 0.5739 - precision: 0.5750 - val_loss: 0.6922 - val_accuracy: 0.5418 - val_precision: 0.5552
# Epoch 7/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6764 - accuracy: 0.5731 - precision: 0.5746 - val_loss: 0.6911 - val_accuracy: 0.5425 - val_precision: 0.5581
# Epoch 8/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6765 - accuracy: 0.5741 - precision: 0.5761 - val_loss: 0.6919 - val_accuracy: 0.5411 - val_precision: 0.5552
# Epoch 9/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6765 - accuracy: 0.5725 - precision: 0.5734 - val_loss: 0.6945 - val_accuracy: 0.5378 - val_precision: 0.5618
# Epoch 10/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6767 - accuracy: 0.5739 - precision: 0.5755 - val_loss: 0.6923 - val_accuracy: 0.5376 - val_precision: 0.5533
# Epoch 11/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6767 - accuracy: 0.5736 - precision: 0.5753 - val_loss: 0.6930 - val_accuracy: 0.5361 - val_precision: 0.5544
# Epoch 12/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6766 - accuracy: 0.5706 - precision: 0.5724 - val_loss: 0.6922 - val_accuracy: 0.5416 - val_precision: 0.5574
# Epoch 13/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6760 - accuracy: 0.5731 - precision: 0.5750 - val_loss: 0.6930 - val_accuracy: 0.5385 - val_precision: 0.5553
# Epoch 14/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6765 - accuracy: 0.5732 - precision: 0.5750 - val_loss: 0.6925 - val_accuracy: 0.5387 - val_precision: 0.5536
# Epoch 15/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6766 - accuracy: 0.5717 - precision: 0.5729 - val_loss: 0.6910 - val_accuracy: 0.5430 - val_precision: 0.5565
# Epoch 16/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6767 - accuracy: 0.5759 - precision: 0.5765 - val_loss: 0.6922 - val_accuracy: 0.5404 - val_precision: 0.5574
# Epoch 17/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6765 - accuracy: 0.5718 - precision: 0.5753 - val_loss: 0.6915 - val_accuracy: 0.5420 - val_precision: 0.5553
# Epoch 18/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6758 - accuracy: 0.5747 - precision: 0.5760 - val_loss: 0.6932 - val_accuracy: 0.5353 - val_precision: 0.5499
# Epoch 19/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6767 - accuracy: 0.5725 - precision: 0.5734 - val_loss: 0.6916 - val_accuracy: 0.5408 - val_precision: 0.5538
# Epoch 20/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6763 - accuracy: 0.5742 - precision: 0.5755 - val_loss: 0.6917 - val_accuracy: 0.5411 - val_precision: 0.5534
# Epoch 21/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6765 - accuracy: 0.5730 - precision: 0.5752 - val_loss: 0.6913 - val_accuracy: 0.5407 - val_precision: 0.5527
# Epoch 22/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6767 - accuracy: 0.5705 - precision: 0.5722 - val_loss: 0.6917 - val_accuracy: 0.5405 - val_precision: 0.5540
# Epoch 23/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6766 - accuracy: 0.5743 - precision: 0.5765 - val_loss: 0.6938 - val_accuracy: 0.5400 - val_precision: 0.5615
# Epoch 24/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6762 - accuracy: 0.5715 - precision: 0.5731 - val_loss: 0.6914 - val_accuracy: 0.5420 - val_precision: 0.5565
# Epoch 25/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6763 - accuracy: 0.5733 - precision: 0.5750 - val_loss: 0.6922 - val_accuracy: 0.5382 - val_precision: 0.5515
# Epoch 26/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6766 - accuracy: 0.5716 - precision: 0.5742 - val_loss: 0.6918 - val_accuracy: 0.5402 - val_precision: 0.5531
# Epoch 27/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6764 - accuracy: 0.5748 - precision: 0.5757 - val_loss: 0.6919 - val_accuracy: 0.5397 - val_precision: 0.5540
# Epoch 28/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6761 - accuracy: 0.5766 - precision: 0.5777 - val_loss: 0.6943 - val_accuracy: 0.5358 - val_precision: 0.5610
# Epoch 29/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6768 - accuracy: 0.5721 - precision: 0.5742 - val_loss: 0.6924 - val_accuracy: 0.5390 - val_precision: 0.5563
# Epoch 30/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6764 - accuracy: 0.5744 - precision: 0.5763 - val_loss: 0.6933 - val_accuracy: 0.5376 - val_precision: 0.5601
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6760 - accuracy: 0.5753 - precision: 0.5770 - val_loss: 0.6921 - val_accuracy: 0.5383 - val_precision: 0.5501
# Epoch 2/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6765 - accuracy: 0.5733 - precision: 0.5750 - val_loss: 0.6926 - val_accuracy: 0.5337 - val_precision: 0.5494
# Epoch 3/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6762 - accuracy: 0.5737 - precision: 0.5749 - val_loss: 0.6938 - val_accuracy: 0.5345 - val_precision: 0.5544
# Epoch 4/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6765 - accuracy: 0.5735 - precision: 0.5761 - val_loss: 0.6925 - val_accuracy: 0.5352 - val_precision: 0.5474
# Epoch 5/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6757 - accuracy: 0.5741 - precision: 0.5753 - val_loss: 0.6917 - val_accuracy: 0.5355 - val_precision: 0.5486
# Epoch 6/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6767 - accuracy: 0.5732 - precision: 0.5748 - val_loss: 0.6932 - val_accuracy: 0.5353 - val_precision: 0.5497
# Epoch 7/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6766 - accuracy: 0.5757 - precision: 0.5766 - val_loss: 0.6918 - val_accuracy: 0.5362 - val_precision: 0.5520
# Epoch 8/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6759 - accuracy: 0.5759 - precision: 0.5776 - val_loss: 0.6929 - val_accuracy: 0.5361 - val_precision: 0.5500
# Epoch 9/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6766 - accuracy: 0.5739 - precision: 0.5750 - val_loss: 0.6951 - val_accuracy: 0.5316 - val_precision: 0.5535
# Epoch 10/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6765 - accuracy: 0.5722 - precision: 0.5738 - val_loss: 0.6929 - val_accuracy: 0.5352 - val_precision: 0.5504
# Epoch 11/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6763 - accuracy: 0.5728 - precision: 0.5746 - val_loss: 0.6936 - val_accuracy: 0.5352 - val_precision: 0.5528
# Epoch 12/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6761 - accuracy: 0.5740 - precision: 0.5754 - val_loss: 0.6935 - val_accuracy: 0.5352 - val_precision: 0.5519
# Epoch 13/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6761 - accuracy: 0.5735 - precision: 0.5753 - val_loss: 0.6940 - val_accuracy: 0.5341 - val_precision: 0.5512
# Epoch 14/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6766 - accuracy: 0.5710 - precision: 0.5736 - val_loss: 0.6938 - val_accuracy: 0.5327 - val_precision: 0.5469
# Epoch 15/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6764 - accuracy: 0.5740 - precision: 0.5749 - val_loss: 0.6922 - val_accuracy: 0.5371 - val_precision: 0.5498
# Epoch 16/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6765 - accuracy: 0.5745 - precision: 0.5752 - val_loss: 0.6931 - val_accuracy: 0.5359 - val_precision: 0.5520
# Epoch 17/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6758 - accuracy: 0.5747 - precision: 0.5781 - val_loss: 0.6921 - val_accuracy: 0.5386 - val_precision: 0.5519
# Epoch 18/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6759 - accuracy: 0.5749 - precision: 0.5767 - val_loss: 0.6950 - val_accuracy: 0.5328 - val_precision: 0.5479
# Epoch 19/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6759 - accuracy: 0.5749 - precision: 0.5757 - val_loss: 0.6926 - val_accuracy: 0.5351 - val_precision: 0.5488
# Epoch 20/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6759 - accuracy: 0.5729 - precision: 0.5752 - val_loss: 0.6924 - val_accuracy: 0.5359 - val_precision: 0.5485
# Epoch 21/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6764 - accuracy: 0.5737 - precision: 0.5763 - val_loss: 0.6926 - val_accuracy: 0.5368 - val_precision: 0.5482
# Epoch 22/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6759 - accuracy: 0.5758 - precision: 0.5771 - val_loss: 0.6931 - val_accuracy: 0.5352 - val_precision: 0.5501
# Epoch 23/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6760 - accuracy: 0.5739 - precision: 0.5760 - val_loss: 0.6947 - val_accuracy: 0.5328 - val_precision: 0.5520
# Epoch 24/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6764 - accuracy: 0.5730 - precision: 0.5743 - val_loss: 0.6924 - val_accuracy: 0.5376 - val_precision: 0.5524
# Epoch 25/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6760 - accuracy: 0.5731 - precision: 0.5747 - val_loss: 0.6938 - val_accuracy: 0.5352 - val_precision: 0.5475
# Epoch 26/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6758 - accuracy: 0.5753 - precision: 0.5776 - val_loss: 0.6920 - val_accuracy: 0.5392 - val_precision: 0.5517
# Epoch 27/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6760 - accuracy: 0.5743 - precision: 0.5753 - val_loss: 0.6937 - val_accuracy: 0.5349 - val_precision: 0.5502
# Epoch 28/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6766 - accuracy: 0.5713 - precision: 0.5734 - val_loss: 0.6947 - val_accuracy: 0.5329 - val_precision: 0.5570
# Epoch 29/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6755 - accuracy: 0.5746 - precision: 0.5766 - val_loss: 0.6938 - val_accuracy: 0.5340 - val_precision: 0.5509
# Epoch 30/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6762 - accuracy: 0.5747 - precision: 0.5771 - val_loss: 0.6932 - val_accuracy: 0.5335 - val_precision: 0.5531
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# accuracy_train     0.561068
# f1_train           0.589651
# recall_train       0.609302
# precision_train    0.571875
# auc_train          0.559259
# accuracy_test      0.548640
# f1_test            0.572838
# recall_test        0.592373
# precision_test     0.560931
# auc_test           0.547009
# dtype: float64
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\rafae\AppData\Local\Temp\tmpjuvijhj8\assets
# INFO:tensorflow:Assets written to: C:\Users\rafae\AppData\Local\Temp\tmpjuvijhj8\assets
# 111/111 [==============================] - 0s 1ms/step

# %% [markdown]
# #### Train NN

# %%
from sklearn.neural_network import MLPClassifier

#set NN model
nn_model = MLPClassifier(activation='tanh',
                         batch_size=64,
                         learning_rate_init=0.01,
                        max_iter=10,
                        random_state=0, 
                        solver='sgd')
name = 'MLP'
assess = class_cv.validateModel(components_pca,
                                y_train_dict['Target_0'],
                                model=nn_model ,
                                scaler=False ,
                                over_sampling=False,
                                under_sampling=False,
                                predictions=True,
                                cv_type='stratKfold',
                                scaler_type='stand',
                                train_size=10,
                                test_size=1,
                                gap=0)

#store scores
assess_df = assess['scores']
assess_df['model'] = name

#store model 
model = assess['model']
new_model_list.append(model)

predictions = assess['predictions']
predictions['model'] = name
predictions_df = pd.concat([predictions_df,predictions],
                            axis=0)

new_model_name = name + '_PCA.pkl'
joblib.dump(model, f'{model_path}{new_model_name}', compress=9)


full_assess = pd.concat([full_assess,
                            assess_df],
                        axis=0)


X_test = pca_components_test

assess_test_dict, assess_test_df = assessTest(X_test,
                                                y_test_dict['Target_0'],
                                                nn_model)
assess_test_dict['model'] = name
assess_test_df['model'] = name

full_assess_test = pd.concat([full_assess_test,
                            assess_test_df],
                        axis=0)
test_assess_list.append(assess_test_dict)
    
test_assess_df = pd.DataFrame.from_records(test_assess_list)
# Out:
# stratKfold
# Nr of splits: 10
# accuracy_train     0.591577
# f1_train           0.634445
# recall_train       0.684177
# precision_train    0.591515
# auc_train          0.588105
# accuracy_test      0.532433
# f1_test            0.579860
# recall_test        0.625303
# precision_test     0.542093
# auc_test           0.528954
# dtype: float64

# %%
# validationPath = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Models\PCA\ValidationPredictions\PCA_ValPredictions_Target_0.csv'
# predictions_df.to_csv(validationPath)

testPath = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Models\PCA\TestPredictions\PCA_TestPredictions_Target_0.csv'
full_assess_test.to_csv(testPath)

# %%
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Validation\Full_Validation\full_CV_results_PCA.csv'
full_assess['subset'] = 'PCA'
full_assess.to_csv(path)

# %% [markdown]
# ### Boxplot Format A

# %%
a = full_assess.copy()
title = 'Target 0 - Model Performance on Validation set - K=10, PCA'
plt.figure(figsize=(15, 10))
ax1 = plt.subplot(2, 1, 1)
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'accuracy_test'].values
df_assess.plot(kind='box', title='boxplot', showmeans=True,ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('Accuracy', size=15)


ax2 = plt.subplot(2, 1, 2, ) # Share x-axis ticks with ax1
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'precision_test'].values
df_assess.plot(kind='box', showmeans=True,ax=ax2)

ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
plt.tight_layout()

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0'
name_plot = f'{path}\\{title}-PCA.png'
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# ### Boxplot Format B

# %%
title = 'Target 0 - Model Performance on Validation set - K=10, PCA'
plt.figure(figsize=(15, 10))

# Use sharex parameter to share x-axis ticks between subplots
ax1 = plt.subplot(2, 1, 1)
sns.boxplot(x=a['model'], y=a['accuracy_test'], hue=a['model'], ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('Accuracy', size=15)

# Set legend location outside the figure
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2 = plt.subplot(2, 1, 2, sharex=ax1) # Share x-axis ticks with ax1
sns.boxplot(x=a['model'], y=a['precision_test'], hue=a['model'], ax=ax2)
ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
ax2.legend().remove()

plt.tight_layout() # To prevent overlapping of the legend with the second subplot

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0'
name_plot = f'{path}\\{title}- PCA - Format 2.png'
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# ### Display Training and Valdation Results

# %% [markdown]
# Export average scores from the Cross Validation

# %% [markdown]
# ##### With Standartization inside CV

# %%
train_val_scores = full_assess.groupby('model').mean()
cols_ = train_val_scores.columns[train_val_scores.columns.str.contains('test')]
for col in cols_:
    
    new_col = col.replace('test','val')
    train_val_scores = train_val_scores.rename(columns = {col:new_col})
    
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Validation\modelMetricPerfomance_Target_0_valSet_PCA.csv'
train_val_scores.to_csv(assess_path)
display(train_val_scores)
# Out:
#                     accuracy_train  f1_train  recall_train  precision_train  \
# model
# DecisionTree              0.544844  0.602487      0.672910         0.550656
# LightGB                   0.568863  0.636858      0.729739         0.564964
# LogisticRegression        0.548555  0.618256      0.705673         0.550151
# MLP                       0.591577  0.634445      0.684177         0.591515
# NeuralNetwork             0.561068  0.589651      0.609302         0.571875
#
#                     auc_train  accuracy_val    f1_val  recall_val  \
# model
# DecisionTree         0.540043      0.514799  0.576056    0.646550
# LightGB              0.562830      0.537835  0.609251    0.699172
# LogisticRegression   0.542664      0.536066  0.600897    0.684193
# MLP                  0.588105      0.532433  0.579860    0.625303
# NeuralNetwork        0.559259      0.548640  0.572838    0.592373
#
#                     precision_val   auc_val
# model
# DecisionTree             0.526109  0.509850
# LightGB                  0.542015  0.531783
# LogisticRegression       0.542350  0.530511
# MLP                      0.542093  0.528954
# NeuralNetwork            0.560931  0.547009

# %% [markdown]
# #### Display test Results

# %% [markdown]
# Export scores on test set

# %%
test_assess_df = test_assess_df.reset_index().set_index('model')
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Test\modelMetricPerfomance_Target_0_testSet_PCA.csv'
test_assess_df.to_csv(assess_path)
display(test_assess_df)
# Out:
#                     index  accuracy       auc  precision    recall
# model
# LogisticRegression      0  0.525441  0.524824   0.512287  0.502369
# DecisionTree            1  0.510317  0.509334   0.496330  0.473532
# LightGB                 2  0.520433  0.522464   0.505852  0.596498
# NeuralNetwork           3  0.520883  0.517165   0.509836  0.381668
# MLP                     4  0.511869  0.511362   0.498075  0.492894

# %% [markdown]
# #### ROC Curve Comparison

# %%
import DataScalling as scalling
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras NN','MLP']
roc_curve(models = new_model_list,
                       names = model_names, 
                       X_train = components_pca,
                       y_train  = y_train_dict['Target_0'],
                       X_val = X_test,
                       y_val= y_test_dict['Target_0'])


title = 'Model Perfomance Comparison - ROC Curve - Test Set - Target 0, PCA'
plt.title(title, 
          size = 15)
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables'
name_plot = f'{path}\\{title}.png'
plt.tight_layout()
# plt.savefig(name_plot, dpi=300)
# Out:
# 111/111 [==============================] - 0s 1ms/step
