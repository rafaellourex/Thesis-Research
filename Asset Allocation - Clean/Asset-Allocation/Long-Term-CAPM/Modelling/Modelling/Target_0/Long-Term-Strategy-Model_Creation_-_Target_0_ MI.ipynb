# %% [markdown]
# ## Import Cleaned Data

# %% [markdown]
# __DataFrames:__
# df_model - df with all the features (independent festures + Target)
# x - df with all independent features
# y - df with dependent feature
# x_train - df with training data from x
# x_train_out - df with training data from x with outliers treatment applied
# x_test - df with test data from x
# x_test_out - df with test data from x with outliers treatment applied

# %%
import sys
sys.path.insert(1, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions')
sys.path.insert(2, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions\Functions')
# sys.path.insert(3, r'C:\Users\rafae\Personal\Github\Asset-Allocation\Long-Term-CAPM')
sys.path.insert(3, r'..\..\..')


import Classification_CV as class_cv
import importCleanedData as importData
import importSubsets as subsets

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from tensorflow import keras

import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

#set preferences
sns.set_style('whitegrid')

#set color for graphs
#set color for graphs
palette = ["#e41a1c", "#377eb8", "#4daf4a", "#984ea3"]

# dir = r'C:\Users\rafae\Personal\Github\Asset-Allocation\Long-Term-CAPM\SampleData\Sample'
dir = r'..\..\..\SampleData\Sample'
df_model_skew,df_target = importData.importCleanedData(dir=dir,target='CAPM')


#split data
date = '2018-01-01'
#split data without transformation
x_train,x_train_out,x_test, x_test_out,y_train_dict ,y_test_dict, y_train,y_test = importData.splitData(df_model_skew, date) 

#set columns
ratio_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Ratio'))]
shares_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Share'))]
margin_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Margin'))]
turnover_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Turnover'))]
dividend_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('dividend'))]


components_pca, pca_components_test = importData.runPCA(x_train_out= x_train_out,x_test = x_test)


#import subsets
lasso_subset_0, lasso_subset_15, mi_subset_0, mi_subset_15, lgb_subset, corr_subset0, corr_subset15 = subsets.importSubsets()


subset_0, subset_15 = lasso_subset_0, lasso_subset_15
# Out:
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# CAPM
# Import data from: ..\..\..\SampleData\Sample\LongTerm-DataPreparation_Skew.csv
# Original CAPM is being used as Target
# Nr of rows:
# 72538
# The variance explained by each component is: [50.70262543 16.3180414  12.90616231  7.80559243  6.69692605  5.82614766
#   4.47015907  4.07836541  3.82626867  3.40508117  3.17395217  2.97398597
#   2.84255924  2.7491931   2.6284572   2.30920491  2.29580116  2.24676716
#   2.1685526   2.08344875  1.96058327  1.88331954  1.85945512  1.79999003
#   1.75303096  1.72999438  1.67342676  1.57892838  1.52235707  1.48115797
#   1.44613583  1.42029951  1.39091026  1.35520895  1.32448072  1.29342424
#   1.27059382  1.25051426  1.2247642   1.18608517  1.17810508  1.15156743
#   1.14454538  1.12935887  1.10669478  1.0815426   1.07222534  1.05458183
#   1.03848544  1.01988948  1.01877496  0.99533768  0.98807987]
# The total variance explained by the components is: 0.7618344466001962

# %% [markdown]
# # Modelling Stage - Target 0

# %% [markdown]
# # Compare Model Perfomance

# %%
def gen_NNClassification (x, y, hidden_layer_sizes,activation_list, dropout,optimizer,loss = 'BinaryCrossentropy', metrics = ['AUC'],batch_size=180,epochs=10,validation_split = 0.25, class_weight = None, output_bias =None ):
    
    print('Neural Network Parameters:')
    print(f'Optimizer: {optimizer}')
    print(f'Loss: {loss}')
    print(f'Hidden Layer tructure: {hidden_layer_sizes}')
    print(f'Acivation Functions: {activation_list}')
    print(f'Dropout: {dropout}')
    print(f'Class Weight: {class_weight}')
    print(f'Output Bias: {output_bias}')
    
    #import libraries
    from scikeras.wrappers import KerasClassifier, KerasRegressor
    from tensorflow import keras
    
    #get nr features in
    n_features_in_ = x.shape[1]
    n_classes_ = len(y.unique())
    
    if output_bias is not None:
        output_bias =keras.initializers.Constant(output_bias)
    
    #set keras model
    model = keras.models.Sequential()
    
    #define input shape
    # model.add(keras.layers.Input(shape=(n_features_in_,)))
    model.add(keras.layers.Dense(
          4, activation='relu',
          input_shape=(n_features_in_,)))
    
    #define hidden layers
    for hidden_layer_size, activation_ in zip(hidden_layer_sizes,
                                              activation_list):
        
        model.add(keras.layers.Dense(hidden_layer_size,
                                     activation=activation_))
        
        model.add(keras.layers.Dropout(dropout))
    
    #define output layer
    model.add(keras.layers.Dense(1,
                                 activation="sigmoid",
                                 bias_initializer=output_bias))
    
    #compile model 
    model.compile(optimizer=optimizer,
                  loss=loss,
                  metrics=metrics,
                  )
    
    #transform to SKlearn format
    NNmodel = KerasClassifier( model=model,
                            batch_size= batch_size,
                            epochs= epochs,
                            class_weight=class_weight,
                            validation_split=validation_split,
                            loss = loss)

    return NNmodel


metrics = ['AUC','Recall','Precision']
pos = len(y_train.loc[y_train.values==1])
neg = len(y_train.loc[y_train.values==0])
output_bias = np.log(pos/neg)

def reset_random_seeds():
    import random
    from numpy.random import seed
    import os
    from tensorflow import random as r
    
    seed_nr = 0
    os.environ['PYTHONHASHSEED']=str(seed_nr)
    r.set_seed(seed_nr)
    np.random.seed(seed_nr)

from numpy.random import seed
from tensorflow import keras 


reset_random_seeds()
optimizer = keras.optimizers.Adam(learning_rate=0.001)
loss_ = keras.losses.BinaryCrossentropy()
NNmodel = gen_NNClassification(x_train_out[mi_subset_0], 
                                 y_train_dict['Target_0'],
                                 hidden_layer_sizes = (150,),
                                 activation_list = ['relu'],
                                 dropout = 0.2,
                                 optimizer =optimizer ,
                                 loss = loss_, 
                                 metrics = ['accuracy', 'Precision'],
                                 batch_size=180,
                                 epochs=30,
                                 validation_split = 0.3,
                                 class_weight = None,
                                 output_bias =None )




def roc_curve (models,names,X_train,y_train, X_val, y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        list with model names and a list of models 
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays ROC curve of the respective models 
    
    '''''''''''''''
    
    names= names
    from sklearn.metrics import roc_curve
    sns.set_theme(style = 'whitegrid')
    plt.figure(figsize = (10,10))
    for i, names ,in zip(models,names):
        # i.fit(X_train,y_train)
        thresh_dict = {}
        prob_model = i.predict_proba(X_val)
        
        fpr_DT_ent, tpr_DT_ent, thresholds_DT_ent = roc_curve(y_val, prob_model[:,1])
        plt.plot(fpr_DT_ent, tpr_DT_ent, label=f"ROC Curve {names}" , )
        
        plt.xlabel('FPR')
        plt.ylabel('TPR')
        plt.legend()
           
def precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted inside the function 
    
    '''''''''''''''
    names=names
    model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()
    
    
def fitted_precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted outside the function 
    
    '''''''''''''''
    names=names
    #model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()

def assessTest (x_test, y_test, model):
    
    col = x_test.columns[4]
    index__ = x_test.reset_index()[['symbol','fillingDate',col]].set_index(['symbol','fillingDate'])
    target_copy = df_target.copy()
    target_copy['fillingDate'] = target_copy['fillingDate'].astype(str)
    target_copy = target_copy.drop_duplicates(['symbol','fillingDate']).set_index(['symbol','fillingDate'])
    target_copy = target_copy.loc[target_copy.index.isin(index__.index)]
    
    assess_test_dict = dict()
    pred_test = model.predict(x_test)
    assess_test = pd.DataFrame(index = y_test.index)
    assess_test['Prediction'] = pred_test
    assess_test['Target'] = y_test
#     assess_test['returns'] = df_model.loc[df_model.index.isin(y_test.index),'futReturns']
    assess_test['excReturns'] = target_copy.loc[target_copy.index.isin(index__.index),'futAlpha']

    avg_returns = assess_test.groupby('Prediction').mean()[['excReturns']]


    from sklearn.metrics import roc_auc_score, precision_score, recall_score,accuracy_score
    auc  = roc_auc_score(assess_test['Target'],assess_test['Prediction'] )
    precision = precision_score(assess_test['Target'],assess_test['Prediction'] )
    recall =  recall_score(assess_test['Target'],assess_test['Prediction'] )
    acc =  accuracy_score(assess_test['Target'],assess_test['Prediction'] )
    
    assess_test_dict['accuracy'] = acc
    assess_test_dict['auc'] = auc
    assess_test_dict['precision'] = precision
    assess_test_dict['recall'] = recall
    return(assess_test_dict,assess_test)
# Out:
# Neural Network Parameters:
# Optimizer: <keras.optimizers.optimizer_experimental.adam.Adam object at 0x000001C692F11370>
# Loss: <keras.losses.BinaryCrossentropy object at 0x000001C6D4F57820>
# Hidden Layer tructure: (150,)
# Acivation Functions: ['relu']
# Dropout: 0.2
# Class Weight: None
# Output Bias: None

# %% [markdown]
# ## Target 0

# %% [markdown]
# Perfomance is compared using using standardized data since Neural Networks and Logistic Regressions are highly affected by data scalling.

# %%
def assessModels (x_train,y_train,x_test,y_test,model_list, model_names,):
    new_model_list = []
    full_assess = pd.DataFrame()
    full_assess_test = pd.DataFrame()
    test_assess_list = []
    #iterate over the models and perform CV 
    for model, name in zip(model_list, model_names):
        assess = class_cv.validateModel(x_train,
                                        y_train,
                                        model=model ,
                                        scaler=True ,
                                        over_sampling=False,
                                        predictions=False,
                                        cv_type='stratKfold',
                                        scaler_type='stand',
                                        train_size=10,
                                        test_size=1,
                                        gap=0)
        
        #store scores
        assess_df = assess['scores']
        assess_df['model'] = name
        
        full_assess = pd.concat([full_assess,
                                assess_df],
                                axis=0)
        
        #store model 
        model = assess['model']
        new_model_list.append(model)
        
        if name =='LightGB':
            features = model.feature_name_
    
        elif name =='Keras_NN':
            features = features
        
        else:
            features = model.feature_names_in_
            
        
        scaler = assess['scaler']
        scale_features = scaler.get_feature_names_out()
    
        rest_ft =[]
        for ft in features:
            if ft not in scale_features:
                rest_ft.append(ft)
    
    
    
        # fit scaler on test set 
        X_test = pd.DataFrame(scaler.transform(x_test[scale_features]), 
                            index = x_test.index, 
                            columns = scale_features)
        
        X_test = pd.concat([X_test, x_test[rest_ft]],axis=1)
            
        
        X_test = X_test[features]
        
        assess_test_dict, assess_test_df = assessTest(X_test,
                                                    y_test,
                                                    model)
        assess_test_dict['model'] = name
        assess_test_df['model'] = name
        
        full_assess_test = pd.concat([full_assess_test,
                                assess_test_df],
                                axis=0)
        test_assess_list.append(assess_test_dict)
        
    test_assess_df = pd.DataFrame.from_records(test_assess_list)
    
    return(full_assess,test_assess_df,new_model_list )

# %%
dt_model = DecisionTreeClassifier(max_depth=6,
                                  max_features=4,
                                  min_samples_leaf=100,
                                   random_state=0)


lgb_model = lgb.LGBMClassifier(learning_rate=0.2,
                               max_depth=2,
                               n_estimators=50,
                               random_state=0)

lr_model = LogisticRegression(random_state=0,
                           solver='liblinear' )


model_list = [lr_model,dt_model, lgb_model,NNmodel]
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras_NN']

full_assess,test_assess_df,new_model_list  = assessModels(x_train_out[mi_subset_0],y_train_dict['Target_0'],
             x_test[mi_subset_0],y_test_dict['Target_0'],model_list[:], model_names[:])
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.536618
# f1_train           0.627753
# recall_train       0.754274
# precision_train    0.537636
# auc_train          0.528456
# accuracy_test      0.529256
# f1_test            0.614201
# recall_test        0.739298
# precision_test     0.533938
# auc_test           0.521370
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.546292
# f1_train           0.613298
# recall_train       0.698880
# precision_train    0.549510
# auc_train          0.540570
# accuracy_test      0.523093
# f1_test            0.593885
# recall_test        0.676153
# precision_test     0.531402
# auc_test           0.517354
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.560394
# f1_train           0.634527
# recall_train       0.736650
# precision_train    0.557308
# auc_train          0.553784
# accuracy_test      0.535724
# f1_test            0.611298
# recall_test        0.711027
# precision_test     0.539966
# auc_test           0.529142
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# Epoch 1/30
# 184/184 [==============================] - 2s 4ms/step - loss: 0.6960 - accuracy: 0.5078 - precision: 0.5251 - val_loss: 0.6934 - val_accuracy: 0.5357 - val_precision: 0.5363
# Epoch 2/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6924 - accuracy: 0.5207 - precision: 0.5307 - val_loss: 0.6915 - val_accuracy: 0.5316 - val_precision: 0.5354
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6914 - accuracy: 0.5265 - precision: 0.5317 - val_loss: 0.6921 - val_accuracy: 0.5247 - val_precision: 0.5352
# Epoch 4/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6913 - accuracy: 0.5279 - precision: 0.5342 - val_loss: 0.6920 - val_accuracy: 0.5178 - val_precision: 0.5326
# Epoch 5/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6909 - accuracy: 0.5298 - precision: 0.5372 - val_loss: 0.6930 - val_accuracy: 0.5180 - val_precision: 0.5329
# Epoch 6/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6905 - accuracy: 0.5316 - precision: 0.5384 - val_loss: 0.6931 - val_accuracy: 0.5143 - val_precision: 0.5350
# Epoch 7/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6901 - accuracy: 0.5341 - precision: 0.5416 - val_loss: 0.6940 - val_accuracy: 0.5142 - val_precision: 0.5346
# Epoch 8/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6898 - accuracy: 0.5358 - precision: 0.5430 - val_loss: 0.6927 - val_accuracy: 0.5175 - val_precision: 0.5364
# Epoch 9/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6893 - accuracy: 0.5375 - precision: 0.5450 - val_loss: 0.6925 - val_accuracy: 0.5219 - val_precision: 0.5364
# Epoch 10/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6893 - accuracy: 0.5380 - precision: 0.5450 - val_loss: 0.6927 - val_accuracy: 0.5179 - val_precision: 0.5362
# Epoch 11/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6891 - accuracy: 0.5386 - precision: 0.5454 - val_loss: 0.6928 - val_accuracy: 0.5178 - val_precision: 0.5358
# Epoch 12/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6890 - accuracy: 0.5385 - precision: 0.5447 - val_loss: 0.6939 - val_accuracy: 0.5072 - val_precision: 0.5340
# Epoch 13/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6890 - accuracy: 0.5398 - precision: 0.5476 - val_loss: 0.6940 - val_accuracy: 0.5158 - val_precision: 0.5358
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6887 - accuracy: 0.5407 - precision: 0.5474 - val_loss: 0.6924 - val_accuracy: 0.5241 - val_precision: 0.5382
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6885 - accuracy: 0.5412 - precision: 0.5480 - val_loss: 0.6935 - val_accuracy: 0.5146 - val_precision: 0.5362
# Epoch 16/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6885 - accuracy: 0.5407 - precision: 0.5480 - val_loss: 0.6926 - val_accuracy: 0.5225 - val_precision: 0.5385
# Epoch 17/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6882 - accuracy: 0.5429 - precision: 0.5496 - val_loss: 0.6939 - val_accuracy: 0.5142 - val_precision: 0.5354
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6883 - accuracy: 0.5425 - precision: 0.5492 - val_loss: 0.6935 - val_accuracy: 0.5211 - val_precision: 0.5383
# Epoch 19/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6883 - accuracy: 0.5424 - precision: 0.5488 - val_loss: 0.6945 - val_accuracy: 0.5137 - val_precision: 0.5351
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6881 - accuracy: 0.5432 - precision: 0.5500 - val_loss: 0.6941 - val_accuracy: 0.5203 - val_precision: 0.5381
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.5428 - precision: 0.5500 - val_loss: 0.6931 - val_accuracy: 0.5165 - val_precision: 0.5372
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6881 - accuracy: 0.5423 - precision: 0.5489 - val_loss: 0.6939 - val_accuracy: 0.5207 - val_precision: 0.5378
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6881 - accuracy: 0.5449 - precision: 0.5516 - val_loss: 0.6932 - val_accuracy: 0.5179 - val_precision: 0.5381
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6880 - accuracy: 0.5432 - precision: 0.5492 - val_loss: 0.6952 - val_accuracy: 0.5087 - val_precision: 0.5367
# Epoch 25/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6877 - accuracy: 0.5439 - precision: 0.5501 - val_loss: 0.6939 - val_accuracy: 0.5135 - val_precision: 0.5370
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6875 - accuracy: 0.5444 - precision: 0.5514 - val_loss: 0.6928 - val_accuracy: 0.5179 - val_precision: 0.5389
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6877 - accuracy: 0.5439 - precision: 0.5493 - val_loss: 0.6941 - val_accuracy: 0.5142 - val_precision: 0.5374
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6875 - accuracy: 0.5441 - precision: 0.5517 - val_loss: 0.6929 - val_accuracy: 0.5190 - val_precision: 0.5390
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6873 - accuracy: 0.5451 - precision: 0.5512 - val_loss: 0.6928 - val_accuracy: 0.5178 - val_precision: 0.5377
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6874 - accuracy: 0.5447 - precision: 0.5503 - val_loss: 0.6932 - val_accuracy: 0.5168 - val_precision: 0.5372
# 263/263 [==============================] - 0s 904us/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6879 - accuracy: 0.5434 - precision: 0.5494 - val_loss: 0.6914 - val_accuracy: 0.5290 - val_precision: 0.5402
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6880 - accuracy: 0.5429 - precision: 0.5488 - val_loss: 0.6909 - val_accuracy: 0.5281 - val_precision: 0.5417
# Epoch 3/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6878 - accuracy: 0.5451 - precision: 0.5486 - val_loss: 0.6918 - val_accuracy: 0.5232 - val_precision: 0.5428
# Epoch 4/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6875 - accuracy: 0.5438 - precision: 0.5484 - val_loss: 0.6910 - val_accuracy: 0.5306 - val_precision: 0.5443
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6875 - accuracy: 0.5455 - precision: 0.5492 - val_loss: 0.6920 - val_accuracy: 0.5251 - val_precision: 0.5454
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6873 - accuracy: 0.5440 - precision: 0.5483 - val_loss: 0.6913 - val_accuracy: 0.5244 - val_precision: 0.5449
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6872 - accuracy: 0.5451 - precision: 0.5493 - val_loss: 0.6912 - val_accuracy: 0.5266 - val_precision: 0.5431
# Epoch 8/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6871 - accuracy: 0.5469 - precision: 0.5505 - val_loss: 0.6909 - val_accuracy: 0.5282 - val_precision: 0.5433
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6870 - accuracy: 0.5455 - precision: 0.5498 - val_loss: 0.6910 - val_accuracy: 0.5300 - val_precision: 0.5436
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6870 - accuracy: 0.5480 - precision: 0.5509 - val_loss: 0.6910 - val_accuracy: 0.5281 - val_precision: 0.5432
# Epoch 11/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6866 - accuracy: 0.5475 - precision: 0.5504 - val_loss: 0.6911 - val_accuracy: 0.5268 - val_precision: 0.5438
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6865 - accuracy: 0.5467 - precision: 0.5495 - val_loss: 0.6920 - val_accuracy: 0.5228 - val_precision: 0.5469
# Epoch 13/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6865 - accuracy: 0.5474 - precision: 0.5521 - val_loss: 0.6914 - val_accuracy: 0.5276 - val_precision: 0.5438
# Epoch 14/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6864 - accuracy: 0.5485 - precision: 0.5514 - val_loss: 0.6909 - val_accuracy: 0.5324 - val_precision: 0.5442
# Epoch 15/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5464 - precision: 0.5504 - val_loss: 0.6907 - val_accuracy: 0.5309 - val_precision: 0.5451
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6865 - accuracy: 0.5479 - precision: 0.5504 - val_loss: 0.6907 - val_accuracy: 0.5331 - val_precision: 0.5460
# Epoch 17/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6866 - accuracy: 0.5484 - precision: 0.5516 - val_loss: 0.6916 - val_accuracy: 0.5274 - val_precision: 0.5455
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6867 - accuracy: 0.5468 - precision: 0.5503 - val_loss: 0.6913 - val_accuracy: 0.5275 - val_precision: 0.5439
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.5490 - precision: 0.5519 - val_loss: 0.6916 - val_accuracy: 0.5266 - val_precision: 0.5437
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.5481 - precision: 0.5509 - val_loss: 0.6918 - val_accuracy: 0.5281 - val_precision: 0.5438
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.5487 - precision: 0.5517 - val_loss: 0.6910 - val_accuracy: 0.5298 - val_precision: 0.5452
# Epoch 22/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6865 - accuracy: 0.5462 - precision: 0.5497 - val_loss: 0.6911 - val_accuracy: 0.5310 - val_precision: 0.5438
# Epoch 23/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6864 - accuracy: 0.5474 - precision: 0.5501 - val_loss: 0.6913 - val_accuracy: 0.5305 - val_precision: 0.5452
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.5488 - precision: 0.5514 - val_loss: 0.6917 - val_accuracy: 0.5281 - val_precision: 0.5491
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5485 - precision: 0.5519 - val_loss: 0.6913 - val_accuracy: 0.5277 - val_precision: 0.5464
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5482 - precision: 0.5513 - val_loss: 0.6913 - val_accuracy: 0.5275 - val_precision: 0.5459
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.5492 - precision: 0.5514 - val_loss: 0.6916 - val_accuracy: 0.5275 - val_precision: 0.5459
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.5474 - precision: 0.5511 - val_loss: 0.6911 - val_accuracy: 0.5297 - val_precision: 0.5445
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.5491 - precision: 0.5518 - val_loss: 0.6912 - val_accuracy: 0.5287 - val_precision: 0.5441
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.5485 - precision: 0.5511 - val_loss: 0.6911 - val_accuracy: 0.5306 - val_precision: 0.5459
# 263/263 [==============================] - 0s 935us/step
# 30/30 [==============================] - 0s 539us/step
# Epoch 1/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6863 - accuracy: 0.5488 - precision: 0.5509 - val_loss: 0.6909 - val_accuracy: 0.5303 - val_precision: 0.5442
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5490 - precision: 0.5520 - val_loss: 0.6909 - val_accuracy: 0.5272 - val_precision: 0.5433
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.5500 - precision: 0.5514 - val_loss: 0.6918 - val_accuracy: 0.5263 - val_precision: 0.5463
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5507 - precision: 0.5535 - val_loss: 0.6911 - val_accuracy: 0.5309 - val_precision: 0.5461
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.5500 - precision: 0.5518 - val_loss: 0.6917 - val_accuracy: 0.5294 - val_precision: 0.5478
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5513 - precision: 0.5538 - val_loss: 0.6915 - val_accuracy: 0.5293 - val_precision: 0.5481
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6853 - accuracy: 0.5516 - precision: 0.5539 - val_loss: 0.6915 - val_accuracy: 0.5306 - val_precision: 0.5481
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6854 - accuracy: 0.5516 - precision: 0.5542 - val_loss: 0.6917 - val_accuracy: 0.5311 - val_precision: 0.5471
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5507 - precision: 0.5541 - val_loss: 0.6917 - val_accuracy: 0.5297 - val_precision: 0.5455
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5519 - precision: 0.5545 - val_loss: 0.6910 - val_accuracy: 0.5329 - val_precision: 0.5490
# Epoch 11/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6855 - accuracy: 0.5503 - precision: 0.5534 - val_loss: 0.6914 - val_accuracy: 0.5332 - val_precision: 0.5501
# Epoch 12/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6850 - accuracy: 0.5513 - precision: 0.5544 - val_loss: 0.6913 - val_accuracy: 0.5332 - val_precision: 0.5521
# Epoch 13/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6851 - accuracy: 0.5528 - precision: 0.5567 - val_loss: 0.6915 - val_accuracy: 0.5317 - val_precision: 0.5490
# Epoch 14/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6850 - accuracy: 0.5546 - precision: 0.5570 - val_loss: 0.6921 - val_accuracy: 0.5308 - val_precision: 0.5467
# Epoch 15/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6852 - accuracy: 0.5517 - precision: 0.5557 - val_loss: 0.6920 - val_accuracy: 0.5278 - val_precision: 0.5479
# Epoch 16/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6850 - accuracy: 0.5548 - precision: 0.5574 - val_loss: 0.6914 - val_accuracy: 0.5330 - val_precision: 0.5490
# Epoch 17/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6852 - accuracy: 0.5524 - precision: 0.5555 - val_loss: 0.6924 - val_accuracy: 0.5257 - val_precision: 0.5469
# Epoch 18/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6851 - accuracy: 0.5542 - precision: 0.5571 - val_loss: 0.6924 - val_accuracy: 0.5261 - val_precision: 0.5447
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.5543 - precision: 0.5568 - val_loss: 0.6923 - val_accuracy: 0.5260 - val_precision: 0.5474
# Epoch 20/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6852 - accuracy: 0.5537 - precision: 0.5569 - val_loss: 0.6924 - val_accuracy: 0.5285 - val_precision: 0.5469
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.5532 - precision: 0.5566 - val_loss: 0.6916 - val_accuracy: 0.5308 - val_precision: 0.5496
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.5539 - precision: 0.5573 - val_loss: 0.6918 - val_accuracy: 0.5313 - val_precision: 0.5491
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.5529 - precision: 0.5561 - val_loss: 0.6925 - val_accuracy: 0.5318 - val_precision: 0.5483
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5542 - precision: 0.5563 - val_loss: 0.6936 - val_accuracy: 0.5206 - val_precision: 0.5471
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.5540 - precision: 0.5572 - val_loss: 0.6924 - val_accuracy: 0.5265 - val_precision: 0.5483
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5544 - precision: 0.5575 - val_loss: 0.6920 - val_accuracy: 0.5274 - val_precision: 0.5486
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5540 - precision: 0.5566 - val_loss: 0.6928 - val_accuracy: 0.5278 - val_precision: 0.5484
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5551 - precision: 0.5586 - val_loss: 0.6920 - val_accuracy: 0.5314 - val_precision: 0.5482
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.5534 - precision: 0.5564 - val_loss: 0.6921 - val_accuracy: 0.5294 - val_precision: 0.5488
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6844 - accuracy: 0.5546 - precision: 0.5574 - val_loss: 0.6920 - val_accuracy: 0.5307 - val_precision: 0.5502
# 263/263 [==============================] - 0s 860us/step
# 30/30 [==============================] - 0s 951us/step
# Epoch 1/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.5482 - precision: 0.5525 - val_loss: 0.6913 - val_accuracy: 0.5333 - val_precision: 0.5502
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5508 - precision: 0.5547 - val_loss: 0.6911 - val_accuracy: 0.5336 - val_precision: 0.5510
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.5524 - precision: 0.5549 - val_loss: 0.6927 - val_accuracy: 0.5248 - val_precision: 0.5481
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.5500 - precision: 0.5546 - val_loss: 0.6918 - val_accuracy: 0.5290 - val_precision: 0.5472
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.5505 - precision: 0.5536 - val_loss: 0.6919 - val_accuracy: 0.5288 - val_precision: 0.5495
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.5514 - precision: 0.5548 - val_loss: 0.6921 - val_accuracy: 0.5252 - val_precision: 0.5472
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.5511 - precision: 0.5539 - val_loss: 0.6924 - val_accuracy: 0.5234 - val_precision: 0.5458
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5505 - precision: 0.5543 - val_loss: 0.6922 - val_accuracy: 0.5309 - val_precision: 0.5477
# Epoch 9/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6855 - accuracy: 0.5511 - precision: 0.5543 - val_loss: 0.6928 - val_accuracy: 0.5241 - val_precision: 0.5454
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5515 - precision: 0.5543 - val_loss: 0.6926 - val_accuracy: 0.5268 - val_precision: 0.5467
# Epoch 11/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6855 - accuracy: 0.5502 - precision: 0.5533 - val_loss: 0.6922 - val_accuracy: 0.5256 - val_precision: 0.5465
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5504 - precision: 0.5531 - val_loss: 0.6925 - val_accuracy: 0.5240 - val_precision: 0.5475
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6854 - accuracy: 0.5535 - precision: 0.5576 - val_loss: 0.6926 - val_accuracy: 0.5200 - val_precision: 0.5428
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5507 - precision: 0.5536 - val_loss: 0.6924 - val_accuracy: 0.5280 - val_precision: 0.5462
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6853 - accuracy: 0.5537 - precision: 0.5567 - val_loss: 0.6926 - val_accuracy: 0.5192 - val_precision: 0.5431
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6853 - accuracy: 0.5525 - precision: 0.5550 - val_loss: 0.6920 - val_accuracy: 0.5267 - val_precision: 0.5470
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5532 - precision: 0.5563 - val_loss: 0.6928 - val_accuracy: 0.5229 - val_precision: 0.5457
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5514 - precision: 0.5541 - val_loss: 0.6931 - val_accuracy: 0.5214 - val_precision: 0.5433
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.5511 - precision: 0.5543 - val_loss: 0.6929 - val_accuracy: 0.5211 - val_precision: 0.5438
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.5530 - precision: 0.5563 - val_loss: 0.6938 - val_accuracy: 0.5199 - val_precision: 0.5424
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5516 - precision: 0.5550 - val_loss: 0.6924 - val_accuracy: 0.5230 - val_precision: 0.5452
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.5525 - precision: 0.5554 - val_loss: 0.6930 - val_accuracy: 0.5230 - val_precision: 0.5448
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.5512 - precision: 0.5547 - val_loss: 0.6935 - val_accuracy: 0.5218 - val_precision: 0.5438
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.5507 - precision: 0.5538 - val_loss: 0.6950 - val_accuracy: 0.5144 - val_precision: 0.5432
# Epoch 25/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6852 - accuracy: 0.5517 - precision: 0.5551 - val_loss: 0.6938 - val_accuracy: 0.5163 - val_precision: 0.5432
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.5516 - precision: 0.5558 - val_loss: 0.6926 - val_accuracy: 0.5217 - val_precision: 0.5454
# Epoch 27/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6852 - accuracy: 0.5507 - precision: 0.5539 - val_loss: 0.6936 - val_accuracy: 0.5201 - val_precision: 0.5446
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.5524 - precision: 0.5561 - val_loss: 0.6926 - val_accuracy: 0.5215 - val_precision: 0.5450
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5504 - precision: 0.5541 - val_loss: 0.6927 - val_accuracy: 0.5200 - val_precision: 0.5434
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.5533 - precision: 0.5568 - val_loss: 0.6934 - val_accuracy: 0.5190 - val_precision: 0.5441
# 263/263 [==============================] - 0s 854us/step
# 30/30 [==============================] - 0s 984us/step
# Epoch 1/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6866 - accuracy: 0.5460 - precision: 0.5500 - val_loss: 0.6916 - val_accuracy: 0.5318 - val_precision: 0.5493
# Epoch 2/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6863 - accuracy: 0.5470 - precision: 0.5509 - val_loss: 0.6921 - val_accuracy: 0.5268 - val_precision: 0.5474
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.5497 - precision: 0.5529 - val_loss: 0.6927 - val_accuracy: 0.5232 - val_precision: 0.5470
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.5486 - precision: 0.5532 - val_loss: 0.6924 - val_accuracy: 0.5241 - val_precision: 0.5457
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.5491 - precision: 0.5529 - val_loss: 0.6916 - val_accuracy: 0.5292 - val_precision: 0.5489
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6865 - accuracy: 0.5470 - precision: 0.5512 - val_loss: 0.6930 - val_accuracy: 0.5232 - val_precision: 0.5458
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.5487 - precision: 0.5527 - val_loss: 0.6927 - val_accuracy: 0.5237 - val_precision: 0.5470
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.5493 - precision: 0.5533 - val_loss: 0.6928 - val_accuracy: 0.5288 - val_precision: 0.5469
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.5476 - precision: 0.5517 - val_loss: 0.6930 - val_accuracy: 0.5239 - val_precision: 0.5454
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.5489 - precision: 0.5534 - val_loss: 0.6928 - val_accuracy: 0.5254 - val_precision: 0.5461
# Epoch 11/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.5478 - precision: 0.5525 - val_loss: 0.6928 - val_accuracy: 0.5286 - val_precision: 0.5478
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.5485 - precision: 0.5520 - val_loss: 0.6926 - val_accuracy: 0.5275 - val_precision: 0.5478
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5501 - precision: 0.5542 - val_loss: 0.6932 - val_accuracy: 0.5212 - val_precision: 0.5441
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6858 - accuracy: 0.5492 - precision: 0.5532 - val_loss: 0.6938 - val_accuracy: 0.5257 - val_precision: 0.5464
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5480 - precision: 0.5526 - val_loss: 0.6927 - val_accuracy: 0.5232 - val_precision: 0.5459
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.5508 - precision: 0.5535 - val_loss: 0.6934 - val_accuracy: 0.5262 - val_precision: 0.5476
# Epoch 17/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6864 - accuracy: 0.5474 - precision: 0.5519 - val_loss: 0.6935 - val_accuracy: 0.5254 - val_precision: 0.5468
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6858 - accuracy: 0.5501 - precision: 0.5536 - val_loss: 0.6936 - val_accuracy: 0.5263 - val_precision: 0.5465
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5509 - precision: 0.5539 - val_loss: 0.6938 - val_accuracy: 0.5271 - val_precision: 0.5475
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5477 - precision: 0.5518 - val_loss: 0.6941 - val_accuracy: 0.5235 - val_precision: 0.5453
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.5501 - precision: 0.5538 - val_loss: 0.6942 - val_accuracy: 0.5223 - val_precision: 0.5441
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5513 - precision: 0.5545 - val_loss: 0.6945 - val_accuracy: 0.5233 - val_precision: 0.5452
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6858 - accuracy: 0.5500 - precision: 0.5530 - val_loss: 0.6940 - val_accuracy: 0.5228 - val_precision: 0.5442
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6858 - accuracy: 0.5499 - precision: 0.5528 - val_loss: 0.6944 - val_accuracy: 0.5159 - val_precision: 0.5424
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.5503 - precision: 0.5534 - val_loss: 0.6946 - val_accuracy: 0.5168 - val_precision: 0.5432
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.5493 - precision: 0.5532 - val_loss: 0.6933 - val_accuracy: 0.5244 - val_precision: 0.5462
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5506 - precision: 0.5533 - val_loss: 0.6949 - val_accuracy: 0.5209 - val_precision: 0.5436
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6853 - accuracy: 0.5520 - precision: 0.5551 - val_loss: 0.6934 - val_accuracy: 0.5261 - val_precision: 0.5468
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5505 - precision: 0.5535 - val_loss: 0.6945 - val_accuracy: 0.5206 - val_precision: 0.5442
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5507 - precision: 0.5545 - val_loss: 0.6937 - val_accuracy: 0.5233 - val_precision: 0.5451
# 263/263 [==============================] - 0s 842us/step
# 30/30 [==============================] - 0s 966us/step
# Epoch 1/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6854 - accuracy: 0.5536 - precision: 0.5570 - val_loss: 0.6934 - val_accuracy: 0.5256 - val_precision: 0.5438
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.5530 - precision: 0.5558 - val_loss: 0.6939 - val_accuracy: 0.5237 - val_precision: 0.5444
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5530 - precision: 0.5564 - val_loss: 0.6946 - val_accuracy: 0.5215 - val_precision: 0.5451
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.5524 - precision: 0.5564 - val_loss: 0.6939 - val_accuracy: 0.5221 - val_precision: 0.5443
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5535 - precision: 0.5570 - val_loss: 0.6937 - val_accuracy: 0.5252 - val_precision: 0.5463
# Epoch 6/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6847 - accuracy: 0.5528 - precision: 0.5564 - val_loss: 0.6945 - val_accuracy: 0.5219 - val_precision: 0.5436
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6853 - accuracy: 0.5525 - precision: 0.5559 - val_loss: 0.6947 - val_accuracy: 0.5190 - val_precision: 0.5433
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5549 - precision: 0.5588 - val_loss: 0.6945 - val_accuracy: 0.5241 - val_precision: 0.5434
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.5532 - precision: 0.5568 - val_loss: 0.6945 - val_accuracy: 0.5196 - val_precision: 0.5417
# Epoch 10/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6849 - accuracy: 0.5538 - precision: 0.5577 - val_loss: 0.6941 - val_accuracy: 0.5231 - val_precision: 0.5459
# Epoch 11/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6852 - accuracy: 0.5526 - precision: 0.5564 - val_loss: 0.6940 - val_accuracy: 0.5228 - val_precision: 0.5428
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5528 - precision: 0.5560 - val_loss: 0.6944 - val_accuracy: 0.5221 - val_precision: 0.5442
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5542 - precision: 0.5570 - val_loss: 0.6948 - val_accuracy: 0.5176 - val_precision: 0.5425
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.5521 - precision: 0.5557 - val_loss: 0.6950 - val_accuracy: 0.5201 - val_precision: 0.5428
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.5530 - precision: 0.5566 - val_loss: 0.6941 - val_accuracy: 0.5180 - val_precision: 0.5421
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5532 - precision: 0.5566 - val_loss: 0.6945 - val_accuracy: 0.5212 - val_precision: 0.5447
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5523 - precision: 0.5569 - val_loss: 0.6942 - val_accuracy: 0.5232 - val_precision: 0.5450
# Epoch 18/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6844 - accuracy: 0.5530 - precision: 0.5570 - val_loss: 0.6950 - val_accuracy: 0.5209 - val_precision: 0.5427
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.5527 - precision: 0.5567 - val_loss: 0.6950 - val_accuracy: 0.5186 - val_precision: 0.5414
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5544 - precision: 0.5577 - val_loss: 0.6951 - val_accuracy: 0.5180 - val_precision: 0.5409
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6845 - accuracy: 0.5548 - precision: 0.5585 - val_loss: 0.6949 - val_accuracy: 0.5230 - val_precision: 0.5446
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.5533 - precision: 0.5569 - val_loss: 0.6952 - val_accuracy: 0.5168 - val_precision: 0.5399
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5534 - precision: 0.5571 - val_loss: 0.6944 - val_accuracy: 0.5224 - val_precision: 0.5448
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5535 - precision: 0.5566 - val_loss: 0.6950 - val_accuracy: 0.5173 - val_precision: 0.5424
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5529 - precision: 0.5564 - val_loss: 0.6956 - val_accuracy: 0.5173 - val_precision: 0.5418
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5522 - precision: 0.5567 - val_loss: 0.6946 - val_accuracy: 0.5215 - val_precision: 0.5442
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5541 - precision: 0.5578 - val_loss: 0.6955 - val_accuracy: 0.5178 - val_precision: 0.5415
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5529 - precision: 0.5573 - val_loss: 0.6939 - val_accuracy: 0.5226 - val_precision: 0.5459
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6844 - accuracy: 0.5526 - precision: 0.5568 - val_loss: 0.6947 - val_accuracy: 0.5201 - val_precision: 0.5434
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6845 - accuracy: 0.5532 - precision: 0.5575 - val_loss: 0.6939 - val_accuracy: 0.5229 - val_precision: 0.5454
# 263/263 [==============================] - 0s 840us/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6841 - accuracy: 0.5541 - precision: 0.5581 - val_loss: 0.6939 - val_accuracy: 0.5277 - val_precision: 0.5461
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6842 - accuracy: 0.5559 - precision: 0.5584 - val_loss: 0.6938 - val_accuracy: 0.5256 - val_precision: 0.5459
# Epoch 3/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6836 - accuracy: 0.5536 - precision: 0.5567 - val_loss: 0.6943 - val_accuracy: 0.5224 - val_precision: 0.5460
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.5563 - precision: 0.5600 - val_loss: 0.6941 - val_accuracy: 0.5221 - val_precision: 0.5442
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.5555 - precision: 0.5592 - val_loss: 0.6932 - val_accuracy: 0.5290 - val_precision: 0.5478
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.5561 - precision: 0.5594 - val_loss: 0.6942 - val_accuracy: 0.5249 - val_precision: 0.5454
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5559 - precision: 0.5597 - val_loss: 0.6945 - val_accuracy: 0.5228 - val_precision: 0.5440
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6834 - accuracy: 0.5554 - precision: 0.5596 - val_loss: 0.6946 - val_accuracy: 0.5280 - val_precision: 0.5467
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5558 - precision: 0.5590 - val_loss: 0.6943 - val_accuracy: 0.5249 - val_precision: 0.5456
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5560 - precision: 0.5603 - val_loss: 0.6941 - val_accuracy: 0.5247 - val_precision: 0.5461
# Epoch 11/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5565 - precision: 0.5610 - val_loss: 0.6946 - val_accuracy: 0.5263 - val_precision: 0.5443
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6833 - accuracy: 0.5558 - precision: 0.5592 - val_loss: 0.6945 - val_accuracy: 0.5235 - val_precision: 0.5452
# Epoch 13/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.5551 - precision: 0.5589 - val_loss: 0.6942 - val_accuracy: 0.5225 - val_precision: 0.5453
# Epoch 14/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.5555 - precision: 0.5595 - val_loss: 0.6946 - val_accuracy: 0.5235 - val_precision: 0.5449
# Epoch 15/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6835 - accuracy: 0.5570 - precision: 0.5615 - val_loss: 0.6941 - val_accuracy: 0.5233 - val_precision: 0.5463
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5559 - precision: 0.5599 - val_loss: 0.6941 - val_accuracy: 0.5250 - val_precision: 0.5467
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5568 - precision: 0.5612 - val_loss: 0.6946 - val_accuracy: 0.5221 - val_precision: 0.5435
# Epoch 18/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5557 - precision: 0.5594 - val_loss: 0.6951 - val_accuracy: 0.5235 - val_precision: 0.5453
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5551 - precision: 0.5590 - val_loss: 0.6947 - val_accuracy: 0.5214 - val_precision: 0.5446
# Epoch 20/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.5550 - precision: 0.5592 - val_loss: 0.6942 - val_accuracy: 0.5233 - val_precision: 0.5438
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5557 - precision: 0.5602 - val_loss: 0.6955 - val_accuracy: 0.5240 - val_precision: 0.5455
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5563 - precision: 0.5606 - val_loss: 0.6949 - val_accuracy: 0.5211 - val_precision: 0.5441
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5556 - precision: 0.5596 - val_loss: 0.6942 - val_accuracy: 0.5233 - val_precision: 0.5459
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5552 - precision: 0.5590 - val_loss: 0.6940 - val_accuracy: 0.5226 - val_precision: 0.5454
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5560 - precision: 0.5597 - val_loss: 0.6943 - val_accuracy: 0.5231 - val_precision: 0.5457
# Epoch 26/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6836 - accuracy: 0.5563 - precision: 0.5598 - val_loss: 0.6944 - val_accuracy: 0.5238 - val_precision: 0.5452
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5547 - precision: 0.5588 - val_loss: 0.6945 - val_accuracy: 0.5241 - val_precision: 0.5451
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5565 - precision: 0.5601 - val_loss: 0.6941 - val_accuracy: 0.5234 - val_precision: 0.5454
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5556 - precision: 0.5593 - val_loss: 0.6945 - val_accuracy: 0.5227 - val_precision: 0.5458
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6834 - accuracy: 0.5566 - precision: 0.5606 - val_loss: 0.6941 - val_accuracy: 0.5244 - val_precision: 0.5466
# 263/263 [==============================] - 0s 843us/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5565 - precision: 0.5621 - val_loss: 0.6932 - val_accuracy: 0.5309 - val_precision: 0.5396
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5566 - precision: 0.5611 - val_loss: 0.6936 - val_accuracy: 0.5299 - val_precision: 0.5411
# Epoch 3/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6835 - accuracy: 0.5557 - precision: 0.5609 - val_loss: 0.6932 - val_accuracy: 0.5261 - val_precision: 0.5401
# Epoch 4/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6836 - accuracy: 0.5576 - precision: 0.5632 - val_loss: 0.6929 - val_accuracy: 0.5292 - val_precision: 0.5405
# Epoch 5/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5580 - precision: 0.5629 - val_loss: 0.6930 - val_accuracy: 0.5309 - val_precision: 0.5408
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5564 - precision: 0.5613 - val_loss: 0.6938 - val_accuracy: 0.5306 - val_precision: 0.5401
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.5565 - precision: 0.5615 - val_loss: 0.6934 - val_accuracy: 0.5301 - val_precision: 0.5412
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5560 - precision: 0.5615 - val_loss: 0.6935 - val_accuracy: 0.5302 - val_precision: 0.5396
# Epoch 9/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5580 - precision: 0.5629 - val_loss: 0.6933 - val_accuracy: 0.5278 - val_precision: 0.5387
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.5580 - precision: 0.5637 - val_loss: 0.6931 - val_accuracy: 0.5298 - val_precision: 0.5414
# Epoch 11/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5570 - precision: 0.5625 - val_loss: 0.6937 - val_accuracy: 0.5286 - val_precision: 0.5377
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5565 - precision: 0.5617 - val_loss: 0.6935 - val_accuracy: 0.5306 - val_precision: 0.5413
# Epoch 13/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6836 - accuracy: 0.5556 - precision: 0.5613 - val_loss: 0.6932 - val_accuracy: 0.5273 - val_precision: 0.5405
# Epoch 14/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6831 - accuracy: 0.5577 - precision: 0.5626 - val_loss: 0.6935 - val_accuracy: 0.5280 - val_precision: 0.5391
# Epoch 15/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6838 - accuracy: 0.5551 - precision: 0.5605 - val_loss: 0.6930 - val_accuracy: 0.5284 - val_precision: 0.5396
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5569 - precision: 0.5615 - val_loss: 0.6935 - val_accuracy: 0.5285 - val_precision: 0.5399
# Epoch 17/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5575 - precision: 0.5635 - val_loss: 0.6934 - val_accuracy: 0.5297 - val_precision: 0.5406
# Epoch 18/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6834 - accuracy: 0.5580 - precision: 0.5629 - val_loss: 0.6943 - val_accuracy: 0.5284 - val_precision: 0.5403
# Epoch 19/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6835 - accuracy: 0.5575 - precision: 0.5620 - val_loss: 0.6938 - val_accuracy: 0.5263 - val_precision: 0.5384
# Epoch 20/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6836 - accuracy: 0.5581 - precision: 0.5626 - val_loss: 0.6934 - val_accuracy: 0.5306 - val_precision: 0.5399
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.5559 - precision: 0.5611 - val_loss: 0.6947 - val_accuracy: 0.5249 - val_precision: 0.5368
# Epoch 22/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6835 - accuracy: 0.5565 - precision: 0.5612 - val_loss: 0.6937 - val_accuracy: 0.5271 - val_precision: 0.5391
# Epoch 23/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6836 - accuracy: 0.5572 - precision: 0.5620 - val_loss: 0.6932 - val_accuracy: 0.5267 - val_precision: 0.5391
# Epoch 24/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6834 - accuracy: 0.5569 - precision: 0.5614 - val_loss: 0.6929 - val_accuracy: 0.5276 - val_precision: 0.5396
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5570 - precision: 0.5616 - val_loss: 0.6936 - val_accuracy: 0.5285 - val_precision: 0.5397
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6834 - accuracy: 0.5564 - precision: 0.5617 - val_loss: 0.6939 - val_accuracy: 0.5305 - val_precision: 0.5411
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6833 - accuracy: 0.5572 - precision: 0.5623 - val_loss: 0.6934 - val_accuracy: 0.5305 - val_precision: 0.5408
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.5561 - precision: 0.5608 - val_loss: 0.6928 - val_accuracy: 0.5307 - val_precision: 0.5420
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5567 - precision: 0.5615 - val_loss: 0.6936 - val_accuracy: 0.5290 - val_precision: 0.5404
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6833 - accuracy: 0.5570 - precision: 0.5624 - val_loss: 0.6926 - val_accuracy: 0.5311 - val_precision: 0.5421
# 263/263 [==============================] - 0s 835us/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.5569 - precision: 0.5620 - val_loss: 0.6927 - val_accuracy: 0.5325 - val_precision: 0.5399
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5574 - precision: 0.5615 - val_loss: 0.6926 - val_accuracy: 0.5315 - val_precision: 0.5414
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5577 - precision: 0.5621 - val_loss: 0.6924 - val_accuracy: 0.5315 - val_precision: 0.5429
# Epoch 4/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6833 - accuracy: 0.5580 - precision: 0.5632 - val_loss: 0.6926 - val_accuracy: 0.5334 - val_precision: 0.5429
# Epoch 5/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6835 - accuracy: 0.5584 - precision: 0.5626 - val_loss: 0.6921 - val_accuracy: 0.5324 - val_precision: 0.5411
# Epoch 6/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5578 - precision: 0.5621 - val_loss: 0.6937 - val_accuracy: 0.5317 - val_precision: 0.5400
# Epoch 7/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6833 - accuracy: 0.5579 - precision: 0.5620 - val_loss: 0.6929 - val_accuracy: 0.5322 - val_precision: 0.5414
# Epoch 8/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6834 - accuracy: 0.5579 - precision: 0.5629 - val_loss: 0.6928 - val_accuracy: 0.5318 - val_precision: 0.5398
# Epoch 9/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6831 - accuracy: 0.5569 - precision: 0.5615 - val_loss: 0.6926 - val_accuracy: 0.5315 - val_precision: 0.5405
# Epoch 10/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5587 - precision: 0.5635 - val_loss: 0.6926 - val_accuracy: 0.5316 - val_precision: 0.5410
# Epoch 11/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6833 - accuracy: 0.5569 - precision: 0.5618 - val_loss: 0.6932 - val_accuracy: 0.5318 - val_precision: 0.5385
# Epoch 12/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.5578 - precision: 0.5621 - val_loss: 0.6927 - val_accuracy: 0.5338 - val_precision: 0.5422
# Epoch 13/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6835 - accuracy: 0.5559 - precision: 0.5603 - val_loss: 0.6925 - val_accuracy: 0.5332 - val_precision: 0.5429
# Epoch 14/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6834 - accuracy: 0.5575 - precision: 0.5623 - val_loss: 0.6925 - val_accuracy: 0.5327 - val_precision: 0.5408
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5556 - precision: 0.5602 - val_loss: 0.6923 - val_accuracy: 0.5322 - val_precision: 0.5418
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5599 - precision: 0.5635 - val_loss: 0.6924 - val_accuracy: 0.5325 - val_precision: 0.5416
# Epoch 17/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6835 - accuracy: 0.5563 - precision: 0.5616 - val_loss: 0.6925 - val_accuracy: 0.5317 - val_precision: 0.5407
# Epoch 18/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6833 - accuracy: 0.5580 - precision: 0.5621 - val_loss: 0.6937 - val_accuracy: 0.5311 - val_precision: 0.5410
# Epoch 19/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6834 - accuracy: 0.5560 - precision: 0.5607 - val_loss: 0.6934 - val_accuracy: 0.5293 - val_precision: 0.5398
# Epoch 20/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6833 - accuracy: 0.5591 - precision: 0.5638 - val_loss: 0.6929 - val_accuracy: 0.5304 - val_precision: 0.5385
# Epoch 21/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6834 - accuracy: 0.5567 - precision: 0.5610 - val_loss: 0.6934 - val_accuracy: 0.5304 - val_precision: 0.5390
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5576 - precision: 0.5622 - val_loss: 0.6929 - val_accuracy: 0.5327 - val_precision: 0.5424
# Epoch 23/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5563 - precision: 0.5608 - val_loss: 0.6925 - val_accuracy: 0.5322 - val_precision: 0.5424
# Epoch 24/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5567 - precision: 0.5611 - val_loss: 0.6925 - val_accuracy: 0.5313 - val_precision: 0.5417
# Epoch 25/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5566 - precision: 0.5614 - val_loss: 0.6930 - val_accuracy: 0.5323 - val_precision: 0.5422
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5574 - precision: 0.5626 - val_loss: 0.6930 - val_accuracy: 0.5329 - val_precision: 0.5418
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5571 - precision: 0.5616 - val_loss: 0.6933 - val_accuracy: 0.5329 - val_precision: 0.5420
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5561 - precision: 0.5605 - val_loss: 0.6926 - val_accuracy: 0.5330 - val_precision: 0.5424
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5575 - precision: 0.5621 - val_loss: 0.6929 - val_accuracy: 0.5334 - val_precision: 0.5431
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6834 - accuracy: 0.5570 - precision: 0.5618 - val_loss: 0.6921 - val_accuracy: 0.5333 - val_precision: 0.5425
# 263/263 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# Epoch 1/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5564 - precision: 0.5611 - val_loss: 0.6954 - val_accuracy: 0.5221 - val_precision: 0.5321
# Epoch 2/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.5572 - precision: 0.5612 - val_loss: 0.6952 - val_accuracy: 0.5195 - val_precision: 0.5316
# Epoch 3/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.5584 - precision: 0.5624 - val_loss: 0.6953 - val_accuracy: 0.5158 - val_precision: 0.5305
# Epoch 4/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6830 - accuracy: 0.5588 - precision: 0.5642 - val_loss: 0.6950 - val_accuracy: 0.5196 - val_precision: 0.5320
# Epoch 5/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6831 - accuracy: 0.5601 - precision: 0.5640 - val_loss: 0.6953 - val_accuracy: 0.5213 - val_precision: 0.5325
# Epoch 6/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6832 - accuracy: 0.5566 - precision: 0.5612 - val_loss: 0.6969 - val_accuracy: 0.5175 - val_precision: 0.5291
# Epoch 7/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5571 - precision: 0.5618 - val_loss: 0.6959 - val_accuracy: 0.5185 - val_precision: 0.5315
# Epoch 8/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6828 - accuracy: 0.5576 - precision: 0.5624 - val_loss: 0.6960 - val_accuracy: 0.5203 - val_precision: 0.5313
# Epoch 9/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6830 - accuracy: 0.5571 - precision: 0.5614 - val_loss: 0.6952 - val_accuracy: 0.5212 - val_precision: 0.5326
# Epoch 10/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6830 - accuracy: 0.5567 - precision: 0.5616 - val_loss: 0.6955 - val_accuracy: 0.5201 - val_precision: 0.5318
# Epoch 11/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6830 - accuracy: 0.5584 - precision: 0.5629 - val_loss: 0.6963 - val_accuracy: 0.5191 - val_precision: 0.5297
# Epoch 12/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6830 - accuracy: 0.5578 - precision: 0.5622 - val_loss: 0.6960 - val_accuracy: 0.5192 - val_precision: 0.5313
# Epoch 13/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.5593 - precision: 0.5634 - val_loss: 0.6959 - val_accuracy: 0.5149 - val_precision: 0.5294
# Epoch 14/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.5571 - precision: 0.5618 - val_loss: 0.6955 - val_accuracy: 0.5187 - val_precision: 0.5304
# Epoch 15/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5561 - precision: 0.5608 - val_loss: 0.6951 - val_accuracy: 0.5206 - val_precision: 0.5329
# Epoch 16/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5579 - precision: 0.5616 - val_loss: 0.6955 - val_accuracy: 0.5187 - val_precision: 0.5312
# Epoch 17/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6830 - accuracy: 0.5590 - precision: 0.5641 - val_loss: 0.6949 - val_accuracy: 0.5209 - val_precision: 0.5327
# Epoch 18/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6829 - accuracy: 0.5596 - precision: 0.5641 - val_loss: 0.6966 - val_accuracy: 0.5189 - val_precision: 0.5313
# Epoch 19/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6830 - accuracy: 0.5569 - precision: 0.5610 - val_loss: 0.6959 - val_accuracy: 0.5165 - val_precision: 0.5292
# Epoch 20/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6829 - accuracy: 0.5580 - precision: 0.5624 - val_loss: 0.6954 - val_accuracy: 0.5211 - val_precision: 0.5321
# Epoch 21/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6829 - accuracy: 0.5580 - precision: 0.5626 - val_loss: 0.6968 - val_accuracy: 0.5184 - val_precision: 0.5304
# Epoch 22/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6833 - accuracy: 0.5572 - precision: 0.5617 - val_loss: 0.6958 - val_accuracy: 0.5187 - val_precision: 0.5316
# Epoch 23/30
# 184/184 [==============================] - 1s 3ms/step - loss: 0.6829 - accuracy: 0.5582 - precision: 0.5627 - val_loss: 0.6953 - val_accuracy: 0.5204 - val_precision: 0.5333
# Epoch 24/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.5576 - precision: 0.5616 - val_loss: 0.6951 - val_accuracy: 0.5204 - val_precision: 0.5331
# Epoch 25/30
# 184/184 [==============================] - 0s 3ms/step - loss: 0.6830 - accuracy: 0.5590 - precision: 0.5629 - val_loss: 0.6958 - val_accuracy: 0.5199 - val_precision: 0.5323
# Epoch 26/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6828 - accuracy: 0.5581 - precision: 0.5634 - val_loss: 0.6959 - val_accuracy: 0.5196 - val_precision: 0.5316
# Epoch 27/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6828 - accuracy: 0.5577 - precision: 0.5621 - val_loss: 0.6957 - val_accuracy: 0.5210 - val_precision: 0.5326
# Epoch 28/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.5568 - precision: 0.5607 - val_loss: 0.6948 - val_accuracy: 0.5199 - val_precision: 0.5322
# Epoch 29/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5573 - precision: 0.5618 - val_loss: 0.6952 - val_accuracy: 0.5199 - val_precision: 0.5324
# Epoch 30/30
# 184/184 [==============================] - 0s 2ms/step - loss: 0.6833 - accuracy: 0.5572 - precision: 0.5624 - val_loss: 0.6942 - val_accuracy: 0.5228 - val_precision: 0.5347
# 263/263 [==============================] - 0s 955us/step
# 30/30 [==============================] - 0s 1ms/step
# accuracy_train     0.546345
# f1_train           0.591230
# recall_train       0.633507
# precision_train    0.554428
# auc_train          0.543076
# accuracy_test      0.535914
# f1_test            0.580224
# recall_test        0.621589
# precision_test     0.546378
# auc_test           0.532699
# dtype: float64
# 111/111 [==============================] - 0s 1ms/step

# %% [markdown]
# #### Train NN

# %%
# from sklearn.neural_network import MLPClassifier

#set NN model
nn_model = MLPClassifier(activation='tanh', batch_size=64, learning_rate_init=0.01,
              max_iter=10, random_state=0, solver='sgd')
name = 'MLP'
assess = class_cv.validateModel(x_train_out[mi_subset_0],
                                y_train_dict['Target_0'],
                                model=nn_model ,
                                scaler=True ,
                                over_sampling=False,
                                under_sampling=False,
                                predictions=False,
                                cv_type='stratKfold',
                                scaler_type='stand',
                                train_size=10,
                                test_size=1,
                                gap=0)

#store scores
assess_df = assess['scores']
assess_df['model'] = name

#store model 
model = assess['model']
new_model_list.append(model)

scaler = assess['scaler']

full_assess = pd.concat([full_assess,
                            assess_df],
                        axis=0)

if name =='LightGB':
        features = model.feature_name_
        
else:
    features = model.feature_names_in_

scaler = assess['scaler']
scale_features = scaler.get_feature_names_out()

rest_ft =[]
for ft in features:
    if ft not in scale_features:
        rest_ft.append(ft)

# fit scaler on test set 
X_test = pd.DataFrame(scaler.transform(x_test[scale_features]), 
                    index = x_test.index, 
                    columns = scale_features)

X_test = pd.concat([X_test, x_test[rest_ft]],axis=1)
X_test = X_test[features]

assess_test_dict, assess_test_df = assessTest(X_test,
                                                y_test_dict['Target_0'],
                                                nn_model)
assess_test_dict['model'] = name
assess_test_df['model'] = name

    
a = pd.DataFrame([assess_test_dict])

test_assess_df = pd.concat([test_assess_df,a],axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-79522b35c1fe> in <module>
#      63 #                             assess_test_df],
#      64 #                         axis=0)
# ---> 65 test_assess_list.append(assess_test_dict)
#      66
#      67 test_assess_df = pd.DataFrame.from_records(test_assess_list)
#
# NameError: name 'test_assess_list' is not defined

# %%
full_assess.groupby('model').mean()
# Out:
#                     accuracy_train  f1_train  recall_train  precision_train  \
# model
# DecisionTree              0.546292  0.613298      0.698880         0.549510
# Keras_NN                  0.546345  0.591230      0.633507         0.554428
# LightGB                   0.560394  0.634527      0.736650         0.557308
# LogisticRegression        0.536618  0.627753      0.754274         0.537636
# MLP                       0.542648  0.622652      0.729420         0.543983
#
#                     auc_train  accuracy_test   f1_test  recall_test  \
# model
# DecisionTree         0.540570       0.523093  0.593885     0.676153
# Keras_NN             0.543076       0.535914  0.580224     0.621589
# LightGB              0.553784       0.535724  0.611298     0.711027
# LogisticRegression   0.528456       0.529256  0.614201     0.739298
# MLP                  0.535644       0.524387  0.607959     0.716247
#
#                     precision_test  auc_test
# model
# DecisionTree              0.531402  0.517354
# Keras_NN                  0.546378  0.532699
# LightGB                   0.539966  0.529142
# LogisticRegression        0.533938  0.521370
# MLP                       0.530845  0.517191

# %%
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Validation\full_CV_results_MI.csv'
full_assess.to_csv(path)

# %% [markdown]
# ### Boxplot Format A

# %%
a = full_assess.copy()
title = 'Target 0 - Model Performance on Validation set - K=10, PCA'
plt.figure(figsize=(15, 10))
ax1 = plt.subplot(2, 1, 1)
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'accuracy_test'].values
df_assess.plot(kind='box', title='boxplot', showmeans=True,ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('Accuracy', size=15)


ax2 = plt.subplot(2, 1, 2, ) # Share x-axis ticks with ax1
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'precision_test'].values
df_assess.plot(kind='box', showmeans=True,ax=ax2)

ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
plt.tight_layout()

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0'
name_plot = f'{path}\\{title}-PCA.png'
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# ### Boxplot Format B

# %%
title = 'Target 0 - Model Performance on Validation set - K=10, PCA'
plt.figure(figsize=(15, 10))

# Use sharex parameter to share x-axis ticks between subplots
ax1 = plt.subplot(2, 1, 1)
sns.boxplot(x=a['model'], y=a['accuracy_test'], hue=a['model'], ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('Accuracy', size=15)

# Set legend location outside the figure
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2 = plt.subplot(2, 1, 2, sharex=ax1) # Share x-axis ticks with ax1
sns.boxplot(x=a['model'], y=a['precision_test'], hue=a['model'], ax=ax2)
ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
ax2.legend().remove()

plt.tight_layout() # To prevent overlapping of the legend with the second subplot

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0'
name_plot = f'{path}\\{title}- PCA - Format 2.png'
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# #### Display Training and Valdation Results

# %% [markdown]
# Export average scores from the Cross Validation

# %% [markdown]
# ##### With Standartization inside CV

# %%
train_val_scores = full_assess.groupby('model').mean()
cols_ = train_val_scores.columns[train_val_scores.columns.str.contains('test')]
for col in cols_:
    
    new_col = col.replace('test','val')
    train_val_scores = train_val_scores.rename(columns = {col:new_col})
    
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Validation\modelMetricPerfomance_Target_0_valSet_MI.csv'
# train_val_scores.to_csv(assess_path)
display(train_val_scores)
# Out:
#                     accuracy_train  f1_train  recall_train  precision_train  \
# model
# DecisionTree              0.546292  0.613298      0.698880         0.549510
# Keras_NN                  0.546345  0.591230      0.633507         0.554428
# LightGB                   0.560394  0.634527      0.736650         0.557308
# LogisticRegression        0.536618  0.627753      0.754274         0.537636
# MLP                       0.542648  0.622652      0.729420         0.543983
#
#                     auc_train  accuracy_val    f1_val  recall_val  \
# model
# DecisionTree         0.540570      0.523093  0.593885    0.676153
# Keras_NN             0.543076      0.535914  0.580224    0.621589
# LightGB              0.553784      0.535724  0.611298    0.711027
# LogisticRegression   0.528456      0.529256  0.614201    0.739298
# MLP                  0.535644      0.524387  0.607959    0.716247
#
#                     precision_val   auc_val
# model
# DecisionTree             0.531402  0.517354
# Keras_NN                 0.546378  0.532699
# LightGB                  0.539966  0.529142
# LogisticRegression       0.533938  0.521370
# MLP                      0.530845  0.517191

# %% [markdown]
# #### Display test Results

# %% [markdown]
# Export scores on test set

# %%
test_assess_df = test_assess_df.reset_index().set_index('model')
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Test\modelMetricPerfomance_Target_0_testSet_MI.csv'
test_assess_df.to_csv(assess_path)

# %% [markdown]
# #### ROC Curve Comparison

# %%
import DataScalling as scalling
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras NN','MLP']
roc_curve(models = new_model_list,
                       names = model_names, 
                       X_train = x_train_stand[mi_subset_0],
                       y_train  = y_train_dict['Target_0'],
                       X_val = X_test,
                       y_val= y_test_dict['Target_0'])


title = 'Model Perfomance Comparison - ROC Curve - Test Set - Target 0, PCA'
plt.title(title, 
          size = 15)
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables'
name_plot = f'{path}\\{title}.png'
plt.tight_layout()
plt.savefig(name_plot, dpi=300)
# Out:
# 111/111 [==============================] - 0s 1ms/step

# %%
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\full_CV_results_noBeta_MI.csv'
full_assess.to_csv(path)

# %% [markdown]
# ## Plot Peromance

# %%
assess_models = full_assess.groupby('model').mean().iloc[:,-5:]


plt.figure(figsize = (15,15))
ax1 = plt.subplot(2,1,1)
sns.scatterplot(x = assess_models['accuracy_test'],y = assess_models['precision_test'], hue = test_assess_df.index,ax = ax1)
ax1.set_title('Validation Perfomance',size = 15)
ax1.set_xlabel('',size = 15)
ax1.set_ylabel('Precision',size = 15)

# Set legend location outside the figure
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2 = plt.subplot(2,1,2)
sns.scatterplot(x = test_assess_df['accuracy'],y = test_assess_df['precision'], hue = test_assess_df.index,ax = ax2)
ax2.legend().remove()
ax2.set_title('Test Perfomance',size = 15)
ax2.set_xlabel('Accuracy',size = 15)

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0'
title = 'Validation & Test Perfomance'
name_plot = f'{path}\\{title}.png'

plt.tight_layout()
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# ### Boxplot Format A

# %%
a = full_assess.copy()
title = 'Target 0 - Model Performance on Validation set - K=10'
plt.figure(figsize=(15, 10))
ax1 = plt.subplot(2, 1, 1)
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'accuracy_test'].values
df_assess.plot(kind='box', title='boxplot', showmeans=True,ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('Accuracy', size=15)


ax2 = plt.subplot(2, 1, 2, ) # Share x-axis ticks with ax1
df_assess = pd.DataFrame()
for model in a.model.unique():
    df_assess[model] = a.loc[a['model']==model,'precision_test'].values
df_assess.plot(kind='box', showmeans=True,ax=ax2)

ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
plt.tight_layout()

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0'
name_plot = f'{path}\\{title}-MI.png'
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# ### Boxplot Format B

# %%
title = 'Target 0 - Model Performance on Validation set - K=10'
plt.figure(figsize=(15, 10))

# Use sharex parameter to share x-axis ticks between subplots
ax1 = plt.subplot(2, 1, 1)
sns.boxplot(x=a['model'], y=a['accuracy_test'], hue=a['model'], ax=ax1)
ax1.set_title(title, size=15)
ax1.set_xlabel('', size=15)
ax1.set_ylabel('Accuracy', size=15)

# Set legend location outside the figure
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

ax2 = plt.subplot(2, 1, 2, sharex=ax1) # Share x-axis ticks with ax1
sns.boxplot(x=a['model'], y=a['precision_test'], hue=a['model'], ax=ax2)
ax2.set_xlabel('Models', size=15)
ax2.set_ylabel('Precision', size=15)
ax2.legend().remove()

plt.tight_layout() # To prevent overlapping of the legend with the second subplot

path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0'
name_plot = f'{path}\\{title}- MI - Format 2.png'
plt.savefig(name_plot, dpi=300)
plt.show()

# %% [markdown]
# #### Display Training and Valdation Results

# %% [markdown]
# Export average scores from the Cross Validation

# %% [markdown]
# ##### With Standartization inside CV

# %%
train_val_scores = full_assess.groupby('model').mean()
cols_ = train_val_scores.columns[train_val_scores.columns.str.contains('test')]
for col in cols_:
    
    new_col = col.replace('test','val')
    train_val_scores = train_val_scores.rename(columns = {col:new_col})
    
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0modelMetricPerfomance_Target_0_valSet_MI.csv'
# train_val_scores.to_csv(assess_path)
display(train_val_scores)
# Out:
#                     accuracy_train  f1_train  recall_train  precision_train  \
# model
# DecisionTree              0.546292  0.613298      0.698880         0.549510
# LightGB                   0.560394  0.634527      0.736650         0.557308
# LogisticRegression        0.536618  0.627753      0.754274         0.537636
# NeuralNetwork             0.541504  0.561134      0.566677         0.556662
#
#                     auc_train  accuracy_val    f1_val  recall_val  \
# model
# DecisionTree         0.540570      0.523093  0.593885    0.676153
# LightGB              0.553784      0.535724  0.611298    0.711027
# LogisticRegression   0.528456      0.529256  0.614201    0.739298
# NeuralNetwork        0.540560      0.532775  0.547439    0.551058
#
#                     precision_val   auc_val
# model
# DecisionTree             0.531402  0.517354
# LightGB                  0.539966  0.529142
# LogisticRegression       0.533938  0.521370
# NeuralNetwork            0.550383  0.532090

# %% [markdown]
# #### Display test Results

# %% [markdown]
# Export scores on test set

# %%
test_assess_df = test_assess_df.reset_index().set_index('model')
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\modelMetricPerfomance_Target_0_testSet.csv'
# test_assess_df.to_csv(assess_path)

# %% [markdown]
# #### ROC Curve Comparison

# %%
import DataScalling as scalling

roc_curve(models = new_model_list,
                       names = model_names, 
                       X_train = x_train_stand[mi_subset_0],
                       y_train  = y_train_dict['Target_0'],
                       X_val = X_test,
                       y_val= y_test_dict['Target_0'])


title = 'Model Perfomance Comparison - ROC Curve - Test Set - Target 0'
plt.title(title, 
          size = 15)
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables'
name_plot = f'{path}\\{title}.png'
plt.tight_layout()
plt.savefig(name_plot, dpi=300)
# Out:
# 111/111 [==============================] - 0s 1ms/step
