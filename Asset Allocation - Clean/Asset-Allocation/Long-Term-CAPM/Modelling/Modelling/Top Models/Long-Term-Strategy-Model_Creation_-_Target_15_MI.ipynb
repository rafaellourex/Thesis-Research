# %% [markdown]
# ## Import Cleaned Data

# %% [markdown]
# __DataFrames:__
# df_model - df with all the features (independent festures + Target)
# x - df with all independent features
# y - df with dependent feature
# x_train - df with training data from x
# x_train_out - df with training data from x with outliers treatment applied
# x_test - df with test data from x
# x_test_out - df with test data from x with outliers treatment applied

# %%
import sys
sys.path.insert(1, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions')
sys.path.insert(2, r'C:\Users\rafae\Personal\Github\Functions\Data-Science-Functions\Functions')
sys.path.insert(3, r'..\..\..')


import Classification_CV as class_cv
import importCleanedData as importData
import importSubsets as subsets

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from tensorflow import keras

import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

#set preferences
sns.set_style('whitegrid')

#set color for graphs
#set color for graphs
palette = ["#e41a1c", "#377eb8", "#4daf4a", "#984ea3"]

# dir = r'C:\Users\rafae\Personal\Github\Asset-Allocation\Long-Term-CAPM\SampleData\Sample'
dir = r'..\..\..\SampleData\Sample'
df_model_skew,df_target = importData.importCleanedData(dir=dir,target='CAPM')


#split data
date = '2018-01-01'
#split data without transformation
x_train,x_train_out,x_test, x_test_out,y_train_dict ,y_test_dict, y_train,y_test = importData.splitData(df_model_skew, date) 

#set columns
ratio_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Ratio'))]
shares_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Share'))]
margin_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Margin'))]
turnover_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('Turnover'))]
dividend_cols = df_model_skew.columns[(df_model_skew.columns.str.contains('dividend'))]


components_pca, pca_components_test = importData.runPCA(x_train_out= x_train_out,x_test = x_test)


#import subsets
lasso_subset_0, lasso_subset_15, mi_subset_0, mi_subset_15, lgb_subset, corr_subset0, corr_subset15 = subsets.importSubsets()


subset_0, subset_15 = lasso_subset_0, lasso_subset_15
# Out:
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# d:\Rafael\Anaconda_Setup\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# CAPM
# Import data from: ..\..\..\SampleData\Sample\LongTerm-DataPreparation_Skew.csv
# Original CAPM is being used as Target
# Nr of rows:
# 72538
# The variance explained by each component is: [50.70262543 16.3180414  12.90616231  7.80559243  6.69692605  5.82614766
#   4.47015907  4.07836541  3.82626867  3.40508117  3.17395217  2.97398597
#   2.84255924  2.7491931   2.6284572   2.30920491  2.29580116  2.24676716
#   2.1685526   2.08344875  1.96058327  1.88331954  1.85945512  1.79999003
#   1.75303096  1.72999438  1.67342676  1.57892838  1.52235707  1.48115797
#   1.44613583  1.42029951  1.39091026  1.35520895  1.32448072  1.29342424
#   1.27059382  1.25051426  1.2247642   1.18608517  1.17810508  1.15156743
#   1.14454538  1.12935887  1.10669478  1.0815426   1.07222534  1.05458183
#   1.03848544  1.01988948  1.01877496  0.99533768  0.98807987]
# The total variance explained by the components is: 0.7618344466001962

# %% [markdown]
# ## Final Subsets

# %%
lasso_subset_0 = ['revenue',
 'costOfRevenue',
 'otherExpenses',
 'interestIncome',
 'weightedAverageShsOut',
 'cashAndShortTermInvestments',
 'otherCurrentAssets',
 'totalCurrentAssets',
 'goodwill',
 'intangibleAssets',
 'longTermInvestments',
 'otherAssets',
 'deferredRevenue',
 'otherCurrentLiabilities',
 'deferredRevenueNonCurrent',
 'totalNonCurrentLiabilities',
 'capitalLeaseObligations',
 'preferredStock',
 'totalInvestments',
 'netIncome_cf',
 'depreciationAndAmortization_cf',
 'deferredIncomeTax',
 'stockBasedCompensation',
 'inventory_cf',
 'netCashProvidedByOperatingActivities',
 'salesMaturitiesOfInvestments',
 'otherFinancingActivites',
 'effectOfForexChangesOnCash',
 'daysOfPayablesOutstanding',
 'netProfitMargin',
 'freeCashFlowPerShare',
 'capitalExpenditureCoverageRatio',
 'priceEarningsRatio',
 'close',
 'totalDividend',
 'operatingIncome_TTM',
 'eps_TTM',
 'YoY_ebitda',
 'YoY_operatingIncome',
 'YoY_eps']
slasso_ubset_15 =  ['revenue',
 'costOfRevenue',
 'generalAndAdministrativeExpenses',
 'sellingAndMarketingExpenses',
 'interestIncome',
 'operatingIncome',
 'weightedAverageShsOut',
 'cashAndShortTermInvestments',
 'otherCurrentAssets',
 'totalCurrentAssets',
 'goodwill',
 'taxAssets',
 'totalAssets',
 'accountPayables',
 'longTermDebt',
 'deferredRevenueNonCurrent',
 'deferredTaxLiabilitiesNonCurrent',
 'capitalLeaseObligations',
 'commonStock',
 'netIncome_cf',
 'depreciationAndAmortization_cf',
 'deferredIncomeTax',
 'commonStockIssued',
 'effectOfForexChangesOnCash',
 'freeCashFlow',
 'daysOfInventoryOutstanding',
 'daysOfPayablesOutstanding',
 'companyEquityMultiplier',
 'operatingCashFlowPerShare',
 'capitalExpenditureCoverageRatio',
 'priceEarningsRatio',
 'priceEarningsToGrowthRatio',
 'close',
 'totalDividend',
 'researchAndDevelopmentExpenses_TTM',
 'YoY_netIncome']


mi_subset_0 =  ['numberOfShares',
  'costOfRevenue_TTM',
  'QoQ_costAndExpenses',
  'incomeBeforeTaxRatio',
  'goodwillAndIntangibleAssets',
  'earnings',
  'accountsPayables',
  'fixedAssetTurnover',
  'excessReturn_84',
  'netIncome_bin',
  'ebtPerEbit',
  'netIncome_cf',
  'YoY_netIncome',
  'totalOtherIncomeExpensesNet',
  'Volatility_42',
  'operatingIncome',
  'dividendPayoutRatio',
  'cashAtEndOfPeriod',
  'depreciationAndAmortization',
  'cashFlowCoverageRatios',
  'purchasesOfInvestments',
  'assetTurnover',
  'eps',
  'commonStock']

mi_subset_15 = ['Volatility_84','Volatility_21','operatingIncome','costAndExpenses_TTM','netIncome_bin',
  'dividendPayoutRatio',
  'totalDividend',
  'dividend',
  'netIncome_TTM',
  'dividendsPaid',
  'otherCurrentLiabilities',
  'dividendYield',
  'totalAssets',
  'eps_TTM',
  'otherNonCurrentAssets',
  'totalLiabilitiesAndTotalEquity',
  'otherCurrentAssets',
  'marketcap_bin',
  'netCashUsedForInvestingActivites',
  'goodwill',
  'totalNonCurrentAssets']

lgb_subset = ['Volatility_84', 'close', 'MA_21', 'Volatility_21', 'YoY_revenue',
       'priceEarningsRatio', 'priceToSalesRatio', 'Volatility_42', 'goodwill',
       'retainedEarnings', 'Volatility_63', 'QoQ_ebitda',
       'otherInvestingActivites', 'excessReturn_21',
       'accumulatedOtherComprehensiveIncomeLoss', 'priceEarningsToGrowthRatio',
       'othertotalStockholdersEquity', 'MA_84', 'payoutRatio',
       'accountsPayables']


corr_subset0 = ['Volatility_63', 'Volatility_42', 'Volatility_84', 'Volatility_21',
       'close', 'netProfitMargin_bin', 'netIncome_bin', 'priceToSalesRatio',
       'priceSalesRatio', 'capitalExpenditureCoverageRatio',
       'sector_priceEarningsRatio_bin', 'industry_Biotechnology',
       'excessReturn_42', 'currentRatio', 'industry_Electronic Components',
       'returnOnCapitalEmployed', 'operatingCashFlowSalesRatio',
       'netCashProvidedByOperatingActivities', 'operatingCashFlow',
       'pretaxProfitMargin', 'incomeBeforeTaxRatio', 'ebitPerRevenue',
       'operatingProfitMargin', 'operatingIncomeRatio', 'netIncomeRatio',
       'netProfitMargin', 'eps', 'epsdiluted', 'returnOnEquity']

corr_subset15 = ['close', 'dividend', 'totalAssets', 'eps_TTM', 'dividendYield',
       'netIncome_TTM', 'earnings_TTM', 'totalDividend', 'ebitda_TTM',
       'dividendPayoutRatio', 'mktcap', 'payoutRatio', 'ebit',
       'retainedEarnings', 'netIncome_cf', 'daysOfInventoryOutstanding',
       'grossProfitMargin', 'fixedAssetTurnover', 'daysOfPayablesOutstanding',
       'payablesTurnover', 'dividendsPaid', 'marketcap_bin', 'assetTurnover',
       'sector_priceEarningsRatio_bin', 'netProfitMargin_bin', 'netIncome_bin',
       'Volatility_21', 'Volatility_42', 'Volatility_63']

# %% [markdown]
# # Train Models

# %%
def gen_NNClassification (x, y, hidden_layer_sizes,activation_list, dropout,optimizer,loss = 'BinaryCrossentropy', metrics = ['AUC'],batch_size=180,epochs=10,validation_split = 0.25, class_weight = None, output_bias =None ):
    
    print('Neural Network Parameters:')
    print(f'Optimizer: {optimizer}')
    print(f'Loss: {loss}')
    print(f'Hidden Layer tructure: {hidden_layer_sizes}')
    print(f'Acivation Functions: {activation_list}')
    print(f'Dropout: {dropout}')
    print(f'Class Weight: {class_weight}')
    print(f'Output Bias: {output_bias}')
    
    #import libraries
    from scikeras.wrappers import KerasClassifier, KerasRegressor
    from tensorflow import keras
    reset_random_seeds()
    #get nr features in
    n_features_in_ = x.shape[1]
    n_classes_ = len(y.unique())
    
    if output_bias is not None:
        output_bias =keras.initializers.Constant(output_bias)
    
    #set keras model
    model = keras.models.Sequential()
    
    #define input shape
    # model.add(keras.layers.Input(shape=(n_features_in_,)))
    model.add(keras.layers.Dense(
          4, activation='relu',
          input_shape=(n_features_in_,)))
    
    #define hidden layers
    for hidden_layer_size, activation_ in zip(hidden_layer_sizes,
                                              activation_list):
        
        model.add(keras.layers.Dense(hidden_layer_size,
                                     activation=activation_))
        
        model.add(keras.layers.Dropout(dropout))
    
    #define output layer
    model.add(keras.layers.Dense(1,
                                 activation="sigmoid",
                                 bias_initializer=output_bias))
    
    #compile model 
    model.compile(optimizer=optimizer,
                  loss=loss,
                  metrics=metrics,
                  )
    
    #transform to SKlearn format
    NNmodel = KerasClassifier( model=model,
                            batch_size= batch_size,
                            epochs= epochs,
                            class_weight=class_weight,
                            validation_split=validation_split,
                            loss = loss)

    return NNmodel

metrics = ['AUC','Recall','Precision']


def reset_random_seeds():
    import random
    from numpy.random import seed
    import os
    import numpy as np 
    from tensorflow import random as r
    
    seed_nr = 0
    os.environ['PYTHONHASHSEED']=str(seed_nr)
    r.set_seed(seed_nr)
    np.random.seed(seed_nr)

from numpy.random import seed
from tensorflow import keras 


reset_random_seeds()
optimizer = keras.optimizers.RMSprop(learning_rate=0.001)
loss_ = keras.losses.BinaryCrossentropy()
NNmodel = gen_NNClassification(x_train_out[mi_subset_15], 
                                 y_train_dict['Target_0.15'],
                                 hidden_layer_sizes = (50,),
                                 activation_list = ['relu'],
                                 dropout = 0.3,
                                 optimizer =optimizer ,
                                 loss = loss_, 
                                 metrics = metrics,
                                 batch_size=64,
                                 epochs=15,
                                 validation_split = 0.25,
                                 class_weight = 'balanced',
                                 output_bias =None )



def roc_curve (models,names,X_train,y_train, X_val, y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        list with model names and a list of models 
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays ROC curve of the respective models 
    
    '''''''''''''''
    
    names= names
    from sklearn.metrics import roc_curve
    sns.set_theme(style = 'whitegrid')
    plt.figure(figsize = (10,10))
    for i, names ,in zip(models,names):
        # i.fit(X_train,y_train)
        thresh_dict = {}
        prob_model = i.predict_proba(X_val)
        
        fpr_DT_ent, tpr_DT_ent, thresholds_DT_ent = roc_curve(y_val, prob_model[:,1])
        plt.plot(fpr_DT_ent, tpr_DT_ent, label=f"ROC Curve {names}" , )
        
        plt.xlabel('FPR')
        plt.ylabel('TPR')
        plt.legend()
        
    
    
def precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted inside the function 
    
    '''''''''''''''
    names=names
    model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()
    
    
def fitted_precision_recall_curve (model,names, X_train,y_train,X_val,y_val):
    ''''''''''''''''
    Compares different models using stratified k fold for classification problems
    Receives:
        model and respective name (string)
        x_train (independent variables) and y_train (dependent variable)
        x_test (independent variables) and y_test (dependent variable)   
        
    Displays Precision - Recall  curve of the respective models 
    Note: the model is fitted outside the function 
    
    '''''''''''''''
    names=names
    #model.fit(X_train,y_train)
    proba = model.predict_proba(X_val)
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(y_val, proba[:,1])

    # apply f1 score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    plt.figure(figsize = (10,10))
    plt.plot(recall, precision, marker='.', label=f'{names}')
    plt.scatter(recall[ix], precision[ix], marker='o', color='black', label='Best')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()

def assessTest (x_test, y_test, model):
    
    col = x_test.columns[4]
    index__ = x_test.reset_index()[['symbol','fillingDate',col]].set_index(['symbol','fillingDate'])
    target_copy = df_target.copy()
    target_copy['fillingDate'] = target_copy['fillingDate'].astype(str)
    target_copy = target_copy.drop_duplicates(['symbol','fillingDate']).set_index(['symbol','fillingDate'])
    target_copy = target_copy.loc[target_copy.index.isin(index__.index)]
    
    assess_test_dict = dict()
    pred_test = model.predict(x_test)
    assess_test = pd.DataFrame(index = y_test.index)
    assess_test['Prediction'] = pred_test
    assess_test['Target'] = y_test
#     assess_test['returns'] = df_model.loc[df_model.index.isin(y_test.index),'futReturns']
    assess_test['excReturns'] = target_copy.loc[target_copy.index.isin(index__.index),'futAlpha']

    avg_returns = assess_test.groupby('Prediction').mean()[['excReturns']]


    from sklearn.metrics import roc_auc_score, precision_score, recall_score,accuracy_score
    auc  = roc_auc_score(assess_test['Target'],assess_test['Prediction'] )
    precision = precision_score(assess_test['Target'],assess_test['Prediction'] )
    recall =  recall_score(assess_test['Target'],assess_test['Prediction'] )
    acc =  accuracy_score(assess_test['Target'],assess_test['Prediction'] )
    
    assess_test_dict['accuracy'] = acc
    assess_test_dict['auc'] = auc
    assess_test_dict['precision'] = precision
    assess_test_dict['recall'] = recall
    return(assess_test_dict,assess_test)
# Out:
# Neural Network Parameters:
# Optimizer: <keras.optimizers.optimizer_experimental.rmsprop.RMSprop object at 0x0000027BC1E69970>
# Loss: <keras.losses.BinaryCrossentropy object at 0x0000027B9AB68790>
# Hidden Layer tructure: (50,)
# Acivation Functions: ['relu']
# Dropout: 0.3
# Class Weight: balanced
# Output Bias: None

# %% [markdown]
# __Final Models:__
# - Neural Network with MI subset
# - Light Gradient Booster with MI subset
# - Logistic Regression with MI subset

# %%
def assessModels (x_train,y_train,x_test,y_test,model_list, model_names,):
    import joblib
    #set path to store models
    model_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Models\Final Models\\'
    
    new_model_list = []
    test_assess_list = []
    
    full_assess = pd.DataFrame()
    full_assess_test = pd.DataFrame()
    predictions_df = pd.DataFrame()
    #iterate over the models and perform CV 
    for model, name in zip(model_list, model_names):
        assess = class_cv.validateModel(x_train,
                                        y_train,
                                        model=model ,
                                        scaler=True ,
                                        over_sampling=False,
                                        predictions=True,
                                        cv_type='stratKfold',
                                        scaler_type='stand',
                                        train_size=10,
                                        test_size=1,
                                        gap=0)
        

        #store scores
        assess_df = assess['scores']
        assess_df['model'] = name
        
        full_assess = pd.concat([full_assess,
                                assess_df],
                                axis=0)
        
        
        predictions = assess['predictions']
        predictions['model'] = name
        predictions_df = pd.concat([predictions_df,predictions],
                                axis=0)
        
        #store model 
        model = assess['model']
        new_model_list.append(model)
        
        
        new_model_name = name + '.pkl'
        # joblib.dump(model, f'{model_path}{new_model_name}', compress=9)
        
        if name =='LightGB':
            features = model.feature_name_
    
        elif name =='Keras_NN':
            features = features
        
        else:
            features = model.feature_names_in_
            
        
        scaler = assess['scaler']
        scale_features = scaler.get_feature_names_out()
    
        rest_ft =[]
        for ft in features:
            if ft not in scale_features:
                rest_ft.append(ft)
    
    
    
        # fit scaler on test set 
        X_test = pd.DataFrame(scaler.transform(x_test[scale_features]), 
                            index = x_test.index, 
                            columns = scale_features)
        
        X_test = pd.concat([X_test, x_test[rest_ft]],axis=1)
            
        
        X_test = X_test[features]
        
        assess_test_dict, assess_test_df = assessTest(X_test,
                                                    y_test,
                                                    model)
        assess_test_dict['model'] = name
        assess_test_df['model'] = name
        
        full_assess_test = pd.concat([full_assess_test,
                                assess_test_df],
                                axis=0)
        test_assess_list.append(assess_test_dict)
        
    test_assess_df = pd.DataFrame.from_records(test_assess_list)
    
    scaler_name = 'scaler.pkl'
    # joblib.dump(scaler, f'{model_path}{scaler_name}', compress=9)
    
    return(full_assess,test_assess_df,new_model_list ,predictions_df)

# %%
#set models

lgb_model = lgb.LGBMClassifier(boosting_type='dart',
                               class_weight='balanced',
                               learning_rate=0.2,
                               max_depth=2, 
                               n_estimators=50,
                               random_state=0)

lr_model = LogisticRegression(class_weight='balanced',
                              penalty=None,
                              random_state=0,
                   solver='newton-cholesky')


model_list = [lr_model, lgb_model,NNmodel]
model_names = ['LogisticRegression','DecisionTree','LightGB','Keras_NN']

full_assess,test_assess_df,new_model_list, predictions_df = assessModels(x_train_out[mi_subset_15],
                                                                         y_train_dict['Target_0.15'],
                                                                        x_test[mi_subset_15],
                                                                        y_test_dict['Target_0.15'],
                                                                        model_list[-2:],
                                                                        model_names[-2:])
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# accuracy_train     0.591603
# f1_train           0.333280
# recall_train       0.718406
# precision_train    0.216997
# auc_train          0.644508
# accuracy_test      0.588206
# f1_test            0.331821
# recall_test        0.699215
# precision_test     0.222205
# auc_test           0.634524
# dtype: float64
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# Epoch 1/15
# 530/555 [===========================>..] - ETA: 0s - loss: 0.6764 - auc: 0.6484 - recall: 0.6669 - precision: 0.2122WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 5s 7ms/step - loss: 0.6748 - auc: 0.6503 - recall: 0.6665 - precision: 0.2124 - val_loss: 0.6096 - val_auc: 0.6687 - val_recall: 0.4889 - val_precision: 0.2139
# Epoch 2/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6643 - auc: 0.6682 - recall: 0.6755 - precision: 0.2223WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6646 - auc: 0.6675 - recall: 0.6739 - precision: 0.2219 - val_loss: 0.6056 - val_auc: 0.6723 - val_recall: 0.5529 - val_precision: 0.2043
# Epoch 3/15
# 520/555 [===========================>..] - ETA: 0s - loss: 0.6592 - auc: 0.6728 - recall: 0.7079 - precision: 0.2174WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6592 - auc: 0.6744 - recall: 0.7104 - precision: 0.2183 - val_loss: 0.6033 - val_auc: 0.6755 - val_recall: 0.5814 - val_precision: 0.2021
# Epoch 4/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6545 - auc: 0.6782 - recall: 0.7311 - precision: 0.2177WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6551 - auc: 0.6783 - recall: 0.7306 - precision: 0.2180 - val_loss: 0.6028 - val_auc: 0.6773 - val_recall: 0.5967 - val_precision: 0.2032
# Epoch 5/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6528 - auc: 0.6826 - recall: 0.7449 - precision: 0.2174WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6521 - auc: 0.6828 - recall: 0.7441 - precision: 0.2171 - val_loss: 0.6036 - val_auc: 0.6786 - val_recall: 0.5389 - val_precision: 0.2083
# Epoch 6/15
# 519/555 [===========================>..] - ETA: 0s - loss: 0.6512 - auc: 0.6826 - recall: 0.7396 - precision: 0.2172WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6515 - auc: 0.6823 - recall: 0.7405 - precision: 0.2172 - val_loss: 0.6015 - val_auc: 0.6791 - val_recall: 0.5897 - val_precision: 0.2021
# Epoch 7/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6514 - auc: 0.6826 - recall: 0.7537 - precision: 0.2168WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6513 - auc: 0.6824 - recall: 0.7539 - precision: 0.2165 - val_loss: 0.6013 - val_auc: 0.6796 - val_recall: 0.5828 - val_precision: 0.2039
# Epoch 8/15
# 518/555 [===========================>..] - ETA: 0s - loss: 0.6486 - auc: 0.6845 - recall: 0.7506 - precision: 0.2146WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6496 - auc: 0.6849 - recall: 0.7511 - precision: 0.2157 - val_loss: 0.6014 - val_auc: 0.6806 - val_recall: 0.5911 - val_precision: 0.1998
# Epoch 9/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6491 - auc: 0.6864 - recall: 0.7495 - precision: 0.2175WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6491 - auc: 0.6863 - recall: 0.7498 - precision: 0.2175 - val_loss: 0.6001 - val_auc: 0.6805 - val_recall: 0.5821 - val_precision: 0.2044
# Epoch 10/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6493 - auc: 0.6858 - recall: 0.7490 - precision: 0.2174WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6484 - auc: 0.6868 - recall: 0.7513 - precision: 0.2176 - val_loss: 0.6022 - val_auc: 0.6813 - val_recall: 0.5563 - val_precision: 0.2059
# Epoch 11/15
# 530/555 [===========================>..] - ETA: 0s - loss: 0.6495 - auc: 0.6857 - recall: 0.7495 - precision: 0.2182WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6483 - auc: 0.6867 - recall: 0.7513 - precision: 0.2184 - val_loss: 0.6039 - val_auc: 0.6818 - val_recall: 0.5577 - val_precision: 0.2066
# Epoch 12/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6499 - auc: 0.6854 - recall: 0.7551 - precision: 0.2171WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6492 - auc: 0.6858 - recall: 0.7556 - precision: 0.2167 - val_loss: 0.6034 - val_auc: 0.6808 - val_recall: 0.5487 - val_precision: 0.2072
# Epoch 13/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6475 - auc: 0.6874 - recall: 0.7467 - precision: 0.2186WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6482 - auc: 0.6872 - recall: 0.7465 - precision: 0.2188 - val_loss: 0.6015 - val_auc: 0.6815 - val_recall: 0.5494 - val_precision: 0.2060
# Epoch 14/15
# 538/555 [============================>.] - ETA: 0s - loss: 0.6482 - auc: 0.6869 - recall: 0.7492 - precision: 0.2189WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6481 - auc: 0.6871 - recall: 0.7490 - precision: 0.2190 - val_loss: 0.6021 - val_auc: 0.6823 - val_recall: 0.5584 - val_precision: 0.2052
# Epoch 15/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6472 - auc: 0.6880 - recall: 0.7532 - precision: 0.2191WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6474 - auc: 0.6882 - recall: 0.7535 - precision: 0.2193 - val_loss: 0.6011 - val_auc: 0.6816 - val_recall: 0.5688 - val_precision: 0.2047
# 740/740 [==============================] - 1s 835us/step
# 83/83 [==============================] - 0s 944us/step
# 83/83 [==============================] - 0s 874us/step
# 83/83 [==============================] - 0s 888us/step
# Epoch 1/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6506 - auc: 0.6799 - recall: 0.7525 - precision: 0.2136WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 6ms/step - loss: 0.6512 - auc: 0.6799 - recall: 0.7524 - precision: 0.2138 - val_loss: 0.6028 - val_auc: 0.6831 - val_recall: 0.5584 - val_precision: 0.2067
# Epoch 2/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6513 - auc: 0.6812 - recall: 0.7592 - precision: 0.2159WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6516 - auc: 0.6808 - recall: 0.7581 - precision: 0.2157 - val_loss: 0.6008 - val_auc: 0.6830 - val_recall: 0.5584 - val_precision: 0.2077
# Epoch 3/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6509 - auc: 0.6801 - recall: 0.7544 - precision: 0.2131WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6514 - auc: 0.6802 - recall: 0.7547 - precision: 0.2136 - val_loss: 0.6015 - val_auc: 0.6830 - val_recall: 0.5709 - val_precision: 0.2072
# Epoch 4/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6501 - auc: 0.6804 - recall: 0.7633 - precision: 0.2133WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6510 - auc: 0.6808 - recall: 0.7626 - precision: 0.2139 - val_loss: 0.6000 - val_auc: 0.6829 - val_recall: 0.5682 - val_precision: 0.2064
# Epoch 5/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6515 - auc: 0.6813 - recall: 0.7615 - precision: 0.2155WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6505 - auc: 0.6814 - recall: 0.7615 - precision: 0.2149 - val_loss: 0.6050 - val_auc: 0.6830 - val_recall: 0.5181 - val_precision: 0.2135
# Epoch 6/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6499 - auc: 0.6829 - recall: 0.7482 - precision: 0.2167WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6506 - auc: 0.6817 - recall: 0.7484 - precision: 0.2160 - val_loss: 0.5982 - val_auc: 0.6829 - val_recall: 0.5855 - val_precision: 0.2038
# Epoch 7/15
# 534/555 [===========================>..] - ETA: 0s - loss: 0.6494 - auc: 0.6836 - recall: 0.7507 - precision: 0.2162WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6490 - auc: 0.6835 - recall: 0.7515 - precision: 0.2159 - val_loss: 0.6014 - val_auc: 0.6831 - val_recall: 0.5508 - val_precision: 0.2084
# Epoch 8/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6507 - auc: 0.6809 - recall: 0.7546 - precision: 0.2159WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6508 - auc: 0.6806 - recall: 0.7541 - precision: 0.2156 - val_loss: 0.6002 - val_auc: 0.6834 - val_recall: 0.5675 - val_precision: 0.2070
# Epoch 9/15
# 529/555 [===========================>..] - ETA: 0s - loss: 0.6495 - auc: 0.6826 - recall: 0.7515 - precision: 0.2149WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6503 - auc: 0.6824 - recall: 0.7520 - precision: 0.2158 - val_loss: 0.5998 - val_auc: 0.6835 - val_recall: 0.5702 - val_precision: 0.2062
# Epoch 10/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6513 - auc: 0.6799 - recall: 0.7520 - precision: 0.2147WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6501 - auc: 0.6818 - recall: 0.7558 - precision: 0.2155 - val_loss: 0.6039 - val_auc: 0.6834 - val_recall: 0.5563 - val_precision: 0.2091
# Epoch 11/15
# 522/555 [===========================>..] - ETA: 0s - loss: 0.6509 - auc: 0.6815 - recall: 0.7536 - precision: 0.2146WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6503 - auc: 0.6822 - recall: 0.7560 - precision: 0.2149 - val_loss: 0.6015 - val_auc: 0.6836 - val_recall: 0.5675 - val_precision: 0.2056
# Epoch 12/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6505 - auc: 0.6817 - recall: 0.7550 - precision: 0.2148WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6503 - auc: 0.6819 - recall: 0.7554 - precision: 0.2147 - val_loss: 0.6024 - val_auc: 0.6830 - val_recall: 0.5570 - val_precision: 0.2068
# Epoch 13/15
# 536/555 [===========================>..] - ETA: 0s - loss: 0.6501 - auc: 0.6813 - recall: 0.7547 - precision: 0.2152WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6501 - auc: 0.6818 - recall: 0.7554 - precision: 0.2155 - val_loss: 0.6003 - val_auc: 0.6829 - val_recall: 0.5640 - val_precision: 0.2068
# Epoch 14/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6496 - auc: 0.6828 - recall: 0.7562 - precision: 0.2153WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6496 - auc: 0.6825 - recall: 0.7560 - precision: 0.2152 - val_loss: 0.6013 - val_auc: 0.6830 - val_recall: 0.5682 - val_precision: 0.2051
# Epoch 15/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6499 - auc: 0.6807 - recall: 0.7630 - precision: 0.2141WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6502 - auc: 0.6806 - recall: 0.7632 - precision: 0.2143 - val_loss: 0.6014 - val_auc: 0.6825 - val_recall: 0.5633 - val_precision: 0.2058
# 740/740 [==============================] - 1s 829us/step
# 83/83 [==============================] - 0s 880us/step
# 83/83 [==============================] - 0s 934us/step
# 83/83 [==============================] - 0s 873us/step
# Epoch 1/15
# 542/555 [============================>.] - ETA: 0s - loss: 0.6419 - auc: 0.6986 - recall: 0.7632 - precision: 0.2235WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 6ms/step - loss: 0.6421 - auc: 0.6989 - recall: 0.7636 - precision: 0.2237 - val_loss: 0.6021 - val_auc: 0.6824 - val_recall: 0.5459 - val_precision: 0.2072
# Epoch 2/15
# 528/555 [===========================>..] - ETA: 0s - loss: 0.6399 - auc: 0.7003 - recall: 0.7487 - precision: 0.2261WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6414 - auc: 0.6987 - recall: 0.7464 - precision: 0.2258 - val_loss: 0.6008 - val_auc: 0.6824 - val_recall: 0.5535 - val_precision: 0.2051
# Epoch 3/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6416 - auc: 0.6975 - recall: 0.7522 - precision: 0.2235WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6411 - auc: 0.6990 - recall: 0.7532 - precision: 0.2242 - val_loss: 0.6043 - val_auc: 0.6825 - val_recall: 0.5313 - val_precision: 0.2078
# Epoch 4/15
# 521/555 [===========================>..] - ETA: 0s - loss: 0.6418 - auc: 0.6986 - recall: 0.7485 - precision: 0.2249WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6414 - auc: 0.6988 - recall: 0.7475 - precision: 0.2247 - val_loss: 0.6049 - val_auc: 0.6812 - val_recall: 0.5410 - val_precision: 0.2072
# Epoch 5/15
# 523/555 [===========================>..] - ETA: 0s - loss: 0.6414 - auc: 0.6991 - recall: 0.7606 - precision: 0.2247WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6409 - auc: 0.6989 - recall: 0.7619 - precision: 0.2242 - val_loss: 0.6061 - val_auc: 0.6822 - val_recall: 0.5146 - val_precision: 0.2090
# Epoch 6/15
# 552/555 [============================>.] - ETA: 0s - loss: 0.6414 - auc: 0.6990 - recall: 0.7515 - precision: 0.2236WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6415 - auc: 0.6992 - recall: 0.7518 - precision: 0.2240 - val_loss: 0.6014 - val_auc: 0.6820 - val_recall: 0.5570 - val_precision: 0.2058
# Epoch 7/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6403 - auc: 0.6996 - recall: 0.7556 - precision: 0.2247WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6404 - auc: 0.6993 - recall: 0.7562 - precision: 0.2249 - val_loss: 0.6039 - val_auc: 0.6820 - val_recall: 0.5403 - val_precision: 0.2074
# Epoch 8/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6402 - auc: 0.6997 - recall: 0.7460 - precision: 0.2250WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6402 - auc: 0.6997 - recall: 0.7460 - precision: 0.2250 - val_loss: 0.6011 - val_auc: 0.6820 - val_recall: 0.5682 - val_precision: 0.2032
# Epoch 9/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6409 - auc: 0.6998 - recall: 0.7535 - precision: 0.2253WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6409 - auc: 0.6998 - recall: 0.7534 - precision: 0.2252 - val_loss: 0.6024 - val_auc: 0.6825 - val_recall: 0.5626 - val_precision: 0.2040
# Epoch 10/15
# 522/555 [===========================>..] - ETA: 0s - loss: 0.6422 - auc: 0.6988 - recall: 0.7570 - precision: 0.2232WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6402 - auc: 0.7007 - recall: 0.7600 - precision: 0.2235 - val_loss: 0.6102 - val_auc: 0.6825 - val_recall: 0.5139 - val_precision: 0.2090
# Epoch 11/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6401 - auc: 0.7014 - recall: 0.7534 - precision: 0.2252WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6405 - auc: 0.7008 - recall: 0.7528 - precision: 0.2250 - val_loss: 0.6045 - val_auc: 0.6827 - val_recall: 0.5410 - val_precision: 0.2058
# Epoch 12/15
# 545/555 [============================>.] - ETA: 0s - loss: 0.6411 - auc: 0.7002 - recall: 0.7526 - precision: 0.2251WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6408 - auc: 0.7003 - recall: 0.7526 - precision: 0.2248 - val_loss: 0.6033 - val_auc: 0.6817 - val_recall: 0.5376 - val_precision: 0.2068
# Epoch 13/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6410 - auc: 0.6992 - recall: 0.7565 - precision: 0.2235WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6411 - auc: 0.6991 - recall: 0.7568 - precision: 0.2236 - val_loss: 0.6041 - val_auc: 0.6818 - val_recall: 0.5410 - val_precision: 0.2075
# Epoch 14/15
# 549/555 [============================>.] - ETA: 0s - loss: 0.6411 - auc: 0.6994 - recall: 0.7397 - precision: 0.2247WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6409 - auc: 0.7002 - recall: 0.7416 - precision: 0.2254 - val_loss: 0.6034 - val_auc: 0.6822 - val_recall: 0.5563 - val_precision: 0.2042
# Epoch 15/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6414 - auc: 0.6993 - recall: 0.7598 - precision: 0.2246WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6413 - auc: 0.6994 - recall: 0.7600 - precision: 0.2245 - val_loss: 0.6061 - val_auc: 0.6819 - val_recall: 0.5188 - val_precision: 0.2072
# 740/740 [==============================] - 1s 915us/step
# 83/83 [==============================] - 0s 884us/step
# 83/83 [==============================] - 0s 903us/step
# 83/83 [==============================] - 0s 850us/step
# Epoch 1/15
# 527/555 [===========================>..] - ETA: 0s - loss: 0.6464 - auc: 0.6908 - recall: 0.7502 - precision: 0.2214WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 6ms/step - loss: 0.6453 - auc: 0.6928 - recall: 0.7527 - precision: 0.2219 - val_loss: 0.6069 - val_auc: 0.6822 - val_recall: 0.5250 - val_precision: 0.2093
# Epoch 2/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6458 - auc: 0.6931 - recall: 0.7431 - precision: 0.2238WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6458 - auc: 0.6932 - recall: 0.7433 - precision: 0.2239 - val_loss: 0.6019 - val_auc: 0.6828 - val_recall: 0.5501 - val_precision: 0.2049
# Epoch 3/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6442 - auc: 0.6946 - recall: 0.7448 - precision: 0.2222WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6442 - auc: 0.6946 - recall: 0.7450 - precision: 0.2223 - val_loss: 0.6028 - val_auc: 0.6826 - val_recall: 0.5389 - val_precision: 0.2068
# Epoch 4/15
# 526/555 [===========================>..] - ETA: 0s - loss: 0.6445 - auc: 0.6947 - recall: 0.7374 - precision: 0.2235WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6448 - auc: 0.6947 - recall: 0.7372 - precision: 0.2240 - val_loss: 0.6033 - val_auc: 0.6830 - val_recall: 0.5723 - val_precision: 0.2046
# Epoch 5/15
# 522/555 [===========================>..] - ETA: 0s - loss: 0.6444 - auc: 0.6967 - recall: 0.7404 - precision: 0.2243WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6438 - auc: 0.6958 - recall: 0.7402 - precision: 0.2232 - val_loss: 0.6049 - val_auc: 0.6836 - val_recall: 0.5278 - val_precision: 0.2069
# Epoch 6/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6443 - auc: 0.6951 - recall: 0.7460 - precision: 0.2228WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6448 - auc: 0.6955 - recall: 0.7474 - precision: 0.2238 - val_loss: 0.6027 - val_auc: 0.6841 - val_recall: 0.5619 - val_precision: 0.2050
# Epoch 7/15
# 522/555 [===========================>..] - ETA: 0s - loss: 0.6446 - auc: 0.6966 - recall: 0.7465 - precision: 0.2251WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6434 - auc: 0.6961 - recall: 0.7473 - precision: 0.2233 - val_loss: 0.6022 - val_auc: 0.6833 - val_recall: 0.5250 - val_precision: 0.2095
# Epoch 8/15
# 537/555 [============================>.] - ETA: 0s - loss: 0.6428 - auc: 0.6962 - recall: 0.7432 - precision: 0.2244WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6434 - auc: 0.6967 - recall: 0.7431 - precision: 0.2254 - val_loss: 0.6016 - val_auc: 0.6845 - val_recall: 0.5793 - val_precision: 0.2038
# Epoch 9/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6431 - auc: 0.6967 - recall: 0.7424 - precision: 0.2249WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6431 - auc: 0.6966 - recall: 0.7420 - precision: 0.2248 - val_loss: 0.6025 - val_auc: 0.6838 - val_recall: 0.5542 - val_precision: 0.2061
# Epoch 10/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6443 - auc: 0.6956 - recall: 0.7472 - precision: 0.2231WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6437 - auc: 0.6967 - recall: 0.7486 - precision: 0.2237 - val_loss: 0.6073 - val_auc: 0.6846 - val_recall: 0.5327 - val_precision: 0.2113
# Epoch 11/15
# 551/555 [============================>.] - ETA: 0s - loss: 0.6423 - auc: 0.6972 - recall: 0.7332 - precision: 0.2244WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6425 - auc: 0.6973 - recall: 0.7332 - precision: 0.2247 - val_loss: 0.6031 - val_auc: 0.6844 - val_recall: 0.5772 - val_precision: 0.2065
# Epoch 12/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6426 - auc: 0.6992 - recall: 0.7461 - precision: 0.2262WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6427 - auc: 0.6982 - recall: 0.7442 - precision: 0.2252 - val_loss: 0.6026 - val_auc: 0.6837 - val_recall: 0.5445 - val_precision: 0.2080
# Epoch 13/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6432 - auc: 0.6969 - recall: 0.7382 - precision: 0.2248WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6428 - auc: 0.6977 - recall: 0.7389 - precision: 0.2252 - val_loss: 0.6052 - val_auc: 0.6837 - val_recall: 0.5508 - val_precision: 0.2087
# Epoch 14/15
# 542/555 [============================>.] - ETA: 0s - loss: 0.6426 - auc: 0.6974 - recall: 0.7324 - precision: 0.2232WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6434 - auc: 0.6978 - recall: 0.7338 - precision: 0.2241 - val_loss: 0.6016 - val_auc: 0.6840 - val_recall: 0.5932 - val_precision: 0.2039
# Epoch 15/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6429 - auc: 0.6975 - recall: 0.7436 - precision: 0.2243WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6427 - auc: 0.6977 - recall: 0.7444 - precision: 0.2239 - val_loss: 0.6027 - val_auc: 0.6843 - val_recall: 0.5640 - val_precision: 0.2081
# 740/740 [==============================] - 1s 926us/step
# 83/83 [==============================] - 0s 914us/step
# 83/83 [==============================] - 0s 905us/step
# 83/83 [==============================] - 0s 951us/step
# Epoch 1/15
# 545/555 [============================>.] - ETA: 0s - loss: 0.6605 - auc: 0.6660 - recall: 0.7599 - precision: 0.2084WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6601 - auc: 0.6668 - recall: 0.7609 - precision: 0.2086 - val_loss: 0.6030 - val_auc: 0.6815 - val_recall: 0.5508 - val_precision: 0.2078
# Epoch 2/15
# 537/555 [============================>.] - ETA: 0s - loss: 0.6578 - auc: 0.6684 - recall: 0.7630 - precision: 0.2091WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6590 - auc: 0.6676 - recall: 0.7618 - precision: 0.2092 - val_loss: 0.5986 - val_auc: 0.6829 - val_recall: 0.6050 - val_precision: 0.1997
# Epoch 3/15
# 524/555 [===========================>..] - ETA: 0s - loss: 0.6598 - auc: 0.6676 - recall: 0.7672 - precision: 0.2083WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6588 - auc: 0.6685 - recall: 0.7679 - precision: 0.2083 - val_loss: 0.6012 - val_auc: 0.6823 - val_recall: 0.5675 - val_precision: 0.2034
# Epoch 4/15
# 532/555 [===========================>..] - ETA: 0s - loss: 0.6579 - auc: 0.6685 - recall: 0.7663 - precision: 0.2077WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6584 - auc: 0.6686 - recall: 0.7654 - precision: 0.2083 - val_loss: 0.6000 - val_auc: 0.6817 - val_recall: 0.5946 - val_precision: 0.2032
# Epoch 5/15
# 554/555 [============================>.] - ETA: 0s - loss: 0.6573 - auc: 0.6697 - recall: 0.7706 - precision: 0.2094WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6572 - auc: 0.6697 - recall: 0.7707 - precision: 0.2094 - val_loss: 0.6020 - val_auc: 0.6811 - val_recall: 0.5682 - val_precision: 0.2030
# Epoch 6/15
# 521/555 [===========================>..] - ETA: 0s - loss: 0.6576 - auc: 0.6694 - recall: 0.7703 - precision: 0.2081WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6578 - auc: 0.6703 - recall: 0.7696 - precision: 0.2083 - val_loss: 0.6007 - val_auc: 0.6808 - val_recall: 0.5946 - val_precision: 0.2013
# Epoch 7/15
# 522/555 [===========================>..] - ETA: 0s - loss: 0.6592 - auc: 0.6691 - recall: 0.7762 - precision: 0.2101WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6577 - auc: 0.6693 - recall: 0.7755 - precision: 0.2089 - val_loss: 0.6031 - val_auc: 0.6808 - val_recall: 0.5431 - val_precision: 0.2067
# Epoch 8/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6576 - auc: 0.6700 - recall: 0.7625 - precision: 0.2097WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6581 - auc: 0.6699 - recall: 0.7626 - precision: 0.2101 - val_loss: 0.5992 - val_auc: 0.6808 - val_recall: 0.6245 - val_precision: 0.1993
# Epoch 9/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6573 - auc: 0.6699 - recall: 0.7627 - precision: 0.2090WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6570 - auc: 0.6712 - recall: 0.7628 - precision: 0.2103 - val_loss: 0.6039 - val_auc: 0.6804 - val_recall: 0.5723 - val_precision: 0.2027
# Epoch 10/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6573 - auc: 0.6709 - recall: 0.7698 - precision: 0.2080WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6573 - auc: 0.6709 - recall: 0.7698 - precision: 0.2080 - val_loss: 0.6061 - val_auc: 0.6798 - val_recall: 0.5299 - val_precision: 0.2047
# Epoch 11/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6555 - auc: 0.6728 - recall: 0.7542 - precision: 0.2101WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6563 - auc: 0.6723 - recall: 0.7535 - precision: 0.2101 - val_loss: 0.5997 - val_auc: 0.6800 - val_recall: 0.6217 - val_precision: 0.2001
# Epoch 12/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6580 - auc: 0.6713 - recall: 0.7704 - precision: 0.2092WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6577 - auc: 0.6709 - recall: 0.7702 - precision: 0.2088 - val_loss: 0.6012 - val_auc: 0.6789 - val_recall: 0.5744 - val_precision: 0.2021
# Epoch 13/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6572 - auc: 0.6716 - recall: 0.7594 - precision: 0.2092WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6572 - auc: 0.6719 - recall: 0.7598 - precision: 0.2096 - val_loss: 0.6023 - val_auc: 0.6795 - val_recall: 0.5855 - val_precision: 0.2021
# Epoch 14/15
# 555/555 [==============================] - ETA: 0s - loss: 0.6567 - auc: 0.6714 - recall: 0.7582 - precision: 0.2101WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6567 - auc: 0.6714 - recall: 0.7582 - precision: 0.2101 - val_loss: 0.6028 - val_auc: 0.6797 - val_recall: 0.6057 - val_precision: 0.1998
# Epoch 15/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6574 - auc: 0.6727 - recall: 0.7599 - precision: 0.2090WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6576 - auc: 0.6726 - recall: 0.7611 - precision: 0.2091 - val_loss: 0.6005 - val_auc: 0.6800 - val_recall: 0.5828 - val_precision: 0.2014
# 740/740 [==============================] - 1s 857us/step
# 83/83 [==============================] - 0s 1ms/step
# 83/83 [==============================] - 0s 1ms/step
# 83/83 [==============================] - 0s 975us/step
# Epoch 1/15
# ...
# Epoch 7/15
# 533/555 [===========================>..] - ETA: 0s - loss: 0.6662 - auc: 0.6760 - recall: 0.7858 - precision: 0.2149WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6653 - auc: 0.6768 - recall: 0.7871 - precision: 0.2145 - val_loss: 0.5433 - val_auc: 0.7030 - val_recall: 0.5648 - val_precision: 0.1917
# Epoch 8/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6660 - auc: 0.6762 - recall: 0.7821 - precision: 0.2130WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6661 - auc: 0.6769 - recall: 0.7824 - precision: 0.2135 - val_loss: 0.5432 - val_auc: 0.7026 - val_recall: 0.5764 - val_precision: 0.1895
# Epoch 9/15
# 539/555 [============================>.] - ETA: 0s - loss: 0.6631 - auc: 0.6773 - recall: 0.7816 - precision: 0.2135WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6649 - auc: 0.6774 - recall: 0.7816 - precision: 0.2142 - val_loss: 0.5439 - val_auc: 0.7030 - val_recall: 0.5896 - val_precision: 0.1886
# Epoch 10/15
# 541/555 [============================>.] - ETA: 0s - loss: 0.6656 - auc: 0.6782 - recall: 0.7880 - precision: 0.2145WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6648 - auc: 0.6778 - recall: 0.7874 - precision: 0.2137 - val_loss: 0.5436 - val_auc: 0.7028 - val_recall: 0.5714 - val_precision: 0.1900
# Epoch 11/15
# 547/555 [============================>.] - ETA: 0s - loss: 0.6647 - auc: 0.6785 - recall: 0.7816 - precision: 0.2142WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6652 - auc: 0.6778 - recall: 0.7802 - precision: 0.2138 - val_loss: 0.5436 - val_auc: 0.7027 - val_recall: 0.6045 - val_precision: 0.1875
# Epoch 12/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6653 - auc: 0.6779 - recall: 0.7853 - precision: 0.2142WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6649 - auc: 0.6776 - recall: 0.7845 - precision: 0.2135 - val_loss: 0.5451 - val_auc: 0.7019 - val_recall: 0.5500 - val_precision: 0.1928
# Epoch 13/15
# 526/555 [===========================>..] - ETA: 0s - loss: 0.6668 - auc: 0.6760 - recall: 0.7834 - precision: 0.2148WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6656 - auc: 0.6765 - recall: 0.7838 - precision: 0.2147 - val_loss: 0.5432 - val_auc: 0.7023 - val_recall: 0.5764 - val_precision: 0.1895
# Epoch 14/15
# 548/555 [============================>.] - ETA: 0s - loss: 0.6650 - auc: 0.6770 - recall: 0.7836 - precision: 0.2146WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6648 - auc: 0.6772 - recall: 0.7836 - precision: 0.2145 - val_loss: 0.5439 - val_auc: 0.7026 - val_recall: 0.6061 - val_precision: 0.1859
# Epoch 15/15
# 546/555 [============================>.] - ETA: 0s - loss: 0.6640 - auc: 0.6781 - recall: 0.7906 - precision: 0.2138WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6643 - auc: 0.6778 - recall: 0.7902 - precision: 0.2140 - val_loss: 0.5433 - val_auc: 0.7028 - val_recall: 0.5500 - val_precision: 0.1935
# 740/740 [==============================] - 1s 799us/step
# 83/83 [==============================] - 0s 831us/step
# 83/83 [==============================] - 0s 875us/step
# 83/83 [==============================] - 0s 848us/step
# Epoch 1/15
# 544/555 [============================>.] - ETA: 0s - loss: 0.6655 - auc: 0.6769 - recall: 0.7817 - precision: 0.2133WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 4s 7ms/step - loss: 0.6655 - auc: 0.6771 - recall: 0.7818 - precision: 0.2135 - val_loss: 0.5475 - val_auc: 0.6966 - val_recall: 0.6028 - val_precision: 0.1854
# Epoch 2/15
# 543/555 [============================>.] - ETA: 0s - loss: 0.6661 - auc: 0.6765 - recall: 0.7762 - precision: 0.2148WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6655 - auc: 0.6767 - recall: 0.7764 - precision: 0.2147 - val_loss: 0.5472 - val_auc: 0.6962 - val_recall: 0.6094 - val_precision: 0.1833
# Epoch 3/15
# 522/555 [===========================>..] - ETA: 0s - loss: 0.6664 - auc: 0.6780 - recall: 0.7827 - precision: 0.2147WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6648 - auc: 0.6784 - recall: 0.7836 - precision: 0.2143 - val_loss: 0.5470 - val_auc: 0.6958 - val_recall: 0.5945 - val_precision: 0.1860
# Epoch 4/15
# 525/555 [===========================>..] - ETA: 0s - loss: 0.6659 - auc: 0.6770 - recall: 0.7784 - precision: 0.2149WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6654 - auc: 0.6774 - recall: 0.7789 - precision: 0.2152 - val_loss: 0.5473 - val_auc: 0.6961 - val_recall: 0.6152 - val_precision: 0.1820
# Epoch 5/15
# 550/555 [============================>.] - ETA: 0s - loss: 0.6641 - auc: 0.6776 - recall: 0.7885 - precision: 0.2142WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6647 - auc: 0.6772 - recall: 0.7882 - precision: 0.2143 - val_loss: 0.5486 - val_auc: 0.6950 - val_recall: 0.6218 - val_precision: 0.1810
# Epoch 6/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6668 - auc: 0.6766 - recall: 0.7898 - precision: 0.2149WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6654 - auc: 0.6774 - recall: 0.7905 - precision: 0.2144 - val_loss: 0.5475 - val_auc: 0.6956 - val_recall: 0.6069 - val_precision: 0.1836
# Epoch 7/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6663 - auc: 0.6762 - recall: 0.7838 - precision: 0.2145WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6658 - auc: 0.6768 - recall: 0.7854 - precision: 0.2143 - val_loss: 0.5476 - val_auc: 0.6966 - val_recall: 0.6160 - val_precision: 0.1820
# Epoch 8/15
# 535/555 [===========================>..] - ETA: 0s - loss: 0.6649 - auc: 0.6768 - recall: 0.7808 - precision: 0.2138WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6646 - auc: 0.6781 - recall: 0.7818 - precision: 0.2147 - val_loss: 0.5473 - val_auc: 0.6962 - val_recall: 0.6119 - val_precision: 0.1820
# Epoch 9/15
# 553/555 [============================>.] - ETA: 0s - loss: 0.6639 - auc: 0.6784 - recall: 0.7803 - precision: 0.2149WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6639 - auc: 0.6784 - recall: 0.7807 - precision: 0.2151 - val_loss: 0.5490 - val_auc: 0.6963 - val_recall: 0.6367 - val_precision: 0.1813
# Epoch 10/15
# 540/555 [============================>.] - ETA: 0s - loss: 0.6657 - auc: 0.6785 - recall: 0.7893 - precision: 0.2150WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6647 - auc: 0.6781 - recall: 0.7887 - precision: 0.2140 - val_loss: 0.5477 - val_auc: 0.6963 - val_recall: 0.6135 - val_precision: 0.1809
# Epoch 11/15
# 526/555 [===========================>..] - ETA: 0s - loss: 0.6641 - auc: 0.6794 - recall: 0.7843 - precision: 0.2139WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6653 - auc: 0.6785 - recall: 0.7833 - precision: 0.2141 - val_loss: 0.5487 - val_auc: 0.6962 - val_recall: 0.6441 - val_precision: 0.1801
# Epoch 12/15
# 536/555 [===========================>..] - ETA: 0s - loss: 0.6656 - auc: 0.6770 - recall: 0.7853 - precision: 0.2141WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6647 - auc: 0.6771 - recall: 0.7849 - precision: 0.2137 - val_loss: 0.5476 - val_auc: 0.6958 - val_recall: 0.5945 - val_precision: 0.1849
# Epoch 13/15
# 549/555 [============================>.] - ETA: 0s - loss: 0.6650 - auc: 0.6773 - recall: 0.7827 - precision: 0.2143WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6650 - auc: 0.6773 - recall: 0.7822 - precision: 0.2143 - val_loss: 0.5477 - val_auc: 0.6960 - val_recall: 0.6168 - val_precision: 0.1800
# Epoch 14/15
# 523/555 [===========================>..] - ETA: 0s - loss: 0.6641 - auc: 0.6784 - recall: 0.7822 - precision: 0.2147WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6656 - auc: 0.6773 - recall: 0.7809 - precision: 0.2147 - val_loss: 0.5491 - val_auc: 0.6961 - val_recall: 0.6408 - val_precision: 0.1795
# Epoch 15/15
# 531/555 [===========================>..] - ETA: 0s - loss: 0.6664 - auc: 0.6772 - recall: 0.7891 - precision: 0.2142WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 555/555 [==============================] - 1s 2ms/step - loss: 0.6653 - auc: 0.6779 - recall: 0.7907 - precision: 0.2142 - val_loss: 0.5477 - val_auc: 0.6959 - val_recall: 0.5970 - val_precision: 0.1848
# 740/740 [==============================] - 1s 894us/step
# 83/83 [==============================] - 0s 863us/step
# 83/83 [==============================] - 0s 849us/step
# 83/83 [==============================] - 0s 817us/step
# accuracy_train     0.590174
# f1_train           0.330638
# recall_train       0.712319
# precision_train    0.215360
# auc_train          0.641136
# accuracy_test      0.587122
# f1_test            0.328931
# recall_test        0.692668
# precision_test     0.220980
# auc_test           0.631163
# dtype: float64
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\rafae\AppData\Local\Temp\tmpks4tjvpi\assets
# INFO:tensorflow:Assets written to: C:\Users\rafae\AppData\Local\Temp\tmpks4tjvpi\assets
# 312/312 [==============================] - 0s 915us/step

# %% [markdown]
# #### Train NN with Random Under Sampling

# %%
# import imblearn.under_sampling as underSample
from sklearn.neural_network import MLPClassifier
import joblib

model_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Models\Final Models\\'
name = 'MLP'

#set NN model
nn_model = MLPClassifier(activation='logistic', batch_size=512, learning_rate='invscaling',
              learning_rate_init=0.1, max_iter=10, random_state=0,
              solver='sgd')

assess = class_cv.validateModel(x_train_out[mi_subset_15],
                                y_train_dict['Target_0.15'],
                                model=nn_model ,
                                scaler=True ,
                                over_sampling=False,
                                under_sampling=True,
                                predictions=True,
                                cv_type='stratKfold',
                                scaler_type='stand',
                                train_size=10,
                                test_size=1,
                                gap=0)

#store scores
assess_df = assess['scores']
assess_df['model'] = name

#store model 
model = assess['model']
new_model_list.append(model)

predictions = assess['predictions']
predictions['model'] = name

predictions_df = pd.concat([predictions_df,predictions],
                                axis=0)
        

new_model_name = name + '.pkl'
joblib.dump(model, f'{model_path}{new_model_name}', compress=9)
        
scaler = assess['scaler']

if name =='LightGB':
        features = model.feature_name_
        
else:
    features = model.feature_names_in_
scale_features = scaler.get_feature_names_out()
 
rest_ft =[]
for ft in features:
    if ft not in scale_features:
        rest_ft.append(ft)

full_assess = pd.concat([full_assess,
                            assess_df],
                        axis=0)

#fit scaler on test set 
X_test = pd.DataFrame(scaler.transform(x_test[scale_features]), 
                        index = x_test.index, 
                        columns = scale_features)

X_test = pd.concat([X_test, x_test[rest_ft]],axis=1)
X_test = X_test[features]

assess_test_dict, assess_test_df = assessTest(X_test,
                                                y_test_dict['Target_0.15'],
                                                model)
assess_test_dict['model'] = name
assess_test_df['model'] = name
# Out:
# stratKfold
# Nr of splits: 10
# Scalling will be performed at each iteration
# Scaler type: stand
# Undersampling will be performed:
# Strategy: Random Undersampling
# accuracy_train     0.627948
# f1_train           0.631862
# recall_train       0.638573
# precision_train    0.625298
# auc_train          0.627948
# accuracy_test      0.622199
# f1_test            0.327299
# recall_test        0.633321
# precision_test     0.223933
# auc_test           0.626841
# dtype: float64

# %%
#store cross validation predictions
# predictions_df.to_csv(r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Models\Final Models\ValidationPredictions\crossValiidationPredictions.csv')
# full_assess_test.to_csv(r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_0\Models\Final Models\TestPredictions\crossValidation_Preictions.csv')

# %%
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Validation\Full_Validation\full_CV_results_Lasso.csv'
full_assess.to_csv(path)

# %% [markdown]
# #### Display Training and Valdation Results

# %% [markdown]
# Export average scores from the Cross Validation

# %%
train_val_scores = t_.groupby('model').mean()
cols_ = train_val_scores.columns[train_val_scores.columns.str.contains('test')]
for col in cols_:
    
    new_col = col.replace('test','val')
    train_val_scores = train_val_scores.rename(columns = {col:new_col})
    
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Validation\modelMetricPerfomance_Target_0.15_valSet_MI.csv'
train_val_scores.to_csv(assess_path)
display(train_val_scores)
# Out:
#                     Unnamed: 0  accuracy_train  f1_train  recall_train  \
# model
# DecisionTree              14.5        0.591404  0.336879      0.729819
# Keras_NN                   NaN        0.590174  0.330638      0.712319
# LightGB                   24.5        0.591603  0.333280      0.718406
# LogisticRegression         4.5        0.631387  0.329061      0.636266
# MLP                       34.5        0.627948  0.631862      0.638573
#
#                     precision_train  auc_train  accuracy_val    f1_val  \
# model
# DecisionTree               0.219233   0.649154      0.580179  0.319157
# Keras_NN                   0.215360   0.641136      0.587122  0.328931
# LightGB                    0.216997   0.644508      0.588206  0.331821
# LogisticRegression         0.221928   0.633423      0.626555  0.327712
# MLP                        0.625298   0.627948      0.622199  0.327299
#
#                     recall_val  precision_val   auc_val
# model
# DecisionTree          0.678174       0.211697  0.621065
# Keras_NN              0.692668       0.220980  0.631163
# LightGB               0.699215       0.222205  0.634524
# LogisticRegression    0.623417       0.228353  0.625248
# MLP                   0.633321       0.223933  0.626841

# %% [markdown]
# Export scores on test set

# %%
test_assess_df.loc[test_assess_df['model']=='Keras_NN','model'] = 'NeuralNetwork'

# %%
assess_path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15\Test\modelMetricPerfomance_Target_0.15_testSet_MI.csv'
t = pd.read_csv(assess_path).iloc[:-1]

# %% [markdown]
# #### ROC Curve Comparison

# %%
import DataScalling as scalling
model_names = ['LogisticRegression','DecisionTree','LightGB','MLP']
roc_curve(models = new_model_list,
                       names = model_names, 
                       X_train = X_test[features],
                       y_train  = X_test,
                       X_val = X_test[features],
                       y_val= y_test)

title = 'Model Perfomance Comparison - ROC Curve - Test Set - Target 0.15'
plt.title(title, 
          size = 15)
path = r'D:\Utilitários\Facul\Mestrado\2o Ano\Research\Thesis\Tables\Target_15'
name_plot = f'{path}\\{title} - MI.png'
plt.tight_layout()
plt.savefig(name_plot, dpi=300)
